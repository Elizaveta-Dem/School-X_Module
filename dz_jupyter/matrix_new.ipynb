# %%
# %pip install -Uq numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
np.matrix
# Out:
# numpy.matrix

# %%
class Matrix:
    def __init__(self, matrix):
        self.matrix = matrix

    def __len__(self):
        return len(self.matrix)

    # def dimensions(self):
    #     rows = len(self.matrix)
    #     columns = len(self.matrix[0]) if rows > 0 else 0
    #     return rows, columns


    # #метод который не зависит от объекта класса
    # @staticmethod 
    # def is_dimensions(matrix1, other_matrix):
    #     return len(matrix1.matrix) == len(other_matrix.matrix) and len(matrix1.matrix[0]) == len(other_matrix.matrix[0]) #сначала сравниваем строки потом столбцы


    # def __eq__(self, other_matrix):
    #     return self.is_dimensions(self, other_matrix) and all(
    #         self.matrix[i][j] == other_matrix.matrix[i][j]
    #         for i in range(len(self))
    #         for j in range(len(self.matrix[i]))
    # #     )


    # def __repr__(self):
    #     return repr(self.matrix)


    # def __add__(self, other_matrix):
    #     new_matrix = []
    #     if isinstance(other_matrix, int) or isinstance(other_matrix, float):
    #         for row in self.matrix:
    #             new_matrix.append([])
    #             for col in row:
    #                 new_matrix[-1].append(col + other_matrix)
    #     else:
    #         for row in zip(self.matrix, other_matrix.matrix):
    #             new_matrix.append([])
    #             for i in range(len(row[0])):
    #                 new_matrix[-1].append(row[0][i] + row[1][i])
    #     return Matrix(new_matrix)


    #сложение матрицы с числом:
    def __add__(self,other):
        #список для результата сложения:
        result_func = [

        ]
        #проверяем числа на вход:
        if isinstance(other, int) or isinstance(other, float):
            #цикл, чтобы прогнаться по рядам матрицы:
            for row in range(len(self.matrix)):
                #список для матрицы, которая получится в результате сложения:
                new_matrix = [

                ]
                #после прогона по рядам, нужно пройтись по столбцам матрицы, начиная с 1 элемента матрицы:
                for column in range(len(self.matrix[0])):
                    #складываем матрицу с числом
                    new_matrix.append(self.matrix[row][column] + other)
                #нужно записать результат сложения
                result_func.append(new_matrix)

        else:
            #цикл, чтобы прогнаться по рядам матрицы:
            for row in range(len(self.matrix)):
                #список для матрицы, которая получится в результате сложения:
                new_matrix = [

                ]
                #после прогона по рядам, нужно пройтись по столбцам матрицы, начиная с 1 элемента матрицы:
                for column in range(len(self.matrix[0])):
                    #складываем матрицу с матрицей
                    new_matrix.append(self.matrix[row][column] + other.matrix[row][column])
                #нужно записать результат сложения
                result_func.append(new_matrix)
        return Matrix(result_func)


    # def __sub__(self, other):
    #         new_matrix = []
    #         if isinstance(other, int) or isinstance(other, float):
    #             for row in self.matrix:
    #                 new_matrix.append([])
    #                 for col in row:
    #                     new_matrix[-1].append(col-other)
    #         else:
    #             if not self.is_dimensions(self, other):
    #                 raise ValueError("Матрицы не одинаковой размерности")
    #             for row in zip(self.matrix, other.matrix):
    #                 new_matrix.append([])
    #                 for i in range(len(row[0])):
    #                     new_matrix[-1].append(row[0][i]-row[1][i])
    #         return Matrix(new_matrix)


    #вычитание из матрицы числа, работает по такому же принципу что и сложение:
    def __sub__(self,other):
        #список для результата вычитания:
        result_func = [

        ]
        #проверяем числа на вход:
        if isinstance(other, int) or isinstance(other, float):
            #цикл, чтобы прогнаться по рядам матрицы:
            for row in range(len(self.matrix)):
                #список для матрицы, которая получится в результате вычитания:
                new_matrix = [

                ]
                #после прогона по рядам, нужно пройтись по столбцам матрицы, начиная с 1 элемента матрицы:
                for column in range(len(self.matrix[0])):
                    #вычитаем из матрицы число
                    new_matrix.append(self.matrix[row][column] - other)
                #нужно записать результат вычитания
                result_func.append(new_matrix)

        else:
            #цикл, чтобы прогнаться по рядам матрицы:
            for row in range(len(self.matrix)):
                #список для матрицы, которая получится в результате вычитания:
                new_matrix = [

                ]
                #после прогона по рядам, нужно пройтись по столбцам матрицы, начиная с 1 элемента матрицы:
                for column in range(len(self.matrix[0])):
                    #вычитаем из матрицы матрицу
                    new_matrix.append(self.matrix[row][column] - other.matrix[row][column])
                #нужно записать результат вычитания
                result_func.append(new_matrix)
        return Matrix(result_func)


    # def __mul__(self, other_matrix):    
    #         result = []
    #         if isinstance(other_matrix, int) or isinstance(other_matrix, float):
    #             for i in self.matrix:
    #                 result.append([])
    #                 for j in i:
    #                     result[-1].append(j*other_matrix)
    #         else:
    #             rows, columns = self.dimensions()
    #             other_rows, other_columns = other_matrix.dimensions()
    #             if columns != other_rows:
    #                 raise ValueError("Матрицы не одинаковой размерности")
    #             if not self.is_dimensions(self, other_matrix):
    #                 raise ValueError("Матрицы не одинаковой размерности")
    #             for row in zip(self.matrix, other_matrix.matrix):
    #                 result.append([])
    #                 for i in range(len(row[0])):
    #                     result[-1].append(row[0][i]*row[1][i])
    #         return Matrix(result)


    # умножение матрицы на число:
    def __mul__(self,other):
        #список для результата вычитания:
        result_func = [

        ]
        #проверяем числа на вход:
        if isinstance(other, int) or isinstance(other, float):
            #цикл, чтобы прогнаться по рядам матрицы:
            for row in range(len(self.matrix)):
                #список для матрицы, которая получится в результате умножения:
                new_matrix = [

                ]
                #после прогона по рядам, нужно пройтись по столбцам матрицы, начиная с 1 элемента матрицы:
                for column in range(len(self.matrix[0])):
                    #умножаем матрицу на число
                    new_matrix.append(self.matrix[row][column] * other)
                #нужно записать результат умножения
                result_func.append(new_matrix)

        else:
            #цикл, чтобы прогнаться по рядам матрицы:
            for row in range(len(self.matrix)):
                #список для матрицы, которая получится в результате умножения:
                new_matrix = [

                ]
                #после прогона по рядам, нужно пройтись по столбцам матрицы, начиная с 1 элемента матрицы:
                for column in range(len(self.matrix[0])):
                    #умножаем матрицу на матрицу
                    new_matrix.append(self.matrix[row][column] * other.matrix[row][column])
                #нужно записать результат умножения
                result_func.append(new_matrix)
        return Matrix(result_func)

    # def __truediv__(self, other_matrix):
    #     result = []
    #     if isinstance(other_matrix, int) or isinstance(other_matrix, float):
    #         for row in self.matrix:
    #             result.append([])
    #             for col in row:
    #                 result[-1].append(col/other_matrix)
    #     else:
    #         if not self.is_dimensions(self, other_matrix):
    #             raise ValueError("Матрицы не одинаковой размерности")

    #         result = [
    #             [self.matrix[i][j] / other_matrix.matrix[i][j] for j in range(len(self.matrix[i]))]
    #             for i in range(len(self.matrix))
    #         ]

    #     return Matrix(result)

    #деление матрицы на число:
    def __truediv__(self,other):
        #список для результата деления:
        result_func = [

        ]
        #проверяем числа на вход:
        if isinstance(other, int) or isinstance(other, float):
            #цикл, чтобы прогнаться по рядам матрицы:
            for row in range(len(self.matrix)):
                #список для матрицы, которая получится в результате деления:
                new_matrix = [

                ]
                #после прогона по рядам, нужно пройтись по столбцам матрицы, начиная с 1 элемента матрицы:
                for column in range(len(self.matrix[0])):
                    #делим матрицу на число
                    new_matrix.append(self.matrix[row][column] / other)
                #нужно записать результат деления
                result_func.append(new_matrix)

        else:
            #цикл, чтобы прогнаться по рядам матрицы:
            for row in range(len(self.matrix)):
                #список для матрицы, которая получится в результате деления:
                new_matrix = [

                ]
                #после прогона по рядам, нужно пройтись по столбцам матрицы, начиная с 1 элемента матрицы:
                for column in range(len(self.matrix[0])):
                    #делим матрицу на матрицу
                    new_matrix.append(self.matrix[row][column] / other.matrix[row][column])
                #нужно записать результат деления
                result_func.append(new_matrix)
        return Matrix(result_func)


    # def T(self):
    #     rows = len(self)
    #     columns = len(self.matrix[0]) if rows > 0 else 0

    #     transposed = []
    #     for j in range(columns):
    #         row = []
    #         for i in range(rows):
    #             row.append(self.matrix[i][j])
    #         transposed.append(row)

    #     return Matrix(transposed)


    #транспонирование матрицы, ряды становятся на место столбцов:
    def T(self):
        # создаем список для результата трансопонирования матрицы:
        result_func = [
            
        ]
        #так как новая матрица начинается со столбца, который был рядом, то нужно сначала прогнаться по столбцам в цикле:
        for column in range(len(self.matrix[0])):
            #список для матрицы, которая получится в результате транспонирования:
            new_matrix = [

            ]
            #цикл, чтобы прогнаться по рядам матрицы:
            for row in range(len(self.matrix)):
                #записать элемент столбца в ряд/строку
                new_matrix.append(self.matrix[row][column])
            #теперь результат транспонирования
            result_func.append(new_matrix)
        return Matrix(result_func)


    #скалярное произведение, ряды одной матрицы умножим на столбцы другой и получится скалярное произведение двух матриц
    def __matmul__ (self, other):
        #список для результата скалярного произведения
        result_func = [

        ]
        #функция должна выполняться тогда, когда матрицы одинаковой размерности:
        if len(self.matrix[0]) != len(other.matrix):
             raise ValueError("Матрицы не одинаковой размерности")
        
        #цикл, чтобы прогнаться по рядам первой матрицы:
        for row in range(len(self.matrix)):
            #список для матрицы, которая получится в результате:
            new_matrix = [

            ]
            #цикл чтобы прогнаться по столбцам второй матрицы:
            for column in range(len(self.matrix[0])):
                # n будет служить значением для функции скалярного произведения, которое будет меняться пока не закончатся все элементы матриц
                n = 0
                #проходимся по каждому элементу каждого ряда первой матрицы и каждому элементу каждого столбца второй матрицы
                for el in range(len(self.matrix[0])):
                    #умножаем ряж=ды одной матрицы на столбцы другой матрицы, каждый раз значение n будет меняться
                    n += self.matrix[row][el] * self.matrix[el][column]
                new_matrix.append(n)
        result_func(new_matrix)

        return Matrix(result_func)


    # def __matmul__(self, other_matrix):
    #     if len(self.matrix[0]) != len(other_matrix.matrix):
    #         raise ValueError("Матрицы не одинаковой размерности")

    #     result = [[sum(self.matrix[i][k] * other_matrix.matrix[k][j] for k in range(len(self.matrix[0])))
    #                for j in range(len(other_matrix.matrix[0]))]
    #               for i in range(len(self.matrix))]

    #     return Matrix(result)

# %%
# %pip install -q ipytest pytest

import ipytest
import pytest
ipytest.autoconfig()
# Out:
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%ipytest
# import numpy as np
#
# matrix1 = Matrix([[3, 1, 2],[1, 2, 3],[4, 2, 1]])
# matrix2 = Matrix([[4, 5, 6],[3, 5, 6],[4, 5, 6]])
#
# @pytest.mark.parametrize("matrix1,matrix2", [[matrix1, matrix2]])
# def test_matrix_add_matrix(matrix1: Matrix, matrix2: Matrix):
#     assert (
#         (np.array((matrix1 + matrix2).matrix) == (np.array(matrix1.matrix) + np.array(matrix2.matrix))).all()
#     ), 'add section with matrices is not working right'
#
# @pytest.mark.parametrize("matrix1,number", [[matrix1, 13.2]])
# def test_matrix_add_number(matrix1: Matrix, number: int | float):
#     assert (
#         (np.array((matrix1 + number).matrix) == np.array(matrix1.matrix) + number).all()
#     ), 'add section with matrix and number is not working right'
#
# @pytest.mark.parametrize("matrix1,matrix2", [[matrix1, matrix2]])
# def test_matrix_sub_matrix(matrix1: Matrix, matrix2: Matrix):
#     assert (
#         (np.array((matrix1 - matrix2).matrix) == np.array(matrix1.matrix) - np.array(matrix2.matrix)).all()
#     ), 'sub section with matrices is not working right'
#
# @pytest.mark.parametrize("matrix1,number", [[matrix1, 12.2]])
# def test_matrix_sub_number(matrix1: Matrix, number: int | float):
#     assert (
#         (np.array((matrix1 - number).matrix) == np.array(matrix1.matrix) - number).all()
#     ), 'sub section with matrix and number is not working right'
#
# @pytest.mark.parametrize("matrix1", [matrix1])
# def test_matrix_transpose(matrix1: Matrix):
#     assert (
#         (np.array(matrix1.T().matrix) == np.array(matrix1.matrix).T).all()
#     ), 'transpose section is not working right'
#
# # -----------------------------------------
#
# @pytest.mark.parametrize("matrix1,matrix2", [[matrix1, matrix2]])
# def test_matrix_mul_matrix(matrix1: Matrix, matrix2: Matrix):
#     assert (
#         (np.array((matrix1 * matrix2).matrix) == np.array(matrix1.matrix) * np.array(matrix2.matrix)).all()
#     ), 'mul section with matrices is not working right'
#
# @pytest.mark.parametrize("matrix1,number", [[matrix1, 13]])
# def test_matrix_mul_number(matrix1: Matrix, number: int | float):
#     assert (
#         (np.array((matrix1 * number).matrix) == np.array(matrix1.matrix) * number).all()
#     ), 'mul section with matrix and number is not working right'
#
# @pytest.mark.parametrize("matrix1,matrix2", [[matrix1, matrix2]])
# def test_matrix_div_matrix(matrix1: Matrix, matrix2: Matrix):
#     assert (
#         (np.array((matrix1 / matrix2).matrix) == np.array(matrix1.matrix) / np.array(matrix2.matrix)).all()
#     ), 'div section with matrices is not working right'
#
# @pytest.mark.parametrize("matrix1,number", [[matrix1, 2]])
# def test_matrix_div_number(matrix1: Matrix, number: int | float):
#     assert (
#         (np.array((matrix1 / number).matrix) == np.array(matrix1.matrix) / number).all()
#     ), 'div section with matrix and number is not working right'
#
# @pytest.mark.parametrize("matrix1,matrix2", [[matrix1, matrix2.T()]])
# def test_matrix_matmul_matrix(matrix1: Matrix, matrix2: Matrix):
#     assert(
#         (np.array((matrix1 @ matrix2).matrix) == np.array(matrix1.matrix) @ np.array(matrix2.matrix)).all()
#     ), 'matmul section is not working right, and don\'t forget about T() if needed'
#
# print((matrix1*matrix2).matrix)
# print(np.array(matrix1.matrix) * np.array(matrix2.matrix))
# Out:
# [[12, 5, 12], [3, 10, 18], [16, 10, 6]]
# [[12  5 12]
#  [ 3 10 18]
#  [16 10  6]]
# .........F                                                                                   [100%]
# ============================================ FAILURES =============================================
# __________________________ test_matrix_matmul_matrix[matrix10-matrix20] ___________________________
#
# matrix1 = <__main__.Matrix object at 0x000001A8B1ABFD50>
# matrix2 = <__main__.Matrix object at 0x000001A8B1B0E450>
#
#     @pytest.mark.parametrize("matrix1,matrix2", [[matrix1, matrix2.T()]])
#     def test_matrix_matmul_matrix(matrix1: Matrix, matrix2: Matrix):
# >       assert(
#             (np.array((matrix1 @ matrix2).matrix) == np.array(matrix1.matrix) @ np.array(matrix2.matrix)).all()
#         ), 'matmul section is not working right, and don\'t forget about T() if needed'
#
# C:\Users\Елизавета\AppData\Local\Temp\ipykernel_5352\2153102649.py:64:
# ...
