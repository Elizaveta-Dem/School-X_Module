# %%
import nltk
from nltk.corpus import wordnet
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_ru')
nltk.download('wordnet')
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('universal_tagset')
from nltk.stem import SnowballStemmer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Елизавета\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]     C:\Users\Елизавета\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_ru is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Елизавета\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\Елизавета\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!

# %%
with open("5_Sudba_cheloveka_1956.txt", "r", encoding="utf-8") as file:
    text5 = file.read()

# %%
sentences = sent_tokenize(text5, language='russian')

for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    tag_words = nltk.pos_tag(words, lang='rus') 
    
    print(tag_words)
# Out:
# [('Евгении', 'S'), ('Григорьевне', 'S'), ('Левицкой', 'S'), (',', 'NONLEX'), ('члену', 'S'), ('КПСС', 'S'), ('с', 'PR'), ('1903', 'NUM=ciph'), ('года', 'S'), ('Первая', 'ANUM=f'), ('послевоенная', 'A=f'), ('весна', 'S'), ('была', 'V'), ('на', 'PR'), ('Верхнем', 'A=m'), ('Дону', 'S'), ('на', 'PR'), ('редкость', 'S'), ('дружная', 'A=f'), ('и', 'CONJ'), ('напористая', 'A=f'), ('.', 'NONLEX')]
# [('В', 'PR'), ('конце', 'S'), ('марта', 'S'), ('из', 'PR'), ('Приазовья', 'S'), ('подули', 'V'), ('теплые', 'A=pl'), ('ветры', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('уже', 'ADV'), ('через', 'PR'), ('двое', 'NUM=acc'), ('суток', 'S'), ('начисто', 'ADV'), ('оголились', 'V'), ('пески', 'ADV'), ('левобережья', 'S'), ('Дона', 'S'), (',', 'NONLEX'), ('в', 'PR'), ('степи', 'S'), ('вспухли', 'V'), ('набитые', 'V'), ('снегом', 'S'), ('лога', 'S'), ('и', 'CONJ'), ('балки', 'S'), (',', 'NONLEX'), ('взломав', 'V'), ('лед', 'S'), (',', 'NONLEX'), ('бешено', 'ADV'), ('взыграли', 'V'), ('степные', 'A=pl'), ('речки', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('дороги', 'S'), ('стали', 'V'), ('почти', 'ADV'), ('совсем', 'ADV'), ('непроездны', 'A=pl'), ('.', 'NONLEX')]
# [('В', 'PR'), ('эту', 'A-PRO=f'), ('недобрую', 'A=f'), ('пору', 'S'), ('бездорожья', 'S'), ('мне', 'S-PRO'), ('пришлось', 'V'), ('ехать', 'V'), ('в', 'PR'), ('станицу', 'S'), ('Букановскую', 'A=f'), ('.', 'NONLEX')]
# [('И', 'CONJ'), ('расстояние', 'S'), ('небольшое', 'A=n'), ('–', 'S'), ('всего', 'PART'), ('лишь', 'PART'), ('около', 'PR'), ('шестидесяти', 'NUM=gen'), ('километров', 'S'), (',', 'NONLEX'), ('–', 'NONLEX'), ('но', 'CONJ'), ('одолеть', 'V'), ('их', 'S-PRO'), ('оказалось', 'V'), ('не', 'PART'), ('так-то', 'S-PRO'), ('просто', 'PART'), ('.', 'NONLEX')]
# [('Мы', 'S-PRO'), ('с', 'PR'), ('товарищами', 'S'), ('выехали', 'V'), ('до', 'PR'), ('восхода', 'S'), ('солнца', 'S'), ('.', 'NONLEX')]
# [('Пара', 'S'), ('сытых', 'A=pl'), ('лошадей', 'S'), (',', 'NONLEX'), ('в', 'PR'), ('струну', 'S'), ('натягивая', 'A=f'), ('постромки', 'S'), (',', 'NONLEX'), ('еле', 'ADV'), ('тащила', 'V'), ('тяжелую', 'A=sg'), ('бричку', 'S'), ('.', 'NONLEX')]
# [('Колеса', 'S'), ('по', 'PR'), ('самую', 'A-PRO=f'), ('ступицу', 'S'), ('проваливались', 'V'), ('в', 'PR'), ('отсыревший', 'A=m'), (',', 'NONLEX'), ('перемешанный', 'A=m'), ('со', 'PR'), ('снегом', 'S'), ('и', 'CONJ'), ('льдом', 'S'), ('песок', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('через', 'PR'), ('час', 'S'), ('на', 'PR'), ('лошадиных', 'A=pl'), ('боках', 'S'), ('и', 'CONJ'), ('стегнах', 'S'), (',', 'NONLEX'), ('под', 'PR'), ('тонкими', 'A=pl'), ('ремнями', 'S'), ('шлеек', 'S'), (',', 'NONLEX'), ('уже', 'ADV'), ('показались', 'V'), ('белые', 'A=pl'), ('пышные', 'A=pl'), ('хлопья', 'S'), ('мыла', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('в', 'PR'), ('утреннем', 'A=m'), ('свежем', 'A=m'), ('воздухе', 'S'), ('остро', 'ADV'), ('и', 'CONJ'), ('пьяняще', 'ADV'), ('запахло', 'V'), ('лошадиным', 'A=m'), ('потом', 'ADV-PRO'), ('и', 'CONJ'), ('согретым', 'A=m'), ('деготьком', 'S'), ('щедро', 'ADV'), ('смазанной', 'A=f'), ('конской', 'S'), ('сбруи', 'S'), ('.', 'NONLEX')]
# [('Там', 'ADV-PRO'), (',', 'NONLEX'), ('где', 'ADV-PRO'), ('было', 'V'), ('особенно', 'ADV'), ('трудно', 'PRAEDIC'), ('лошадям', 'S'), (',', 'NONLEX'), ('мы', 'S-PRO'), ('слезали', 'V'), ('с', 'PR'), ('брички', 'S'), (',', 'NONLEX'), ('шли', 'V'), ('пешком', 'ADV'), ('.', 'NONLEX')]
# [('Под', 'PR'), ('сапогами', 'S'), ('хлюпал', 'V'), ('размокший', 'V'), ('снег', 'S'), (',', 'NONLEX'), ('идти', 'V'), ('было', 'V'), ('тяжело', 'PRAEDIC'), (',', 'NONLEX'), ('но', 'CONJ'), ('по', 'PR'), ('обочинам', 'S'), ('дороги', 'S'), ('все', 'S-PRO'), ('еще', 'ADV'), ('держался', 'V'), ('хрустально', 'ADV'), ('поблескивавший', 'V'), ('на', 'PR'), ('солнце', 'S'), ('ледок', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('там', 'ADV-PRO'), ('пробираться', 'V'), ('было', 'V'), ('еще', 'ADV'), ('труднее', 'PRAEDIC=comp'), ('.', 'NONLEX')]
# [('Только', 'PART'), ('часов', 'S'), ('через', 'PR'), ('шесть', 'NUM=acc'), ('покрыли', 'V'), ('расстояние', 'S'), ('в', 'PR'), ('тридцать', 'NUM=acc'), ('километров', 'S'), (',', 'NONLEX'), ('подъехали', 'V'), ('к', 'PR'), ('переправе', 'S'), ('через', 'PR'), ('речку', 'S'), ('Еланку', 'S'), ('.', 'NONLEX')]
# [('Небольшая', 'A=f'), (',', 'NONLEX'), ('местами', 'S'), ('пересыхающая', 'V'), ('летом', 'S'), ('речушка', 'S'), ('против', 'PR'), ('хутора', 'S'), ('Моховского', 'A=m'), ('в', 'PR'), ('заболоченной', 'A=f'), (',', 'NONLEX'), ('поросшей', 'V'), ('ольхами', 'S'), ('пойме', 'S'), ('разлилась', 'V'), ('на', 'PR'), ('целый', 'A=m'), ('километр', 'S'), ('.', 'NONLEX')]
# [('Переправляться', 'V'), ('надо', 'PRAEDIC'), ('было', 'V'), ('на', 'PR'), ('утлой', 'A=f'), ('плоскодонке', 'S'), (',', 'NONLEX'), ('поднимавшей', 'V'), ('не', 'PART'), ('больше', 'NUM=comp'), ('трех', 'NUM=gen'), ('человек', 'S'), ('.', 'NONLEX')]
# [('Мы', 'S-PRO'), ('отпустили', 'V'), ('лошадей', 'S'), ('.', 'NONLEX')]
# [('На', 'PR'), ('той', 'A-PRO=f'), ('стороне', 'S'), ('в', 'PR'), ('колхозном', 'A=m'), ('сарае', 'S'), ('нас', 'S-PRO'), ('ожидал', 'V'), ('старенький', 'A=m'), (',', 'NONLEX'), ('видавший', 'V'), ('виды', 'S'), ('«', 'NONLEX'), ('Виллис', 'S'), ('»', 'NONLEX'), (',', 'NONLEX'), ('оставленный', 'V'), ('там', 'ADV-PRO'), ('еще', 'ADV'), ('зимою', 'V'), ('.', 'NONLEX')]
# [('Вдвоем', 'S'), ('с', 'PR'), ('шофером', 'S'), ('мы', 'S-PRO'), ('не', 'PART'), ('без', 'PR'), ('опасения', 'S'), ('сели', 'V'), ('в', 'PR'), ('ветхую', 'A=f'), ('лодчонку', 'S'), ('.', 'NONLEX')]
# [('Товарищ', 'S'), ('с', 'PR'), ('вещами', 'S'), ('остался', 'V'), ('на', 'PR'), ('берегу', 'S'), ('.', 'NONLEX')]
# [('Едва', 'ADV'), ('отчалили', 'V'), (',', 'NONLEX'), ('как', 'CONJ'), ('из', 'PR'), ('прогнившего', 'A=sg'), ('днища', 'S'), ('в', 'PR'), ('разных', 'A=pl'), ('местах', 'S'), ('фонтанчиками', 'S'), ('забила', 'V'), ('вода', 'S'), ('.', 'NONLEX')]
# [('Подручными', 'A=pl'), ('средствами', 'S'), ('конопатили', 'V'), ('ненадежную', 'A=f'), ('посудину', 'S'), ('и', 'CONJ'), ('вычерпывали', 'V'), ('из', 'PR'), ('нее', 'A=sg'), ('воду', 'S'), (',', 'NONLEX'), ('пока', 'CONJ'), ('не', 'PART'), ('доехали', 'V'), ('.', 'NONLEX')]
# [('Через', 'PR'), ('час', 'S'), ('мы', 'S-PRO'), ('были', 'V'), ('на', 'PR'), ('той', 'A-PRO=f'), ('стороне', 'S'), ('Еланки', 'S'), ('.', 'NONLEX')]
# [('Шофер', 'S'), ('пригнал', 'V'), ('из', 'PR'), ('хутора', 'S'), ('машину', 'S'), (',', 'NONLEX'), ('подошел', 'V'), ('к', 'PR'), ('лодке', 'S'), ('и', 'CONJ'), ('сказал', 'V'), (',', 'NONLEX'), ('берясь', 'V'), ('за', 'PR'), ('весло', 'S'), (':', 'NONLEX'), ('–', 'NONLEX'), ('Если', 'CONJ'), ('это', 'S-PRO'), ('проклятое', 'A=n'), ('корыто', 'S'), ('не', 'PART'), ('развалится', 'V'), ('на', 'PR'), ('воде', 'S'), (',', 'NONLEX'), ('–', 'S'), ('часа', 'S'), ('через', 'PR'), ('два', 'NUM=m'), ('приедем', 'V'), (',', 'NONLEX'), ('раньше', 'ADV'), ('не', 'PART'), ('ждите', 'V'), ('.', 'NONLEX')]
# [('Хутор', 'S'), ('раскинулся', 'V'), ('далеко', 'ADV'), ('в', 'PR'), ('стороне', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('возле', 'PR'), ('причала', 'V'), ('стояла', 'V'), ('такая', 'A-PRO=f'), ('тишина', 'S'), (',', 'NONLEX'), ('какая', 'A-PRO=f'), ('бывает', 'V'), ('в', 'PR'), ('безлюдных', 'A=pl'), ('местах', 'S'), ('только', 'PART'), ('глухою', 'S'), ('осенью', 'S'), ('и', 'CONJ'), ('в', 'PR'), ('самом', 'A-PRO=n'), ('начале', 'S'), ('весны', 'S'), ('.', 'NONLEX')]
# [('От', 'PR'), ('воды', 'S'), ('тянуло', 'V'), ('сыростью', 'S'), (',', 'NONLEX'), ('терпкой', 'A=f'), ('горечью', 'S'), ('гниющей', 'V'), ('ольхи', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('с', 'PR'), ('дальних', 'A=pl'), ('прихоперских', 'A=pl'), ('степей', 'S'), (',', 'NONLEX'), ('тонувших', 'V'), ('в', 'PR'), ('сиреневой', 'A=f'), ('дымке', 'S'), ('тумана', 'S'), (',', 'NONLEX'), ('легкий', 'A=m'), ('ветерок', 'S'), ('нес', 'S'), ('извечно', 'ADV'), ('юный', 'A=m'), (',', 'NONLEX'), ('еле', 'ADV'), ('уловимый', 'V'), ('аромат', 'S'), ('недавно', 'ADV'), ('освободившейся', 'V'), ('из-под', 'PR'), ('снега', 'S'), ('земли', 'S'), ('.', 'NONLEX')]
# [('Неподалеку', 'S'), (',', 'NONLEX'), ('на', 'PR'), ('прибрежном', 'A=m'), ('песке', 'S'), (',', 'NONLEX'), ('лежал', 'V'), ('поваленный', 'A=sg'), ('плетень', 'S'), ('.', 'NONLEX')]
# [('Я', 'S-PRO'), ('присел', 'V'), ('на', 'PR'), ('него', 'S-PRO'), (',', 'NONLEX'), ('хотел', 'V'), ('закурить', 'V'), (',', 'NONLEX'), ('но', 'CONJ'), (',', 'NONLEX'), ('сунув', 'V'), ('руку', 'S'), ('в', 'PR'), ('правый', 'A=m'), ('карман', 'S'), ('ватной', 'A=f'), ('стеганки', 'S'), (',', 'NONLEX'), ('к', 'PR'), ('великому', 'A=n'), ('огорчению', 'S'), (',', 'NONLEX'), ('обнаружил', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('пачка', 'S'), ('«', 'NONLEX'), ('Беломора', 'S'), ('»', 'NONLEX'), ('совершенно', 'ADV'), ('размокла', 'V'), ('.', 'NONLEX')]
# [('Во', 'PR'), ('время', 'S'), ('переправы', 'S'), ('волна', 'S'), ('хлестнула', 'V'), ('через', 'PR'), ('борт', 'S'), ('низко', 'ADV'), ('сидевшей', 'V'), ('лодки', 'S'), (',', 'NONLEX'), ('по', 'PR'), ('пояс', 'S'), ('окатила', 'V'), ('меня', 'S-PRO'), ('мутной', 'A=f'), ('водой', 'S'), ('.', 'NONLEX')]
# [('Тогда', 'ADV-PRO'), ('мне', 'S-PRO'), ('некогда', 'PRAEDIC'), ('было', 'V'), ('думать', 'V'), ('о', 'PR'), ('папиросах', 'S'), (',', 'NONLEX'), ('надо', 'PRAEDIC'), ('было', 'V'), (',', 'NONLEX'), ('бросив', 'V'), ('весло', 'S'), (',', 'NONLEX'), ('побыстрее', 'ADV=comp2'), ('вычерпывать', 'V'), ('воду', 'S'), (',', 'NONLEX'), ('чтобы', 'CONJ'), ('лодка', 'S'), ('не', 'PART'), ('затонула', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('теперь', 'ADV-PRO'), (',', 'NONLEX'), ('горько', 'PRAEDIC'), ('досадуя', 'V'), ('на', 'PR'), ('свою', 'A-PRO=f'), ('оплошность', 'S'), (',', 'NONLEX'), ('я', 'S-PRO'), ('бережно', 'ADV'), ('извлек', 'V'), ('из', 'PR'), ('кармана', 'S'), ('раскисшую', 'V'), ('пачку', 'S'), (',', 'NONLEX'), ('присел', 'V'), ('на', 'PR'), ('корточки', 'S'), ('и', 'CONJ'), ('стал', 'V'), ('по', 'PR'), ('одной', 'A-PRO=f'), ('раскладывать', 'V'), ('на', 'PR'), ('плетне', 'S'), ('влажные', 'A=pl'), (',', 'NONLEX'), ('побуревшие', 'V'), ('папиросы', 'S'), ('.', 'NONLEX')]
# [('Был', 'V'), ('полдень', 'S'), ('.', 'NONLEX')]
# [('Солнце', 'S'), ('светило', 'V'), ('горячо', 'ADV'), (',', 'NONLEX'), ('как', 'CONJ'), ('в', 'PR'), ('мае', 'S'), ('.', 'NONLEX')]
# [('Я', 'S-PRO'), ('надеялся', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('папиросы', 'S'), ('скоро', 'ADV'), ('высохнут', 'V'), ('.', 'NONLEX')]
# [('Солнце', 'S'), ('светило', 'V'), ('так', 'ADV-PRO'), ('горячо', 'ADV'), (',', 'NONLEX'), ('что', 'CONJ'), ('я', 'S-PRO'), ('уже', 'ADV'), ('пожалел', 'V'), ('о', 'PR'), ('том', 'S-PRO'), (',', 'NONLEX'), ('что', 'CONJ'), ('надел', 'V'), ('в', 'PR'), ('дорогу', 'S'), ('солдатские', 'A=pl'), ('ватные', 'A=pl'), ('штаны', 'S'), ('и', 'CONJ'), ('стеганку', 'S'), ('.', 'NONLEX')]
# [('Это', 'S-PRO'), ('был', 'V'), ('первый', 'ANUM=m'), ('после', 'PR'), ('зимы', 'S'), ('по-настоящему', 'ADV'), ('теплый', 'A=m'), ('день', 'S'), ('.', 'NONLEX')]
# [('Хорошо', 'PRAEDIC'), ('было', 'V'), ('сидеть', 'V'), ('на', 'PR'), ('плетне', 'S'), ('вот', 'PART'), ('так', 'ADV-PRO'), (',', 'NONLEX'), ('одному', 'ADV-PRO'), (',', 'NONLEX'), ('целиком', 'ADV'), ('покорясь', 'V'), ('тишине', 'S'), ('и', 'CONJ'), ('одиночеству', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), (',', 'NONLEX'), ('сняв', 'V'), ('с', 'PR'), ('головы', 'S'), ('старую', 'A=f'), ('солдатскую', 'A=f'), ('ушанку', 'S'), (',', 'NONLEX'), ('сушить', 'V'), ('на', 'PR'), ('ветерке', 'S'), ('мокрые', 'A=pl'), ('после', 'PR'), ('тяжелой', 'A=f'), ('гребли', 'S'), ('волосы', 'S'), (',', 'NONLEX'), ('бездумно', 'ADV'), ('следить', 'V'), ('за', 'PR'), ('проплывающими', 'V'), ('в', 'PR'), ('блеклой', 'A=f'), ('синеве', 'S'), ('белыми', 'A=pl'), ('грудастыми', 'A=pl'), ('облаками', 'S'), ('.', 'NONLEX')]
# [('Вскоре', 'ADV'), ('я', 'S-PRO'), ('увидел', 'V'), (',', 'NONLEX'), ('как', 'CONJ'), ('из-за', 'PR'), ('крайних', 'A=pl'), ('дворов', 'S'), ('хутора', 'S'), ('вышел', 'V'), ('на', 'PR'), ('дорогу', 'S'), ('мужчина', 'S'), ('.', 'NONLEX')]
# [('Он', 'S-PRO'), ('вел', 'V'), ('за', 'PR'), ('руку', 'S'), ('маленького', 'A=m'), ('мальчика', 'S'), (',', 'NONLEX'), ('судя', 'ADV'), ('по', 'PR'), ('росту', 'S'), ('–', 'NONLEX'), ('лет', 'S'), ('пяти-шести', 'S'), (',', 'NONLEX'), ('не', 'PART'), ('больше', 'NUM=comp'), ('.', 'NONLEX')]
# [('Они', 'S-PRO'), ('устало', 'V'), ('брели', 'S'), ('по', 'PR'), ('направлению', 'S'), ('к', 'PR'), ('переправе', 'S'), (',', 'NONLEX'), ('но', 'CONJ'), (',', 'NONLEX'), ('поравнявшись', 'V'), ('с', 'PR'), ('машиной', 'S'), (',', 'NONLEX'), ('повернули', 'V'), ('ко', 'PR'), ('мне', 'S-PRO'), ('.', 'NONLEX')]
# [('Высокий', 'A=m'), (',', 'NONLEX'), ('сутуловатый', 'A=m'), ('мужчина', 'S'), (',', 'NONLEX'), ('подойдя', 'V'), ('вплотную', 'ADV'), (',', 'NONLEX'), ('сказал', 'V'), ('приглушенным', 'A=m'), ('баском', 'S'), (':', 'NONLEX'), ('–', 'NONLEX'), ('Здорово', 'ADV'), (',', 'NONLEX'), ('браток', 'S'), ('!', 'NONLEX')]
# [('–', 'NONLEX'), ('Здравствуй', 'INTJ'), ('.', 'NONLEX')]
# [('–', 'NONLEX'), ('Я', 'S-PRO'), ('пожал', 'V'), ('протянутую', 'V'), ('мне', 'S-PRO'), ('большую', 'A=f'), (',', 'NONLEX'), ('черствую', 'A=f'), ('руку', 'S'), ('.', 'NONLEX')]
# [('Мужчина', 'S'), ('наклонился', 'V'), ('к', 'PR'), ('мальчику', 'S'), (',', 'NONLEX'), ('сказал', 'V'), (':', 'NONLEX'), ('–', 'NONLEX'), ('Поздоровайся', 'V'), ('с', 'PR'), ('дядей', 'S'), (',', 'NONLEX'), ('сынок', 'S'), ('.', 'NONLEX')]
# [('Он', 'S-PRO'), (',', 'NONLEX'), ('видать', 'PARENTH'), (',', 'NONLEX'), ('такой', 'A-PRO=m'), ('же', 'PART'), ('шофер', 'S'), (',', 'NONLEX'), ('как', 'CONJ'), ('и', 'CONJ'), ('твой', 'A-PRO=m'), ('папанька', 'S'), ('.', 'NONLEX')]
# [('Только', 'PART'), ('мы', 'S-PRO'), ('с', 'PR'), ('тобой', 'S-PRO'), ('на', 'PR'), ('грузовой', 'S'), ('ездили', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('он', 'S-PRO'), ('вот', 'PART'), ('эту', 'A-PRO=f'), ('маленькую', 'A=f'), ('машину', 'S'), ('гоняет', 'V'), ('.', 'NONLEX')]
# [('Глядя', 'V'), ('мне', 'S-PRO'), ('прямо', 'ADV'), ('в', 'PR'), ('глаза', 'S'), ('светлыми', 'A=pl'), (',', 'NONLEX'), ('как', 'CONJ'), ('небушко', 'S'), (',', 'NONLEX'), ('глазами', 'S'), (',', 'NONLEX'), ('чуть-чуть', 'ADV'), ('улыбаясь', 'V'), (',', 'NONLEX'), ('мальчик', 'S'), ('смело', 'ADV'), ('протянул', 'V'), ('мне', 'S-PRO'), ('розовую', 'A=f'), ('холодную', 'A=f'), ('ручонку', 'S'), ('.', 'NONLEX')]
# [('Я', 'S-PRO'), ('легонько', 'ADV'), ('потряс', 'V'), ('ее', 'S'), (',', 'NONLEX'), ('спросил', 'V'), (':', 'NONLEX'), ('–', 'S'), ('Что', 'S-PRO'), ('же', 'PART'), ('это', 'S-PRO'), ('у', 'PR'), ('тебя', 'S-PRO'), (',', 'NONLEX'), ('старик', 'S'), (',', 'NONLEX'), ('рука', 'S'), ('такая', 'A-PRO=f'), ('холодная', 'A=f'), ('?', 'NONLEX')]
# [('На', 'PR'), ('дворе', 'S'), ('теплынь', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('ты', 'S-PRO'), ('замерзаешь', 'V'), ('?', 'NONLEX')]
# [('С', 'PR'), ('трогательной', 'A=f'), ('детской', 'A=f'), ('доверчивостью', 'S'), ('малыш', 'S'), ('прижался', 'V'), ('к', 'PR'), ('моим', 'A-PRO=pl'), ('коленям', 'S'), (',', 'NONLEX'), ('удивленно', 'ADV'), ('приподнял', 'V'), ('белесые', 'S'), ('бровки', 'S'), ('.', 'NONLEX')]
# [('–', 'S'), ('Какой', 'A-PRO=m'), ('же', 'PART'), ('я', 'S-PRO'), ('старик', 'S'), (',', 'NONLEX'), ('дядя', 'S'), ('?', 'NONLEX')]
# [('Я', 'S-PRO'), ('вовсе', 'ADV'), ('мальчик', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('я', 'S-PRO'), ('вовсе', 'ADV'), ('не', 'PART'), ('замерзаю', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('руки', 'S'), ('холодные', 'A=pl'), ('–', 'S'), ('снежки', 'S'), ('катал', 'V'), ('потому', 'ADV-PRO'), ('что', 'CONJ'), ('.', 'NONLEX')]
# [('Сняв', 'V'), ('со', 'PR'), ('спины', 'S'), ('тощий', 'V'), ('вещевой', 'A=m'), ('мешок', 'S'), (',', 'NONLEX'), ('устало', 'ADV'), ('присаживаясь', 'V'), ('рядом', 'ADV'), ('со', 'PR'), ('мною', 'S-PRO'), (',', 'NONLEX'), ('отец', 'S'), ('сказал', 'V'), (':', 'NONLEX'), ('–', 'NONLEX'), ('Беда', 'S'), ('мне', 'S-PRO'), ('с', 'PR'), ('этим', 'A-PRO=m'), ('пассажиром', 'S'), ('!', 'NONLEX')]
# [('Через', 'PR'), ('него', 'S-PRO'), ('и', 'CONJ'), ('я', 'S-PRO'), ('подбился', 'V'), ('.', 'NONLEX')]
# [('Широко', 'ADV'), ('шагнешь', 'V'), ('–', 'S'), ('он', 'S-PRO'), ('уже', 'ADV'), ('на', 'PR'), ('рысь', 'S'), ('переходит', 'V'), (',', 'NONLEX'), ('вот', 'PART'), ('и', 'CONJ'), ('изволь', 'S'), ('к', 'PR'), ('такому', 'A-PRO=m'), ('пехотинцу', 'S'), ('приноравливаться', 'V'), ('.', 'NONLEX')]
# [('Там', 'ADV-PRO'), (',', 'NONLEX'), ('где', 'ADV-PRO'), ('мне', 'S-PRO'), ('надо', 'PRAEDIC'), ('раз', 'S'), ('шагнуть', 'V'), (',', 'NONLEX'), ('–', 'S'), ('я', 'S-PRO'), ('три', 'NUM=acc'), ('раза', 'S'), ('шагаю', 'S'), (',', 'NONLEX'), ('так', 'ADV-PRO'), ('и', 'CONJ'), ('идем', 'V'), ('с', 'PR'), ('ним', 'S-PRO'), ('враздробь', 'S'), (',', 'NONLEX'), ('как', 'CONJ'), ('конь', 'S'), ('с', 'PR'), ('черепахой', 'S'), ('.', 'NONLEX')]
# [('А', 'CONJ'), ('тут', 'ADV-PRO'), ('ведь', 'PART'), ('за', 'PR'), ('ним', 'S-PRO'), ('глаз', 'S'), ('да', 'CONJ'), ('глаз', 'S'), ('нужен', 'A=m'), ('.', 'NONLEX')]
# [('Чуть', 'ADV'), ('отвернешься', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('он', 'S-PRO'), ('уже', 'ADV'), ('по', 'PR'), ('лужине', 'S'), ('бредет', 'V'), ('или', 'CONJ'), ('леденику', 'S'), ('отломит', 'V'), ('и', 'CONJ'), ('сосет', 'S'), ('вместо', 'PR'), ('конфеты', 'S'), ('.', 'NONLEX')]
# [('Нет', 'PART'), (',', 'NONLEX'), ('не', 'PART'), ('мужчинское', 'A=n'), ('это', 'A-PRO=n'), ('дело', 'S'), ('с', 'PR'), ('такими', 'A-PRO=pl'), ('пассажирами', 'S'), ('путешествовать', 'V'), (',', 'NONLEX'), ('да', 'CONJ'), ('еще', 'ADV'), ('походным', 'V'), ('порядком', 'S'), ('.', 'NONLEX')]
# [('–', 'NONLEX'), ('Он', 'S-PRO'), ('помолчал', 'V'), ('немного', 'ADV'), (',', 'NONLEX'), ('потом', 'ADV-PRO'), ('спросил', 'V'), (':', 'NONLEX'), ('–', 'NONLEX'), ('А', 'CONJ'), ('ты', 'S-PRO'), ('что', 'ADV-PRO'), ('же', 'PART'), (',', 'NONLEX'), ('браток', 'S'), (',', 'NONLEX'), ('свое', 'A=n'), ('начальство', 'S'), ('ждешь', 'V'), ('?', 'NONLEX')]
# [('Мне', 'S-PRO'), ('было', 'V'), ('неудобно', 'PRAEDIC'), ('разуверять', 'V'), ('его', 'S-PRO'), ('в', 'PR'), ('том', 'S-PRO'), (',', 'NONLEX'), ('что', 'CONJ'), ('я', 'S-PRO'), ('не', 'PART'), ('шофер', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('я', 'S-PRO'), ('ответил', 'V'), (':', 'NONLEX'), ('–', 'S'), ('Приходится', 'V'), ('ждать', 'V'), ('.', 'NONLEX')]
# [('–', 'S'), ('С', 'PR'), ('той', 'A-PRO=f'), ('стороны', 'S'), ('подъедут', 'V'), ('?', 'NONLEX')]
# [('–', 'NONLEX'), ('Да', 'PART'), ('.', 'NONLEX')]
# [('–', 'S'), ('Не', 'PART'), ('знаешь', 'V'), (',', 'NONLEX'), ('скоро', 'ADV'), ('ли', 'CONJ'), ('подойдет', 'V'), ('лодка', 'S'), ('?', 'NONLEX')]
# [('–', 'A=m'), ('Часа', 'S'), ('через', 'PR'), ('два', 'NUM=m'), ('.', 'NONLEX')]
# [('–', 'V'), ('Порядком', 'S'), ('.', 'NONLEX')]
# [('Ну', 'PART'), ('что', 'S-PRO'), ('ж', 'PART'), (',', 'NONLEX'), ('пока', 'CONJ'), ('отдохнем', 'V'), (',', 'NONLEX'), ('спешить', 'V'), ('мне', 'S-PRO'), ('некуда', 'PRAEDIC'), ('.', 'NONLEX')]
# [('А', 'CONJ'), ('я', 'S-PRO'), ('иду', 'V'), ('мимо', 'ADV'), (',', 'NONLEX'), ('гляжу', 'V'), (':', 'NONLEX'), ('свой', 'A-PRO=m'), ('брат-шофер', 'S'), ('загорает', 'V'), ('.', 'NONLEX')]
# [('Дай', 'V'), (',', 'NONLEX'), ('думаю', 'V'), (',', 'NONLEX'), ('зайду', 'V'), (',', 'NONLEX'), ('перекурим', 'V'), ('вместе', 'ADV'), ('.', 'NONLEX')]
# [('Одному-то', 'ADV-PRO'), ('и', 'CONJ'), ('курить', 'V'), ('и', 'CONJ'), ('помирать', 'V'), ('тошно', 'PRAEDIC'), ('.', 'NONLEX')]
# [('А', 'CONJ'), ('ты', 'S-PRO'), ('богато', 'ADV'), ('живешь', 'V'), (',', 'NONLEX'), ('папироски', 'ADV'), ('куришь', 'V'), ('.', 'NONLEX')]
# [('Подмочил', 'V'), ('их', 'S-PRO'), (',', 'NONLEX'), ('стало', 'V'), ('быть', 'V'), ('?', 'NONLEX')]
# [('Ну', 'PART'), (',', 'NONLEX'), ('брат', 'S'), (',', 'NONLEX'), ('табак', 'S'), ('моченый', 'A=m'), (',', 'NONLEX'), ('что', 'CONJ'), ('конь', 'S'), ('леченый', 'A=m'), (',', 'NONLEX'), ('никуда', 'ADV-PRO'), ('не', 'PART'), ('годится', 'V'), ('.', 'NONLEX')]
# [('Давай-ка', 'INTJ'), ('лучше', 'A=comp'), ('моего', 'A-PRO=m'), ('крепачка', 'S'), ('закурим', 'V'), ('.', 'NONLEX')]
# [('Он', 'S-PRO'), ('достал', 'V'), ('из', 'PR'), ('кармана', 'S'), ('защитных', 'A=pl'), ('летних', 'A=pl'), ('штанов', 'S'), ('свернутый', 'V'), ('в', 'PR'), ('трубку', 'S'), ('малиновый', 'A=m'), ('шелковый', 'A=m'), ('потертый', 'A=m'), ('кисет', 'S'), (',', 'NONLEX'), ('развернул', 'V'), ('его', 'S-PRO'), (',', 'NONLEX'), ('и', 'CONJ'), ('я', 'S-PRO'), ('успел', 'V'), ('прочитать', 'V'), ('вышитую', 'ADV'), ('на', 'PR'), ('уголке', 'S'), ('надпись', 'S'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Дорогому', 'NONLEX'), ('бойцу', 'S'), ('от', 'PR'), ('ученицы', 'S'), ('6', 'NUM=ciph'), ('?', 'NONLEX'), ('го', 'S'), ('класса', 'S'), ('Лебедянской', 'A=f'), ('средней', 'A=f'), ('школы', 'S'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('Мы', 'S-PRO'), ('закурили', 'V'), ('крепчайшего', 'A=m'), ('самосада', 'S'), ('и', 'CONJ'), ('долго', 'ADV'), ('молчали', 'V'), ('.', 'NONLEX')]
# [('Я', 'S-PRO'), ('хотел', 'V'), ('было', 'V'), ('спросить', 'V'), (',', 'NONLEX'), ('куда', 'ADV-PRO'), ('он', 'S-PRO'), ('идет', 'V'), ('с', 'PR'), ('ребенком', 'S'), (',', 'NONLEX'), ('какая', 'A-PRO=f'), ('нужда', 'S'), ('его', 'A-PRO'), ('гонит', 'V'), ('в', 'PR'), ('такую', 'A-PRO=f'), ('распутицу', 'S'), (',', 'NONLEX'), ('но', 'CONJ'), ('он', 'S-PRO'), ('опередил', 'V'), ('меня', 'S-PRO'), ('вопросом', 'S'), (':', 'NONLEX'), ('–', 'NONLEX'), ('Ты', 'S-PRO'), ('что', 'ADV-PRO'), ('же', 'PART'), (',', 'NONLEX'), ('всю', 'A-PRO=f'), ('войну', 'S'), ('за', 'PR'), ('баранкой', 'S'), ('?', 'NONLEX')]
# [('–', 'S'), ('Почти', 'ADV'), ('всю', 'A-PRO=f'), ('.', 'NONLEX')]
# [('–', 'V'), ('На', 'PR'), ('фронте', 'S'), ('?', 'NONLEX')]
# [('–', 'NONLEX'), ('Да', 'PART'), ('.', 'NONLEX')]
# [('–', 'NONLEX'), ('Ну', 'PART'), (',', 'NONLEX'), ('и', 'CONJ'), ('мне', 'S-PRO'), ('там', 'ADV-PRO'), ('пришлось', 'V'), (',', 'NONLEX'), ('браток', 'S'), (',', 'NONLEX'), ('хлебнуть', 'V'), ('горюшка', 'S'), ('по', 'PR'), ('ноздри', 'S'), ('и', 'CONJ'), ('выше', 'A=comp'), ('.', 'NONLEX')]
# [('Он', 'S-PRO'), ('положил', 'V'), ('на', 'PR'), ('колени', 'S'), ('большие', 'A=pl'), ('темные', 'A=pl'), ('руки', 'S'), (',', 'NONLEX'), ('сгорбился', 'V'), ('.', 'NONLEX')]
# [('Я', 'S-PRO'), ('сбоку', 'ADV'), ('взглянул', 'V'), ('на', 'PR'), ('него', 'S-PRO'), (',', 'NONLEX'), ('и', 'CONJ'), ('мне', 'S-PRO'), ('стало', 'V'), ('что-то', 'S-PRO'), ('не', 'PART'), ('по', 'PR'), ('себе…', 'S'), ('Видали', 'V'), ('вы', 'S-PRO'), ('когда-нибудь', 'ADV-PRO'), ('глаза', 'S'), (',', 'NONLEX'), ('словно', 'CONJ'), ('присыпанные', 'V'), ('пеплом', 'S'), (',', 'NONLEX'), ('наполненные', 'V'), ('такой', 'A-PRO=f'), ('неизбывной', 'A=f'), ('смертной', 'A=f'), ('тоской', 'S'), (',', 'NONLEX'), ('что', 'CONJ'), ('в', 'PR'), ('них', 'S-PRO'), ('трудно', 'PRAEDIC'), ('смотреть', 'V'), ('?', 'NONLEX')]
# [('Вот', 'PART'), ('такие', 'A-PRO=pl'), ('глаза', 'S'), ('были', 'V'), ('у', 'PR'), ('моего', 'A-PRO=m'), ('случайного', 'A=m'), ('собеседника', 'S'), ('.', 'NONLEX')]
# [('Выломав', 'V'), ('из', 'PR'), ('плетня', 'S'), ('сухую', 'A=f'), ('искривленную', 'A=f'), ('хворостинку', 'S'), (',', 'NONLEX'), ('он', 'S-PRO'), ('с', 'PR'), ('минуту', 'S'), ('молча', 'ADV'), ('водил', 'V'), ('ею', 'S-PRO'), ('по', 'PR'), ('песку', 'S'), (',', 'NONLEX'), ('вычерчивая', 'V'), ('какие-то', 'A-PRO=pl'), ('замысловатые', 'A=pl'), ('фигуры', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('потом', 'ADV-PRO'), ('заговорил', 'V'), (':', 'NONLEX'), ('–', 'S'), ('Иной', 'A-PRO=m'), ('раз', 'S'), ('не', 'PART'), ('спишь', 'V'), ('ночью', 'S'), (',', 'NONLEX'), ('глядишь', 'V'), ('в', 'PR'), ('темноту', 'S'), ('пустыми', 'A=pl'), ('глазами', 'S'), ('и', 'CONJ'), ('думаешь', 'V'), (':', 'NONLEX'), ('«', 'NONLEX'), ('За', 'PR'), ('что', 'S-PRO'), ('же', 'PART'), ('ты', 'S-PRO'), (',', 'NONLEX'), ('жизнь', 'S'), (',', 'NONLEX'), ('меня', 'S-PRO'), ('так', 'ADV-PRO'), ('покалечила', 'V'), ('?', 'NONLEX')]
# [('За', 'PR'), ('что', 'S-PRO'), ('так', 'ADV-PRO'), ('исказнила', 'V'), ('?', 'NONLEX'), ('»', 'NONLEX'), ('Нету', 'PRAEDIC'), ('мне', 'S-PRO'), ('ответа', 'S'), ('ни', 'CONJ'), ('в', 'PR'), ('темноте', 'S'), (',', 'NONLEX'), ('ни', 'CONJ'), ('при', 'PR'), ('ясном', 'A=m'), ('солнышке…', 'S'), ('Нету', 'S'), ('и', 'CONJ'), ('не', 'PART'), ('дождусь', 'V'), ('!', 'NONLEX')]
# [('–', 'NONLEX'), ('И', 'CONJ'), ('вдруг', 'ADV'), ('спохватился', 'V'), (':', 'NONLEX'), ('ласково', 'ADV'), ('подталкивая', 'V'), ('сынишку', 'S'), (',', 'NONLEX'), ('сказал', 'V'), (':', 'NONLEX'), ('–', 'NONLEX'), ('Пойди', 'V'), (',', 'NONLEX'), ('милок', 'S'), (',', 'NONLEX'), ('поиграйся', 'V'), ('возле', 'PR'), ('воды', 'S'), (',', 'NONLEX'), ('у', 'PR'), ('большой', 'A=f'), ('воды', 'S'), ('для', 'PR'), ('ребятишек', 'S'), ('всегда', 'ADV-PRO'), ('какая-нибудь', 'A-PRO=m'), ('добыча', 'S'), ('найдется', 'V'), ('.', 'NONLEX')]
# [('Только', 'PART'), (',', 'NONLEX'), ('гляди', 'V'), (',', 'NONLEX'), ('ноги', 'S'), ('не', 'PART'), ('промочи', 'V'), ('!', 'NONLEX')]
# [('Еще', 'PART'), ('когда', 'CONJ'), ('мы', 'S-PRO'), ('в', 'PR'), ('молчании', 'S'), ('курили', 'V'), (',', 'NONLEX'), ('я', 'S-PRO'), (',', 'NONLEX'), ('украдкой', 'ADV'), ('рассматривая', 'V'), ('отца', 'S'), ('и', 'CONJ'), ('сынишку', 'S'), (',', 'NONLEX'), ('с', 'PR'), ('удивлением', 'S'), ('отметил', 'V'), ('про', 'PR'), ('себя', 'S-PRO=acc'), ('одно', 'ANUM=n'), (',', 'NONLEX'), ('странное', 'A=n'), ('на', 'PR'), ('мой', 'A-PRO=m'), ('взгляд', 'S'), (',', 'NONLEX'), ('обстоятельство', 'S'), ('.', 'NONLEX')]
# [('Мальчик', 'S'), ('был', 'V'), ('одет', 'V'), ('просто', 'PART'), (',', 'NONLEX'), ('но', 'CONJ'), ('добротно', 'ADV'), (':', 'NONLEX'), ('и', 'CONJ'), ('в', 'PR'), ('том', 'S-PRO'), (',', 'NONLEX'), ('как', 'ADV-PRO'), ('сидела', 'V'), ('на', 'PR'), ('нем', 'A=m'), ('подбитая', 'A=f'), ('легкой', 'S'), (',', 'NONLEX'), ('поношенной', 'A=f'), ('цигейкой', 'A=f'), ('длиннополая', 'A=f'), ('курточка', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('в', 'PR'), ('том', 'S-PRO'), (',', 'NONLEX'), ('что', 'CONJ'), ('крохотные', 'A=pl'), ('сапожки', 'S'), ('были', 'V'), ('сшиты', 'V'), ('с', 'PR'), ('расчетом', 'S'), ('надевать', 'V'), ('их', 'S-PRO'), ('на', 'PR'), ('шерстяной', 'A=f'), ('носок', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('очень', 'ADV'), ('искусный', 'A=m'), ('шов', 'S'), ('на', 'PR'), ('разорванном', 'S'), ('когда-то', 'ADV-PRO'), ('рукаве', 'V'), ('курточки', 'S'), ('–', 'S'), ('все', 'S-PRO'), ('выдавало', 'V'), ('женскую', 'A=f'), ('заботу', 'S'), (',', 'NONLEX'), ('умелые', 'A=pl'), ('материнские', 'A=pl'), ('руки', 'S'), ('.', 'NONLEX')]
# [('А', 'CONJ'), ('отец', 'S'), ('выглядел', 'V'), ('иначе', 'ADV-PRO'), (':', 'NONLEX'), ('прожженный', 'A=m'), ('в', 'PR'), ('нескольких', 'NUM=loc'), ('местах', 'S'), ('ватник', 'S'), ('был', 'V'), ('небрежно', 'ADV'), ('и', 'CONJ'), ('грубо', 'ADV'), ('заштопан', 'V'), (',', 'NONLEX'), ('латка', 'S'), ('на', 'PR'), ('выношенных', 'A=pl'), ('защитных', 'A=pl'), ('штанах', 'S'), ('не', 'PART'), ('пришита', 'V'), ('как', 'CONJ'), ('следует', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('скорее', 'ADV=comp'), ('наживлена', 'V'), ('широкими', 'A=pl'), (',', 'NONLEX'), ('мужскими', 'A=pl'), ('стежками', 'S'), (';', 'NONLEX'), ('на', 'PR'), ('нем', 'A=m'), ('были', 'V'), ('почти', 'ADV'), ('новые', 'A=pl'), ('солдатские', 'A=pl'), ('ботинки', 'S'), (',', 'NONLEX'), ('но', 'CONJ'), ('плотные', 'A=pl'), ('шерстяные', 'A=pl'), ('носки', 'S'), ('изъедены', 'V'), ('молью', 'S'), (',', 'NONLEX'), ('их', 'S-PRO'), ('не', 'PART'), ('коснулась', 'V'), ('женская', 'A=f'), ('рука…', 'S'), ('Еще', 'PART'), ('тогда', 'ADV-PRO'), ('я', 'S-PRO'), ('подумал', 'V'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Или', 'CONJ'), ('вдовец', 'S'), (',', 'NONLEX'), ('или', 'CONJ'), ('живет', 'S'), ('не', 'PART'), ('в', 'PR'), ('ладах', 'S'), ('с', 'PR'), ('женой', 'S'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('Но', 'CONJ'), ('вот', 'PART'), ('он', 'S-PRO'), (',', 'NONLEX'), ('проводив', 'V'), ('глазами', 'S'), ('сынишку', 'S'), (',', 'NONLEX'), ('глухо', 'ADV'), ('покашлял', 'V'), (',', 'NONLEX'), ('снова', 'ADV'), ('заговорил', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('я', 'S-PRO'), ('весь', 'A-PRO=m'), ('превратился', 'V'), ('в', 'PR'), ('слух', 'S'), (':', 'NONLEX'), ('–', 'NONLEX'), ('Поначалу', 'ADV'), ('жизнь', 'S'), ('моя', 'A-PRO=f'), ('была', 'V'), ('обыкновенная', 'A=f'), ('.', 'NONLEX')]
# [('Сам', 'A-PRO=m'), ('я', 'S-PRO'), ('уроженец', 'S'), ('Воронежской', 'A=f'), ('губернии', 'S'), (',', 'NONLEX'), ('с', 'PR'), ('тысяча', 'S'), ('девятьсотого', 'A=m'), ('года', 'S'), ('рождения', 'S'), ('.', 'NONLEX')]
# [('В', 'PR'), ('Гражданскую', 'A=f'), ('войну', 'S'), ('был', 'V'), ('в', 'PR'), ('Красной', 'A=f'), ('Армии', 'S'), (',', 'NONLEX'), ('в', 'PR'), ('дивизии', 'S'), ('Киквидзе', 'S'), ('.', 'NONLEX')]
# [('В', 'PR'), ('голодный', 'A=m'), ('двадцать', 'NUM=nom'), ('второй', 'ANUM=m'), ('год', 'S'), ('подался', 'V'), ('на', 'PR'), ('Кубань', 'S'), (',', 'NONLEX'), ('ишачить', 'V'), ('на', 'PR'), ('кулаков', 'S'), (',', 'NONLEX'), ('потому', 'ADV-PRO'), ('и', 'CONJ'), ('уцелел', 'V'), ('.', 'NONLEX')]
# [('А', 'CONJ'), ('отец', 'S'), ('с', 'PR'), ('матерью', 'S'), ('и', 'CONJ'), ('сестренкой', 'S'), ('дома', 'S'), ('померли', 'V'), ('от', 'PR'), ('голода', 'S'), ('.', 'NONLEX')]
# [('Остался', 'V'), ('один', 'A-PRO=m'), ('.', 'NONLEX')]
# [('Родни', 'S'), ('–', 'NONLEX'), ('хоть', 'PART'), ('шаром', 'S'), ('покати', 'NUM=gen'), (',', 'NONLEX'), ('–', 'S'), ('нигде', 'ADV-PRO'), (',', 'NONLEX'), ('никого', 'S-PRO'), (',', 'NONLEX'), ('ни', 'PART'), ('одной', 'ANUM=sg'), ('души', 'S'), ('.', 'NONLEX')]
# [('Ну', 'PART'), (',', 'NONLEX'), ('через', 'PR'), ('год', 'S'), ('вернулся', 'V'), ('с', 'PR'), ('Кубани', 'S'), (',', 'NONLEX'), ('хатенку', 'S'), ('продал', 'V'), (',', 'NONLEX'), ('поехал', 'V'), ('в', 'PR'), ('Воронеж', 'S'), ('.', 'NONLEX')]
# [('Поначалу', 'ADV'), ('работал', 'V'), ('в', 'PR'), ('плотницкой', 'A=f'), ('артели', 'S'), (',', 'NONLEX'), ('потом', 'ADV-PRO'), ('пошел', 'V'), ('на', 'PR'), ('завод', 'S'), (',', 'NONLEX'), ('выучился', 'V'), ('на', 'PR'), ('слесаря', 'S'), ('.', 'NONLEX')]
# [('Вскорости', 'S'), ('женился', 'V'), ('.', 'NONLEX')]
# [('Жена', 'S'), ('воспитывалась', 'V'), ('в', 'PR'), ('детском', 'A=m'), ('доме', 'S'), ('.', 'NONLEX')]
# [('Сиротка', 'S'), ('.', 'NONLEX')]
# [('Хорошая', 'A=f'), ('попалась', 'V'), ('мне', 'S-PRO'), ('девка', 'S'), ('!', 'NONLEX')]
# [('Смирная', 'A=f'), (',', 'NONLEX'), ('веселая', 'A=f'), (',', 'NONLEX'), ('угодливая', 'A=f'), ('и', 'CONJ'), ('умница', 'S'), (',', 'NONLEX'), ('не', 'PART'), ('мне', 'S-PRO'), ('чета', 'S'), ('.', 'NONLEX')]
# [('Она', 'S-PRO'), ('с', 'PR'), ('детства', 'S'), ('узнала', 'V'), (',', 'NONLEX'), ('почем', 'CONJ'), ('фунт', 'S'), ('лиха', 'S'), ('стоит', 'V'), (',', 'NONLEX'), ('может', 'PARENTH'), (',', 'NONLEX'), ('это', 'S-PRO'), ('и', 'CONJ'), ('сказалось', 'V'), ('на', 'PR'), ('ее', 'A=sg'), ('характере', 'S'), ('.', 'NONLEX')]
# [('Со', 'PR'), ('стороны', 'S'), ('глядеть', 'V'), ('–', 'S'), ('не', 'PART'), ('так', 'ADV-PRO'), ('уж', 'PART'), ('она', 'S-PRO'), ('была', 'V'), ('из', 'PR'), ('себя', 'S-PRO=gen'), ('видная', 'A=f'), (',', 'NONLEX'), ('но', 'CONJ'), ('ведь', 'PART'), ('я-то', 'S-PRO'), ('не', 'PART'), ('со', 'PR'), ('стороны', 'S'), ('на', 'PR'), ('нее', 'A=sg'), ('глядел', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('в', 'PR'), ('упор', 'S'), ('.', 'NONLEX')]
# [('И', 'CONJ'), ('не', 'PART'), ('было', 'V'), ('для', 'PR'), ('меня', 'S-PRO'), ('красивей', 'S'), ('и', 'CONJ'), ('желанней', 'A=f'), ('ее', 'S'), (',', 'NONLEX'), ('не', 'PART'), ('было', 'V'), ('на', 'PR'), ('свете', 'S'), ('и', 'CONJ'), ('не', 'PART'), ('будет', 'V'), ('!', 'NONLEX')]
# [('Придешь', 'V'), ('с', 'PR'), ('работы', 'S'), ('усталый', 'A=m'), (',', 'NONLEX'), ('а', 'CONJ'), ('иной', 'A-PRO=m'), ('раз', 'S'), ('и', 'CONJ'), ('злой', 'A=sg'), (',', 'NONLEX'), ('как', 'CONJ'), ('черт', 'S'), ('.', 'NONLEX')]
# [('Нет', 'PART'), (',', 'NONLEX'), ('на', 'PR'), ('грубое', 'A=sg'), ('слово', 'S'), ('она', 'S-PRO'), ('тебе', 'S-PRO'), ('не', 'PART'), ('нагрубит', 'V'), ('в', 'PR'), ('ответ', 'S'), ('.', 'NONLEX'), ('Ласковая', 'A=f'), (',', 'NONLEX'), ('тихая', 'A=f'), (',', 'NONLEX'), ('не', 'PART'), ('знает', 'V'), (',', 'NONLEX'), ('где', 'ADV-PRO'), ('тебя', 'S-PRO'), ('усадить', 'V'), (',', 'NONLEX'), ('бьется', 'V'), (',', 'NONLEX'), ('чтобы', 'CONJ'), ('и', 'CONJ'), ('при', 'PR'), ('малом', 'A=m'), ('достатке', 'S'), ('сладкий', 'A=m'), ('кусок', 'S'), ('тебе', 'S-PRO'), ('сготовить', 'V'), ('.', 'NONLEX')]
# [('Смотришь', 'V'), ('на', 'PR'), ('нее', 'A=n'), ('и', 'CONJ'), ('отходишь', 'V'), ('сердцем', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('спустя', 'PR'), ('немного', 'ADV'), ('обнимешь', 'V'), ('ее', 'S'), (',', 'NONLEX'), ('скажешь', 'V'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Прости', 'S'), (',', 'NONLEX'), ('милая', 'A=f'), ('Иринка', 'S'), (',', 'NONLEX'), ('нахамил', 'V'), ('я', 'S-PRO'), ('тебе', 'S-PRO'), ('.', 'NONLEX')]
# [('Понимаешь', 'V'), (',', 'NONLEX'), ('с', 'PR'), ('работой', 'S'), ('у', 'PR'), ('меня', 'S-PRO'), ('нынче', 'ADV'), ('не', 'PART'), ('заладилось', 'V'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('И', 'CONJ'), ('опять', 'ADV'), ('у', 'PR'), ('нас', 'S-PRO'), ('мир', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('у', 'PR'), ('меня', 'S-PRO'), ('покой', 'S'), ('на', 'PR'), ('душе', 'S'), ('.', 'NONLEX')]
# [('А', 'CONJ'), ('ты', 'S-PRO'), ('знаешь', 'V'), (',', 'NONLEX'), ('браток', 'S'), (',', 'NONLEX'), ('что', 'CONJ'), ('это', 'S-PRO'), ('означает', 'V'), ('для', 'PR'), ('работы', 'S'), ('?', 'NONLEX')]
# [('Утром', 'S'), ('я', 'S-PRO'), ('встаю', 'V'), ('как', 'CONJ'), ('встрепанный', 'A=m'), (',', 'NONLEX'), ('иду', 'V'), ('на', 'PR'), ('завод', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('любая', 'A-PRO=f'), ('работа', 'S'), ('у', 'PR'), ('меня', 'S-PRO'), ('в', 'PR'), ('руках', 'S'), ('кипит', 'V'), ('и', 'CONJ'), ('спорится', 'V'), ('!', 'NONLEX')]
# [('Вот', 'PART'), ('что', 'S-PRO'), ('это', 'S-PRO'), ('означает', 'V'), ('–', 'S'), ('иметь', 'V'), ('умную', 'A=f'), ('жену-подругу', 'S'), ('.', 'NONLEX')]
# [('Приходилось', 'V'), ('кое-когда', 'ADV'), ('после', 'PR'), ('получки', 'S'), ('и', 'CONJ'), ('выпивать', 'V'), ('с', 'PR'), ('товарищами', 'S'), ('.', 'NONLEX')]
# [('Кое-когда', 'ADV-PRO'), ('бывало', 'V'), ('и', 'CONJ'), ('так', 'ADV-PRO'), (',', 'NONLEX'), ('что', 'CONJ'), ('идешь', 'V'), ('домой', 'ADV'), ('и', 'CONJ'), ('такие', 'A-PRO=pl'), ('кренделя', 'S'), ('ногами', 'S'), ('выписываешь', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('со', 'PR'), ('стороны', 'S'), ('небось', 'V'), ('глядеть', 'V'), ('страшно', 'ADV'), ('.', 'NONLEX')]
# [('Тесна', 'S'), ('тебе', 'S-PRO'), ('улица', 'S'), (',', 'NONLEX'), ('да', 'CONJ'), ('и', 'CONJ'), ('шабаш', 'S'), (',', 'NONLEX'), ('не', 'PART'), ('говоря', 'V'), ('уже', 'ADV'), ('про', 'PR'), ('переулки', 'S'), ('.', 'NONLEX')]
# [('Парень', 'S'), ('я', 'S-PRO'), ('был', 'V'), ('тогда', 'ADV-PRO'), ('здоровый', 'A=m'), ('и', 'CONJ'), ('сильный', 'A=m'), (',', 'NONLEX'), ('как', 'CONJ'), ('дьявол', 'S'), (',', 'NONLEX'), ('выпить', 'V'), ('мог', 'V'), ('много', 'NUM=nom'), (',', 'NONLEX'), ('а', 'CONJ'), ('до', 'PR'), ('дому', 'S'), ('всегда', 'ADV-PRO'), ('добирался', 'V'), ('на', 'PR'), ('своих', 'A-PRO=pl'), ('ногах', 'S'), ('.', 'NONLEX')]
# [('Но', 'CONJ'), ('случалось', 'V'), ('иной', 'A-PRO=m'), ('раз', 'S'), ('и', 'CONJ'), ('так', 'ADV-PRO'), (',', 'NONLEX'), ('что', 'CONJ'), ('последний', 'A=m'), ('перегон', 'S'), ('шел', 'V'), ('на', 'PR'), ('первой', 'ANUM=f'), ('скорости', 'S'), (',', 'NONLEX'), ('то', 'S-PRO'), ('есть', 'V'), ('на', 'PR'), ('четвереньках', 'S'), (',', 'NONLEX'), ('однако', 'CONJ'), ('же', 'PART'), ('добирался', 'V'), ('.', 'NONLEX')]
# [('И', 'CONJ'), ('опять', 'ADV'), ('же', 'PART'), ('ни', 'PART'), ('тебе', 'S-PRO'), ('упрека', 'S'), (',', 'NONLEX'), ('ни', 'CONJ'), ('крика', 'S'), (',', 'NONLEX'), ('ни', 'CONJ'), ('скандала', 'S'), ('.', 'NONLEX')]
# [('Только', 'PART'), ('посмеивается', 'V'), ('моя', 'A-PRO=sg'), ('Иринка', 'S'), (',', 'NONLEX'), ('да', 'CONJ'), ('и', 'CONJ'), ('то', 'S-PRO'), ('осторожно', 'ADV'), (',', 'NONLEX'), ('чтобы', 'CONJ'), ('я', 'S-PRO'), ('спьяну', 'ADV'), ('не', 'PART'), ('обиделся', 'V'), ('.', 'NONLEX')]
# [('Разует', 'V'), ('меня', 'S-PRO'), ('и', 'CONJ'), ('шепчет', 'V'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Ложись', 'V'), ('к', 'PR'), ('стенке', 'S'), (',', 'NONLEX'), ('Андрюша', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('то', 'S-PRO'), ('сонный', 'A=m'), ('упадешь', 'V'), ('с', 'PR'), ('кровати', 'S'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('Ну', 'PART'), (',', 'NONLEX'), ('я', 'S-PRO'), ('как', 'CONJ'), ('куль', 'S'), ('с', 'PR'), ('овсом', 'S'), (',', 'NONLEX'), ('упаду', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('все', 'A-PRO=pl'), ('поплывет', 'S'), ('перед', 'PR'), ('глазами', 'S'), ('.', 'NONLEX')]
# [('Только', 'PART'), ('слышу', 'V'), ('сквозь', 'PR'), ('сон', 'S'), (',', 'NONLEX'), ('что', 'CONJ'), ('она', 'S-PRO'), ('по', 'PR'), ('голове', 'S'), ('меня', 'S-PRO'), ('тихонько', 'ADV'), ('гладит', 'V'), ('рукою', 'S'), ('и', 'CONJ'), ('шепчет', 'V'), ('что-то', 'S-PRO'), ('ласковое', 'A=n'), (',', 'NONLEX'), ('жалеет', 'V'), (',', 'NONLEX'), ('значит…', 'V'), ('Утром', 'S'), ('она', 'S-PRO'), ('меня', 'S-PRO'), ('часа', 'S'), ('за', 'PR'), ('два', 'NUM=m'), ('до', 'PR'), ('работы', 'S'), ('на', 'PR'), ('ноги', 'S'), ('подымет', 'V'), (',', 'NONLEX'), ('чтобы', 'CONJ'), ('я', 'S-PRO'), ('размялся', 'V'), ('.', 'NONLEX')]
# [('Знает', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('на', 'PR'), ('похмелье', 'S'), ('я', 'S-PRO'), ('ничего', 'S-PRO'), ('есть', 'V'), ('не', 'PART'), ('буду', 'V'), (',', 'NONLEX'), ('ну', 'PART'), (',', 'NONLEX'), ('достанет', 'V'), ('огурец', 'S'), ('соленый', 'A=m'), ('или', 'CONJ'), ('еще', 'ADV'), ('что-нибудь', 'S-PRO'), ('по', 'PR'), ('легости', 'S'), (',', 'NONLEX'), ('нальет', 'V'), ('граненый', 'A=m'), ('стаканчик', 'S'), ('водки', 'S'), ('.', 'NONLEX')]
# [('«', 'NONLEX'), ('Похмелись', 'V'), (',', 'NONLEX'), ('Андрюша', 'S'), (',', 'NONLEX'), ('только', 'CONJ'), ('больше', 'ADV'), ('не', 'PART'), ('надо', 'PRAEDIC'), (',', 'NONLEX'), ('мой', 'A-PRO=m'), ('милый', 'A=sg'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('Да', 'CONJ'), ('разве', 'PART'), ('же', 'PART'), ('можно', 'PRAEDIC'), ('не', 'PART'), ('оправдать', 'V'), ('такого', 'A-PRO=n'), ('доверия', 'S'), ('?', 'NONLEX')]
# [('Выпью', 'S'), (',', 'NONLEX'), ('поблагодарю', 'V'), ('ее', 'S'), ('без', 'PR'), ('слов', 'S'), (',', 'NONLEX'), ('одними', 'V'), ('глазами', 'S'), ('поцелую', 'A=f'), ('и', 'CONJ'), ('пошел', 'V'), ('на', 'PR'), ('работу', 'S'), (',', 'NONLEX'), ('как', 'CONJ'), ('миленький', 'A=m'), ('.', 'NONLEX')]
# [('А', 'CONJ'), ('скажи', 'V'), ('она', 'S-PRO'), ('мне', 'S-PRO'), (',', 'NONLEX'), ('хмельному', 'A=m'), (',', 'NONLEX'), ('слово', 'S'), ('поперек', 'S'), (',', 'NONLEX'), ('крикни', 'S'), ('или', 'CONJ'), ('обругайся', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('я', 'S-PRO'), ('бы', 'PART'), (',', 'NONLEX'), ('как', 'CONJ'), ('бог', 'S'), ('свят', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('на', 'PR'), ('второй', 'ANUM=m'), ('день', 'S'), ('напился', 'V'), ('.', 'NONLEX')]
# [('Так', 'ADV-PRO'), ('бывает', 'V'), ('в', 'PR'), ('иных', 'A-PRO=pl'), ('семьях', 'S'), (',', 'NONLEX'), ('где', 'ADV-PRO'), ('жена', 'S'), ('дура', 'S'), (';', 'NONLEX'), ('насмотрелся', 'V'), ('я', 'S-PRO'), ('на', 'PR'), ('таких', 'A-PRO=pl'), ('шалав', 'S'), (',', 'NONLEX'), ('знаю', 'V'), ('.', 'NONLEX')]
# [('Вскорости', 'S'), ('дети', 'S'), ('у', 'PR'), ('нас', 'S-PRO'), ('пошли', 'V'), ('.', 'NONLEX')]
# [('Сначала', 'ADV'), ('сынишка', 'S'), ('родился', 'V'), (',', 'NONLEX'), ('через', 'PR'), ('года', 'S'), ('?', 'NONLEX')]
# [('еще', 'ADV'), ('две', 'NUM=f'), ('девочки…', 'S'), ('Тут', 'ADV-PRO'), ('я', 'S-PRO'), ('от', 'PR'), ('товарищей', 'S'), ('откололся', 'V'), ('.', 'NONLEX')]
# [('Всю', 'A-PRO=f'), ('получку', 'S'), ('домой', 'ADV'), ('несу', 'S'), (',', 'NONLEX'), ('семья', 'S'), ('стала', 'V'), ('числом', 'S'), ('порядочная', 'A=f'), (',', 'NONLEX'), ('не', 'PART'), ('до', 'PR'), ('выпивки', 'S'), ('.', 'NONLEX')]
# [('В', 'PR'), ('выходной', 'A=f'), ('кружку', 'S'), ('пива', 'S'), ('выпью', 'V'), ('и', 'CONJ'), ('на', 'PR'), ('этом', 'S-PRO'), ('ставлю', 'V'), ('точку', 'S'), ('.', 'NONLEX')]
# [('В', 'PR'), ('двадцать', 'NUM=nom'), ('девятом', 'ANUM=m'), ('году', 'S'), ('завлекли', 'V'), ('меня', 'S-PRO'), ('машины', 'S'), ('.', 'NONLEX')]
# [('Изучил', 'V'), ('автодело', 'S'), (',', 'NONLEX'), ('сел', 'V'), ('за', 'PR'), ('баранку', 'S'), (',', 'NONLEX'), ('на', 'PR'), ('грузовой', 'A=f'), ('.', 'NONLEX')]
# [('Потом', 'ADV-PRO'), ('втянулся', 'V'), ('и', 'CONJ'), ('уже', 'ADV'), ('не', 'PART'), ('захотел', 'V'), ('возвращаться', 'V'), ('на', 'PR'), ('завод', 'S'), ('.', 'NONLEX')]
# [('За', 'PR'), ('рулем', 'S'), ('показалось', 'V'), ('мне', 'S-PRO'), ('веселее', 'A=comp'), ('.', 'NONLEX')]
# [('Так', 'ADV-PRO'), ('и', 'CONJ'), ('прожил', 'V'), ('десять', 'NUM=acc'), ('лет', 'S'), ('и', 'CONJ'), ('не', 'PART'), ('заметил', 'V'), (',', 'NONLEX'), ('как', 'CONJ'), ('они', 'S-PRO'), ('прошли', 'V'), ('.', 'NONLEX')]
# [('Прошли', 'V'), ('как', 'ADV-PRO'), ('будто', 'PART'), ('во', 'PR'), ('сне', 'S'), ('.', 'NONLEX')]
# [('Да', 'CONJ'), ('что', 'S-PRO'), ('десять', 'NUM=nom'), ('лет', 'S'), ('!', 'NONLEX')]
# [('Спроси', 'V'), ('у', 'PR'), ('любого', 'A-PRO=m'), ('пожилого', 'A=m'), ('человека', 'S'), (',', 'NONLEX'), ('приметил', 'V'), ('он', 'S-PRO'), (',', 'NONLEX'), ('как', 'CONJ'), ('жизнь', 'S'), ('прожил', 'V'), ('?', 'NONLEX')]
# [('Ни', 'PART'), ('черта', 'S'), ('он', 'S-PRO'), ('не', 'PART'), ('приметил', 'V'), ('!', 'NONLEX')]
# [('Прошлое', 'S'), ('–', 'NONLEX'), ('вот', 'PART'), ('как', 'CONJ'), ('та', 'A-PRO=f'), ('дальняя', 'A=f'), ('степь', 'S'), ('в', 'PR'), ('дымке', 'S'), ('.', 'NONLEX')]
# [('Утром', 'S'), ('я', 'S-PRO'), ('шел', 'V'), ('по', 'PR'), ('ней', 'S-PRO'), (',', 'NONLEX'), ('все', 'S-PRO'), ('было', 'V'), ('ясно', 'PRAEDIC'), ('кругом', 'ADV'), (',', 'NONLEX'), ('а', 'CONJ'), ('отшагал', 'V'), ('двадцать', 'NUM=nom'), ('километров', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('вот', 'PART'), ('уже', 'ADV'), ('затянула', 'V'), ('степь', 'S'), ('дымка', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('отсюда', 'ADV-PRO'), ('уже', 'ADV'), ('не', 'PART'), ('отличишь', 'V'), ('лес', 'S'), ('от', 'PR'), ('бурьяна', 'S'), (',', 'NONLEX'), ('пашню', 'S'), ('от', 'PR'), ('травокоса…', 'S'), ('Работал', 'V'), ('я', 'S-PRO'), ('эти', 'A-PRO=pl'), ('десять', 'NUM=acc'), ('лет', 'S'), ('и', 'CONJ'), ('день', 'S'), ('и', 'CONJ'), ('ночь', 'S'), ('.', 'NONLEX')]
# [('Зарабатывал', 'V'), ('хорошо', 'ADV'), (',', 'NONLEX'), ('и', 'CONJ'), ('жили', 'V'), ('мы', 'S-PRO'), ('не', 'PART'), ('хуже', 'ADV=comp'), ('людей', 'S'), ('.', 'NONLEX')]
# [('И', 'CONJ'), ('дети', 'S'), ('радовали', 'V'), (':', 'NONLEX'), ('все', 'A-PRO=pl'), ('трое', 'NUM=nom'), ('учились', 'V'), ('на', 'PR'), ('«', 'NONLEX'), ('отлично', 'ADV'), ('»', 'NONLEX'), (',', 'NONLEX'), ('а', 'CONJ'), ('старшенький', 'A=m'), (',', 'NONLEX'), ('Анатолий', 'S'), (',', 'NONLEX'), ('оказался', 'V'), ('таким', 'A-PRO=m'), ('способным', 'A=m'), ('к', 'PR'), ('математике', 'S'), (',', 'NONLEX'), ('что', 'CONJ'), ('про', 'PR'), ('него', 'S-PRO'), ('даже', 'PART'), ('в', 'PR'), ('центральной', 'A=f'), ('газете', 'S'), ('писали', 'V'), ('.', 'NONLEX')]
# [('Откуда', 'ADV-PRO'), ('у', 'PR'), ('него', 'S-PRO'), ('проявился', 'V'), ('такой', 'A-PRO=m'), ('огромадный', 'A=m'), ('талант', 'S'), ('к', 'PR'), ('этой', 'A-PRO=f'), ('науке', 'S'), (',', 'NONLEX'), ('я', 'S-PRO'), ('и', 'CONJ'), ('сам', 'A-PRO=m'), (',', 'NONLEX'), ('браток', 'S'), (',', 'NONLEX'), ('не', 'PART'), ('знаю', 'V'), ('.', 'NONLEX')]
# [('Только', 'PART'), ('очень', 'ADV'), ('мне', 'S-PRO'), ('это', 'S-PRO'), ('было', 'V'), ('лестно', 'A=n'), (',', 'NONLEX'), ('и', 'CONJ'), ('гордился', 'V'), ('я', 'S-PRO'), ('им', 'S-PRO'), (',', 'NONLEX'), ('страсть', 'S'), ('как', 'CONJ'), ('гордился', 'V'), ('!', 'NONLEX')]
# [('За', 'PR'), ('десять', 'NUM=acc'), ('лет', 'S'), ('скопили', 'V'), ('мы', 'S-PRO'), ('немного', 'ADV'), ('деньжонок', 'S'), ('и', 'CONJ'), ('перед', 'PR'), ('войной', 'S'), ('поставили', 'V'), ('себе', 'S-PRO=dat'), ('домишко', 'S'), ('об', 'PR'), ('двух', 'NUM=f'), ('комнатках', 'S'), (',', 'NONLEX'), ('с', 'PR'), ('кладовкой', 'S'), ('и', 'CONJ'), ('коридорчиком', 'S'), ('.', 'NONLEX')]
# [('Ирина', 'S'), ('купила', 'V'), ('двух', 'NUM=m'), ('коз', 'S'), ('.', 'NONLEX')]
# [('Чего', 'S-PRO'), ('еще', 'ADV'), ('больше', 'ADV-PRO=comp'), ('надо', 'PRAEDIC'), ('?', 'NONLEX')]
# [('Дети', 'S'), ('кашу', 'S'), ('едят', 'V'), ('с', 'PR'), ('молоком', 'S'), (',', 'NONLEX'), ('крыша', 'S'), ('над', 'PR'), ('головою', 'S'), ('есть', 'V'), (',', 'NONLEX'), ('одеты', 'S'), (',', 'NONLEX'), ('обуты', 'V'), (',', 'NONLEX'), ('стало', 'V'), ('быть', 'V'), (',', 'NONLEX'), ('все', 'S-PRO'), ('в', 'PR'), ('порядке', 'S'), ('.', 'NONLEX')]
# [('Только', 'PART'), ('построился', 'V'), ('я', 'S-PRO'), ('неловко', 'ADV'), ('.', 'NONLEX')]
# [('Отвели', 'V'), ('мне', 'S-PRO'), ('участок', 'S'), ('в', 'PR'), ('шесть', 'NUM=acc'), ('соток', 'S'), ('неподалеку', 'S'), ('от', 'PR'), ('авиазавода', 'S'), ('.', 'NONLEX')]
# [('Будь', 'V'), ('моя', 'A-PRO=f'), ('хибарка', 'S'), ('в', 'PR'), ('другом', 'A-PRO=n'), ('месте', 'S'), (',', 'NONLEX'), ('может', 'PARENTH'), (',', 'NONLEX'), ('и', 'CONJ'), ('жизнь', 'S'), ('сложилась', 'V'), ('бы', 'PART'), ('иначе…', 'S'), ('А', 'INIT=abbr'), ('тут', 'ADV-PRO'), ('вот', 'PART'), ('она', 'S-PRO'), (',', 'NONLEX'), ('война', 'S'), ('.', 'NONLEX')]
# [('На', 'PR'), ('второй', 'ANUM=m'), ('день', 'S'), ('повестка', 'S'), ('из', 'PR'), ('военкомата', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('на', 'PR'), ('третий', 'ANUM=m'), ('–', 'S'), ('пожалуйте', 'V'), ('в', 'PR'), ('эшелон', 'S'), ('.', 'NONLEX')]
# [('Провожали', 'V'), ('меня', 'S-PRO'), ('все', 'A-PRO=pl'), ('четверо', 'NUM=nom'), ('моих', 'A-PRO=pl'), (':', 'NONLEX'), ('Ирина', 'S'), (',', 'NONLEX'), ('Анатолий', 'S'), ('и', 'CONJ'), ('дочери', 'S'), ('–', 'NONLEX'), ('Настенька', 'S'), ('и', 'CONJ'), ('Олюшка', 'S'), ('.', 'NONLEX')]
# [('Все', 'A-PRO=pl'), ('ребята', 'S'), ('держались', 'V'), ('молодцом', 'S'), ('.', 'NONLEX')]
# [('Ну', 'PART'), (',', 'NONLEX'), ('у', 'PR'), ('дочерей', 'S'), ('–', 'S'), ('не', 'PART'), ('без', 'PR'), ('того', 'S-PRO'), (',', 'NONLEX'), ('посверкивали', 'V'), ('слезинки', 'S'), ('.', 'NONLEX')]
# [('Анатолий', 'S'), ('только', 'PART'), ('плечами', 'S'), ('передергивал', 'V'), (',', 'NONLEX'), ('как', 'CONJ'), ('от', 'PR'), ('холода', 'S'), (',', 'NONLEX'), ('ему', 'S-PRO'), ('к', 'PR'), ('тому', 'A-PRO=n'), ('времени', 'S'), ('уже', 'ADV'), ('семнадцатый', 'ANUM=m'), ('год', 'S'), ('шел', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('Ирина', 'S'), ('моя…', 'S'), ('Такой', 'A-PRO=m'), ('я', 'S-PRO'), ('ее', 'V'), ('за', 'PR'), ('все', 'A-PRO=pl'), ('семнадцать', 'NUM=acc'), ('лет', 'S'), ('нашей', 'A-PRO=f'), ('совместной', 'A=f'), ('жизни', 'S'), ('ни', 'PART'), ('разу', 'S'), ('не', 'PART'), ('видал', 'V'), ('.', 'NONLEX')]
# [('Ночью', 'S'), ('у', 'PR'), ('меня', 'S-PRO'), ('на', 'PR'), ('плече', 'S'), ('и', 'CONJ'), ('на', 'PR'), ('груди', 'S'), ('рубаха', 'S'), ('от', 'PR'), ('ее', 'S'), ('слез', 'V'), ('не', 'PART'), ('просыхала', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('утром', 'S'), ('такая', 'A-PRO=f'), ('же', 'PART'), ('история…', 'S'), ('Пришли', 'V'), ('на', 'PR'), ('вокзал', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('я', 'S-PRO'), ('на', 'PR'), ('нее', 'NUM=loc'), ('от', 'PR'), ('жалости', 'S'), ('глядеть', 'V'), ('не', 'PART'), ('могу', 'V'), (':', 'NONLEX'), ('губы', 'S'), ('от', 'PR'), ('слез', 'V'), ('распухли', 'V'), (',', 'NONLEX'), ('волосы', 'S'), ('из-под', 'PR'), ('платка', 'S'), ('выбились', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('глаза', 'S'), ('мутные', 'A=pl'), (',', 'NONLEX'), ('несмысленные', 'A=pl'), (',', 'NONLEX'), ('как', 'CONJ'), ('у', 'PR'), ('тронутого', 'A=m'), ('умом', 'S'), ('человека', 'S'), ('.', 'NONLEX')]
# ...
# [('До', 'PR'), ('поздней', 'A=f'), ('ночи', 'S'), ('ожидал', 'V'), ('там', 'ADV-PRO'), ('.', 'NONLEX')]
# [('Трудно', 'PRAEDIC'), ('мне', 'S-PRO'), ('с', 'PR'), ('ним', 'S-PRO'), ('было', 'V'), ('на', 'PR'), ('первых', 'ANUM=pl'), ('порах', 'S'), ('.', 'NONLEX')]
# [('Один', 'A-PRO=m'), ('раз', 'S'), ('легли', 'V'), ('спать', 'V'), ('еще', 'ADV'), ('засветло', 'V'), (',', 'NONLEX'), ('днем', 'S'), ('наморился', 'V'), ('я', 'S-PRO'), ('очень', 'ADV'), (',', 'NONLEX'), ('и', 'CONJ'), ('он', 'S-PRO'), ('–', 'NONLEX'), ('то', 'CONJ'), ('всегда', 'ADV-PRO'), ('щебечет', 'V'), (',', 'NONLEX'), ('как', 'CONJ'), ('воробушек', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('то', 'S-PRO'), ('что-то', 'S-PRO'), ('примолчался', 'V'), ('.', 'NONLEX')]
# [('Спрашиваю', 'V'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Ты', 'S-PRO'), ('о', 'PR'), ('чем', 'S-PRO'), ('думаешь', 'V'), (',', 'NONLEX'), ('сынок', 'S'), ('?', 'NONLEX'), ('»', 'NONLEX'), ('А', 'CONJ'), ('он', 'S-PRO'), ('меня', 'S-PRO'), ('спрашивает', 'V'), (',', 'NONLEX'), ('сам', 'A-PRO=m'), ('в', 'PR'), ('потолок', 'S'), ('смотрит', 'V'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Папка', 'S'), (',', 'NONLEX'), ('ты', 'S-PRO'), ('куда', 'ADV-PRO'), ('свое', 'A=n'), ('кожаное', 'A=n'), ('пальто', 'S'), ('дел', 'S'), ('?', 'NONLEX'), ('»', 'NONLEX'), ('В', 'PR'), ('жизни', 'S'), ('у', 'PR'), ('меня', 'S-PRO'), ('никогда', 'ADV-PRO'), ('не', 'PART'), ('было', 'V'), ('кожаного', 'A=n'), ('пальто', 'S'), ('!', 'NONLEX')]
# [('Пришлось', 'V'), ('изворачиваться', 'V'), (':', 'NONLEX'), ('«', 'NONLEX'), ('В', 'PR'), ('Воронеже', 'S'), ('осталось', 'V'), ('»', 'NONLEX'), (',', 'NONLEX'), ('–', 'NONLEX'), ('говорю', 'V'), ('ему', 'S-PRO'), ('.', 'NONLEX')]
# [('«', 'NONLEX'), ('А', 'CONJ'), ('почему', 'ADV-PRO'), ('ты', 'S-PRO'), ('меня', 'S-PRO'), ('так', 'ADV-PRO'), ('долго', 'ADV'), ('искал', 'V'), ('?', 'NONLEX'), ('»', 'NONLEX'), ('Отвечаю', 'V'), ('ему', 'S-PRO'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Я', 'S-PRO'), ('тебя', 'S-PRO'), (',', 'NONLEX'), ('сынок', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('в', 'PR'), ('Германии', 'S'), ('искал', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('в', 'PR'), ('Польше', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('всю', 'A-PRO=f'), ('Белоруссию', 'S'), ('прошел', 'V'), ('и', 'CONJ'), ('проехал', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('ты', 'S-PRO'), ('в', 'PR'), ('Урюпинске', 'S'), ('оказался', 'V'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('–', 'NONLEX'), ('«', 'NONLEX'), ('А', 'CONJ'), ('Урюпинск', 'S'), ('–', 'S'), ('это', 'S-PRO'), ('ближе', 'A=comp'), ('Германии', 'S'), ('?', 'NONLEX')]
# [('А', 'CONJ'), ('до', 'PR'), ('Польши', 'S'), ('далеко', 'ADV'), ('от', 'PR'), ('нашего', 'A-PRO=m'), ('дома', 'S'), ('?', 'NONLEX'), ('»', 'NONLEX'), ('Так', 'ADV-PRO'), ('и', 'CONJ'), ('болтаем', 'V'), ('с', 'PR'), ('ним', 'S-PRO'), ('перед', 'PR'), ('сном', 'S'), ('.', 'NONLEX')]
# [('А', 'CONJ'), ('ты', 'S-PRO'), ('думаешь', 'V'), (',', 'NONLEX'), ('браток', 'S'), (',', 'NONLEX'), ('про', 'PR'), ('кожаное', 'A=n'), ('пальто', 'S'), ('он', 'S-PRO'), ('зря', 'ADV'), ('спросил', 'V'), ('?', 'NONLEX')]
# [('Нет', 'PART'), (',', 'NONLEX'), ('все', 'A-PRO=pl'), ('это', 'S-PRO'), ('неспроста', 'ADV'), ('.', 'NONLEX')]
# [('Значит', 'PARENTH'), (',', 'NONLEX'), ('когда-то', 'ADV-PRO'), ('отец', 'S'), ('его', 'A-PRO'), ('настоящий', 'A=m'), ('носил', 'V'), ('такое', 'A-PRO=n'), ('пальто', 'S'), (',', 'NONLEX'), ('вот', 'PART'), ('ему', 'S-PRO'), ('и', 'CONJ'), ('запомнилось', 'V'), ('.', 'NONLEX')]
# [('Ведь', 'CONJ'), ('детская', 'A=f'), ('память', 'S'), (',', 'NONLEX'), ('как', 'CONJ'), ('летняя', 'A=f'), ('зарница', 'S'), (':', 'NONLEX'), ('вспыхнет', 'V'), (',', 'NONLEX'), ('накоротке', 'S'), ('осветит', 'V'), ('все', 'A-PRO=pl'), ('и', 'CONJ'), ('потухнет', 'V'), ('.', 'NONLEX')]
# [('Так', 'ADV-PRO'), ('и', 'CONJ'), ('у', 'PR'), ('него', 'S-PRO'), ('память', 'S'), (',', 'NONLEX'), ('вроде', 'PR'), ('зарницы', 'S'), (',', 'NONLEX'), ('проблесками', 'S'), ('работает', 'V'), ('.', 'NONLEX')]
# [('Может', 'PARENTH'), (',', 'NONLEX'), ('и', 'CONJ'), ('жили', 'V'), ('бы', 'PART'), ('мы', 'S-PRO'), ('с', 'PR'), ('ним', 'S-PRO'), ('еще', 'ADV'), ('годик', 'S'), ('в', 'PR'), ('Урюпинске', 'S'), (',', 'NONLEX'), ('но', 'CONJ'), ('в', 'PR'), ('ноябре', 'S'), ('случился', 'V'), ('со', 'PR'), ('мной', 'S-PRO'), ('грех', 'S'), (':', 'NONLEX'), ('ехал', 'V'), ('по', 'PR'), ('грязи', 'S'), (',', 'NONLEX'), ('в', 'PR'), ('одном', 'A-PRO=m'), ('хуторе', 'S'), ('машину', 'S'), ('мою', 'A-PRO=f'), ('занесло', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('тут', 'ADV-PRO'), ('корова', 'S'), ('подвернулась', 'V'), (',', 'NONLEX'), ('я', 'S-PRO'), ('и', 'CONJ'), ('сбил', 'V'), ('ее', 'S'), ('с', 'PR'), ('ног', 'S'), ('.', 'NONLEX')]
# [('Ну', 'PART'), (',', 'NONLEX'), ('известное', 'A=n'), ('дело', 'S'), (',', 'NONLEX'), ('бабы', 'CONJ'), ('крик', 'S'), ('подняли', 'V'), (',', 'NONLEX'), ('народ', 'S'), ('сбежался', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('автоинспектор', 'S'), ('тут', 'ADV-PRO'), ('как', 'ADV-PRO'), ('тут', 'ADV-PRO'), ('.', 'NONLEX')]
# [('Отобрал', 'V'), ('у', 'PR'), ('меня', 'S-PRO'), ('шоферскую', 'A=f'), ('книжку', 'S'), (',', 'NONLEX'), ('как', 'CONJ'), ('я', 'S-PRO'), ('ни', 'PART'), ('просил', 'V'), ('его', 'S-PRO'), ('смилостивиться', 'V'), ('.', 'NONLEX')]
# [('Корова', 'S'), ('поднялась', 'V'), (',', 'NONLEX'), ('хвост', 'S'), ('задрала', 'V'), ('и', 'CONJ'), ('пошла', 'V'), ('скакать', 'V'), ('по', 'PR'), ('переулкам', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('я', 'S-PRO'), ('книжки', 'S'), ('лишился', 'V'), ('.', 'NONLEX')]
# [('Зиму', 'S'), ('проработал', 'V'), ('плотником', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('потом', 'ADV-PRO'), ('списался', 'V'), ('с', 'PR'), ('одним', 'ANUM=sg'), ('приятелем', 'S'), (',', 'NONLEX'), ('тоже', 'PART'), ('сослуживцем', 'S'), (',', 'NONLEX'), ('–', 'S'), ('он', 'S-PRO'), ('в', 'PR'), ('вашей', 'A-PRO=f'), ('области', 'S'), (',', 'NONLEX'), ('в', 'PR'), ('Кашарском', 'A=m'), ('районе', 'S'), (',', 'NONLEX'), ('работает', 'V'), ('шофером', 'S'), (',', 'NONLEX'), ('–', 'NONLEX'), ('и', 'CONJ'), ('тот', 'A-PRO=m'), ('пригласил', 'V'), ('меня', 'S-PRO'), ('к', 'PR'), ('себе', 'S-PRO=dat'), ('.', 'NONLEX')]
# [('Пишет', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), (',', 'NONLEX'), ('мол', 'PARENTH'), (',', 'NONLEX'), ('поработаешь', 'V'), ('полгода', 'S'), ('по', 'PR'), ('плотницкой', 'A=f'), ('части', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('там', 'ADV-PRO'), ('в', 'PR'), ('нашей', 'A-PRO=f'), ('области', 'S'), ('выдадут', 'V'), ('тебе', 'S-PRO'), ('новую', 'A=f'), ('книжку', 'S'), ('.', 'NONLEX')]
# [('Вот', 'PART'), ('мы', 'S-PRO'), ('с', 'PR'), ('сынком', 'S'), ('и', 'CONJ'), ('командируемся', 'V'), ('в', 'PR'), ('Кашары', 'S'), ('походным', 'A=m'), ('порядком', 'S'), ('.', 'NONLEX')]
# [('Да', 'CONJ'), ('оно', 'S-PRO'), (',', 'NONLEX'), ('как', 'CONJ'), ('тебе', 'S-PRO'), ('сказать', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('не', 'PART'), ('случись', 'V'), ('у', 'PR'), ('меня', 'S-PRO'), ('этой', 'A-PRO=f'), ('аварии', 'S'), ('с', 'PR'), ('коровой', 'S'), (',', 'NONLEX'), ('я', 'S-PRO'), ('все', 'S-PRO'), ('равно', 'ADV'), ('подался', 'V'), ('бы', 'PART'), ('из', 'PR'), ('Урюпинска', 'S'), ('.', 'NONLEX')]
# [('Тоска', 'S'), ('мне', 'S-PRO'), ('не', 'PART'), ('дает', 'V'), ('на', 'PR'), ('одном', 'A-PRO=n'), ('месте', 'S'), ('долго', 'ADV'), ('засиживаться', 'V'), ('.', 'NONLEX')]
# [('Вот', 'PART'), ('уже', 'ADV'), ('когда', 'CONJ'), ('Ванюшка', 'S'), ('мой', 'A-PRO=m'), ('подрастет', 'S'), ('и', 'CONJ'), ('придется', 'V'), ('определять', 'V'), ('его', 'S-PRO'), ('в', 'PR'), ('школу', 'S'), (',', 'NONLEX'), ('тогда', 'ADV-PRO'), (',', 'NONLEX'), ('может', 'PARENTH'), (',', 'NONLEX'), ('и', 'CONJ'), ('я', 'S-PRO'), ('угомонюсь', 'V'), (',', 'NONLEX'), ('осяду', 'V'), ('на', 'PR'), ('одном', 'ANUM=n'), ('месте', 'S'), ('.', 'NONLEX')]
# [('А', 'CONJ'), ('сейчас', 'ADV-PRO'), ('пока', 'ADV'), ('шагаем', 'V'), ('с', 'PR'), ('ним', 'S-PRO'), ('по', 'PR'), ('русской', 'A=f'), ('земле', 'S'), ('.', 'NONLEX')]
# [('–', 'S'), ('Тяжело', 'PRAEDIC'), ('ему', 'S-PRO'), ('идти', 'V'), (',', 'NONLEX'), ('–', 'S'), ('сказал', 'V'), ('я', 'S-PRO'), ('.', 'NONLEX')]
# [('–', 'V'), ('Так', 'ADV-PRO'), ('он', 'S-PRO'), ('вовсе', 'ADV'), ('мало', 'ADV'), ('на', 'PR'), ('своих', 'A-PRO=pl'), ('ногах', 'S'), ('идет', 'V'), (',', 'NONLEX'), ('все', 'S-PRO'), ('больше', 'ADV'), ('на', 'PR'), ('мне', 'S-PRO'), ('едет', 'V'), ('.', 'NONLEX')]
# [('Посажу', 'V'), ('его', 'S-PRO'), ('на', 'PR'), ('плечи', 'S'), ('и', 'CONJ'), ('несу', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('захочет', 'V'), ('промяться', 'V'), ('–', 'S'), ('слезает', 'V'), ('с', 'PR'), ('меня', 'S-PRO'), ('и', 'CONJ'), ('бегает', 'V'), ('сбоку', 'ADV'), ('дороги', 'S'), (',', 'NONLEX'), ('взбрыкивает', 'V'), (',', 'NONLEX'), ('как', 'CONJ'), ('козленок', 'S'), ('.', 'NONLEX')]
# [('Все', 'A-PRO=pl'), ('это', 'S-PRO'), (',', 'NONLEX'), ('браток', 'S'), (',', 'NONLEX'), ('ничего', 'S-PRO'), ('бы', 'PART'), (',', 'NONLEX'), ('как-нибудь', 'ADV-PRO'), ('мы', 'S-PRO'), ('с', 'PR'), ('ним', 'S-PRO'), ('прожили', 'V'), ('бы', 'PART'), (',', 'NONLEX'), ('да', 'CONJ'), ('вот', 'PART'), ('сердце', 'S'), ('у', 'PR'), ('меня', 'S-PRO'), ('раскачалось', 'V'), (',', 'NONLEX'), ('поршня', 'S'), ('надо', 'PRAEDIC'), ('менять…', 'S'), ('Иной', 'A-PRO=m'), ('раз', 'S'), ('так', 'ADV-PRO'), ('схватит', 'V'), ('и', 'CONJ'), ('прижмет', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('белый', 'A=m'), ('свет', 'S'), ('в', 'PR'), ('глазах', 'S'), ('меркнет', 'S'), ('.', 'NONLEX')]
# [('Боюсь', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('когда-нибудь', 'ADV-PRO'), ('во', 'PR'), ('сне', 'S'), ('помру', 'S'), ('и', 'CONJ'), ('напугаю', 'V'), ('своего', 'A-PRO=m'), ('сынишку', 'S'), ('.', 'NONLEX')]
# [('А', 'CONJ'), ('тут', 'ADV-PRO'), ('еще', 'ADV'), ('одна', 'ANUM=f'), ('беда', 'S'), (':', 'NONLEX'), ('почти', 'ADV'), ('каждую', 'A-PRO=f'), ('ночь', 'S'), ('своих', 'A-PRO=pl'), ('покойников', 'S'), ('дорогих', 'A=pl'), ('во', 'PR'), ('сне', 'S'), ('вижу', 'V'), ('.', 'NONLEX')]
# [('И', 'CONJ'), ('все', 'S-PRO'), ('больше', 'ADV'), ('так', 'ADV-PRO'), (',', 'NONLEX'), ('что', 'CONJ'), ('я', 'S-PRO'), ('–', 'V'), ('за', 'PR'), ('колючей', 'S'), ('проволокой', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('они', 'S-PRO'), ('на', 'PR'), ('воле', 'S'), (',', 'NONLEX'), ('по', 'PR'), ('другую', 'A-PRO=f'), ('сторону…', 'S'), ('Разговариваю', 'V'), ('обо', 'PR'), ('всем', 'S-PRO'), ('и', 'CONJ'), ('с', 'PR'), ('Ириной', 'S'), ('и', 'CONJ'), ('с', 'PR'), ('детишками', 'S'), (',', 'NONLEX'), ('но', 'CONJ'), ('только', 'PART'), ('хочу', 'V'), ('проволоку', 'V'), ('руками', 'S'), ('раздвинуть', 'V'), ('–', 'S'), ('они', 'S-PRO'), ('уходят', 'V'), ('от', 'PR'), ('меня', 'S-PRO'), (',', 'NONLEX'), ('будто', 'CONJ'), ('тают', 'V'), ('на', 'PR'), ('глазах…', 'S'), ('И', 'CONJ'), ('вот', 'PART'), ('удивительное', 'A=n'), ('дело', 'S'), (':', 'NONLEX'), ('днем', 'S'), ('я', 'S-PRO'), ('всегда', 'ADV-PRO'), ('крепко', 'ADV'), ('себя', 'S-PRO=acc'), ('держу', 'S'), (',', 'NONLEX'), ('из', 'PR'), ('меня', 'S-PRO'), ('ни', 'CONJ'), ('«', 'NONLEX'), ('оха', 'V'), ('»', 'NONLEX'), (',', 'NONLEX'), ('ни', 'CONJ'), ('вздоха', 'S'), ('не', 'PART'), ('выжмешь', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('ночью', 'S'), ('проснусь', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('вся', 'A-PRO=f'), ('подушка', 'S'), ('мокрая', 'A=f'), ('от', 'PR'), ('слез…', 'S'), ('В', 'PR'), ('лесу', 'S'), ('послышался', 'V'), ('голос', 'S'), ('моего', 'A-PRO=m'), ('товарища', 'S'), (',', 'NONLEX'), ('плеск', 'S'), ('весла', 'V'), ('по', 'PR'), ('воде', 'S'), ('.', 'NONLEX')]
# [('Чужой', 'S'), (',', 'NONLEX'), ('но', 'CONJ'), ('ставший', 'V'), ('мне', 'S-PRO'), ('близким', 'A=sg'), ('человек', 'S'), ('поднялся', 'V'), (',', 'NONLEX'), ('протянул', 'V'), ('большую', 'A=f'), (',', 'NONLEX'), ('твердую', 'A=f'), (',', 'NONLEX'), ('как', 'CONJ'), ('дерево', 'S'), (',', 'NONLEX'), ('руку', 'S'), (':', 'NONLEX'), ('–', 'NONLEX'), ('Прощай', 'V'), (',', 'NONLEX'), ('браток', 'S'), (',', 'NONLEX'), ('счастливо', 'ADV'), ('тебе', 'S-PRO'), ('!', 'NONLEX')]
# [('–', 'NONLEX'), ('И', 'CONJ'), ('тебе', 'S-PRO'), ('счастливо', 'ADV'), ('добраться', 'V'), ('до', 'PR'), ('Кашар', 'S'), ('.', 'NONLEX')]
# [('–', 'V'), ('Благодарствую', 'A=f'), ('.', 'NONLEX')]
# [('Эй', 'INTJ'), (',', 'NONLEX'), ('сынок', 'S'), (',', 'NONLEX'), ('пойдем', 'V'), ('к', 'PR'), ('лодке', 'S'), ('.', 'NONLEX')]
# [('Мальчик', 'S'), ('подбежал', 'V'), ('к', 'PR'), ('отцу', 'S'), (',', 'NONLEX'), ('пристроился', 'V'), ('справа', 'ADV'), ('и', 'CONJ'), (',', 'NONLEX'), ('держась', 'V'), ('за', 'PR'), ('полу', 'S'), ('отцовского', 'A=m'), ('ватника', 'S'), (',', 'NONLEX'), ('засеменил', 'V'), ('рядом', 'ADV'), ('с', 'PR'), ('широко', 'ADV'), ('шагавшим', 'V'), ('мужчиной', 'S'), ('.', 'NONLEX')]
# [('Два', 'NUM=m'), ('осиротевших', 'V'), ('человека', 'S'), (',', 'NONLEX'), ('две', 'NUM=f'), ('песчинки', 'S'), (',', 'NONLEX'), ('заброшенные', 'V'), ('в', 'PR'), ('чужие', 'A=pl'), ('края', 'S'), ('военным', 'A=m'), ('ураганом', 'S'), ('невиданной', 'A=f'), ('силы…', 'S'), ('Что-то', 'S-PRO'), ('ждет', 'V'), ('их', 'S-PRO'), ('впереди', 'ADV'), ('?', 'NONLEX')]
# [('И', 'CONJ'), ('хотелось', 'V'), ('бы', 'PART'), ('думать', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('этот', 'A-PRO=m'), ('русский', 'A=m'), ('человек', 'S'), (',', 'NONLEX'), ('человек', 'S'), ('несгибаемой', 'A=sg'), ('воли', 'S'), (',', 'NONLEX'), ('выдюжит', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('около', 'PR'), ('отцовского', 'A=m'), ('плеча', 'S'), ('вырастет', 'V'), ('тот', 'A-PRO=m'), (',', 'NONLEX'), ('который', 'A-PRO=m'), (',', 'NONLEX'), ('повзрослев', 'V'), (',', 'NONLEX'), ('сможет', 'V'), ('все', 'A-PRO=pl'), ('вытерпеть', 'V'), (',', 'NONLEX'), ('все', 'S-PRO'), ('преодолеть', 'V'), ('на', 'PR'), ('своем', 'S'), ('пути', 'S'), (',', 'NONLEX'), ('если', 'CONJ'), ('к', 'PR'), ('этому', 'S-PRO'), ('позовет', 'S'), ('его', 'A-PRO'), ('Родина', 'S'), ('.', 'NONLEX')]
# [('С', 'PR'), ('тяжелой', 'A=f'), ('грустью', 'S'), ('смотрел', 'V'), ('я', 'S-PRO'), ('им', 'S-PRO'), ('вслед…', 'S'), ('Может', 'V'), ('быть', 'V'), (',', 'NONLEX'), ('все', 'S-PRO'), ('и', 'CONJ'), ('обошлось', 'V'), ('бы', 'PART'), ('благополучно', 'ADV'), ('при', 'PR'), ('нашем', 'A-PRO=n'), ('расставании', 'S'), (',', 'NONLEX'), ('но', 'CONJ'), ('Ванюшка', 'S'), (',', 'NONLEX'), ('отойдя', 'V'), ('несколько', 'NUM=acc'), ('шагов', 'S'), ('и', 'CONJ'), ('заплетая', 'V'), ('куцыми', 'A=pl'), ('ножками', 'S'), (',', 'NONLEX'), ('повернулся', 'V'), ('на', 'PR'), ('ходу', 'S'), ('ко', 'PR'), ('мне', 'S-PRO'), ('лицом', 'S'), (',', 'NONLEX'), ('помахал', 'V'), ('розовой', 'A=sg'), ('ручонкой', 'S'), ('.', 'NONLEX')]
# [('И', 'CONJ'), ('вдруг', 'ADV'), ('словно', 'CONJ'), ('мягкая', 'A=f'), (',', 'NONLEX'), ('но', 'CONJ'), ('когтистая', 'A=f'), ('лапа', 'S'), ('сжала', 'V'), ('мне', 'S-PRO'), ('сердце', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('я', 'S-PRO'), ('поспешно', 'ADV'), ('отвернулся', 'V'), ('.', 'NONLEX')]
# [('Нет', 'PART'), (',', 'NONLEX'), ('не', 'PART'), ('только', 'PART'), ('во', 'PR'), ('сне', 'S'), ('плачут', 'V'), ('пожилые', 'A=pl'), (',', 'NONLEX'), ('поседевшие', 'V'), ('за', 'PR'), ('годы', 'S'), ('войны', 'S'), ('мужчины', 'S'), ('.', 'NONLEX')]
# [('Плачут', 'V'), ('они', 'S-PRO'), ('и', 'CONJ'), ('наяву', 'ADV'), ('.', 'NONLEX')]
# [('Тут', 'ADV-PRO'), ('главное', 'S'), ('–', 'S'), ('уметь', 'V'), ('вовремя', 'ADV'), ('отвернуться', 'V'), ('.', 'NONLEX')]
# [('Тут', 'ADV-PRO'), ('самое', 'A-PRO=n'), ('главное', 'S'), ('–', 'S'), ('не', 'PART'), ('ранить', 'V'), ('сердце', 'S'), ('ребенка', 'S'), (',', 'NONLEX'), ('чтобы', 'CONJ'), ('он', 'S-PRO'), ('не', 'PART'), ('увидел', 'V'), (',', 'NONLEX'), ('как', 'CONJ'), ('бежит', 'V'), ('по', 'PR'), ('твоей', 'A-PRO=f'), ('щеке', 'S'), ('жгучая', 'A=f'), ('и', 'CONJ'), ('скупая', 'A=f'), ('мужская', 'A=f'), ('слеза…', 'S'), ('1956', 'NUM=ciph')]

# %%
# лемматизация с учетом части речи
# меняем теги
tokenized = nltk.word_tokenize(text5)
tagged = nltk.pos_tag(tokenized)

def pos_tagger(nltk_tag):
    if nltk_tag.startswith('J'):
        return nltk.corpus.wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return nltk.corpus.wordnet.VERB
    elif nltk_tag.startswith('N'):
        return nltk.corpus.wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return nltk.corpus.wordnet.ADV
    else:          
        return None

tagged
# Out:
# [('Евгении', 'JJ'),
#  ('Григорьевне', 'NNP'),
#  ('Левицкой', 'NNP'),
#  (',', ','),
#  ('члену', 'NNP'),
#  ('КПСС', 'NNP'),
#  ('с', 'NNP'),
#  ('1903', 'CD'),
#  ('года', 'NNP'),
#  ('Первая', 'NNP'),
#  ('послевоенная', 'NNP'),
#  ('весна', 'NNP'),
#  ('была', 'NNP'),
#  ('на', 'NNP'),
#  ('Верхнем', 'NNP'),
#  ('Дону', 'NNP'),
#  ('на', 'NNP'),
#  ('редкость', 'NNP'),
#  ('дружная', 'NNP'),
#  ('и', 'NNP'),
#  ('напористая', 'NNP'),
#  ('.', '.'),
#  ('В', 'VB'),
#  ('конце', 'JJ'),
#  ('марта', 'NNP'),
#  ('из', 'NNP'),
#  ('Приазовья', 'NNP'),
#  ('подули', 'NNP'),
#  ('теплые', 'NNP'),
#  ('ветры', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('уже', 'NNP'),
#  ('через', 'NNP'),
#  ('двое', 'NNP'),
#  ('суток', 'NNP'),
#  ('начисто', 'NNP'),
#  ('оголились', 'NNP'),
#  ('пески', 'NNP'),
#  ('левобережья', 'NNP'),
#  ('Дона', 'NNP'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('степи', 'NNP'),
#  ('вспухли', 'NNP'),
#  ('набитые', 'NNP'),
#  ('снегом', 'NNP'),
#  ('лога', 'NNP'),
#  ('и', 'NNP'),
#  ('балки', 'NNP'),
#  (',', ','),
#  ('взломав', 'NNP'),
#  ('лед', 'NNP'),
#  (',', ','),
#  ('бешено', 'NNP'),
#  ('взыграли', 'NNP'),
#  ('степные', 'NNP'),
#  ('речки', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('дороги', 'NNP'),
#  ('стали', 'NNP'),
#  ('почти', 'NNP'),
#  ('совсем', 'NNP'),
#  ('непроездны', 'NNP'),
#  ('.', '.'),
#  ('В', 'VB'),
#  ('эту', 'JJ'),
#  ('недобрую', 'NNP'),
#  ('пору', 'NNP'),
#  ('бездорожья', 'NNP'),
#  ('мне', 'NNP'),
#  ('пришлось', 'NNP'),
#  ('ехать', 'NNP'),
#  ('в', 'NNP'),
#  ('станицу', 'NNP'),
#  ('Букановскую', 'NNP'),
#  ('.', '.'),
#  ('И', 'VB'),
#  ('расстояние', 'JJ'),
#  ('небольшое', 'NNP'),
#  ('–', 'NNP'),
#  ('всего', 'NNP'),
#  ('лишь', 'NNP'),
#  ('около', 'NNP'),
#  ('шестидесяти', 'NNP'),
#  ('километров', 'NNP'),
#  (',', ','),
#  ('–', 'NNP'),
#  ('но', 'NNP'),
#  ('одолеть', 'NNP'),
#  ('их', 'NNP'),
#  ('оказалось', 'NNP'),
#  ('не', 'NNP'),
#  ('так-то', 'JJ'),
#  ('просто', 'NNP'),
#  ('.', '.'),
#  ('Мы', 'VB'),
#  ('с', 'JJ'),
#  ('товарищами', 'NNP'),
#  ('выехали', 'NNP'),
#  ('до', 'NNP'),
#  ('восхода', 'NNP'),
#  ('солнца', 'NNP'),
#  ('.', '.'),
#  ('Пара', 'VB'),
#  ('сытых', 'JJ'),
#  ('лошадей', 'NNP'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('струну', 'NNP'),
#  ('натягивая', 'NNP'),
#  ('постромки', 'NNP'),
#  (',', ','),
#  ('еле', 'NNP'),
#  ('тащила', 'NNP'),
#  ('тяжелую', 'NNP'),
#  ('бричку', 'NNP'),
#  ('.', '.'),
#  ('Колеса', 'VB'),
#  ('по', 'JJ'),
#  ('самую', 'NNP'),
#  ('ступицу', 'NNP'),
#  ('проваливались', 'NNP'),
#  ('в', 'NNP'),
#  ('отсыревший', 'NNP'),
#  (',', ','),
#  ('перемешанный', 'NNP'),
#  ('со', 'NNP'),
#  ('снегом', 'NNP'),
#  ('и', 'NNP'),
#  ('льдом', 'NNP'),
#  ('песок', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('через', 'NNP'),
#  ('час', 'NNP'),
#  ('на', 'NNP'),
#  ('лошадиных', 'NNP'),
#  ('боках', 'NNP'),
#  ('и', 'NNP'),
#  ('стегнах', 'NNP'),
#  (',', ','),
#  ('под', 'NNP'),
#  ('тонкими', 'NNP'),
#  ('ремнями', 'NNP'),
#  ('шлеек', 'NNP'),
#  (',', ','),
#  ('уже', 'NNP'),
#  ('показались', 'NNP'),
#  ('белые', 'NNP'),
#  ('пышные', 'NNP'),
#  ('хлопья', 'NNP'),
#  ('мыла', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('в', 'NNP'),
#  ('утреннем', 'NNP'),
#  ('свежем', 'NNP'),
#  ('воздухе', 'NNP'),
#  ('остро', 'NNP'),
#  ('и', 'NNP'),
#  ('пьяняще', 'NNP'),
#  ('запахло', 'NNP'),
#  ('лошадиным', 'NNP'),
#  ('потом', 'NNP'),
#  ('и', 'NNP'),
#  ('согретым', 'NNP'),
#  ('деготьком', 'NNP'),
#  ('щедро', 'NNP'),
#  ('смазанной', 'NNP'),
#  ('конской', 'NNP'),
#  ('сбруи', 'NNP'),
#  ('.', '.'),
#  ('Там', 'NN'),
#  (',', ','),
#  ('где', 'NNP'),
#  ('было', 'NNP'),
#  ('особенно', 'NNP'),
#  ('трудно', 'NNP'),
#  ('лошадям', 'NNP'),
#  (',', ','),
#  ('мы', 'NNP'),
#  ('слезали', 'NNP'),
#  ('с', 'NNP'),
#  ('брички', 'NNP'),
#  (',', ','),
#  ('шли', 'NNP'),
#  ('пешком', 'NNP'),
#  ('.', '.'),
#  ('Под', 'VB'),
#  ('сапогами', 'JJ'),
#  ('хлюпал', 'NNP'),
#  ('размокший', 'NNP'),
#  ('снег', 'NNP'),
#  (',', ','),
#  ('идти', 'NNP'),
#  ('было', 'NNP'),
#  ('тяжело', 'NNP'),
#  (',', ','),
#  ('но', 'NNP'),
#  ('по', 'NNP'),
#  ('обочинам', 'NNP'),
#  ('дороги', 'NNP'),
#  ('все', 'NNP'),
#  ('еще', 'NNP'),
#  ('держался', 'NNP'),
#  ('хрустально', 'NNP'),
#  ('поблескивавший', 'NNP'),
#  ('на', 'NNP'),
#  ('солнце', 'NNP'),
#  ('ледок', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('там', 'NNP'),
#  ('пробираться', 'NNP'),
#  ('было', 'NNP'),
#  ('еще', 'NNP'),
#  ('труднее', 'NNP'),
#  ('.', '.'),
#  ('Только', 'VB'),
#  ('часов', 'JJ'),
#  ('через', 'NNP'),
#  ('шесть', 'NNP'),
#  ('покрыли', 'NNP'),
#  ('расстояние', 'NNP'),
#  ('в', 'NNP'),
#  ('тридцать', 'NNP'),
#  ('километров', 'NNP'),
#  (',', ','),
#  ('подъехали', 'NNP'),
#  ('к', 'NNP'),
#  ('переправе', 'NNP'),
#  ('через', 'NNP'),
#  ('речку', 'NNP'),
#  ('Еланку', 'NNP'),
#  ('.', '.'),
#  ('Небольшая', 'NN'),
#  (',', ','),
#  ('местами', 'NNP'),
#  ('пересыхающая', 'NNP'),
#  ('летом', 'NNP'),
#  ('речушка', 'NNP'),
#  ('против', 'NNP'),
#  ('хутора', 'NNP'),
#  ('Моховского', 'NNP'),
#  ('в', 'NNP'),
#  ('заболоченной', 'NNP'),
#  (',', ','),
#  ('поросшей', 'NNP'),
#  ('ольхами', 'NNP'),
#  ('пойме', 'NNP'),
#  ('разлилась', 'NNP'),
#  ('на', 'NNP'),
#  ('целый', 'NNP'),
#  ('километр', 'NNP'),
#  ('.', '.'),
#  ('Переправляться', 'VB'),
#  ('надо', 'JJ'),
#  ('было', 'NNP'),
#  ('на', 'NNP'),
#  ('утлой', 'NNP'),
#  ('плоскодонке', 'NNP'),
#  (',', ','),
#  ('поднимавшей', 'NNP'),
#  ('не', 'NNP'),
#  ('больше', 'NNP'),
#  ('трех', 'NNP'),
#  ('человек', 'NNP'),
#  ('.', '.'),
#  ('Мы', 'VB'),
#  ('отпустили', 'JJ'),
#  ('лошадей', 'NNP'),
#  ('.', '.'),
#  ('На', 'VB'),
#  ('той', 'JJ'),
#  ('стороне', 'NNP'),
#  ('в', 'NNP'),
#  ('колхозном', 'NNP'),
#  ('сарае', 'NNP'),
#  ('нас', 'NNP'),
#  ('ожидал', 'NNP'),
#  ('старенький', 'NNP'),
#  (',', ','),
#  ('видавший', 'NNP'),
#  ('виды', 'NNP'),
#  ('«', 'NNP'),
#  ('Виллис', 'NNP'),
#  ('»', 'NNP'),
#  (',', ','),
#  ('оставленный', 'NNP'),
#  ('там', 'NNP'),
#  ('еще', 'NNP'),
#  ('зимою', 'NNP'),
#  ('.', '.'),
#  ('Вдвоем', 'VB'),
#  ('с', 'JJ'),
#  ('шофером', 'NNP'),
#  ('мы', 'NNP'),
#  ('не', 'NNP'),
#  ('без', 'NNP'),
#  ('опасения', 'NNP'),
#  ('сели', 'NNP'),
#  ('в', 'NNP'),
#  ('ветхую', 'NNP'),
#  ('лодчонку', 'NNP'),
#  ('.', '.'),
#  ('Товарищ', 'VB'),
#  ('с', 'JJ'),
#  ('вещами', 'NNP'),
#  ('остался', 'NNP'),
#  ('на', 'NNP'),
#  ('берегу', 'NNP'),
#  ('.', '.'),
#  ('Едва', 'NN'),
#  ('отчалили', 'NN'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('из', 'NNP'),
#  ('прогнившего', 'NNP'),
#  ('днища', 'NNP'),
#  ('в', 'NNP'),
#  ('разных', 'NNP'),
#  ('местах', 'NNP'),
#  ('фонтанчиками', 'NNP'),
#  ('забила', 'NNP'),
#  ('вода', 'NNP'),
#  ('.', '.'),
#  ('Подручными', 'VB'),
#  ('средствами', 'JJ'),
#  ('конопатили', 'NNP'),
#  ('ненадежную', 'NNP'),
#  ('посудину', 'NNP'),
#  ('и', 'NNP'),
#  ('вычерпывали', 'NNP'),
#  ('из', 'NNP'),
#  ('нее', 'NNP'),
#  ('воду', 'NNP'),
#  (',', ','),
#  ('пока', 'NNP'),
#  ('не', 'NNP'),
#  ('доехали', 'NNP'),
#  ('.', '.'),
#  ('Через', 'VB'),
#  ('час', 'JJ'),
#  ('мы', 'NNP'),
#  ('были', 'NNP'),
#  ('на', 'NNP'),
#  ('той', 'NNP'),
#  ('стороне', 'NNP'),
#  ('Еланки', 'NNP'),
#  ('.', '.'),
#  ('Шофер', 'VB'),
#  ('пригнал', 'JJ'),
#  ('из', 'NNP'),
#  ('хутора', 'NNP'),
#  ('машину', 'NNP'),
#  (',', ','),
#  ('подошел', 'NNP'),
#  ('к', 'NNP'),
#  ('лодке', 'NNP'),
#  ('и', 'NNP'),
#  ('сказал', 'NNP'),
#  (',', ','),
#  ('берясь', 'NNP'),
#  ('за', 'NNP'),
#  ('весло', 'NN'),
#  (':', ':'),
#  ('–', 'JJ'),
#  ('Если', 'NNP'),
#  ('это', 'NNP'),
#  ('проклятое', 'NNP'),
#  ('корыто', 'NNP'),
#  ('не', 'NNP'),
#  ('развалится', 'NNP'),
#  ('на', 'NNP'),
#  ('воде', 'NNP'),
#  (',', ','),
#  ('–', 'NNP'),
#  ('часа', 'NNP'),
#  ('через', 'NNP'),
#  ('два', 'NNP'),
#  ('приедем', 'NNP'),
#  (',', ','),
#  ('раньше', 'NNP'),
#  ('не', 'NNP'),
#  ('ждите', 'NNP'),
#  ('.', '.'),
#  ('Хутор', 'VB'),
#  ('раскинулся', 'JJ'),
#  ('далеко', 'NNP'),
#  ('в', 'NNP'),
#  ('стороне', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('возле', 'NNP'),
#  ('причала', 'NNP'),
#  ('стояла', 'NNP'),
#  ('такая', 'NNP'),
#  ('тишина', 'NNP'),
#  (',', ','),
#  ('какая', 'NNP'),
#  ('бывает', 'NNP'),
#  ('в', 'NNP'),
#  ('безлюдных', 'NNP'),
#  ('местах', 'NNP'),
#  ('только', 'NNP'),
#  ('глухою', 'NNP'),
#  ('осенью', 'NNP'),
#  ('и', 'NNP'),
#  ('в', 'NNP'),
#  ('самом', 'NNP'),
#  ('начале', 'NNP'),
#  ('весны', 'NNP'),
#  ('.', '.'),
#  ('От', 'VB'),
#  ('воды', 'JJ'),
#  ('тянуло', 'NNP'),
#  ('сыростью', 'NNP'),
#  (',', ','),
#  ('терпкой', 'NNP'),
#  ('горечью', 'NNP'),
#  ('гниющей', 'NNP'),
#  ('ольхи', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('с', 'NNP'),
#  ('дальних', 'NNP'),
#  ('прихоперских', 'NNP'),
#  ('степей', 'NNP'),
#  (',', ','),
#  ('тонувших', 'NNP'),
#  ('в', 'NNP'),
#  ('сиреневой', 'NNP'),
#  ('дымке', 'NNP'),
#  ('тумана', 'NNP'),
#  (',', ','),
#  ('легкий', 'NNP'),
#  ('ветерок', 'NNP'),
#  ('нес', 'NNP'),
#  ('извечно', 'NNP'),
#  ('юный', 'NNP'),
#  (',', ','),
#  ('еле', 'NNP'),
#  ('уловимый', 'NNP'),
#  ('аромат', 'NNP'),
#  ('недавно', 'NNP'),
#  ('освободившейся', 'NNP'),
#  ('из-под', 'JJ'),
#  ('снега', 'NNP'),
#  ('земли', 'NNP'),
#  ('.', '.'),
#  ('Неподалеку', 'NN'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('прибрежном', 'NNP'),
#  ('песке', 'NNP'),
#  (',', ','),
#  ('лежал', 'NNP'),
#  ('поваленный', 'NNP'),
#  ('плетень', 'NNP'),
#  ('.', '.'),
#  ('Я', 'VB'),
#  ('присел', 'JJ'),
#  ('на', 'NNP'),
#  ('него', 'NNP'),
#  (',', ','),
#  ('хотел', 'NNP'),
#  ('закурить', 'NNP'),
#  (',', ','),
#  ('но', 'NNP'),
#  (',', ','),
#  ('сунув', 'NNP'),
#  ('руку', 'NNP'),
#  ('в', 'NNP'),
#  ('правый', 'NNP'),
#  ('карман', 'NNP'),
#  ('ватной', 'NNP'),
#  ('стеганки', 'NNP'),
#  (',', ','),
#  ('к', 'NNP'),
#  ('великому', 'NNP'),
#  ('огорчению', 'NNP'),
#  (',', ','),
#  ('обнаружил', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('пачка', 'NNP'),
#  ('«', 'NNP'),
#  ('Беломора', 'NNP'),
#  ('»', 'NNP'),
#  ('совершенно', 'NNP'),
#  ('размокла', 'NNP'),
#  ('.', '.'),
#  ('Во', 'VB'),
#  ('время', 'JJ'),
#  ('переправы', 'NNP'),
#  ('волна', 'NNP'),
#  ('хлестнула', 'NNP'),
#  ('через', 'NNP'),
#  ('борт', 'NNP'),
#  ('низко', 'NNP'),
#  ('сидевшей', 'NNP'),
#  ('лодки', 'NNP'),
#  (',', ','),
#  ('по', 'NNP'),
#  ('пояс', 'NNP'),
#  ('окатила', 'NNP'),
#  ('меня', 'NNP'),
#  ('мутной', 'NNP'),
#  ('водой', 'NNP'),
#  ('.', '.'),
#  ('Тогда', 'VB'),
#  ('мне', 'JJ'),
#  ('некогда', 'NNP'),
#  ('было', 'NNP'),
#  ('думать', 'NNP'),
#  ('о', 'NNP'),
#  ('папиросах', 'NNP'),
#  (',', ','),
#  ('надо', 'NNP'),
#  ('было', 'NNP'),
#  (',', ','),
#  ('бросив', 'NNP'),
#  ('весло', 'NNP'),
#  (',', ','),
#  ('побыстрее', 'NNP'),
#  ('вычерпывать', 'NNP'),
#  ('воду', 'NNP'),
#  (',', ','),
#  ('чтобы', 'NNP'),
#  ('лодка', 'NNP'),
#  ('не', 'NNP'),
#  ('затонула', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('теперь', 'NNP'),
#  (',', ','),
#  ('горько', 'NNP'),
#  ('досадуя', 'NNP'),
#  ('на', 'NNP'),
#  ('свою', 'NNP'),
#  ('оплошность', 'NNP'),
#  (',', ','),
#  ('я', 'NNP'),
#  ('бережно', 'NNP'),
#  ('извлек', 'NNP'),
#  ('из', 'NNP'),
#  ('кармана', 'NNP'),
#  ('раскисшую', 'NNP'),
#  ('пачку', 'NNP'),
#  (',', ','),
#  ('присел', 'NNP'),
#  ('на', 'NNP'),
#  ('корточки', 'NNP'),
#  ('и', 'NNP'),
#  ('стал', 'NNP'),
#  ('по', 'NNP'),
#  ('одной', 'NNP'),
#  ('раскладывать', 'NNP'),
#  ('на', 'NNP'),
#  ('плетне', 'NNP'),
#  ('влажные', 'NNP'),
#  (',', ','),
#  ('побуревшие', 'NNP'),
#  ('папиросы', 'NNP'),
#  ('.', '.'),
#  ('Был', 'NN'),
#  ('полдень', 'NN'),
#  ('.', '.'),
#  ('Солнце', 'CC'),
#  ('светило', 'JJ'),
#  ('горячо', 'NN'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('в', 'NNP'),
#  ('мае', 'NNP'),
#  ('.', '.'),
#  ('Я', 'NN'),
#  ('надеялся', 'NN'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('папиросы', 'NNP'),
#  ('скоро', 'NNP'),
#  ('высохнут', 'NNP'),
#  ('.', '.'),
#  ('Солнце', 'VB'),
#  ('светило', 'JJ'),
#  ('так', 'NNP'),
#  ('горячо', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('я', 'NNP'),
#  ('уже', 'NNP'),
#  ('пожалел', 'NNP'),
#  ('о', 'NNP'),
#  ('том', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('надел', 'NNP'),
#  ('в', 'NNP'),
#  ('дорогу', 'NNP'),
#  ('солдатские', 'NNP'),
#  ('ватные', 'NNP'),
#  ('штаны', 'NNP'),
#  ('и', 'NNP'),
#  ('стеганку', 'NNP'),
#  ('.', '.'),
#  ('Это', 'VB'),
#  ('был', 'JJ'),
#  ('первый', 'NNP'),
#  ('после', 'NNP'),
#  ('зимы', 'NNP'),
#  ('по-настоящему', 'JJ'),
#  ('теплый', 'NNP'),
#  ('день', 'NNP'),
#  ('.', '.'),
#  ('Хорошо', 'VB'),
#  ('было', 'JJ'),
#  ('сидеть', 'NNP'),
#  ('на', 'NNP'),
#  ('плетне', 'NNP'),
#  ('вот', 'NNP'),
#  ('так', 'NNP'),
#  (',', ','),
#  ('одному', 'NNP'),
#  (',', ','),
#  ('целиком', 'NNP'),
#  ('покорясь', 'NNP'),
#  ('тишине', 'NNP'),
#  ('и', 'NNP'),
#  ('одиночеству', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  (',', ','),
#  ('сняв', 'NNP'),
#  ('с', 'NNP'),
#  ('головы', 'NNP'),
#  ('старую', 'NNP'),
#  ('солдатскую', 'NNP'),
#  ('ушанку', 'NNP'),
#  (',', ','),
#  ('сушить', 'NNP'),
#  ('на', 'NNP'),
#  ('ветерке', 'NNP'),
#  ('мокрые', 'NNP'),
#  ('после', 'NNP'),
#  ('тяжелой', 'NNP'),
#  ('гребли', 'NNP'),
#  ('волосы', 'NNP'),
#  (',', ','),
#  ('бездумно', 'NNP'),
#  ('следить', 'NNP'),
#  ('за', 'NNP'),
#  ('проплывающими', 'NNP'),
#  ('в', 'NNP'),
#  ('блеклой', 'NNP'),
#  ('синеве', 'NNP'),
#  ('белыми', 'NNP'),
#  ('грудастыми', 'NNP'),
#  ('облаками', 'NNP'),
#  ('.', '.'),
#  ('Вскоре', 'VB'),
#  ('я', 'JJ'),
#  ('увидел', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('из-за', 'NNP'),
#  ('крайних', 'NNP'),
#  ('дворов', 'NNP'),
#  ('хутора', 'NNP'),
#  ('вышел', 'NNP'),
#  ('на', 'NNP'),
#  ('дорогу', 'NNP'),
#  ('мужчина', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('вел', 'JJ'),
#  ('за', 'NNP'),
#  ('руку', 'NNP'),
#  ('маленького', 'NNP'),
#  ('мальчика', 'NNP'),
#  (',', ','),
#  ('судя', 'NNP'),
#  ('по', 'NNP'),
#  ('росту', 'NNP'),
#  ('–', 'NNP'),
#  ('лет', 'NNP'),
#  ('пяти-шести', 'NNP'),
#  (',', ','),
#  ('не', 'NNP'),
#  ('больше', 'NNP'),
#  ('.', '.'),
#  ('Они', 'VB'),
#  ('устало', 'JJ'),
#  ('брели', 'NNP'),
#  ('по', 'NNP'),
#  ('направлению', 'NNP'),
#  ('к', 'NNP'),
#  ('переправе', 'NNP'),
#  (',', ','),
#  ('но', 'NNP'),
#  (',', ','),
#  ('поравнявшись', 'NNP'),
#  ('с', 'NNP'),
#  ('машиной', 'NNP'),
#  (',', ','),
#  ('повернули', 'NNP'),
#  ('ко', 'NNP'),
#  ('мне', 'NNP'),
#  ('.', '.'),
#  ('Высокий', 'NN'),
#  (',', ','),
#  ('сутуловатый', 'NNP'),
#  ('мужчина', 'NNP'),
#  (',', ','),
#  ('подойдя', 'NNP'),
#  ('вплотную', 'NNP'),
#  (',', ','),
#  ('сказал', 'NNP'),
#  ('приглушенным', 'NNP'),
#  ('баском', 'NN'),
#  (':', ':'),
#  ('–', 'NN'),
#  ('Здорово', 'NN'),
#  (',', ','),
#  ('браток', 'NN'),
#  ('!', '.'),
#  ('–', 'JJ'),
#  ('Здравствуй', 'NN'),
#  ('.', '.'),
#  ('–', 'CC'),
#  ('Я', 'JJ'),
#  ('пожал', 'NNP'),
#  ('протянутую', 'NNP'),
#  ('мне', 'NNP'),
#  ('большую', 'NNP'),
#  (',', ','),
#  ('черствую', 'NNP'),
#  ('руку', 'NNP'),
#  ('.', '.'),
#  ('Мужчина', 'VB'),
#  ('наклонился', 'JJ'),
#  ('к', 'NNP'),
#  ('мальчику', 'NNP'),
#  (',', ','),
#  ('сказал', 'NN'),
#  (':', ':'),
#  ('–', 'JJ'),
#  ('Поздоровайся', 'NNP'),
#  ('с', 'NNP'),
#  ('дядей', 'NNP'),
#  (',', ','),
#  ('сынок', 'NNP'),
#  ('.', '.'),
#  ('Он', 'NN'),
#  (',', ','),
#  ('видать', 'NNP'),
#  (',', ','),
#  ('такой', 'NNP'),
#  ('же', 'NNP'),
#  ('шофер', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('и', 'NNP'),
#  ('твой', 'NNP'),
#  ('папанька', 'NNP'),
#  ('.', '.'),
#  ('Только', 'VB'),
#  ('мы', 'JJ'),
#  ('с', 'NNP'),
#  ('тобой', 'NNP'),
#  ('на', 'NNP'),
#  ('грузовой', 'NNP'),
#  ('ездили', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('он', 'NNP'),
#  ('вот', 'NNP'),
#  ('эту', 'NNP'),
#  ('маленькую', 'NNP'),
#  ('машину', 'NNP'),
#  ('гоняет', 'NNP'),
#  ('.', '.'),
#  ('Глядя', 'VB'),
#  ('мне', 'JJ'),
#  ('прямо', 'NNP'),
#  ('в', 'NNP'),
#  ('глаза', 'NNP'),
#  ('светлыми', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('небушко', 'NNP'),
#  (',', ','),
#  ('глазами', 'NNP'),
#  (',', ','),
#  ('чуть-чуть', 'JJ'),
#  ('улыбаясь', 'NN'),
#  (',', ','),
#  ('мальчик', 'NNP'),
#  ('смело', 'NNP'),
#  ('протянул', 'NNP'),
#  ('мне', 'NNP'),
#  ('розовую', 'NNP'),
#  ('холодную', 'NNP'),
#  ('ручонку', 'NNP'),
#  ('.', '.'),
#  ('Я', 'VB'),
#  ('легонько', 'JJ'),
#  ('потряс', 'NNP'),
#  ('ее', 'NNP'),
#  (',', ','),
#  ('спросил', 'NN'),
#  (':', ':'),
#  ('–', 'JJ'),
#  ('Что', 'NNP'),
#  ('же', 'NNP'),
#  ('это', 'NNP'),
#  ('у', 'NNP'),
#  ('тебя', 'NNP'),
#  (',', ','),
#  ('старик', 'NNP'),
#  (',', ','),
#  ('рука', 'NNP'),
#  ('такая', 'NNP'),
#  ('холодная', 'NNP'),
#  ('?', '.'),
#  ('На', 'NNP'),
#  ('дворе', 'NNP'),
#  ('теплынь', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('ты', 'NNP'),
#  ('замерзаешь', 'NNP'),
#  ('?', '.'),
#  ('С', 'NNP'),
#  ('трогательной', 'NNP'),
#  ('детской', 'NNP'),
#  ('доверчивостью', 'NNP'),
#  ('малыш', 'NNP'),
#  ('прижался', 'NNP'),
#  ('к', 'NNP'),
#  ('моим', 'NNP'),
#  ('коленям', 'NNP'),
#  (',', ','),
#  ('удивленно', 'NNP'),
#  ('приподнял', 'NNP'),
#  ('белесые', 'NNP'),
#  ('бровки', 'NNP'),
#  ('.', '.'),
#  ('–', 'VB'),
#  ('Какой', 'JJ'),
#  ('же', 'NNP'),
#  ('я', 'NNP'),
#  ('старик', 'NNP'),
#  (',', ','),
#  ('дядя', 'NNP'),
#  ('?', '.'),
#  ('Я', 'NNP'),
#  ('вовсе', 'NNP'),
#  ('мальчик', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('я', 'NNP'),
#  ('вовсе', 'NNP'),
#  ('не', 'NNP'),
#  ('замерзаю', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('руки', 'NNP'),
#  ('холодные', 'NNP'),
#  ('–', 'NNP'),
#  ('снежки', 'NNP'),
#  ('катал', 'NNP'),
#  ('потому', 'NNP'),
#  ('что', 'NNP'),
#  ('.', '.'),
#  ('Сняв', 'VB'),
#  ('со', 'JJ'),
#  ('спины', 'NNP'),
#  ('тощий', 'NNP'),
#  ('вещевой', 'NNP'),
#  ('мешок', 'NNP'),
#  (',', ','),
#  ('устало', 'NNP'),
#  ('присаживаясь', 'NNP'),
#  ('рядом', 'NNP'),
#  ('со', 'NNP'),
#  ('мною', 'NNP'),
#  (',', ','),
#  ('отец', 'NNP'),
#  ('сказал', 'NN'),
#  (':', ':'),
#  ('–', 'JJ'),
#  ('Беда', 'NNP'),
#  ('мне', 'NNP'),
#  ('с', 'NNP'),
#  ('этим', 'NNP'),
#  ('пассажиром', 'NN'),
#  ('!', '.'),
#  ('Через', 'JJ'),
#  ('него', 'JJ'),
#  ('и', 'NN'),
#  ('я', 'NNP'),
#  ('подбился', 'NNP'),
#  ('.', '.'),
#  ('Широко', 'VB'),
#  ('шагнешь', 'JJ'),
#  ('–', 'NNP'),
#  ('он', 'NNP'),
#  ('уже', 'NNP'),
#  ('на', 'NNP'),
#  ('рысь', 'NNP'),
#  ('переходит', 'NNP'),
#  (',', ','),
#  ('вот', 'NNP'),
#  ('и', 'NNP'),
#  ('изволь', 'NNP'),
#  ('к', 'NNP'),
#  ('такому', 'NNP'),
#  ('пехотинцу', 'NNP'),
#  ('приноравливаться', 'NNP'),
#  ('.', '.'),
#  ('Там', 'NN'),
#  (',', ','),
#  ('где', 'NNP'),
#  ('мне', 'NNP'),
#  ('надо', 'NNP'),
#  ('раз', 'NNP'),
#  ('шагнуть', 'NNP'),
#  (',', ','),
#  ('–', 'NNP'),
#  ('я', 'NNP'),
#  ('три', 'NNP'),
#  ('раза', 'NNP'),
#  ('шагаю', 'NNP'),
#  (',', ','),
#  ('так', 'NNP'),
#  ('и', 'NNP'),
#  ('идем', 'NNP'),
#  ('с', 'NNP'),
#  ('ним', 'NNP'),
#  ('враздробь', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('конь', 'NNP'),
#  ('с', 'NNP'),
#  ('черепахой', 'NNP'),
#  ('.', '.'),
#  ('А', 'VB'),
#  ('тут', 'JJ'),
#  ('ведь', 'NNP'),
#  ('за', 'NNP'),
#  ('ним', 'NNP'),
#  ('глаз', 'NNP'),
#  ('да', 'NNP'),
#  ('глаз', 'NNP'),
#  ('нужен', 'NNP'),
#  ('.', '.'),
#  ('Чуть', 'NN'),
#  ('отвернешься', 'NN'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('он', 'NNP'),
#  ('уже', 'NNP'),
#  ('по', 'NNP'),
#  ('лужине', 'NNP'),
#  ('бредет', 'NNP'),
#  ('или', 'NNP'),
#  ('леденику', 'NNP'),
#  ('отломит', 'NNP'),
#  ('и', 'NNP'),
#  ('сосет', 'NNP'),
#  ('вместо', 'NNP'),
#  ('конфеты', 'NNP'),
#  ('.', '.'),
#  ('Нет', 'NN'),
#  (',', ','),
#  ('не', 'NNP'),
#  ('мужчинское', 'NNP'),
#  ('это', 'NNP'),
#  ('дело', 'NNP'),
#  ('с', 'NNP'),
#  ('такими', 'NNP'),
#  ('пассажирами', 'NNP'),
#  ('путешествовать', 'NNP'),
#  (',', ','),
#  ('да', 'NNP'),
#  ('еще', 'NNP'),
#  ('походным', 'NNP'),
#  ('порядком', 'NNP'),
#  ('.', '.'),
#  ('–', 'VB'),
#  ('Он', 'JJ'),
#  ('помолчал', 'NNP'),
#  ('немного', 'NNP'),
#  (',', ','),
#  ('потом', 'NNP'),
#  ('спросил', 'NN'),
#  (':', ':'),
#  ...]

# %%
from collections import Counter
lower_case = text5.lower()
tokens = nltk.word_tokenize(lower_case)
tags = nltk.pos_tag(tokens)
counts = Counter( tag for word,  tag in tags)
print(counts)
# Out:
# Counter({'NNP': 9460, ',': 1563, 'JJ': 819, '.': 791, 'NN': 568, 'VB': 464, ':': 143, 'CC': 19, 'CD': 6, 'VBD': 1})

# %%
from collections import Counter
lower_case = text5.lower()
tokens = nltk.word_tokenize(lower_case)
tags = nltk.pos_tag(tokens, lang='rus')
counts = Counter( tag for word,  tag in tags)
print(counts)
# Out:
# Counter({'NONLEX': 2836, 'S': 2629, 'V': 2090, 'PR': 1320, 'S-PRO': 1109, 'CONJ': 1104, 'PART': 489, 'ADV': 434, 'ADV-PRO': 307, 'A=m': 213, 'A-PRO=m': 192, 'A=f': 184, 'A=pl': 140, 'A-PRO=f': 122, 'A-PRO=pl': 121, 'PRAEDIC': 69, 'A=n': 56, 'A=sg': 51, 'A-PRO=n': 36, 'PARENTH': 35, 'NUM=nom': 35, 'ANUM=m': 32, 'NUM=acc': 30, 'NUM=m': 20, 'A-PRO': 18, 'A-PRO=sg': 17, 'A=comp': 16, 'NUM=gen': 14, 'ADV=comp': 10, 'S-PRO=acc': 10, 'S-PRO=dat': 10, 'ANUM=f': 8, 'NUM=comp': 8, 'S-PRO=gen': 8, 'NUM=f': 8, 'S-PRO=ins': 8, 'INTJ': 6, 'NUM=ciph': 5, 'ANUM=n': 5, 'PRAEDIC-PRO': 5, 'NUM=loc': 4, 'A': 4, 'ANUM=pl': 3, 'PRAEDIC=comp': 2, 'ADV=comp2': 2, 'ANUM=sg': 2, 'A=comp2': 2, 'S-PRO=pl': 2, 'ADV-PRO=comp': 1, 'INTJ=distort': 1, 'A=brev': 1})

# %%
tokenizer = nltk.tokenize.BlanklineTokenizer()
tokens = tokenizer.tokenize(text5)
print(len(tokenizer.tokenize(text5)))
# print(tokenizer.tokenize(text1))
print('Разделение текста по абзацам')
# Out:
# 150
# Разделение текста по абзацам

# %%
tokenizer = nltk.tokenize.WhitespaceTokenizer()
print(len(tokenizer.tokenize(text5)))
print(tokenizer.tokenize(text5))
# Out:
# 11091
# ['Евгении', 'Григорьевне', 'Левицкой,', 'члену', 'КПСС', 'с', '1903', 'года', 'Первая', 'послевоенная', 'весна', 'была', 'на', 'Верхнем', 'Дону', 'на', 'редкость', 'дружная', 'и', 'напористая.', 'В', 'конце', 'марта', 'из', 'Приазовья', 'подули', 'теплые', 'ветры,', 'и', 'уже', 'через', 'двое', 'суток', 'начисто', 'оголились', 'пески', 'левобережья', 'Дона,', 'в', 'степи', 'вспухли', 'набитые', 'снегом', 'лога', 'и', 'балки,', 'взломав', 'лед,', 'бешено', 'взыграли', 'степные', 'речки,', 'и', 'дороги', 'стали', 'почти', 'совсем', 'непроездны.', 'В', 'эту', 'недобрую', 'пору', 'бездорожья', 'мне', 'пришлось', 'ехать', 'в', 'станицу', 'Букановскую.', 'И', 'расстояние', 'небольшое', '–', 'всего', 'лишь', 'около', 'шестидесяти', 'километров,', '–', 'но', 'одолеть', 'их', 'оказалось', 'не', 'так-то', 'просто.', 'Мы', 'с', 'товарищами', 'выехали', 'до', 'восхода', 'солнца.', 'Пара', 'сытых', 'лошадей,', 'в', 'струну', 'натягивая', 'постромки,', 'еле', 'тащила', 'тяжелую', 'бричку.', 'Колеса', 'по', 'самую', 'ступицу', 'проваливались', 'в', 'отсыревший,', 'перемешанный', 'со', 'снегом', 'и', 'льдом', 'песок,', 'и', 'через', 'час', 'на', 'лошадиных', 'боках', 'и', 'стегнах,', 'под', 'тонкими', 'ремнями', 'шлеек,', 'уже', 'показались', 'белые', 'пышные', 'хлопья', 'мыла,', 'а', 'в', 'утреннем', 'свежем', 'воздухе', 'остро', 'и', 'пьяняще', 'запахло', 'лошадиным', 'потом', 'и', 'согретым', 'деготьком', 'щедро', 'смазанной', 'конской', 'сбруи.', 'Там,', 'где', 'было', 'особенно', 'трудно', 'лошадям,', 'мы', 'слезали', 'с', 'брички,', 'шли', 'пешком.', 'Под', 'сапогами', 'хлюпал', 'размокший', 'снег,', 'идти', 'было', 'тяжело,', 'но', 'по', 'обочинам', 'дороги', 'все', 'еще', 'держался', 'хрустально', 'поблескивавший', 'на', 'солнце', 'ледок,', 'и', 'там', 'пробираться', 'было', 'еще', 'труднее.', 'Только', 'часов', 'через', 'шесть', 'покрыли', 'расстояние', 'в', 'тридцать', 'километров,', 'подъехали', 'к', 'переправе', 'через', 'речку', 'Еланку.', 'Небольшая,', 'местами', 'пересыхающая', 'летом', 'речушка', 'против', 'хутора', 'Моховского', 'в', 'заболоченной,', 'поросшей', 'ольхами', 'пойме', 'разлилась', 'на', 'целый', 'километр.', 'Переправляться', 'надо', 'было', 'на', 'утлой', 'плоскодонке,', 'поднимавшей', 'не', 'больше', 'трех', 'человек.', 'Мы', 'отпустили', 'лошадей.', 'На', 'той', 'стороне', 'в', 'колхозном', 'сарае', 'нас', 'ожидал', 'старенький,', 'видавший', 'виды', '«Виллис»,', 'оставленный', 'там', 'еще', 'зимою.', 'Вдвоем', 'с', 'шофером', 'мы', 'не', 'без', 'опасения', 'сели', 'в', 'ветхую', 'лодчонку.', 'Товарищ', 'с', 'вещами', 'остался', 'на', 'берегу.', 'Едва', 'отчалили,', 'как', 'из', 'прогнившего', 'днища', 'в', 'разных', 'местах', 'фонтанчиками', 'забила', 'вода.', 'Подручными', 'средствами', 'конопатили', 'ненадежную', 'посудину', 'и', 'вычерпывали', 'из', 'нее', 'воду,', 'пока', 'не', 'доехали.', 'Через', 'час', 'мы', 'были', 'на', 'той', 'стороне', 'Еланки.', 'Шофер', 'пригнал', 'из', 'хутора', 'машину,', 'подошел', 'к', 'лодке', 'и', 'сказал,', 'берясь', 'за', 'весло:', '–', 'Если', 'это', 'проклятое', 'корыто', 'не', 'развалится', 'на', 'воде,', '–', 'часа', 'через', 'два', 'приедем,', 'раньше', 'не', 'ждите.', 'Хутор', 'раскинулся', 'далеко', 'в', 'стороне,', 'и', 'возле', 'причала', 'стояла', 'такая', 'тишина,', 'какая', 'бывает', 'в', 'безлюдных', 'местах', 'только', 'глухою', 'осенью', 'и', 'в', 'самом', 'начале', 'весны.', 'От', 'воды', 'тянуло', 'сыростью,', 'терпкой', 'горечью', 'гниющей', 'ольхи,', 'а', 'с', 'дальних', 'прихоперских', 'степей,', 'тонувших', 'в', 'сиреневой', 'дымке', 'тумана,', 'легкий', 'ветерок', 'нес', 'извечно', 'юный,', 'еле', 'уловимый', 'аромат', 'недавно', 'освободившейся', 'из-под', 'снега', 'земли.', 'Неподалеку,', 'на', 'прибрежном', 'песке,', 'лежал', 'поваленный', 'плетень.', 'Я', 'присел', 'на', 'него,', 'хотел', 'закурить,', 'но,', 'сунув', 'руку', 'в', 'правый', 'карман', 'ватной', 'стеганки,', 'к', 'великому', 'огорчению,', 'обнаружил,', 'что', 'пачка', '«Беломора»', ...
