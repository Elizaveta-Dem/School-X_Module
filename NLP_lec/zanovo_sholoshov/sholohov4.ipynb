# %%
import nltk
from nltk.corpus import wordnet
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_ru')
nltk.download('wordnet')
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('universal_tagset')
from nltk.stem import SnowballStemmer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Елизавета\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]     C:\Users\Елизавета\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_ru is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Елизавета\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\Елизавета\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!

# %%
with open("4_Nauka_nenavist_1942.txt", "r", encoding="utf-8") as file:
    text4 = file.read()

# %%
sentences = sent_tokenize(text4, language='russian')

for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    tag_words = nltk.pos_tag(words, lang='rus') 
    
    print(tag_words)
# Out:
# [('На', 'PR'), ('войне', 'S'), ('деревья', 'S'), (',', 'NONLEX'), ('как', 'CONJ'), ('и', 'CONJ'), ('люди', 'S'), (',', 'NONLEX'), ('имеют', 'V'), ('каждое', 'A-PRO=n'), ('свою', 'A-PRO=f'), ('судьбу', 'S'), ('.', 'NONLEX')]
# [('Я', 'S-PRO'), ('видел', 'V'), ('огромный', 'A=m'), ('участок', 'S'), ('леса', 'S'), (',', 'NONLEX'), ('срезанного', 'A=m'), ('огнем', 'S'), ('нашей', 'A-PRO=f'), ('артиллерии', 'S'), ('.', 'NONLEX')]
# [('В', 'PR'), ('этом', 'A-PRO=m'), ('лесу', 'S'), ('недавно', 'ADV'), ('укреплялись', 'V'), ('немцы', 'S'), (',', 'NONLEX'), ('выбитые', 'V'), ('из', 'PR'), ('села', 'S'), ('С.', 'S'), (',', 'NONLEX'), ('здесь', 'ADV-PRO'), ('они', 'S-PRO'), ('думали', 'V'), ('задержаться', 'V'), (',', 'NONLEX'), ('но', 'CONJ'), ('смерть', 'S'), ('скосила', 'V'), ('их', 'S-PRO'), ('вместе', 'ADV'), ('с', 'PR'), ('деревьями', 'S'), ('.', 'NONLEX')]
# [('Под', 'PR'), ('поверженными', 'A=pl'), ('стволами', 'S'), ('сосен', 'S'), ('лежали', 'V'), ('мертвые', 'A=pl'), ('немецкие', 'A=pl'), ('солдаты', 'S'), (',', 'NONLEX'), ('в', 'PR'), ('зеленом', 'A=m'), ('папоротнике', 'S'), ('гнили', 'V'), ('их', 'A-PRO'), ('изорванные', 'A=pl'), ('в', 'PR'), ('клочья', 'S'), ('тела', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('смолистый', 'A=m'), ('аромат', 'S'), ('расщепленных', 'A=pl'), ('снарядами', 'S'), ('сосен', 'S'), ('не', 'PART'), ('мог', 'V'), ('заглушить', 'V'), ('удушливо-приторной', 'A=f'), (',', 'NONLEX'), ('острой', 'A=f'), ('вони', 'S'), ('разлагающихся', 'V'), ('трупов', 'S'), ('.', 'NONLEX')]
# [('Казалось', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('даже', 'PART'), ('земля', 'S'), ('с', 'PR'), ('бурыми', 'A=pl'), (',', 'NONLEX'), ('опаленными', 'A=pl'), ('и', 'CONJ'), ('жесткими', 'A=pl'), ('краями', 'S'), ('воронок', 'S'), ('источает', 'V'), ('могильный', 'A=m'), ('запах', 'S'), ('.', 'NONLEX')]
# [('Смерть', 'S'), ('величественно', 'ADV'), ('и', 'CONJ'), ('безмолвно', 'ADV'), ('властвовала', 'V'), ('на', 'PR'), ('этой', 'A-PRO=sg'), ('поляне', 'S'), (',', 'NONLEX'), ('созданной', 'V'), ('и', 'CONJ'), ('взрытой', 'V'), ('нашими', 'A-PRO=pl'), ('снарядами', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('только', 'PART'), ('в', 'PR'), ('самом', 'A-PRO=m'), ('центре', 'S'), ('поляны', 'S'), ('стояла', 'V'), ('одна', 'ANUM=f'), ('чудом', 'S'), ('сохранившаяся', 'V'), ('березка', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('ветер', 'S'), ('раскачивал', 'V'), ('ее', 'S'), ('израненные', 'A=pl'), ('осколками', 'S'), ('ветви', 'S'), ('и', 'CONJ'), ('шумел', 'V'), ('в', 'PR'), ('молодых', 'A=pl'), (',', 'NONLEX'), ('глянцевито-клейких', 'A=pl'), ('листках', 'S'), ('.', 'NONLEX')]
# [('Мы', 'S-PRO'), ('проходили', 'V'), ('через', 'PR'), ('поляну', 'S'), ('.', 'NONLEX')]
# [('Шедший', 'V'), ('впереди', 'PR'), ('меня', 'S-PRO'), ('связной', 'A=f'), ('красноармеец', 'S'), ('слегка', 'ADV'), ('коснулся', 'V'), ('рукой', 'S'), ('ствола', 'S'), ('березы', 'S'), (',', 'NONLEX'), ('спросил', 'V'), ('с', 'PR'), ('искренним', 'S'), ('и', 'CONJ'), ('ласковым', 'A=n'), ('удивлением', 'S'), (':', 'NONLEX'), ('—', 'S'), ('Как', 'ADV-PRO'), ('же', 'PART'), ('ты', 'S-PRO'), ('тут', 'ADV-PRO'), ('уцелела', 'V'), (',', 'NONLEX'), ('милая', 'A=f'), ('?', 'NONLEX'), ('..', 'NONLEX')]
# [('Но', 'CONJ'), ('если', 'CONJ'), ('сосна', 'S'), ('гибнет', 'V'), ('от', 'PR'), ('снаряда', 'S'), (',', 'NONLEX'), ('падая', 'V'), (',', 'NONLEX'), ('как', 'CONJ'), ('скошенная', 'A=f'), (',', 'NONLEX'), ('и', 'CONJ'), ('на', 'PR'), ('месте', 'S'), ('среза', 'S'), ('остается', 'V'), ('лишь', 'PART'), ('иглистая', 'A=f'), (',', 'NONLEX'), ('истекающая', 'V'), ('смолой', 'S'), ('макушка', 'S'), (',', 'NONLEX'), ('то', 'CONJ'), ('по-иному', 'ADV'), ('встречается', 'V'), ('со', 'PR'), ('смертью', 'S'), ('дуб', 'S'), ('.', 'NONLEX')]
# [('На', 'PR'), ('провесне', 'S'), ('немецкий', 'A=m'), ('снаряд', 'S'), ('попал', 'V'), ('в', 'PR'), ('ствол', 'S'), ('старого', 'A=m'), ('дуба', 'S'), (',', 'NONLEX'), ('росшего', 'V'), ('на', 'PR'), ('берегу', 'S'), ('безыменной', 'A=f'), ('речушки', 'S'), ('.', 'NONLEX')]
# [('Рваная', 'A=f'), (',', 'NONLEX'), ('зияющая', 'V'), ('пробоина', 'S'), ('иссушила', 'V'), ('полдерева', 'S'), (',', 'NONLEX'), ('но', 'CONJ'), ('вторая', 'ANUM=f'), ('половина', 'S'), (',', 'NONLEX'), ('пригнутая', 'V'), ('разрывом', 'S'), ('к', 'PR'), ('воде', 'S'), (',', 'NONLEX'), ('весною', 'S'), ('дивно', 'ADV'), ('ожила', 'V'), ('и', 'CONJ'), ('покрылась', 'V'), ('свежей', 'A=f'), ('листвой', 'S'), ('.', 'NONLEX')]
# [('И', 'CONJ'), ('до', 'PR'), ('сегодняшнего', 'A=m'), ('дня', 'S'), (',', 'NONLEX'), ('наверное', 'PARENTH'), (',', 'NONLEX'), ('нижние', 'S'), ('ветви', 'S'), ('искалеченного', 'A=m'), ('дуба', 'S'), ('купаются', 'V'), ('в', 'PR'), ('текучей', 'A-PRO=m'), ('воде', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('верхние', 'S'), ('все', 'A-PRO=pl'), ('еще', 'ADV'), ('жадно', 'ADV'), ('протягивают', 'V'), ('к', 'PR'), ('солнцу', 'S'), ('точеные', 'A=pl'), (',', 'NONLEX'), ('тугие', 'A=pl'), ('листья…', 'S'), ('*', 'NONLEX'), ('*', 'NONLEX'), ('*', 'NONLEX'), ('Высокий', 'A=m'), (',', 'NONLEX'), ('немного', 'ADV'), ('сутулый', 'A=m'), (',', 'NONLEX'), ('с', 'PR'), ('приподнятыми', 'A=pl'), (',', 'NONLEX'), ('как', 'CONJ'), ('у', 'PR'), ('коршуна', 'S'), (',', 'NONLEX'), ('широкими', 'A=pl'), ('плечами', 'S'), (',', 'NONLEX'), ('лейтенант', 'S'), ('Герасимов', 'S'), ('сидел', 'V'), ('у', 'PR'), ('входа', 'S'), ('в', 'PR'), ('блиндаж', 'S'), ('и', 'CONJ'), ('обстоятельно', 'ADV'), ('рассказывал', 'V'), ('о', 'PR'), ('сегодняшнем', 'A=m'), ('бое', 'S'), (',', 'NONLEX'), ('о', 'PR'), ('танковой', 'A=f'), ('атаке', 'S'), ('противника', 'S'), (',', 'NONLEX'), ('успешно', 'ADV'), ('отбитой', 'V'), ('батальоном', 'S'), ('.', 'NONLEX')]
# [('Худое', 'A-PRO=n'), ('лицо', 'S'), ('лейтенанта', 'S'), ('было', 'V'), ('спокойно', 'ADV'), (',', 'NONLEX'), ('почти', 'ADV'), ('бесстрастно', 'ADV'), (',', 'NONLEX'), ('воспаленные', 'A=pl'), ('глаза', 'S'), ('устало', 'V'), ('прищурены', 'V'), ('.', 'NONLEX')]
# [('Он', 'S-PRO'), ('говорил', 'V'), ('надтреснутым', 'A=m'), ('баском', 'S'), (',', 'NONLEX'), ('изредка', 'ADV'), ('скрещивая', 'V'), ('крупные', 'A=pl'), ('узловатые', 'A=pl'), ('пальцы', 'S'), ('рук', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('странно', 'ADV'), ('не', 'PART'), ('вязался', 'V'), ('с', 'PR'), ('его', 'A-PRO'), ('сильной', 'A=f'), ('фигурой', 'S'), (',', 'NONLEX'), ('с', 'PR'), ('энергическим', 'S'), (',', 'NONLEX'), ('мужественным', 'A=n'), ('лицом', 'S'), ('этот', 'A-PRO=m'), ('жест', 'S'), (',', 'NONLEX'), ('так', 'ADV-PRO'), ('красноречиво', 'ADV'), ('передающий', 'V'), ('безмолвное', 'A=n'), ('горе', 'S'), ('или', 'CONJ'), ('глубокое', 'A=n'), ('и', 'CONJ'), ('тягостное', 'A=n'), ('раздумье', 'S'), ('.', 'NONLEX')]
# [('Но', 'CONJ'), ('вдруг', 'ADV'), ('он', 'S-PRO'), ('умолк', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('лицо', 'S'), ('его', 'A-PRO'), ('мгновенно', 'ADV'), ('преобразилось', 'V'), (':', 'NONLEX'), ('смуглые', 'A=pl'), ('щеки', 'S'), ('побледнели', 'V'), (',', 'NONLEX'), ('под', 'PR'), ('скулами', 'S'), (',', 'NONLEX'), ('перекатываясь', 'V'), (',', 'NONLEX'), ('заходили', 'V'), ('желваки', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('пристально', 'ADV'), ('устремленные', 'V'), ('вперед', 'S'), ('глаза', 'S'), ('вспыхнули', 'V'), ('такой', 'A-PRO=f'), ('неугасимой', 'A=f'), (',', 'NONLEX'), ('лютой', 'A=f'), ('ненавистью', 'S'), (',', 'NONLEX'), ('что', 'CONJ'), ('я', 'S-PRO'), ('невольно', 'ADV'), ('повернулся', 'V'), ('в', 'PR'), ('сторону', 'S'), ('его', 'A-PRO'), ('взгляда', 'S'), ('и', 'CONJ'), ('увидел', 'V'), ('шедших', 'V'), ('по', 'PR'), ('лесу', 'S'), ('от', 'PR'), ('переднего', 'A=m'), ('края', 'S'), ('нашей', 'A-PRO=f'), ('обороны', 'S'), ('трех', 'NUM=gen'), ('пленных', 'A=pl'), ('немцев', 'S'), ('и', 'CONJ'), ('сзади', 'ADV'), ('—', 'S'), ('конвоировавшего', 'V'), ('их', 'S-PRO'), ('красноармейца', 'S'), ('в', 'PR'), ('выгоревшей', 'V'), (',', 'NONLEX'), ('почти', 'ADV'), ('белой', 'A=sg'), ('от', 'PR'), ('солнца', 'S'), (',', 'NONLEX'), ('летней', 'A=f'), ('гимнастерке', 'S'), ('и', 'CONJ'), ('сдвинутой', 'S'), ('на', 'PR'), ('затылок', 'S'), ('пилотке', 'S'), ('.', 'NONLEX')]
# [('Красноармеец', 'S'), ('шел', 'S'), ('медленно', 'ADV'), ('.', 'NONLEX')]
# [('Мерно', 'ADV'), ('раскачивалась', 'V'), ('в', 'PR'), ('его', 'A-PRO'), ('руках', 'S'), ('винтовка', 'S'), (',', 'NONLEX'), ('посверкивая', 'V'), ('на', 'PR'), ('солнце', 'S'), ('жалом', 'S'), ('штыка', 'S'), ('.', 'NONLEX')]
# [('И', 'CONJ'), ('так', 'ADV-PRO'), ('же', 'PART'), ('медленно', 'ADV'), ('брели', 'V'), ('пленные', 'A=pl'), ('немцы', 'S'), (',', 'NONLEX'), ('нехотя', 'ADV'), ('переставляя', 'V'), ('ноги', 'S'), (',', 'NONLEX'), ('обутые', 'V'), ('в', 'PR'), ('короткие', 'A=pl'), (',', 'NONLEX'), ('измазанные', 'A=pl'), ('желтой', 'A=f'), ('глиной', 'S'), ('сапоги', 'S'), ('.', 'NONLEX')]
# [('Шагавший', 'V'), ('впереди', 'ADV'), ('немец', 'S'), ('—', 'NONLEX'), ('пожилой', 'A=f'), (',', 'NONLEX'), ('со', 'PR'), ('впалыми', 'A=pl'), ('щеками', 'S'), (',', 'NONLEX'), ('густо', 'ADV'), ('заросшими', 'V'), ('каштановой', 'A=f'), ('щетиной', 'S'), (',', 'NONLEX'), ('—', 'S'), ('поравнялся', 'V'), ('с', 'PR'), ('блиндажом', 'S'), (',', 'NONLEX'), ('кинул', 'V'), ('в', 'PR'), ('нашу', 'A-PRO=f'), ('сторону', 'S'), ('исподлобный', 'A=m'), (',', 'NONLEX'), ('волчий', 'A=m'), ('взгляд', 'S'), (',', 'NONLEX'), ('отвернулся', 'V'), (',', 'NONLEX'), ('на', 'PR'), ('ходу', 'S'), ('поправляя', 'V'), ('привешенную', 'A=f'), ('к', 'PR'), ('поясу', 'S'), ('каску', 'S'), ('.', 'NONLEX')]
# [('И', 'CONJ'), ('тогда', 'ADV-PRO'), ('лейтенант', 'S'), ('Герасимов', 'S'), ('порывисто', 'ADV'), ('вскочил', 'V'), (',', 'NONLEX'), ('крикнул', 'V'), ('красноармейцу', 'S'), ('резким', 'A=m'), (',', 'NONLEX'), ('лающим', 'V'), ('голосом', 'S'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Ты', 'S-PRO'), ('что', 'ADV-PRO'), (',', 'NONLEX'), ('на', 'PR'), ('прогулке', 'S'), ('с', 'PR'), ('ними', 'S-PRO'), ('?', 'NONLEX')]
# [('Прибавить', 'V'), ('шагу', 'S'), ('!', 'NONLEX')]
# [('Веди', 'S'), ('быстрей', 'S'), (',', 'NONLEX'), ('говорят', 'V'), ('тебе', 'S-PRO'), ('!', 'NONLEX'), ('..', 'NONLEX')]
# [('Он', 'S-PRO'), (',', 'NONLEX'), ('видимо', 'PARENTH'), (',', 'NONLEX'), ('хотел', 'V'), ('еще', 'ADV'), ('что-то', 'S-PRO'), ('крикнуть', 'V'), (',', 'NONLEX'), ('но', 'CONJ'), ('задохнулся', 'V'), ('от', 'PR'), ('волнения', 'S'), ('и', 'CONJ'), (',', 'NONLEX'), ('круто', 'ADV'), ('повернувшись', 'V'), (',', 'NONLEX'), ('быстро', 'ADV'), ('сбежал', 'V'), ('по', 'PR'), ('ступенькам', 'S'), ('в', 'PR'), ('блиндаж', 'S'), ('.', 'NONLEX')]
# [('Присутствовавший', 'V'), ('при', 'PR'), ('разговоре', 'S'), ('политрук', 'S'), (',', 'NONLEX'), ('отвечая', 'V'), ('на', 'PR'), ('мой', 'A-PRO=m'), ('удивленный', 'A=m'), ('взгляд', 'S'), (',', 'NONLEX'), ('вполголоса', 'ADV'), ('сказал', 'V'), (':', 'NONLEX'), ('—', 'S'), ('Ничего', 'S-PRO'), ('не', 'PART'), ('поделаешь', 'V'), ('—', 'NONLEX'), ('нервы', 'S'), ('.', 'NONLEX')]
# [('Он', 'S-PRO'), ('в', 'PR'), ('плену', 'S'), ('у', 'PR'), ('немцев', 'S'), ('был', 'V'), (',', 'NONLEX'), ('разве', 'PART'), ('вы', 'S-PRO'), ('не', 'PART'), ('знаете', 'V'), ('?', 'NONLEX')]
# [('Вы', 'S-PRO'), ('поговорите', 'V'), ('с', 'PR'), ('ним', 'S-PRO'), ('как-нибудь', 'ADV-PRO'), ('.', 'NONLEX')]
# [('Он', 'S-PRO'), ('очень', 'ADV'), ('много', 'ADV-PRO'), ('пережил', 'V'), ('там', 'ADV-PRO'), ('и', 'CONJ'), ('после', 'PR'), ('этого', 'S-PRO'), ('живых', 'A=pl'), ('гитлеровцев', 'S'), ('не', 'PART'), ('может', 'V'), ('видеть', 'V'), (',', 'NONLEX'), ('именно', 'PART'), ('живых', 'A=pl'), ('!', 'NONLEX')]
# [('На', 'PR'), ('мертвых', 'S'), ('смотрит', 'V'), ('ничего', 'S-PRO'), (',', 'NONLEX'), ('я', 'S-PRO'), ('бы', 'PART'), ('сказал', 'V'), ('—', 'S'), ('даже', 'PART'), ('с', 'PR'), ('удовольствием', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('вот', 'PART'), ('пленных', 'S'), ('увидит', 'V'), ('и', 'CONJ'), ('либо', 'CONJ'), ('закроет', 'V'), ('глаза', 'S'), ('и', 'CONJ'), ('сидит', 'V'), ('бледный', 'A=m'), ('и', 'CONJ'), ('потный', 'A=m'), (',', 'NONLEX'), ('либо', 'CONJ'), ('повернется', 'V'), ('и', 'CONJ'), ('уйдет', 'V'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Политрук', 'S'), ('придвинулся', 'V'), ('ко', 'PR'), ('мне', 'S-PRO'), (',', 'NONLEX'), ('перешел', 'V'), ('на', 'PR'), ('шепот', 'S'), (':', 'NONLEX'), ('—', 'S'), ('Мне', 'S-PRO'), ('с', 'PR'), ('ним', 'S-PRO'), ('пришлось', 'V'), ('два', 'NUM=m'), ('раза', 'S'), ('ходить', 'V'), ('в', 'PR'), ('атаку', 'S'), (':', 'NONLEX'), ('силища', 'S'), ('у', 'PR'), ('него', 'S-PRO'), ('лошадиная', 'A=f'), (',', 'NONLEX'), ('и', 'CONJ'), ('вы', 'S-PRO'), ('бы', 'PART'), ('посмотрели', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('он', 'S-PRO'), ('делает…', 'S'), ('Всякие', 'A=pl'), ('виды', 'S'), ('мне', 'S-PRO'), ('приходилось', 'V'), ('видывать', 'V'), (',', 'NONLEX'), ('но', 'CONJ'), ('как', 'ADV-PRO'), ('он', 'S-PRO'), ('орудует', 'V'), ('штыком', 'S'), ('и', 'CONJ'), ('прикладом', 'S'), (',', 'NONLEX'), ('знаете', 'V'), ('ли', 'PART'), (',', 'NONLEX'), ('—', 'NONLEX'), ('это', 'S-PRO'), ('страшно', 'A=n'), ('!', 'NONLEX')]
# [('*', 'NONLEX'), ('*', 'NONLEX'), ('*', 'NONLEX'), ('Ночью', 'S'), ('немецкая', 'A=f'), ('тяжелая', 'A=f'), ('артиллерия', 'S'), ('вела', 'V'), ('тревожащий', 'V'), ('огонь', 'S'), ('.', 'NONLEX')]
# [('Методически', 'ADV'), (',', 'NONLEX'), ('через', 'PR'), ('ровные', 'A=pl'), ('промежутки', 'S'), ('времени', 'S'), (',', 'NONLEX'), ('издалека', 'S'), ('доносился', 'V'), ('орудийный', 'A=m'), ('выстрел', 'S'), (',', 'NONLEX'), ('спустя', 'PR'), ('несколько', 'NUM=acc'), ('секунд', 'S'), ('над', 'PR'), ('нашими', 'A-PRO=pl'), ('головами', 'S'), (',', 'NONLEX'), ('высоко', 'ADV'), ('в', 'PR'), ('звездном', 'A=n'), ('небе', 'S'), (',', 'NONLEX'), ('слышался', 'V'), ('железный', 'A=m'), ('клекот', 'S'), ('снаряда', 'S'), (',', 'NONLEX'), ('воющий', 'V'), ('звук', 'S'), ('нарастал', 'V'), ('и', 'CONJ'), ('удалялся', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('затем', 'ADV'), ('где-то', 'ADV-PRO'), ('позади', 'PR'), ('нас', 'S-PRO'), (',', 'NONLEX'), ('в', 'PR'), ('направлении', 'S'), ('дороги', 'S'), (',', 'NONLEX'), ('по', 'PR'), ('которой', 'A-PRO=f'), ('днем', 'V'), ('густо', 'ADV'), ('шли', 'V'), ('машины', 'S'), (',', 'NONLEX'), ('подвозившие', 'V'), ('к', 'PR'), ('линии', 'S'), ('фронта', 'S'), ('боеприпасы', 'S'), (',', 'NONLEX'), ('желтой', 'A=f'), ('зарницей', 'S'), ('вспыхивало', 'V'), ('пламя', 'S'), ('и', 'CONJ'), ('громово', 'ADV'), ('звучал', 'V'), ('разрыв', 'S'), ('.', 'NONLEX')]
# [('В', 'PR'), ('промежутках', 'S'), ('между', 'PR'), ('выстрелами', 'S'), (',', 'NONLEX'), ('когда', 'CONJ'), ('в', 'PR'), ('лесу', 'S'), ('устанавливалась', 'V'), ('тишина', 'S'), (',', 'NONLEX'), ('слышно', 'PRAEDIC'), ('было', 'V'), (',', 'NONLEX'), ('как', 'CONJ'), ('тонко', 'ADV'), ('пели', 'V'), ('комары', 'S'), ('и', 'CONJ'), ('несмело', 'ADV'), ('перекликались', 'V'), ('в', 'PR'), ('соседнем', 'A=m'), ('болотце', 'S'), ('потревоженные', 'A=pl'), ('стрельбой', 'S'), ('лягушки', 'S'), ('.', 'NONLEX')]
# [('Мы', 'S-PRO'), ('лежали', 'V'), ('под', 'PR'), ('кустом', 'S'), ('орешника', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('лейтенант', 'S'), ('Герасимов', 'S'), (',', 'NONLEX'), ('отмахиваясь', 'V'), ('от', 'PR'), ('комаров', 'S'), ('сломленной', 'A=f'), ('веткой', 'S'), (',', 'NONLEX'), ('неторопливо', 'ADV'), ('рассказывал', 'V'), ('о', 'PR'), ('себе', 'S-PRO=loc'), ('.', 'NONLEX')]
# [('Я', 'S-PRO'), ('передаю', 'V'), ('этот', 'A-PRO=m'), ('рассказ', 'S'), ('так', 'ADV-PRO'), (',', 'NONLEX'), ('как', 'ADV-PRO'), ('мне', 'S-PRO'), ('удалось', 'V'), ('его', 'S-PRO'), ('запомнить', 'V'), ('.', 'NONLEX')]
# [('—', 'V'), ('До', 'PR'), ('войны', 'S'), ('работал', 'V'), ('я', 'S-PRO'), ('механиком', 'S'), ('на', 'PR'), ('одном', 'A-PRO=m'), ('из', 'PR'), ('заводов', 'S'), ('Западной', 'A=f'), ('Сибири', 'S'), ('.', 'NONLEX')]
# [('В', 'PR'), ('армию', 'S'), ('призван', 'A=m'), ('девятого', 'A=m'), ('июля', 'S'), ('прошлого', 'A=m'), ('года', 'S'), ('.', 'NONLEX')]
# [('Семья', 'S'), ('у', 'PR'), ('меня', 'S-PRO'), ('—', 'NONLEX'), ('жена', 'S'), (',', 'NONLEX'), ('двое', 'NUM=nom'), ('ребят', 'S'), (',', 'NONLEX'), ('отец-инвалид', 'S'), ('.', 'NONLEX')]
# [('Ну', 'PART'), (',', 'NONLEX'), ('на', 'PR'), ('проводах', 'S'), (',', 'NONLEX'), ('как', 'CONJ'), ('полагается', 'V'), (',', 'NONLEX'), ('жена', 'S'), ('и', 'CONJ'), ('поплакала', 'V'), ('и', 'CONJ'), ('напутствие', 'S'), ('сказала', 'V'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Защищай', 'NONLEX'), ('родину', 'S'), ('и', 'CONJ'), ('нас', 'S-PRO'), ('крепко', 'ADV'), ('.', 'NONLEX')]
# [('Если', 'CONJ'), ('понадобится', 'V'), ('—', 'NONLEX'), ('жизнь', 'S'), ('отдай', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('чтобы', 'CONJ'), ('победа', 'S'), ('была', 'V'), ('нашей', 'A-PRO=f'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('Помню', 'V'), (',', 'NONLEX'), ('засмеялся', 'V'), ('я', 'S-PRO'), ('тогда', 'ADV-PRO'), ('и', 'CONJ'), ('говорю', 'V'), ('ей', 'S-PRO'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Кто', 'S-PRO'), ('ты', 'S-PRO'), ('мне', 'S-PRO'), ('есть', 'V'), (',', 'NONLEX'), ('жена', 'S'), ('или', 'CONJ'), ('семейный', 'A=m'), ('агитатор', 'S'), ('?', 'NONLEX')]
# [('Я', 'S-PRO'), ('сам', 'A-PRO=m'), ('большой', 'A=m'), (',', 'NONLEX'), ('а', 'CONJ'), ('что', 'S-PRO'), ('касается', 'V'), ('победы', 'S'), (',', 'NONLEX'), ('так', 'ADV-PRO'), ('мы', 'S-PRO'), ('ее', 'V'), ('у', 'PR'), ('фашистов', 'S'), ('вместе', 'ADV'), ('с', 'PR'), ('горлом', 'S'), ('вынем', 'S'), (',', 'NONLEX'), ('не', 'PART'), ('беспокойся', 'V'), ('!', 'NONLEX'), ('»', 'NONLEX'), ('Отец', 'S'), (',', 'NONLEX'), ('тот', 'A-PRO=m'), (',', 'NONLEX'), ('конечно', 'PARENTH'), (',', 'NONLEX'), ('покрепче', 'A=comp2'), (',', 'NONLEX'), ('но', 'CONJ'), ('без', 'PR'), ('наказа', 'S'), ('и', 'CONJ'), ('тут', 'ADV-PRO'), ('не', 'PART'), ('обошлось', 'V'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Смотри', 'V'), (',', 'NONLEX'), ('—', 'S'), ('говорит', 'V'), (',', 'NONLEX'), ('—', 'CONJ'), ('Виктор', 'S'), (',', 'NONLEX'), ('фамилия', 'S'), ('Герасимовых', 'A=pl'), ('—', 'S'), ('это', 'S-PRO'), ('не', 'PART'), ('простая', 'A=f'), ('фамилия', 'S'), ('.', 'NONLEX')]
# [('Ты', 'S-PRO'), ('—', 'NONLEX'), ('потомственный', 'A=m'), ('рабочий', 'A=m'), (';', 'NONLEX'), ('прадед', 'S'), ('твой', 'A-PRO=m'), ('еще', 'ADV'), ('у', 'PR'), ('Строганова', 'S'), ('работал', 'V'), (';', 'NONLEX'), ('наша', 'A-PRO=f'), ('фамилия', 'S'), ('сотни', 'S'), ('лет', 'S'), ('железо', 'S'), ('для', 'PR'), ('родины', 'S'), ('делала', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('чтобы', 'CONJ'), ('ты', 'S-PRO'), ('на', 'PR'), ('этой', 'A-PRO=f'), ('войне', 'S'), ('был', 'V'), ('железным', 'A=m'), ('.', 'NONLEX')]
# [('Власть-то', 'PART'), ('—', 'NONLEX'), ('твоя', 'A-PRO=sg'), (',', 'NONLEX'), ('она', 'S-PRO'), ('тебя', 'S-PRO'), ('командиром', 'S'), ('запаса', 'S'), ('до', 'PR'), ('войны', 'S'), ('держала', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('должен', 'A'), ('ты', 'S-PRO'), ('врага', 'V'), ('бить', 'V'), ('крепко', 'ADV'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('«', 'NONLEX'), ('Будет', 'V'), ('сделано', 'V'), (',', 'NONLEX'), ('отец', 'S'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('По', 'PR'), ('пути', 'S'), ('на', 'PR'), ('вокзал', 'S'), ('забежал', 'V'), ('в', 'PR'), ('райком', 'S'), ('партии', 'S'), ('.', 'NONLEX')]
# [('Секретарь', 'S'), ('у', 'PR'), ('нас', 'S-PRO'), ('был', 'V'), ('какой-то', 'A-PRO=f'), ('очень', 'ADV'), ('сухой', 'A=f'), (',', 'NONLEX'), ('рассудочный', 'A=m'), ('человек…', 'S'), ('Ну', 'PART'), (',', 'NONLEX'), ('думаю', 'V'), (',', 'NONLEX'), ('уж', 'PART'), ('если', 'CONJ'), ('жена', 'S'), ('с', 'PR'), ('отцом', 'S'), ('меня', 'S-PRO'), ('на', 'PR'), ('дорогу', 'S'), ('агитировали', 'V'), (',', 'NONLEX'), ('то', 'CONJ'), ('этот', 'A-PRO=m'), ('вовсе', 'ADV'), ('спуску', 'S'), ('не', 'PART'), ('даст', 'V'), (',', 'NONLEX'), ('двинет', 'V'), ('какую-нибудь', 'S-PRO'), ('речугу', 'S'), ('на', 'PR'), ('полчаса', 'S'), (',', 'NONLEX'), ('обязательно', 'ADV'), ('двинет', 'V'), ('!', 'NONLEX')]
# [('А', 'CONJ'), ('получилось', 'V'), ('все', 'S-PRO'), ('наоборот', 'ADV'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Садись', 'V'), (',', 'NONLEX'), ('Герасимов', 'S'), (',', 'NONLEX'), ('—', 'S'), ('говорит', 'V'), ('мой', 'A-PRO=m'), ('секретарь', 'S'), (',', 'NONLEX'), ('—', 'NONLEX'), ('перед', 'PR'), ('дорогой', 'S'), ('посидим', 'V'), ('минутку', 'S'), ('по', 'PR'), ('старому', 'A=m'), ('обычаю', 'S'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('Посидели', 'V'), ('мы', 'S-PRO'), ('с', 'PR'), ('ним', 'S-PRO'), ('немного', 'ADV'), (',', 'NONLEX'), ('помолчали', 'V'), (',', 'NONLEX'), ('потом', 'ADV-PRO'), ('он', 'S-PRO'), ('встал', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('вижу', 'V'), ('—', 'NONLEX'), ('очки', 'S'), ('у', 'PR'), ('него', 'S-PRO'), ('будто', 'PART'), ('бы', 'PART'), ('отпотели…', 'V'), ('Вот', 'PART'), (',', 'NONLEX'), ('думаю', 'V'), (',', 'NONLEX'), ('чудеса', 'S'), ('какие', 'A-PRO=pl'), ('нынче', 'ADV'), ('происходят', 'V'), ('!', 'NONLEX')]
# [('А', 'CONJ'), ('секретарь', 'S'), ('и', 'CONJ'), ('говорит', 'V'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Все', 'S-PRO'), ('ясно', 'ADV'), ('и', 'CONJ'), ('понятно', 'ADV'), (',', 'NONLEX'), ('товарищ', 'S'), ('Герасимов', 'S'), ('.', 'NONLEX')]
# [('Помню', 'V'), ('я', 'S-PRO'), ('тебя', 'S-PRO'), ('еще', 'ADV'), ('вот', 'PART'), ('таким', 'A-PRO=m'), (',', 'NONLEX'), ('лопоухим', 'A=m'), (',', 'NONLEX'), ('когда', 'CONJ'), ('ты', 'S-PRO'), ('пионерский', 'A=m'), ('галстук', 'S'), ('носил', 'V'), (',', 'NONLEX'), ('помню', 'V'), ('затем', 'ADV'), ('комсомольцем', 'S'), (',', 'NONLEX'), ('знаю', 'V'), ('и', 'CONJ'), ('как', 'ADV-PRO'), ('коммуниста', 'S'), ('на', 'PR'), ('протяжении', 'S'), ('десяти', 'NUM=gen'), ('лет', 'S'), ('.', 'NONLEX')]
# [('Иди', 'V'), (',', 'NONLEX'), ('бей', 'V'), ('гадов', 'S'), ('беспощадно', 'ADV'), ('!', 'NONLEX')]
# [('Парторганизация', 'S'), ('на', 'PR'), ('тебя', 'S-PRO'), ('надеется', 'V'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('Первый', 'ANUM=m'), ('раз', 'S'), ('в', 'PR'), ('жизни', 'S'), ('расцеловался', 'V'), ('я', 'S-PRO'), ('со', 'PR'), ('своим', 'A-PRO=sg'), ('секретарем', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), (',', 'NONLEX'), ('черт', 'S'), ('его', 'S-PRO'), ('знает', 'V'), (',', 'NONLEX'), ('показался', 'V'), ('он', 'S-PRO'), ('тогда', 'ADV-PRO'), ('мне', 'S-PRO'), ('вовсе', 'ADV'), ('не', 'PART'), ('таким', 'A-PRO=pl'), ('уж', 'PART'), ('сухарем', 'S'), (',', 'NONLEX'), ('как', 'CONJ'), ('раньше…', 'S'), ('И', 'CONJ'), ('до', 'PR'), ('того', 'S-PRO'), ('мне', 'S-PRO'), ('тепло', 'PRAEDIC'), ('стало', 'V'), ('от', 'PR'), ('этой', 'A-PRO=f'), ('его', 'A-PRO'), ('душевности', 'S'), (',', 'NONLEX'), ('что', 'CONJ'), ('вышел', 'V'), ('я', 'S-PRO'), ('из', 'PR'), ('райкома', 'S'), ('радостный', 'A=m'), ('и', 'CONJ'), ('взволнованный', 'A=m'), ('.', 'NONLEX')]
# [('А', 'CONJ'), ('тут', 'ADV-PRO'), ('еще', 'ADV'), ('жена', 'S'), ('развеселила', 'V'), ('.', 'NONLEX')]
# [('Сами', 'A-PRO=pl'), ('понимаете', 'V'), (',', 'NONLEX'), ('что', 'S-PRO'), ('провожать', 'V'), ('мужа', 'S'), ('на', 'PR'), ('фронт', 'S'), ('никакой', 'A-PRO=f'), ('жене', 'S'), ('невесело', 'ADV'), (';', 'NONLEX'), ('ну', 'PART'), (',', 'NONLEX'), ('и', 'CONJ'), ('моя', 'A-PRO=f'), ('жена', 'S'), (',', 'NONLEX'), ('конечно', 'PARENTH'), (',', 'NONLEX'), ('тоже', 'PART'), ('растерялась', 'V'), ('немного', 'ADV'), ('от', 'PR'), ('горя', 'S'), (',', 'NONLEX'), ('все', 'A-PRO=pl'), ('хотела', 'V'), ('что-то', 'S-PRO'), ('важное', 'A=n'), ('сказать', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('в', 'PR'), ('голове', 'S'), ('у', 'PR'), ('нее', 'A=n'), ('сквозняк', 'S'), ('получился', 'V'), (',', 'NONLEX'), ('все', 'A-PRO=pl'), ('мысли', 'S'), ('вылетели', 'V'), ('.', 'NONLEX')]
# [('И', 'CONJ'), ('вот', 'PART'), ('уже', 'ADV'), ('поезд', 'S'), ('тронулся', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('она', 'S-PRO'), ('идет', 'V'), ('рядом', 'ADV'), ('с', 'PR'), ('моим', 'A-PRO=m'), ('вагоном', 'S'), (',', 'NONLEX'), ('руку', 'S'), ('мою', 'A-PRO=f'), ('из', 'PR'), ('своей', 'A-PRO=f'), ('не', 'PART'), ('выпускает', 'V'), ('и', 'CONJ'), ('быстро', 'ADV'), ('так', 'ADV-PRO'), ('говорит', 'V'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Смотри', 'V'), (',', 'NONLEX'), ('Витя', 'S'), (',', 'NONLEX'), ('береги', 'V'), ('себя', 'S-PRO=acc'), (',', 'NONLEX'), ('не', 'PART'), ('простудись', 'V'), ('там', 'ADV-PRO'), (',', 'NONLEX'), ('на', 'PR'), ('фронте', 'S'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('«', 'NONLEX'), ('Что', 'S-PRO'), ('ты', 'S-PRO'), (',', 'NONLEX'), ('—', 'S'), ('говорю', 'V'), ('ей', 'S-PRO'), (',', 'NONLEX'), ('—', 'NONLEX'), ('Надя', 'S'), (',', 'NONLEX'), ('что', 'CONJ'), ('ты', 'S-PRO'), ('!', 'NONLEX')]
# [('Ни', 'PART'), ('за', 'PR'), ('что', 'S-PRO'), ('не', 'PART'), ('простужусь', 'V'), ('.', 'NONLEX')]
# [('Там', 'ADV-PRO'), ('климат', 'S'), ('отличный', 'A=m'), ('и', 'CONJ'), ('очень', 'ADV'), ('даже', 'PART'), ('умеренный', 'A=sg'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('И', 'CONJ'), ('горько', 'ADV'), ('мне', 'S-PRO'), ('было', 'V'), ('расставаться', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('веселее', 'PRAEDIC=comp'), ('стало', 'V'), ('от', 'PR'), ('милых', 'A=pl'), ('и', 'CONJ'), ('глупеньких', 'A=pl'), ('слов', 'S'), ('жены', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('такое', 'A-PRO=n'), ('зло', 'S'), ('взяло', 'V'), ('на', 'PR'), ('немцев', 'S'), ('.', 'NONLEX')]
# [('Ну', 'PART'), (',', 'NONLEX'), ('думаю', 'V'), (',', 'NONLEX'), ('тронули', 'V'), ('нас', 'S-PRO'), (',', 'NONLEX'), ('вероломные', 'A=pl'), ('соседи', 'S'), (',', 'NONLEX'), ('—', 'NONLEX'), ('теперь', 'ADV-PRO'), ('держитесь', 'V'), ('!', 'NONLEX')]
# [('Вколем', 'S'), ('мы', 'S-PRO'), ('вам', 'S-PRO'), ('по', 'PR'), ('первое', 'ANUM=n'), ('число', 'S'), ('!', 'NONLEX')]
# [('Герасимов', 'S'), ('помолчал', 'V'), ('несколько', 'NUM=acc'), ('минут', 'S'), (',', 'NONLEX'), ('прислушиваясь', 'V'), ('к', 'PR'), ('вспыхнувшей', 'V'), ('на', 'PR'), ('переднем', 'A=m'), ('крае', 'S'), ('пулеметной', 'A=f'), ('перестрелке', 'S'), (',', 'NONLEX'), ('потом', 'ADV-PRO'), (',', 'NONLEX'), ('когда', 'CONJ'), ('стрельба', 'S'), ('прекратилась', 'V'), ('так', 'ADV-PRO'), ('же', 'PART'), ('внезапно', 'ADV'), (',', 'NONLEX'), ('как', 'CONJ'), ('и', 'CONJ'), ('началась', 'V'), (',', 'NONLEX'), ('продолжал', 'V'), (':', 'NONLEX'), ('—', 'S'), ('До', 'PR'), ('войны', 'S'), ('на', 'PR'), ('завод', 'S'), ('к', 'PR'), ('нам', 'S-PRO'), ('поступали', 'V'), ('машины', 'S'), ('из', 'PR'), ('Германии', 'S'), ('.', 'NONLEX')]
# [('При', 'PR'), ('сборке', 'S'), (',', 'NONLEX'), ('бывало', 'PARENTH'), (',', 'NONLEX'), ('раз', 'S'), ('по', 'PR'), ('пять', 'NUM=acc'), ('ощупаю', 'V'), ('каждую', 'A-PRO=f'), ('деталь', 'S'), (',', 'NONLEX'), ('осмотрю', 'V'), ('ее', 'S'), ('со', 'PR'), ('всех', 'A-PRO=pl'), ('сторон', 'S'), ('.', 'NONLEX')]
# [('Ничего', 'S-PRO'), ('не', 'PART'), ('скажешь', 'V'), ('—', 'S'), ('умные', 'A=pl'), ('руки', 'S'), ('эти', 'A-PRO=pl'), ('машины', 'S'), ('делали', 'V'), ('.', 'NONLEX')]
# [('Книги', 'S'), ('немецких', 'A=pl'), ('писателей', 'S'), ('читал', 'V'), ('и', 'CONJ'), ('любил', 'V'), ('и', 'CONJ'), ('как-то', 'ADV-PRO'), ('привык', 'V'), ('с', 'PR'), ('уважением', 'S'), ('относиться', 'V'), ('к', 'PR'), ('немецкому', 'A=m'), ('народу', 'S'), ('.', 'NONLEX')]
# [('Правда', 'PARENTH'), (',', 'NONLEX'), ('иной', 'A-PRO=m'), ('раз', 'S'), ('обидно', 'PRAEDIC'), ('становилось', 'V'), ('за', 'PR'), ('то', 'S-PRO'), (',', 'NONLEX'), ('что', 'CONJ'), ('такой', 'A-PRO=m'), ('трудолюбивый', 'A=m'), ('и', 'CONJ'), ('талантливый', 'A=m'), ('народ', 'S'), ('терпит', 'V'), ('у', 'PR'), ('себя', 'S-PRO=gen'), ('самый', 'A-PRO=m'), ('паскудный', 'A=m'), ('гитлеровский', 'A=m'), ('режим', 'S'), (',', 'NONLEX'), ('но', 'CONJ'), ('это', 'S-PRO'), ('было', 'V'), ('в', 'PR'), ('конце', 'S'), ('концов', 'S'), ('их', 'A-PRO'), ('дело', 'S'), ('.', 'NONLEX')]
# [('Потом', 'ADV-PRO'), ('началась', 'V'), ('война', 'S'), ('в', 'PR'), ('Западной', 'A=f'), ('Европе…', 'S'), ('И', 'CONJ'), ('вот', 'PART'), ('еду', 'S'), ('я', 'S-PRO'), ('на', 'PR'), ('фронт', 'S'), ('и', 'CONJ'), ('думаю', 'V'), (':', 'NONLEX'), ('техника', 'S'), ('у', 'PR'), ('немцев', 'S'), ('сильная', 'A=f'), (',', 'NONLEX'), ('армия', 'S'), ('—', 'S'), ('тоже', 'PART'), ('ничего', 'S-PRO'), ('себе', 'S-PRO=dat'), ('.', 'NONLEX')]
# [('Черт', 'S'), ('возьми', 'V'), (',', 'NONLEX'), ('с', 'PR'), ('таким', 'A-PRO=m'), ('противником', 'S'), ('даже', 'PART'), ('интересно', 'PRAEDIC'), ('подраться', 'V'), ('и', 'CONJ'), ('наломать', 'V'), ('ему', 'S-PRO'), ('бока', 'S'), ('.', 'NONLEX')]
# [('Мы-то', 'S-PRO'), ('тоже', 'PART'), ('к', 'PR'), ('сорок', 'NUM=acc'), ('первому', 'ANUM=m'), ('году', 'S'), ('были', 'V'), ('не', 'PART'), ('лыком', 'A=sg'), ('шиты', 'S'), ('.', 'NONLEX')]
# [('Признаться', 'V'), (',', 'NONLEX'), ('особой', 'A=f'), ('честности', 'S'), ('я', 'S-PRO'), ('от', 'PR'), ('этого', 'A-PRO=m'), ('противника', 'S'), ('не', 'PART'), ('ждал', 'V'), (',', 'NONLEX'), ('какая', 'A-PRO=f'), ('уж', 'ADV'), ('там', 'ADV-PRO'), ('честность', 'S'), (',', 'NONLEX'), ('когда', 'ADV-PRO'), ('имеешь', 'V'), ('дело', 'S'), ('с', 'PR'), ('фашизмом', 'S'), (',', 'NONLEX'), ('но', 'CONJ'), ('никогда', 'ADV-PRO'), ('не', 'PART'), ('думал', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('придется', 'V'), ('воевать', 'V'), ('с', 'PR'), ('такой', 'A-PRO=f'), ('бессовестной', 'A=sg'), ('сволочью', 'S'), (',', 'NONLEX'), ('какой', 'A-PRO=m'), ('оказалась', 'V'), ('армия', 'S'), ('Гитлера', 'S'), ('.', 'NONLEX')]
# [('Ну', 'PART'), (',', 'NONLEX'), ('да', 'PART'), ('об', 'PR'), ('этом', 'S-PRO'), ('после…', 'S'), ('В', 'PR'), ('конце', 'S'), ('июля', 'S'), ('наша', 'A-PRO=f'), ('часть', 'S'), ('прибыла', 'V'), ('на', 'PR'), ('фронт', 'S'), ('.', 'NONLEX')]
# [('В', 'PR'), ('бой', 'S'), ('вступили', 'V'), ('двадцать', 'NUM=acc'), ('седьмого', 'ANUM=m'), ('рано', 'ADV'), ('утром', 'S'), ('.', 'NONLEX')]
# [('Сначала', 'ADV'), (',', 'NONLEX'), ('в', 'PR'), ('новинку-то', 'A-PRO=sg'), (',', 'NONLEX'), ('было', 'V'), ('страшновато', 'PRAEDIC'), ('малость', 'S'), ('.', 'NONLEX')]
# [('Минометами', 'S'), ('сильно', 'ADV'), ('они', 'S-PRO'), ('нас', 'S-PRO'), ('одолевали', 'V'), (',', 'NONLEX'), ('но', 'CONJ'), ('к', 'PR'), ('вечеру', 'S'), ('освоились', 'V'), ('мы', 'S-PRO'), ('немного', 'ADV'), ('и', 'CONJ'), ('дали', 'V'), ('им', 'S-PRO'), ('по', 'PR'), ('зубам', 'S'), (',', 'NONLEX'), ('выбили', 'V'), ('из', 'PR'), ('одной', 'ANUM=f'), ('деревушки', 'S'), ('.', 'NONLEX')]
# [('В', 'PR'), ('этом', 'A-PRO=m'), ('же', 'PART'), ('бою', 'S'), ('захватили', 'V'), ('мы', 'S-PRO'), ('группу', 'S'), (',', 'NONLEX'), ('человек', 'S'), ('в', 'PR'), ('пятнадцать', 'NUM=acc'), (',', 'NONLEX'), ('пленных', 'A=pl'), ('.', 'NONLEX')]
# [('Помню', 'V'), (',', 'NONLEX'), ('как', 'CONJ'), ('сейчас', 'ADV-PRO'), (';', 'NONLEX'), ('привели', 'V'), ('их', 'S-PRO'), (',', 'NONLEX'), ('испуганных', 'A=pl'), (',', 'NONLEX'), ('бледных', 'A=pl'), (';', 'NONLEX'), ('бойцы', 'S'), ('мои', 'A-PRO=pl'), ('к', 'PR'), ('этому', 'A-PRO=n'), ('времени', 'S'), ('остыли', 'V'), ('от', 'PR'), ('боя', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('вот', 'PART'), ('каждый', 'A-PRO=m'), ('из', 'PR'), ('них', 'S-PRO'), ('тащит', 'V'), ('пленным', 'A=pl'), ('все', 'A-PRO=pl'), (',', 'NONLEX'), ('что', 'S-PRO'), ('может', 'V'), (':', 'NONLEX'), ('кто', 'S-PRO'), ('—', 'NONLEX'), ('котелок', 'S'), ('щей', 'S'), (',', 'NONLEX'), ('кто', 'S-PRO'), ('—', 'NONLEX'), ('табаку', 'S'), ('или', 'CONJ'), ('папирос', 'S'), (',', 'NONLEX'), ('кто', 'S-PRO'), ('—', 'NONLEX'), ('чаем', 'S'), ('угощает', 'V'), ('.', 'NONLEX')]
# [('По', 'PR'), ('спинам', 'S'), ('их', 'S-PRO'), ('похлопывают', 'V'), (',', 'NONLEX'), ('«', 'NONLEX'), ('камрадами', 'S'), ('»', 'NONLEX'), ('называют', 'V'), (':', 'NONLEX'), ('за', 'PR'), ('что', 'S-PRO'), (',', 'NONLEX'), ('мол', 'PARENTH'), (',', 'NONLEX'), ('воюете', 'V'), (',', 'NONLEX'), ('камрады', 'S'), ('?', 'NONLEX'), ('..', 'NONLEX')]
# [('А', 'CONJ'), ('один', 'ANUM=m'), ('боец-кадровик', 'S'), ('смотрел-смотрел', 'S'), ('на', 'PR'), ('эту', 'A-PRO=f'), ('трогательную', 'A=f'), ('картину', 'S'), ('и', 'CONJ'), ('говорит', 'V'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Слюни', 'S'), ('вы', 'S-PRO'), ('распустили', 'V'), ('с', 'PR'), ('этими', 'A-PRO=pl'), ('«', 'NONLEX'), ('друзьями', 'S'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('Здесь', 'ADV-PRO'), ('они', 'S-PRO'), ('все', 'A-PRO=pl'), ('камрады', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('вы', 'S-PRO'), ('бы', 'PART'), ('посмотрели', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('эти', 'A-PRO=pl'), ('камрады', 'S'), ('делают', 'V'), ('там', 'ADV-PRO'), (',', 'NONLEX'), ('за', 'PR'), ('линией', 'S'), ('фронта', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('как', 'ADV-PRO'), ('они', 'S-PRO'), ('с', 'PR'), ('нашими', 'A-PRO=pl'), ('ранеными', 'A=pl'), ('и', 'CONJ'), ('с', 'PR'), ('мирным', 'A=n'), ('населением', 'S'), ('обращаются', 'V'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('Сказал', 'V'), (',', 'NONLEX'), ('словно', 'CONJ'), ('ушат', 'V'), ('холодной', 'A=f'), ('воды', 'S'), ('на', 'PR'), ('нас', 'S-PRO'), ('вылил', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('ушел', 'V'), ('.', 'NONLEX')]
# [('Вскоре', 'ADV'), ('перешли', 'V'), ('мы', 'S-PRO'), ('в', 'PR'), ('наступление', 'S'), ('и', 'CONJ'), ('тут', 'ADV-PRO'), ('действительно', 'ADV'), ('насмотрелись…', 'V'), ('Сожженные', 'A=pl'), ('дотла', 'S'), ('деревни', 'S'), (',', 'NONLEX'), ('сотни', 'S'), ('расстрелянных', 'A=pl'), ('женщин', 'S'), (',', 'NONLEX'), ('детей', 'S'), (',', 'NONLEX'), ('стариков', 'S'), (',', 'NONLEX'), ('изуродованные', 'V'), ('трупы', 'S'), ('попавших', 'V'), ('в', 'PR'), ('плен', 'S'), ('красноармейцев', 'S'), (',', 'NONLEX'), ('изнасилованные', 'A=pl'), ('и', 'CONJ'), ('зверски', 'ADV'), ('убитые', 'A=pl'), ('женщины', 'S'), (',', 'NONLEX'), ('девушки', 'S'), ('и', 'CONJ'), ('девочки-подростки…', 'S'), ('Особенно', 'ADV'), ('одна', 'ANUM=f'), ('осталась', 'V'), ('у', 'PR'), ('меня', 'S-PRO'), ('в', 'PR'), ('памяти', 'S'), (':', 'NONLEX'), ('ей', 'S-PRO'), ('было', 'V'), ('лет', 'S'), ('одиннадцать', 'NUM=acc'), (',', 'NONLEX'), ('она', 'S-PRO'), (',', 'NONLEX'), ('как', 'ADV-PRO'), ('видно', 'PRAEDIC'), (',', 'NONLEX'), ('шла', 'V'), ('в', 'PR'), ('школу', 'S'), (';', 'NONLEX'), ('немцы', 'S'), ('поймали', 'V'), ('ее', 'S'), (',', 'NONLEX'), ('затащили', 'V'), ('на', 'PR'), ('огород', 'S'), (',', 'NONLEX'), ('изнасиловали', 'V'), ('и', 'CONJ'), ('убили', 'V'), ('.', 'NONLEX')]
# [('Она', 'S-PRO'), ('лежала', 'V'), ('в', 'PR'), ('помятой', 'A=f'), ('картофельной', 'A=f'), ('ботве', 'S'), (',', 'NONLEX'), ('маленькая', 'A=sg'), ('девочка', 'S'), (',', 'NONLEX'), ('почти', 'ADV'), ('ребенок', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('кругом', 'ADV'), ('валялись', 'V'), ('залитые', 'V'), ('кровью', 'S'), ('ученические', 'A=pl'), ('тетради', 'S'), ('и', 'CONJ'), ('учебники…', 'S'), ('Лицо', 'S'), ('ее', 'S'), ('было', 'V'), ('страшно', 'PRAEDIC'), ('изрублено', 'V'), ('тесаком', 'S'), (',', 'NONLEX'), ('в', 'PR'), ('руке', 'S'), ('она', 'S-PRO'), ('сжимала', 'V'), ('раскрытую', 'A=f'), ('школьную', 'A=f'), ('сумку', 'S'), ('.', 'NONLEX')]
# [('Мы', 'S-PRO'), ('накрыли', 'V'), ('тело', 'S'), ('плащ-палаткой', 'A=f'), ('и', 'CONJ'), ('стояли', 'V'), ('молча', 'ADV'), ('.', 'NONLEX')]
# [('Потом', 'ADV-PRO'), ('бойцы', 'S'), ('так', 'ADV-PRO'), ('же', 'PART'), ('молча', 'ADV'), ('разошлись', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('я', 'S-PRO'), ('стоял', 'V'), ('и', 'CONJ'), (',', 'NONLEX'), ('помню', 'V'), (',', 'NONLEX'), ('как', 'CONJ'), ('исступленный', 'A=m'), (',', 'NONLEX'), ('шептал', 'V'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Барков', 'S'), (',', 'NONLEX'), ('Половинкин', 'S'), ('.', 'NONLEX')]
# [('Физическая', 'A=f'), ('география', 'S'), ('.', 'NONLEX')]
# [('Учебник', 'S'), ('для', 'PR'), ('неполной', 'A=f'), ('средней', 'A=f'), ('и', 'CONJ'), ('средней', 'A=f'), ('школы', 'S'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('Это', 'S-PRO'), ('я', 'S-PRO'), ('прочитал', 'V'), ('на', 'PR'), ('одном', 'A-PRO=sg'), ('из', 'PR'), ('учебников', 'S'), (',', 'NONLEX'), ('валявшихся', 'V'), ('там', 'ADV-PRO'), ('же', 'PART'), (',', 'NONLEX'), ('в', 'PR'), ('траве', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('учебник', 'S'), ('этот', 'A-PRO=m'), ('мне', 'S-PRO'), ('знаком', 'A=m'), ('.', 'NONLEX')]
# [('Моя', 'A-PRO=f'), ('дочь', 'S'), ('тоже', 'PART'), ('училась', 'V'), ('в', 'PR'), ('пятом', 'ANUM=m'), ('классе', 'S'), ('.', 'NONLEX')]
# [('Это', 'S-PRO'), ('было', 'V'), ('неподалеку', 'S'), ('от', 'PR'), ('Ружина', 'S'), ('.', 'NONLEX')]
# [('А', 'CONJ'), ('около', 'PR'), ('Сквиры', 'S'), ('в', 'PR'), ('овраге', 'S'), ('мы', 'S-PRO'), ('наткнулись', 'V'), ('на', 'PR'), ('место', 'S'), ('казни', 'S'), (',', 'NONLEX'), ('где', 'ADV-PRO'), ('мучили', 'V'), ('захваченных', 'V'), ('в', 'PR'), ('плен', 'S'), ('красноармейцев', 'S'), ('.', 'NONLEX')]
# [('Приходилось', 'V'), ('вам', 'S-PRO'), ('бывать', 'V'), ('в', 'PR'), ('мясных', 'A=pl'), ('лавках', 'S'), ('?', 'NONLEX')]
# [('Ну', 'PART'), (',', 'NONLEX'), ('вот', 'PART'), ('так', 'ADV-PRO'), ('примерно', 'ADV'), ('выглядело', 'V'), ('это', 'S-PRO'), ('место…', 'S'), ('На', 'PR'), ('ветвях', 'S'), ('деревьев', 'S'), (',', 'NONLEX'), ('росших', 'V'), ('по', 'PR'), ('оврагу', 'S'), (',', 'NONLEX'), ('висели', 'V'), ('окровавленные', 'A=pl'), ('туловища', 'S'), (',', 'NONLEX'), ('без', 'PR'), ('рук', 'S'), (',', 'NONLEX'), ('без', 'PR'), ('ног', 'S'), (',', 'NONLEX'), ('со', 'PR'), ('снятой', 'S'), ('до', 'PR'), ('половины', 'S'), ('кожей…', 'S'), ('Отдельной', 'A=f'), ('кучей', 'S'), ('было', 'V'), ('свалено', 'V'), ('на', 'PR'), ('дне', 'S'), ('оврага', 'S'), ('восемь', 'NUM=nom'), ('человек', 'S'), ('убитых', 'V'), ('.', 'NONLEX')]
# [('Там', 'ADV-PRO'), ('нельзя', 'PRAEDIC'), ('было', 'V'), ('понять', 'V'), (',', 'NONLEX'), ('кому', 'S-PRO'), ('из', 'PR'), ('замученных', 'A=pl'), ('что', 'CONJ'), ('принадлежит', 'V'), (',', 'NONLEX'), ('лежала', 'V'), ('просто', 'PART'), ('куча', 'S'), ('крупно', 'ADV'), ('нарубленного', 'V'), ('мяса', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('сверху', 'ADV'), ('—', 'S'), ('стопкой', 'A=f'), (',', 'NONLEX'), ('как', 'CONJ'), ('надвинутые', 'A=pl'), ('одна', 'A-PRO=f'), ('на', 'PR'), ('другую', 'A-PRO=f'), ('тарелки', 'S'), (',', 'NONLEX'), ('—', 'NONLEX'), ('восемь', 'NUM=nom'), ('красноармейских', 'A=pl'), ('пилоток…', 'S'), ('Вы', 'S-PRO'), ('думаете', 'V'), (',', 'NONLEX'), ('можно', 'PRAEDIC'), ('рассказать', 'V'), ('словами', 'S'), ('обо', 'PR'), ('всем', 'S-PRO'), (',', 'NONLEX'), ('что', 'S-PRO'), ('пришлось', 'V'), ('видеть', 'V'), ('?', 'NONLEX')]
# [('Нельзя', 'PRAEDIC'), ('!', 'NONLEX')]
# [('Нет', 'PART'), ('таких', 'A-PRO=pl'), ('слов', 'S'), ('.', 'NONLEX')]
# [('Это', 'S-PRO'), ('надо', 'PRAEDIC'), ('видеть', 'V'), ('самому', 'A-PRO=m'), ('.', 'NONLEX')]
# [('И', 'CONJ'), ('вообще', 'ADV'), ('хватит', 'V'), ('об', 'PR'), ('этом', 'S-PRO'), ('!', 'NONLEX')]
# [('—', 'NONLEX'), ('Лейтенант', 'S'), ('Герасимов', 'S'), ('надолго', 'ADV'), ('умолк', 'V'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Можно', 'PRAEDIC'), ('здесь', 'ADV-PRO'), ('закурить', 'V'), ('?', 'NONLEX')]
# [('—', 'NONLEX'), ('спросил', 'V'), ('я', 'S-PRO'), ('его', 'S-PRO'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Можно', 'PRAEDIC'), ('.', 'NONLEX')]
# [('Курите', 'V'), ('в', 'PR'), ('руку', 'S'), (',', 'NONLEX'), ('—', 'NONLEX'), ('охрипшим', 'V'), ('голосом', 'S'), ('ответил', 'V'), ('он', 'S-PRO'), ('.', 'NONLEX')]
# [('И', 'CONJ'), (',', 'NONLEX'), ('закурив', 'V'), (',', 'NONLEX'), ('продолжал', 'V'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Вы', 'S-PRO'), ('понимаете', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('мы', 'S-PRO'), ('озверели', 'V'), (',', 'NONLEX'), ('насмотревшись', 'V'), ('на', 'PR'), ('все', 'S-PRO'), (',', 'NONLEX'), ('что', 'CONJ'), ('творили', 'V'), ('фашисты', 'S'), (',', 'NONLEX'), ('да', 'CONJ'), ('иначе', 'ADV-PRO'), ('и', 'CONJ'), ('не', 'PART'), ('могло', 'V'), ('быть', 'V'), ('.', 'NONLEX')]
# [('Все', 'A-PRO=pl'), ('мы', 'S-PRO'), ('поняли', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('имеем', 'V'), ('дело', 'S'), ('не', 'PART'), ('с', 'PR'), ('людьми', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('с', 'PR'), ('какими-то', 'A-PRO=pl'), ('осатаневшими', 'V'), ('от', 'PR'), ('крови', 'S'), ('собачьими', 'A=pl'), ('выродками', 'S'), ('.', 'NONLEX')]
# [('Оказалось', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('они', 'S-PRO'), ('с', 'PR'), ('такой', 'A-PRO=f'), ('же', 'PART'), ('тщательностью', 'S'), (',', 'NONLEX'), ('с', 'PR'), ('какой', 'A-PRO=f'), ('когда-то', 'ADV-PRO'), ('делали', 'V'), ('станки', 'S'), ('и', 'CONJ'), ('машины', 'S'), (',', 'NONLEX'), ('теперь', 'ADV-PRO'), ('убивают', 'V'), (',', 'NONLEX'), ('насилуют', 'V'), ('и', 'CONJ'), ('казнят', 'V'), ('наших', 'A-PRO=pl'), ('людей', 'S'), ('.', 'NONLEX')]
# [('Потом', 'ADV-PRO'), ('мы', 'S-PRO'), ('снова', 'ADV'), ('отступали', 'V'), (',', 'NONLEX'), ('но', 'CONJ'), ('дрались', 'V'), ('как', 'CONJ'), ('черти', 'S'), ('!', 'NONLEX')]
# [('В', 'PR'), ('моей', 'A-PRO=f'), ('роте', 'S'), ('почти', 'ADV'), ('все', 'A-PRO=pl'), ('бойцы', 'S'), ('были', 'V'), ('сибиряки', 'S'), ('.', 'NONLEX')]
# [('Однако', 'CONJ'), ('украинскую', 'A=f'), ('землю', 'S'), ('мы', 'S-PRO'), ('защищали', 'V'), ('прямо-таки', 'ADV'), ('отчаянно', 'ADV'), ('.', 'NONLEX')]
# [('Много', 'NUM=nom'), ('моих', 'A-PRO=pl'), ('земляков', 'S'), ('погибло', 'V'), ('на', 'PR'), ('Украине', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('фашистов', 'S'), ('мы', 'S-PRO'), ('положили', 'V'), ('там', 'ADV-PRO'), ('еще', 'ADV'), ('больше', 'NUM=comp'), ('.', 'NONLEX')]
# [('Что', 'S-PRO'), ('ж', 'PART'), (',', 'NONLEX'), ('мы', 'S-PRO'), ('отходили', 'V'), (',', 'NONLEX'), ('но', 'CONJ'), ('духу', 'S'), ('им', 'S-PRO'), ('давали', 'V'), ('неплохо', 'ADV'), ('.', 'NONLEX')]
# [('С', 'PR'), ('жадностью', 'S'), ('затягиваясь', 'V'), ('папиросой', 'S'), (',', 'NONLEX'), ('лейтенант', 'S'), ('Герасимов', 'S'), ('сказал', 'V'), ('уже', 'ADV'), ('несколько', 'NUM=acc'), ('иным', 'S'), (',', 'NONLEX'), ('смягченным', 'A=m'), ('тоном', 'S'), (':', 'NONLEX'), ('—', 'S'), ('Хорошая', 'A=f'), ('земля', 'S'), ('на', 'PR'), ('Украине', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('природа', 'S'), ('там', 'ADV-PRO'), ('чудесная', 'A=f'), ('!', 'NONLEX')]
# [('Каждое', 'A-PRO=n'), ('село', 'S'), ('и', 'CONJ'), ('деревушка', 'S'), ('казались', 'V'), ('нам', 'S-PRO'), ('родными', 'A=pl'), (',', 'NONLEX'), ('может', 'V'), ('быть', 'V'), (',', 'NONLEX'), ('потому', 'ADV-PRO'), (',', 'NONLEX'), ('что', 'CONJ'), (',', 'NONLEX'), ('не', 'PART'), ('скупясь', 'V'), (',', 'NONLEX'), ('проливали', 'V'), ('мы', 'S-PRO'), ('там', 'ADV-PRO'), ('свою', 'A-PRO=f'), ('кровь', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('кровь', 'S'), ('ведь', 'PART'), (',', 'NONLEX'), ('как', 'CONJ'), ('говорят', 'V'), (',', 'NONLEX'), ('роднит…', 'S'), ('И', 'CONJ'), ('вот', 'PART'), ('оставляешь', 'V'), ('какое-нибудь', 'A-PRO=n'), ('село', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('сердце', 'S'), ('щемит', 'V'), ('и', 'CONJ'), ('щемит', 'V'), (',', 'NONLEX'), ('как', 'CONJ'), ('проклятое', 'A=n'), ('.', 'NONLEX')]
# [('Жалко', 'PRAEDIC'), ('было', 'V'), (',', 'NONLEX'), ('просто', 'PART'), ('до', 'PR'), ('боли', 'S'), ('жалко', 'PRAEDIC'), ('!', 'NONLEX')]
# [('Уходим', 'V'), ('и', 'CONJ'), ('в', 'PR'), ('глаза', 'S'), ('друг', 'S-PRO'), ('другу', 'S-PRO'), ('не', 'PART'), ('глядим', 'V'), ('.', 'NONLEX')]
# [('…Не', 'NONLEX'), ('думал', 'V'), ('я', 'S-PRO'), ('тогда', 'ADV-PRO'), (',', 'NONLEX'), ('что', 'S-PRO'), ('придется', 'V'), ('побывать', 'V'), ('у', 'PR'), ('фашистов', 'S'), ('в', 'PR'), ('плену', 'S'), (',', 'NONLEX'), ('однако', 'CONJ'), ('пришлось', 'V'), ('.', 'NONLEX')]
# [('В', 'PR'), ('сентябре', 'S'), ('я', 'S-PRO'), ('был', 'V'), ('первый', 'ANUM=m'), ('раз', 'S'), ('ранен', 'V'), (',', 'NONLEX'), ('но', 'CONJ'), ('остался', 'V'), ('в', 'PR'), ('строю', 'S'), ('.', 'NONLEX')]
# [('А', 'CONJ'), ('двадцать', 'NUM=nom'), ('первого', 'ANUM=m'), ('в', 'PR'), ('бою', 'S'), ('под', 'PR'), ('Денисовкой', 'S'), (',', 'NONLEX'), ('Полтавской', 'A=f'), ('области', 'S'), (',', 'NONLEX'), ('я', 'S-PRO'), ('был', 'V'), ('ранен', 'V'), ('вторично', 'ADV'), ('и', 'CONJ'), ('взят', 'V'), ('в', 'PR'), ('плен', 'S'), ('.', 'NONLEX')]
# [('Немецкие', 'A=pl'), ('танки', 'S'), ('прорвались', 'V'), ('на', 'PR'), ('нашем', 'A-PRO=n'), ('левом', 'A=m'), ('фланге', 'S'), (',', 'NONLEX'), ('следом', 'ADV'), ('за', 'PR'), ('ними', 'S-PRO'), ('потекла', 'V'), ('пехота', 'S'), ('.', 'NONLEX')]
# [('Мы', 'S-PRO'), ('с', 'PR'), ('боем', 'S'), ('выходили', 'V'), ('из', 'PR'), ('окружения', 'S'), ('.', 'NONLEX')]
# [('В', 'PR'), ('этот', 'A-PRO=m'), ('день', 'S'), ('моя', 'A-PRO=f'), ('рота', 'S'), ('понесла', 'V'), ('очень', 'ADV'), ('большие', 'A=pl'), ('потери', 'S'), ('.', 'NONLEX')]
# [('Два', 'NUM=m'), ('раза', 'S'), ('мы', 'S-PRO'), ('отбили', 'V'), ('танковые', 'A=pl'), ('атаки', 'S'), ('противника', 'S'), (',', 'NONLEX'), ('сожгли', 'V'), ('и', 'CONJ'), ('подбили', 'V'), ('шесть', 'NUM=acc'), ('танков', 'S'), ('и', 'CONJ'), ('одну', 'A-PRO=sg'), ('бронемашину', 'S'), (',', 'NONLEX'), ('уложили', 'V'), ('на', 'PR'), ('кукурузном', 'A=m'), ('поле', 'S'), ('человек', 'S'), ('сто', 'NUM=acc'), ('двадцать', 'NUM=nom'), ('гитлеровцев', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('потом', 'ADV-PRO'), ('они', 'S-PRO'), ('подтянули', 'V'), ('минометные', 'A=pl'), ('батареи', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('мы', 'S-PRO'), ('вынуждены', 'V'), ('были', 'V'), ('оставить', 'V'), ('высотку', 'S'), (',', 'NONLEX'), ('которую', 'A-PRO=f'), ('держали', 'V'), ('с', 'PR'), ('полудня', 'S'), ('до', 'PR'), ('четырех', 'NUM=gen'), ('часов', 'S'), ('.', 'NONLEX')]
# [('С', 'PR'), ('утра', 'S'), ('было', 'V'), ('жарко', 'PRAEDIC'), ('.', 'NONLEX')]
# [('В', 'PR'), ('небе', 'S'), ('ни', 'PART'), ('облачка', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('солнце', 'S'), ('палило', 'V'), ('так', 'ADV-PRO'), (',', 'NONLEX'), ('что', 'CONJ'), ('буквально', 'ADV'), ('нечем', 'PRAEDIC-PRO'), ('было', 'V'), ('дышать', 'V'), ('.', 'NONLEX')]
# [('Мины', 'S'), ('ложились', 'V'), ('страшно', 'ADV'), ('густо', 'ADV'), (',', 'NONLEX'), ('и', 'CONJ'), (',', 'NONLEX'), ('помню', 'V'), (',', 'NONLEX'), ('пить', 'V'), ('хотелось', 'V'), ('до', 'PR'), ('того', 'S-PRO'), (',', 'NONLEX'), ('что', 'CONJ'), ('у', 'PR'), ('бойцов', 'S'), ('губы', 'S'), ('чернели', 'S'), ('от', 'PR'), ('жажды', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('я', 'S-PRO'), ('подавал', 'V'), ('команду', 'S'), ('каким-то', 'A-PRO=m'), ('чужим', 'A=m'), (',', 'NONLEX'), ('окончательно', 'ADV'), ('осипшим', 'V'), ('голосом', 'S'), ('.', 'NONLEX')]
# [('Мы', 'S-PRO'), ('перебегали', 'V'), ('по', 'PR'), ('лощине', 'S'), (',', 'NONLEX'), ('когда', 'CONJ'), ('впереди', 'PR'), ('меня', 'S-PRO'), ('разорвалась', 'V'), ('мина', 'S'), ('.', 'NONLEX')]
# [('Кажется', 'PARENTH'), (',', 'NONLEX'), ('я', 'S-PRO'), ('успел', 'V'), ('увидеть', 'V'), ('столб', 'S'), ('черной', 'A=f'), ('земли', 'S'), ('и', 'CONJ'), ('пыли', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('это', 'S-PRO'), ('—', 'NONLEX'), ('все', 'S-PRO'), ('.', 'NONLEX')]
# [('Осколок', 'S'), ('мины', 'S'), ('пробил', 'V'), ('мою', 'A-PRO=f'), ('каску', 'S'), (',', 'NONLEX'), ('второй', 'ANUM=m'), ('попал', 'V'), ('в', 'PR'), ('правое', 'A=n'), ('плечо', 'S'), ('.', 'NONLEX')]
# [('Не', 'PART'), ('помню', 'V'), (',', 'NONLEX'), ('сколько', 'NUM=acc'), ('я', 'S-PRO'), ('пролежал', 'V'), ('без', 'PR'), ('сознания', 'S'), (',', 'NONLEX'), ('но', 'CONJ'), ('очнулся', 'V'), ('от', 'PR'), ('топота', 'S'), ('чьих-то', 'S-PRO'), ('ног', 'S'), ('.', 'NONLEX')]
# [('Приподнял', 'V'), ('голову', 'S'), ('и', 'CONJ'), ('увидел', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('лежу', 'S'), ('не', 'PART'), ('на', 'PR'), ('том', 'A-PRO=n'), ('месте', 'S'), (',', 'NONLEX'), ('где', 'ADV-PRO'), ('упал', 'V'), ('.', 'NONLEX')]
# [('Гимнастерки', 'S'), ('на', 'PR'), ('мне', 'S-PRO'), ('нет', 'PRAEDIC'), (',', 'NONLEX'), ('а', 'CONJ'), ('плечо', 'S'), ('наспех', 'ADV'), ('кем-то', 'S-PRO'), ('перевязано', 'V'), ('.', 'NONLEX')]
# [('Нет', 'PART'), ('и', 'CONJ'), ('каски', 'ADV'), ('на', 'PR'), ('голове', 'S'), ('.', 'NONLEX')]
# ...
# [('«', 'NONLEX'), ('Все', 'A-PRO=n'), ('это', 'S-PRO'), ('—', 'NONLEX'), ('собственность', 'S'), ('германского', 'A=n'), ('государства', 'S'), (',', 'NONLEX'), ('—', 'S'), ('сказал', 'V'), ('унтер', 'S'), (',', 'NONLEX'), ('широко', 'ADV'), ('поводя', 'V'), ('вокруг', 'PR'), ('рукой', 'S'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Всякий', 'A-PRO=m'), ('из', 'PR'), ('вас', 'S-PRO'), (',', 'NONLEX'), ('кто', 'S-PRO'), ('самовольно', 'ADV'), ('что-либо', 'S-PRO'), ('возьмет', 'V'), (',', 'NONLEX'), ('будет', 'V'), ('убит', 'V'), ('»', 'NONLEX'), ('.', 'NONLEX')]
# [('В', 'PR'), ('деревне', 'S'), (',', 'NONLEX'), ('через', 'PR'), ('которую', 'A-PRO=f'), ('мы', 'S-PRO'), ('проходили', 'V'), (',', 'NONLEX'), ('женщины', 'S'), (',', 'NONLEX'), ('увидев', 'V'), ('нас', 'S-PRO'), (',', 'NONLEX'), ('стали', 'V'), ('бросать', 'V'), ('нам', 'S-PRO'), ('куски', 'S'), ('хлеба', 'S'), (',', 'NONLEX'), ('печеный', 'A=m'), ('картофель', 'S'), ('.', 'NONLEX')]
# [('Кое-кто', 'S-PRO'), ('из', 'PR'), ('наших', 'A-PRO=pl'), ('успел', 'V'), ('поднять', 'V'), (',', 'NONLEX'), ('остальным', 'S-PRO=pl'), ('не', 'PART'), ('удалось', 'V'), (':', 'NONLEX'), ('конвой', 'A=f'), ('открыл', 'V'), ('стрельбу', 'S'), ('по', 'PR'), ('окнам', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('нам', 'S-PRO'), ('приказано', 'V'), ('было', 'V'), ('идти', 'V'), ('быстрее', 'ADV=comp'), ('.', 'NONLEX')]
# [('Но', 'CONJ'), ('ребятишки', 'S'), ('—', 'NONLEX'), ('бесстрашный', 'A=m'), ('народ', 'S'), (',', 'NONLEX'), ('они', 'S-PRO'), ('выбегали', 'V'), ('за', 'PR'), ('несколько', 'NUM=acc'), ('кварталов', 'S'), ('вперед', 'S'), (',', 'NONLEX'), ('прямо', 'PART'), ('на', 'PR'), ('дорогу', 'S'), ('клали', 'V'), ('хлеб', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('мы', 'S-PRO'), ('подбирали', 'V'), ('его', 'S-PRO'), ('.', 'NONLEX')]
# [('Мне', 'S-PRO'), ('досталась', 'V'), ('большая', 'A=f'), ('вареная', 'A=f'), ('картофелина', 'S'), ('.', 'NONLEX')]
# [('Разделили', 'V'), ('ее', 'S'), ('пополам', 'ADV'), ('с', 'PR'), ('соседом', 'S'), (',', 'NONLEX'), ('съели', 'V'), ('с', 'PR'), ('кожурой', 'S'), ('.', 'NONLEX')]
# [('В', 'PR'), ('жизни', 'S'), ('я', 'S-PRO'), ('не', 'PART'), ('ел', 'V'), ('более', 'ADV'), ('вкусного', 'A=m'), ('картофеля', 'S'), ('!', 'NONLEX')]
# [('Укрепления', 'S'), ('строились', 'V'), ('в', 'PR'), ('лесу', 'S'), ('.', 'NONLEX')]
# [('Немцы', 'S'), ('значительно', 'ADV'), ('усилили', 'V'), ('охрану', 'S'), (',', 'NONLEX'), ('выдали', 'V'), ('нам', 'S-PRO'), ('лопаты', 'S'), ('.', 'NONLEX')]
# [('Нет', 'PART'), (',', 'NONLEX'), ('не', 'PART'), ('строить', 'V'), ('им', 'S-PRO'), ('укрепления', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('разрушать', 'V'), ('я', 'S-PRO'), ('хотел', 'V'), ('!', 'NONLEX')]
# [('В', 'PR'), ('этот', 'A-PRO=m'), ('же', 'PART'), ('день', 'S'), ('перед', 'PR'), ('вечером', 'S'), ('я', 'S-PRO'), ('решился', 'V'), (':', 'NONLEX'), ('вылез', 'V'), ('из', 'PR'), ('ямы', 'S'), (',', 'NONLEX'), ('которую', 'A-PRO=f'), ('мы', 'S-PRO'), ('рыли', 'V'), (',', 'NONLEX'), ('взял', 'V'), ('лопату', 'S'), ('в', 'PR'), ('левую', 'A=f'), ('руку', 'S'), (',', 'NONLEX'), ('подошел', 'V'), ('к', 'PR'), ('охраннику…', 'S'), ('До', 'PR'), ('этого', 'S-PRO'), ('я', 'S-PRO'), ('приметил', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('остальные', 'S-PRO=pl'), ('немцы', 'S'), ('находятся', 'V'), ('у', 'PR'), ('рва', 'S'), ('и', 'CONJ'), (',', 'NONLEX'), ('кроме', 'PR'), ('этого', 'S-PRO'), (',', 'NONLEX'), ('какой', 'A-PRO=m'), ('наблюдал', 'V'), ('за', 'PR'), ('нашей', 'A-PRO=f'), ('группой', 'S'), (',', 'NONLEX'), ('поблизости', 'S'), ('никого', 'S-PRO'), ('из', 'PR'), ('охраны', 'S'), ('не', 'PART'), ('было', 'V'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('У', 'PR'), ('меня', 'S-PRO'), ('сломалась', 'V'), ('лопата…', 'S'), ('вот', 'PART'), ('посмотрите', 'V'), (',', 'NONLEX'), ('—', 'NONLEX'), ('бормотал', 'V'), ('я', 'S-PRO'), (',', 'NONLEX'), ('приближаясь', 'V'), ('к', 'PR'), ('солдату', 'S'), ('.', 'NONLEX')]
# [('На', 'PR'), ('какой-то', 'A-PRO=m'), ('миг', 'S'), ('мелькнула', 'V'), ('у', 'PR'), ('меня', 'S-PRO'), ('мысль', 'S'), (',', 'NONLEX'), ('что', 'CONJ'), ('если', 'CONJ'), ('не', 'PART'), ('хватит', 'V'), ('сил', 'S'), ('и', 'CONJ'), ('я', 'S-PRO'), ('не', 'PART'), ('свалю', 'V'), ('его', 'S-PRO'), ('с', 'PR'), ('первого', 'ANUM=m'), ('удара', 'S'), (',', 'NONLEX'), ('—', 'NONLEX'), ('я', 'S-PRO'), ('погиб', 'V'), ('.', 'NONLEX')]
# [('Часовой', 'S'), (',', 'NONLEX'), ('видимо', 'PARENTH'), (',', 'NONLEX'), ('что-то', 'S-PRO'), ('заметил', 'V'), ('в', 'PR'), ('выражении', 'S'), ('моего', 'A-PRO=n'), ('лица', 'S'), ('.', 'NONLEX')]
# [('Он', 'S-PRO'), ('сделал', 'V'), ('движение', 'S'), ('плечом', 'S'), (',', 'NONLEX'), ('снимая', 'V'), ('ремень', 'S'), ('автомата', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('тогда', 'ADV-PRO'), ('я', 'S-PRO'), ('нанес', 'V'), ('удар', 'S'), ('лопатой', 'S'), ('ему', 'S-PRO'), ('по', 'PR'), ('лицу', 'S'), ('.', 'NONLEX')]
# [('Я', 'S-PRO'), ('не', 'PART'), ('мог', 'V'), ('ударить', 'V'), ('его', 'S-PRO'), ('по', 'PR'), ('голове', 'S'), (',', 'NONLEX'), ('на', 'PR'), ('нем', 'A=m'), ('была', 'V'), ('каска', 'S'), ('.', 'NONLEX')]
# [('Силы', 'S'), ('у', 'PR'), ('меня', 'S-PRO'), ('все', 'A-PRO=pl'), ('же', 'PART'), ('хватило', 'V'), (',', 'NONLEX'), ('немец', 'S'), ('без', 'PR'), ('крика', 'S'), ('запрокинулся', 'V'), ('навзничь', 'S'), ('.', 'NONLEX')]
# [('В', 'PR'), ('руках', 'S'), ('у', 'PR'), ('меня', 'S-PRO'), ('автомат', 'S'), ('и', 'CONJ'), ('три', 'NUM=acc'), ('обоймы', 'S'), ('.', 'NONLEX')]
# [('Бегу', 'S'), ('!', 'NONLEX')]
# [('И', 'CONJ'), ('тут-то', 'S-PRO'), ('оказалось', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('бегать', 'V'), ('я', 'S-PRO'), ('не', 'PART'), ('могу', 'V'), ('.', 'NONLEX')]
# [('Нет', 'PART'), ('сил', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('баста', 'S'), ('!', 'NONLEX')]
# [('Остановился', 'V'), (',', 'NONLEX'), ('перевел', 'V'), ('дух', 'S'), ('и', 'CONJ'), ('снова', 'ADV'), ('еле-еле', 'ADV'), ('потрусил', 'V'), ('рысцой', 'S'), ('.', 'NONLEX')]
# [('За', 'PR'), ('оврагом', 'S'), ('лес', 'S'), ('был', 'V'), ('гуще', 'A=comp'), (',', 'NONLEX'), ('и', 'CONJ'), ('я', 'S-PRO'), ('стремился', 'V'), ('туда', 'ADV-PRO'), ('.', 'NONLEX')]
# [('Уже', 'ADV'), ('не', 'PART'), ('помню', 'V'), (',', 'NONLEX'), ('сколько', 'NUM=acc'), ('раз', 'S'), ('падал', 'V'), (',', 'NONLEX'), ('вставал', 'V'), (',', 'NONLEX'), ('снова', 'ADV'), ('падал…', 'V'), ('Но', 'CONJ'), ('с', 'PR'), ('каждой', 'A-PRO=f'), ('минутой', 'S'), ('уходил', 'V'), ('все', 'S-PRO'), ('дальше', 'ADV'), ('.', 'NONLEX')]
# [('Всхлипывая', 'A=f'), ('и', 'CONJ'), ('задыхаясь', 'V'), ('от', 'PR'), ('усталости', 'S'), (',', 'NONLEX'), ('пробирался', 'V'), ('я', 'S-PRO'), ('по', 'PR'), ('чаще', 'ADV=comp'), ('на', 'PR'), ('той', 'A-PRO=f'), ('стороне', 'S'), ('холма', 'S'), (',', 'NONLEX'), ('когда', 'CONJ'), ('далеко', 'ADV'), ('сзади', 'ADV'), ('застучали', 'V'), ('очереди', 'S'), ('автоматов', 'S'), ('и', 'CONJ'), ('послышался', 'V'), ('крик', 'S'), ('.', 'NONLEX')]
# [('Теперь', 'ADV-PRO'), ('поймать', 'V'), ('меня', 'S-PRO'), ('было', 'V'), ('нелегко', 'PRAEDIC'), ('.', 'NONLEX')]
# [('Приближались', 'V'), ('сумерки', 'S'), ('.', 'NONLEX')]
# [('Но', 'CONJ'), ('если', 'CONJ'), ('бы', 'PART'), ('немцы', 'S'), ('сумели', 'V'), ('напасть', 'V'), ('на', 'PR'), ('мой', 'A-PRO=m'), ('след', 'S'), ('и', 'CONJ'), ('приблизиться', 'V'), (',', 'NONLEX'), ('—', 'S'), ('только', 'PART'), ('последний', 'A=m'), ('патрон', 'S'), ('я', 'S-PRO'), ('приберег', 'V'), ('бы', 'PART'), ('для', 'PR'), ('себя', 'S-PRO=gen'), ('.', 'NONLEX')]
# [('Эта', 'A-PRO=f'), ('мысль', 'S'), ('меня', 'S-PRO'), ('ободрила', 'V'), (',', 'NONLEX'), ('я', 'S-PRO'), ('пошел', 'V'), ('тише', 'S'), ('и', 'CONJ'), ('осторожнее', 'PRAEDIC=comp'), ('.', 'NONLEX')]
# [('Ночевал', 'V'), ('в', 'PR'), ('лесу', 'S'), ('.', 'NONLEX')]
# [('Какая-то', 'ADV-PRO'), ('деревня', 'S'), ('была', 'V'), ('от', 'PR'), ('меня', 'S-PRO'), ('в', 'PR'), ('полукилометре', 'S'), (',', 'NONLEX'), ('но', 'CONJ'), ('я', 'S-PRO'), ('побоялся', 'V'), ('идти', 'V'), ('туда', 'ADV-PRO'), (',', 'NONLEX'), ('опасаясь', 'V'), ('нарваться', 'V'), ('на', 'PR'), ('немцев', 'S'), ('.', 'NONLEX')]
# [('На', 'PR'), ('другой', 'A-PRO=m'), ('день', 'S'), ('меня', 'S-PRO'), ('подобрали', 'V'), ('партизаны', 'S'), ('.', 'NONLEX')]
# [('Недели', 'V'), ('две', 'NUM=f'), ('я', 'S-PRO'), ('отлеживался', 'V'), ('у', 'PR'), ('них', 'S-PRO'), ('в', 'PR'), ('землянке', 'S'), (',', 'NONLEX'), ('окреп', 'S'), ('и', 'CONJ'), ('набрался', 'V'), ('сил', 'S'), ('.', 'NONLEX')]
# [('Вначале', 'ADV'), ('они', 'S-PRO'), ('относились', 'V'), ('ко', 'PR'), ('мне', 'S-PRO'), ('с', 'PR'), ('некоторым', 'A-PRO=n'), ('подозрением', 'S'), (',', 'NONLEX'), ('несмотря', 'ADV'), ('на', 'PR'), ('то', 'S-PRO'), (',', 'NONLEX'), ('что', 'CONJ'), ('я', 'S-PRO'), ('достал', 'V'), ('из-под', 'PR'), ('подкладки', 'S'), ('шинели', 'S'), ('кое-как', 'ADV-PRO'), ('зашитый', 'V'), ('мною', 'S-PRO'), ('в', 'PR'), ('лагере', 'S'), ('партбилет', 'S'), ('и', 'CONJ'), ('показал', 'V'), ('им', 'S-PRO'), ('.', 'NONLEX'), ('Потом', 'ADV-PRO'), (',', 'NONLEX'), ('когда', 'CONJ'), ('я', 'S-PRO'), ('стал', 'V'), ('принимать', 'V'), ('участие', 'S'), ('в', 'PR'), ('их', 'A-PRO'), ('операциях', 'S'), (',', 'NONLEX'), ('отношение', 'S'), ('ко', 'PR'), ('мне', 'S-PRO'), ('сразу', 'ADV'), ('изменилось', 'V'), ('.', 'NONLEX')]
# [('Еще', 'ADV'), ('там', 'ADV-PRO'), ('открыл', 'V'), ('я', 'S-PRO'), ('счет', 'V'), ('убитым', 'V'), ('мною', 'S-PRO'), ('фашистам', 'S'), (',', 'NONLEX'), ('тщательно', 'ADV'), ('веду', 'V'), ('его', 'S-PRO'), ('до', 'PR'), ('сих', 'A-PRO=pl'), ('пор', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('цифра', 'S'), ('помаленьку', 'ADV'), ('подвигается', 'V'), ('к', 'PR'), ('сотне', 'S'), ('.', 'NONLEX')]
# [('В', 'PR'), ('январе', 'S'), ('партизаны', 'S'), ('провели', 'V'), ('меня', 'S-PRO'), ('через', 'PR'), ('линию', 'S'), ('фронта', 'S'), ('.', 'NONLEX')]
# [('Около', 'PR'), ('месяца', 'S'), ('пролежал', 'V'), ('в', 'PR'), ('госпитале', 'S'), ('.', 'NONLEX')]
# [('Удалили', 'V'), ('из', 'PR'), ('плеча', 'S'), ('осколок', 'S'), ('мины', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('добытый', 'V'), ('в', 'PR'), ('лагерях', 'S'), ('ревматизм', 'S'), ('и', 'CONJ'), ('все', 'A-PRO=pl'), ('остальные', 'A-PRO=pl'), ('недуги', 'S'), ('буду', 'V'), ('залечивать', 'V'), ('после', 'PR'), ('войны', 'S'), ('.', 'NONLEX')]
# [('Из', 'PR'), ('госпиталя', 'S'), ('отпустили', 'V'), ('меня', 'S-PRO'), ('домой', 'ADV'), ('на', 'PR'), ('поправку', 'S'), ('.', 'NONLEX')]
# [('Пожил', 'V'), ('дома', 'ADV'), ('неделю', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('больше', 'ADV'), ('не', 'PART'), ('мог', 'V'), ('.', 'NONLEX')]
# [('Затосковал', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('все', 'S-PRO'), ('тут', 'ADV-PRO'), ('!', 'NONLEX')]
# [('Как', 'ADV-PRO'), ('там', 'ADV-PRO'), ('ни', 'PART'), ('говори', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('мое', 'A=n'), ('место', 'S'), ('здесь', 'ADV-PRO'), ('до', 'PR'), ('конца', 'S'), ('.', 'NONLEX')]
# [('*', 'NONLEX'), ('*', 'NONLEX'), ('*', 'NONLEX'), ('Прощались', 'V'), ('мы', 'S-PRO'), ('у', 'PR'), ('входа', 'S'), ('в', 'PR'), ('землянку', 'S'), ('.', 'NONLEX')]
# [('Задумчиво', 'ADV'), ('глядя', 'V'), ('на', 'PR'), ('залитую', 'V'), ('ярким', 'A=m'), ('солнечным', 'A=m'), ('светом', 'S'), ('просеку', 'S'), (',', 'NONLEX'), ('лейтенант', 'S'), ('Герасимов', 'S'), ('говорил', 'V'), (':', 'NONLEX'), ('—', 'NONLEX'), ('…И', 'NONLEX'), ('воевать', 'V'), ('научились', 'V'), ('по-настоящему', 'ADV'), (',', 'NONLEX'), ('и', 'CONJ'), ('ненавидеть', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('любить', 'V'), ('.', 'NONLEX')]
# [('На', 'PR'), ('таком', 'A-PRO=m'), ('оселке', 'S'), (',', 'NONLEX'), ('как', 'CONJ'), ('война', 'S'), (',', 'NONLEX'), ('все', 'A-PRO=pl'), ('чувства', 'S'), ('отлично', 'ADV'), ('оттачиваются', 'V'), ('.', 'NONLEX')]
# [('Казалось', 'V'), ('бы', 'PART'), (',', 'NONLEX'), ('любовь', 'S'), ('и', 'CONJ'), ('ненависть', 'S'), ('никак', 'ADV-PRO'), ('нельзя', 'PRAEDIC'), ('поставить', 'V'), ('рядышком', 'ADV'), (';', 'NONLEX'), ('знаете', 'V'), (',', 'NONLEX'), ('как', 'ADV-PRO'), ('это', 'S-PRO'), ('говорится', 'V'), (':', 'NONLEX'), ('«', 'NONLEX'), ('В', 'PR'), ('одну', 'ANUM=f'), ('телегу', 'S'), ('впрячь', 'S'), ('не', 'PART'), ('можно', 'PRAEDIC'), ('коня', 'S'), ('и', 'CONJ'), ('трепетную', 'A=f'), ('лань', 'S'), ('»', 'NONLEX'), (',', 'NONLEX'), ('—', 'NONLEX'), ('а', 'CONJ'), ('вот', 'PART'), ('у', 'PR'), ('нас', 'S-PRO'), ('они', 'S-PRO'), ('впряжены', 'V'), ('и', 'CONJ'), ('здорово', 'ADV'), ('тянут', 'V'), ('!', 'NONLEX')]
# [('Тяжко', 'S'), ('я', 'S-PRO'), ('ненавижу', 'V'), ('фашистов', 'S'), ('за', 'PR'), ('все', 'S-PRO'), (',', 'NONLEX'), ('что', 'CONJ'), ('они', 'S-PRO'), ('причинили', 'V'), ('моей', 'A-PRO=f'), ('Родине', 'S'), ('и', 'CONJ'), ('мне', 'S-PRO'), ('лично', 'ADV'), (',', 'NONLEX'), ('и', 'CONJ'), ('в', 'PR'), ('то', 'A-PRO=n'), ('же', 'PART'), ('время', 'S'), ('всем', 'A-PRO=pl'), ('сердцем', 'S'), ('люблю', 'V'), ('свой', 'A-PRO=m'), ('народ', 'S'), ('и', 'CONJ'), ('не', 'PART'), ('хочу', 'V'), (',', 'NONLEX'), ('чтобы', 'CONJ'), ('ему', 'S-PRO'), ('пришлось', 'V'), ('страдать', 'V'), ('под', 'PR'), ('фашистским', 'A=m'), ('игом', 'S'), ('.', 'NONLEX')]
# [('Вот', 'PART'), ('это-то', 'S-PRO'), ('и', 'CONJ'), ('заставляет', 'V'), ('меня', 'S-PRO'), (',', 'NONLEX'), ('да', 'CONJ'), ('и', 'CONJ'), ('всех', 'A-PRO=pl'), ('нас', 'S-PRO'), (',', 'NONLEX'), ('драться', 'V'), ('с', 'PR'), ('таким', 'A-PRO=sg'), ('ожесточением', 'S'), (',', 'NONLEX'), ('именно', 'PART'), ('эти', 'A-PRO=pl'), ('два', 'NUM=n'), ('чувства', 'S'), (',', 'NONLEX'), ('воплощенные', 'V'), ('в', 'PR'), ('действие', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('приведут', 'V'), ('к', 'PR'), ('нам', 'S-PRO'), ('победу', 'S'), ('.', 'NONLEX')]
# [('И', 'CONJ'), ('если', 'CONJ'), ('любовь', 'S'), ('к', 'PR'), ('Родине', 'S'), ('хранится', 'V'), ('у', 'PR'), ('нас', 'S-PRO'), ('в', 'PR'), ('сердцах', 'S'), ('и', 'CONJ'), ('будет', 'V'), ('храниться', 'V'), ('до', 'PR'), ('тех', 'A-PRO=pl'), ('пор', 'S'), (',', 'NONLEX'), ('пока', 'CONJ'), ('эти', 'A-PRO=pl'), ('сердца', 'S'), ('бьются', 'V'), (',', 'NONLEX'), ('то', 'CONJ'), ('ненависть', 'S'), ('всегда', 'ADV-PRO'), ('мы', 'S-PRO'), ('носим', 'V'), ('на', 'PR'), ('кончиках', 'S'), ('штыков', 'S'), ('.', 'NONLEX')]
# [('Извините', 'V'), (',', 'NONLEX'), ('если', 'CONJ'), ('это', 'S-PRO'), ('замысловато', 'V'), ('сказано', 'V'), (',', 'NONLEX'), ('но', 'CONJ'), ('я', 'S-PRO'), ('так', 'ADV-PRO'), ('думаю', 'V'), (',', 'NONLEX'), ('—', 'NONLEX'), ('закончил', 'V'), ('лейтенант', 'S'), ('Герасимов', 'S'), ('и', 'CONJ'), ('впервые', 'ADV'), ('за', 'PR'), ('время', 'S'), ('нашего', 'A-PRO=n'), ('знакомства', 'S'), ('улыбнулся', 'V'), ('простой', 'A=m'), ('и', 'CONJ'), ('милой', 'A=f'), (',', 'NONLEX'), ('ребяческой', 'A=f'), ('улыбкой', 'S'), ('.', 'NONLEX')]
# [('А', 'CONJ'), ('я', 'S-PRO'), ('впервые', 'ADV'), ('заметил', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('у', 'PR'), ('этого', 'S-PRO'), ('тридцатидвухлетнего', 'A=m'), ('лейтенанта', 'S'), (',', 'NONLEX'), ('надломленного', 'V'), ('пережитыми', 'A=pl'), ('лишениями', 'S'), (',', 'NONLEX'), ('но', 'CONJ'), ('все', 'S-PRO'), ('еще', 'ADV'), ('сильного', 'A=m'), ('и', 'CONJ'), ('крепкого', 'A=m'), (',', 'NONLEX'), ('как', 'CONJ'), ('дуб', 'S'), (',', 'NONLEX'), ('ослепительно', 'ADV'), ('белые', 'A=pl'), ('от', 'PR'), ('седины', 'S'), ('виски', 'ADV'), ('.', 'NONLEX')]
# [('И', 'CONJ'), ('так', 'ADV-PRO'), ('чиста', 'A=f'), ('была', 'V'), ('эта', 'A-PRO=f'), ('добытая', 'V'), ('большими', 'A=pl'), ('страданиями', 'S'), ('седина', 'S'), (',', 'NONLEX'), ('что', 'CONJ'), ('белая', 'A=f'), ('нитка', 'S'), ('паутины', 'S'), (',', 'NONLEX'), ('прилипшая', 'V'), ('к', 'PR'), ('пилотке', 'S'), ('лейтенанта', 'S'), (',', 'NONLEX'), ('исчезала', 'V'), (',', 'NONLEX'), ('коснувшись', 'V'), ('виска', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('рассмотреть', 'V'), ('ее', 'S'), ('было', 'V'), ('невозможно', 'PRAEDIC'), (',', 'NONLEX'), ('как', 'CONJ'), ('я', 'S-PRO'), ('ни', 'PART'), ('старался', 'V'), ('.', 'NONLEX')]
# [('1942', 'NUM=ciph')]

# %%
# лемматизация с учетом части речи
# меняем теги
tokenized = nltk.word_tokenize(text4)
tagged = nltk.pos_tag(tokenized)

def pos_tagger(nltk_tag):
    if nltk_tag.startswith('J'):
        return nltk.corpus.wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return nltk.corpus.wordnet.VERB
    elif nltk_tag.startswith('N'):
        return nltk.corpus.wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return nltk.corpus.wordnet.ADV
    else:          
        return None

tagged
# Out:
# [('На', 'JJ'),
#  ('войне', 'NNP'),
#  ('деревья', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('и', 'NNP'),
#  ('люди', 'NNP'),
#  (',', ','),
#  ('имеют', 'NNP'),
#  ('каждое', 'NNP'),
#  ('свою', 'NNP'),
#  ('судьбу', 'NNP'),
#  ('.', '.'),
#  ('Я', 'VB'),
#  ('видел', 'JJ'),
#  ('огромный', 'NNP'),
#  ('участок', 'NNP'),
#  ('леса', 'NNP'),
#  (',', ','),
#  ('срезанного', 'NNP'),
#  ('огнем', 'NNP'),
#  ('нашей', 'NNP'),
#  ('артиллерии', 'NNP'),
#  ('.', '.'),
#  ('В', 'VB'),
#  ('этом', 'JJ'),
#  ('лесу', 'NNP'),
#  ('недавно', 'NNP'),
#  ('укреплялись', 'NNP'),
#  ('немцы', 'NNP'),
#  (',', ','),
#  ('выбитые', 'NNP'),
#  ('из', 'NNP'),
#  ('села', 'NNP'),
#  ('С.', 'NNP'),
#  (',', ','),
#  ('здесь', 'NNP'),
#  ('они', 'NNP'),
#  ('думали', 'NNP'),
#  ('задержаться', 'NNP'),
#  (',', ','),
#  ('но', 'NNP'),
#  ('смерть', 'NNP'),
#  ('скосила', 'NNP'),
#  ('их', 'NNP'),
#  ('вместе', 'NNP'),
#  ('с', 'NNP'),
#  ('деревьями', 'NNP'),
#  ('.', '.'),
#  ('Под', 'VB'),
#  ('поверженными', 'JJ'),
#  ('стволами', 'NNP'),
#  ('сосен', 'NNP'),
#  ('лежали', 'NNP'),
#  ('мертвые', 'NNP'),
#  ('немецкие', 'NNP'),
#  ('солдаты', 'NNP'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('зеленом', 'NNP'),
#  ('папоротнике', 'NNP'),
#  ('гнили', 'NNP'),
#  ('их', 'NNP'),
#  ('изорванные', 'NNP'),
#  ('в', 'NNP'),
#  ('клочья', 'NNP'),
#  ('тела', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('смолистый', 'NNP'),
#  ('аромат', 'NNP'),
#  ('расщепленных', 'NNP'),
#  ('снарядами', 'NNP'),
#  ('сосен', 'NNP'),
#  ('не', 'NNP'),
#  ('мог', 'NNP'),
#  ('заглушить', 'NNP'),
#  ('удушливо-приторной', 'NNP'),
#  (',', ','),
#  ('острой', 'NNP'),
#  ('вони', 'NNP'),
#  ('разлагающихся', 'NNP'),
#  ('трупов', 'NNP'),
#  ('.', '.'),
#  ('Казалось', 'NN'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('даже', 'NNP'),
#  ('земля', 'NNP'),
#  ('с', 'NNP'),
#  ('бурыми', 'NNP'),
#  (',', ','),
#  ('опаленными', 'NNP'),
#  ('и', 'NNP'),
#  ('жесткими', 'NNP'),
#  ('краями', 'NNP'),
#  ('воронок', 'NNP'),
#  ('источает', 'NNP'),
#  ('могильный', 'NNP'),
#  ('запах', 'NNP'),
#  ('.', '.'),
#  ('Смерть', 'VB'),
#  ('величественно', 'JJ'),
#  ('и', 'NNP'),
#  ('безмолвно', 'NNP'),
#  ('властвовала', 'NNP'),
#  ('на', 'NNP'),
#  ('этой', 'NNP'),
#  ('поляне', 'NNP'),
#  (',', ','),
#  ('созданной', 'NNP'),
#  ('и', 'NNP'),
#  ('взрытой', 'NNP'),
#  ('нашими', 'NNP'),
#  ('снарядами', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('только', 'NNP'),
#  ('в', 'NNP'),
#  ('самом', 'NNP'),
#  ('центре', 'NNP'),
#  ('поляны', 'NNP'),
#  ('стояла', 'NNP'),
#  ('одна', 'NNP'),
#  ('чудом', 'NNP'),
#  ('сохранившаяся', 'NNP'),
#  ('березка', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('ветер', 'NNP'),
#  ('раскачивал', 'NNP'),
#  ('ее', 'NNP'),
#  ('израненные', 'NNP'),
#  ('осколками', 'NNP'),
#  ('ветви', 'NNP'),
#  ('и', 'NNP'),
#  ('шумел', 'NNP'),
#  ('в', 'NNP'),
#  ('молодых', 'NNP'),
#  (',', ','),
#  ('глянцевито-клейких', 'JJ'),
#  ('листках', 'NN'),
#  ('.', '.'),
#  ('Мы', 'CC'),
#  ('проходили', 'JJ'),
#  ('через', 'NNP'),
#  ('поляну', 'NNP'),
#  ('.', '.'),
#  ('Шедший', 'VB'),
#  ('впереди', 'JJ'),
#  ('меня', 'NNP'),
#  ('связной', 'NNP'),
#  ('красноармеец', 'NNP'),
#  ('слегка', 'NNP'),
#  ('коснулся', 'NNP'),
#  ('рукой', 'NNP'),
#  ('ствола', 'NNP'),
#  ('березы', 'NNP'),
#  (',', ','),
#  ('спросил', 'NNP'),
#  ('с', 'NNP'),
#  ('искренним', 'NNP'),
#  ('и', 'NNP'),
#  ('ласковым', 'NNP'),
#  ('удивлением', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('Как', 'NNP'),
#  ('же', 'NNP'),
#  ('ты', 'NNP'),
#  ('тут', 'NNP'),
#  ('уцелела', 'NNP'),
#  (',', ','),
#  ('милая', 'NNP'),
#  ('?', '.'),
#  ('..', 'NNP'),
#  ('Но', 'NNP'),
#  ('если', 'NNP'),
#  ('сосна', 'NNP'),
#  ('гибнет', 'NNP'),
#  ('от', 'NNP'),
#  ('снаряда', 'NNP'),
#  (',', ','),
#  ('падая', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('скошенная', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('на', 'NNP'),
#  ('месте', 'NNP'),
#  ('среза', 'NNP'),
#  ('остается', 'NNP'),
#  ('лишь', 'NNP'),
#  ('иглистая', 'NNP'),
#  (',', ','),
#  ('истекающая', 'NNP'),
#  ('смолой', 'NNP'),
#  ('макушка', 'NNP'),
#  (',', ','),
#  ('то', 'NNP'),
#  ('по-иному', 'NNP'),
#  ('встречается', 'NNP'),
#  ('со', 'NNP'),
#  ('смертью', 'NNP'),
#  ('дуб', 'NNP'),
#  ('.', '.'),
#  ('На', 'VB'),
#  ('провесне', 'JJ'),
#  ('немецкий', 'NNP'),
#  ('снаряд', 'NNP'),
#  ('попал', 'NNP'),
#  ('в', 'NNP'),
#  ('ствол', 'NNP'),
#  ('старого', 'NNP'),
#  ('дуба', 'NNP'),
#  (',', ','),
#  ('росшего', 'NNP'),
#  ('на', 'NNP'),
#  ('берегу', 'NNP'),
#  ('безыменной', 'NNP'),
#  ('речушки', 'NNP'),
#  ('.', '.'),
#  ('Рваная', 'NN'),
#  (',', ','),
#  ('зияющая', 'NNP'),
#  ('пробоина', 'NNP'),
#  ('иссушила', 'NNP'),
#  ('полдерева', 'NNP'),
#  (',', ','),
#  ('но', 'NNP'),
#  ('вторая', 'NNP'),
#  ('половина', 'NNP'),
#  (',', ','),
#  ('пригнутая', 'NNP'),
#  ('разрывом', 'NNP'),
#  ('к', 'NNP'),
#  ('воде', 'NNP'),
#  (',', ','),
#  ('весною', 'NNP'),
#  ('дивно', 'NNP'),
#  ('ожила', 'NNP'),
#  ('и', 'NNP'),
#  ('покрылась', 'NNP'),
#  ('свежей', 'NNP'),
#  ('листвой', 'NNP'),
#  ('.', '.'),
#  ('И', 'VB'),
#  ('до', 'JJ'),
#  ('сегодняшнего', 'NNP'),
#  ('дня', 'NNP'),
#  (',', ','),
#  ('наверное', 'NNP'),
#  (',', ','),
#  ('нижние', 'NNP'),
#  ('ветви', 'NNP'),
#  ('искалеченного', 'NNP'),
#  ('дуба', 'NNP'),
#  ('купаются', 'NNP'),
#  ('в', 'NNP'),
#  ('текучей', 'NNP'),
#  ('воде', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('верхние', 'NNP'),
#  ('все', 'NNP'),
#  ('еще', 'NNP'),
#  ('жадно', 'NNP'),
#  ('протягивают', 'NNP'),
#  ('к', 'NNP'),
#  ('солнцу', 'NNP'),
#  ('точеные', 'NNP'),
#  (',', ','),
#  ('тугие', 'NNP'),
#  ('листья…', 'NNP'),
#  ('*', 'NNP'),
#  ('*', 'NNP'),
#  ('*', 'NNP'),
#  ('Высокий', 'NNP'),
#  (',', ','),
#  ('немного', 'NNP'),
#  ('сутулый', 'NNP'),
#  (',', ','),
#  ('с', 'NNP'),
#  ('приподнятыми', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('у', 'NNP'),
#  ('коршуна', 'NNP'),
#  (',', ','),
#  ('широкими', 'NNP'),
#  ('плечами', 'NNP'),
#  (',', ','),
#  ('лейтенант', 'NNP'),
#  ('Герасимов', 'NNP'),
#  ('сидел', 'NNP'),
#  ('у', 'NNP'),
#  ('входа', 'NNP'),
#  ('в', 'NNP'),
#  ('блиндаж', 'NNP'),
#  ('и', 'NNP'),
#  ('обстоятельно', 'NNP'),
#  ('рассказывал', 'NNP'),
#  ('о', 'NNP'),
#  ('сегодняшнем', 'NNP'),
#  ('бое', 'NNP'),
#  (',', ','),
#  ('о', 'NNP'),
#  ('танковой', 'NNP'),
#  ('атаке', 'NNP'),
#  ('противника', 'NNP'),
#  (',', ','),
#  ('успешно', 'NNP'),
#  ('отбитой', 'NNP'),
#  ('батальоном', 'NNP'),
#  ('.', '.'),
#  ('Худое', 'VB'),
#  ('лицо', 'JJ'),
#  ('лейтенанта', 'NNP'),
#  ('было', 'NNP'),
#  ('спокойно', 'NNP'),
#  (',', ','),
#  ('почти', 'NNP'),
#  ('бесстрастно', 'NNP'),
#  (',', ','),
#  ('воспаленные', 'NNP'),
#  ('глаза', 'NNP'),
#  ('устало', 'NNP'),
#  ('прищурены', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('говорил', 'JJ'),
#  ('надтреснутым', 'NNP'),
#  ('баском', 'NNP'),
#  (',', ','),
#  ('изредка', 'NNP'),
#  ('скрещивая', 'NNP'),
#  ('крупные', 'NNP'),
#  ('узловатые', 'NNP'),
#  ('пальцы', 'NNP'),
#  ('рук', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('странно', 'NNP'),
#  ('не', 'NNP'),
#  ('вязался', 'NNP'),
#  ('с', 'NNP'),
#  ('его', 'NNP'),
#  ('сильной', 'NNP'),
#  ('фигурой', 'NNP'),
#  (',', ','),
#  ('с', 'NNP'),
#  ('энергическим', 'NNP'),
#  (',', ','),
#  ('мужественным', 'NNP'),
#  ('лицом', 'NNP'),
#  ('этот', 'NNP'),
#  ('жест', 'NNP'),
#  (',', ','),
#  ('так', 'NNP'),
#  ('красноречиво', 'NNP'),
#  ('передающий', 'NNP'),
#  ('безмолвное', 'NNP'),
#  ('горе', 'NNP'),
#  ('или', 'NNP'),
#  ('глубокое', 'NNP'),
#  ('и', 'NNP'),
#  ('тягостное', 'NNP'),
#  ('раздумье', 'NNP'),
#  ('.', '.'),
#  ('Но', 'VB'),
#  ('вдруг', 'JJ'),
#  ('он', 'NNP'),
#  ('умолк', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('лицо', 'NNP'),
#  ('его', 'NNP'),
#  ('мгновенно', 'NNP'),
#  ('преобразилось', 'NN'),
#  (':', ':'),
#  ('смуглые', 'JJ'),
#  ('щеки', 'NNP'),
#  ('побледнели', 'NNP'),
#  (',', ','),
#  ('под', 'NNP'),
#  ('скулами', 'NNP'),
#  (',', ','),
#  ('перекатываясь', 'NNP'),
#  (',', ','),
#  ('заходили', 'NNP'),
#  ('желваки', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('пристально', 'NNP'),
#  ('устремленные', 'NNP'),
#  ('вперед', 'NNP'),
#  ('глаза', 'NNP'),
#  ('вспыхнули', 'NNP'),
#  ('такой', 'NNP'),
#  ('неугасимой', 'NNP'),
#  (',', ','),
#  ('лютой', 'NNP'),
#  ('ненавистью', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('я', 'NNP'),
#  ('невольно', 'NNP'),
#  ('повернулся', 'NNP'),
#  ('в', 'NNP'),
#  ('сторону', 'NNP'),
#  ('его', 'NNP'),
#  ('взгляда', 'NNP'),
#  ('и', 'NNP'),
#  ('увидел', 'NNP'),
#  ('шедших', 'NNP'),
#  ('по', 'NNP'),
#  ('лесу', 'NNP'),
#  ('от', 'NNP'),
#  ('переднего', 'NNP'),
#  ('края', 'NNP'),
#  ('нашей', 'NNP'),
#  ('обороны', 'NNP'),
#  ('трех', 'NNP'),
#  ('пленных', 'NNP'),
#  ('немцев', 'NNP'),
#  ('и', 'NNP'),
#  ('сзади', 'NNP'),
#  ('—', 'NNP'),
#  ('конвоировавшего', 'NNP'),
#  ('их', 'NNP'),
#  ('красноармейца', 'NNP'),
#  ('в', 'NNP'),
#  ('выгоревшей', 'NNP'),
#  (',', ','),
#  ('почти', 'NNP'),
#  ('белой', 'NNP'),
#  ('от', 'NNP'),
#  ('солнца', 'NNP'),
#  (',', ','),
#  ('летней', 'NNP'),
#  ('гимнастерке', 'NNP'),
#  ('и', 'NNP'),
#  ('сдвинутой', 'NNP'),
#  ('на', 'NNP'),
#  ('затылок', 'NNP'),
#  ('пилотке', 'NNP'),
#  ('.', '.'),
#  ('Красноармеец', 'VB'),
#  ('шел', 'JJ'),
#  ('медленно', 'NNP'),
#  ('.', '.'),
#  ('Мерно', 'VB'),
#  ('раскачивалась', 'JJ'),
#  ('в', 'NNP'),
#  ('его', 'NNP'),
#  ('руках', 'NNP'),
#  ('винтовка', 'NNP'),
#  (',', ','),
#  ('посверкивая', 'NNP'),
#  ('на', 'NNP'),
#  ('солнце', 'NNP'),
#  ('жалом', 'NNP'),
#  ('штыка', 'NNP'),
#  ('.', '.'),
#  ('И', 'VB'),
#  ('так', 'JJ'),
#  ('же', 'NNP'),
#  ('медленно', 'NNP'),
#  ('брели', 'NNP'),
#  ('пленные', 'NNP'),
#  ('немцы', 'NNP'),
#  (',', ','),
#  ('нехотя', 'NNP'),
#  ('переставляя', 'NNP'),
#  ('ноги', 'NNP'),
#  (',', ','),
#  ('обутые', 'NNP'),
#  ('в', 'NNP'),
#  ('короткие', 'NNP'),
#  (',', ','),
#  ('измазанные', 'NNP'),
#  ('желтой', 'NNP'),
#  ('глиной', 'NNP'),
#  ('сапоги', 'NNP'),
#  ('.', '.'),
#  ('Шагавший', 'VB'),
#  ('впереди', 'JJ'),
#  ('немец', 'NNP'),
#  ('—', 'NNP'),
#  ('пожилой', 'NNP'),
#  (',', ','),
#  ('со', 'NNP'),
#  ('впалыми', 'NNP'),
#  ('щеками', 'NNP'),
#  (',', ','),
#  ('густо', 'NNP'),
#  ('заросшими', 'NNP'),
#  ('каштановой', 'NNP'),
#  ('щетиной', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('поравнялся', 'NNP'),
#  ('с', 'NNP'),
#  ('блиндажом', 'NNP'),
#  (',', ','),
#  ('кинул', 'NNP'),
#  ('в', 'NNP'),
#  ('нашу', 'NNP'),
#  ('сторону', 'NNP'),
#  ('исподлобный', 'NNP'),
#  (',', ','),
#  ('волчий', 'NNP'),
#  ('взгляд', 'NNP'),
#  (',', ','),
#  ('отвернулся', 'NNP'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('ходу', 'NNP'),
#  ('поправляя', 'NNP'),
#  ('привешенную', 'NNP'),
#  ('к', 'NNP'),
#  ('поясу', 'NNP'),
#  ('каску', 'NNP'),
#  ('.', '.'),
#  ('И', 'VB'),
#  ('тогда', 'JJ'),
#  ('лейтенант', 'NNP'),
#  ('Герасимов', 'NNP'),
#  ('порывисто', 'NNP'),
#  ('вскочил', 'NNP'),
#  (',', ','),
#  ('крикнул', 'NNP'),
#  ('красноармейцу', 'NNP'),
#  ('резким', 'NNP'),
#  (',', ','),
#  ('лающим', 'NNP'),
#  ('голосом', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('Ты', 'NNP'),
#  ('что', 'NNP'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('прогулке', 'NNP'),
#  ('с', 'NNP'),
#  ('ними', 'NNP'),
#  ('?', '.'),
#  ('Прибавить', 'JJ'),
#  ('шагу', 'NN'),
#  ('!', '.'),
#  ('Веди', 'NN'),
#  ('быстрей', 'NN'),
#  (',', ','),
#  ('говорят', 'NNP'),
#  ('тебе', 'NN'),
#  ('!', '.'),
#  ('..', 'JJ'),
#  ('Он', 'NN'),
#  (',', ','),
#  ('видимо', 'NNP'),
#  (',', ','),
#  ('хотел', 'NNP'),
#  ('еще', 'NNP'),
#  ('что-то', 'JJ'),
#  ('крикнуть', 'NNP'),
#  (',', ','),
#  ('но', 'NNP'),
#  ('задохнулся', 'NNP'),
#  ('от', 'NNP'),
#  ('волнения', 'NNP'),
#  ('и', 'NNP'),
#  (',', ','),
#  ('круто', 'NNP'),
#  ('повернувшись', 'NNP'),
#  (',', ','),
#  ('быстро', 'NNP'),
#  ('сбежал', 'NNP'),
#  ('по', 'NNP'),
#  ('ступенькам', 'NNP'),
#  ('в', 'NNP'),
#  ('блиндаж', 'NNP'),
#  ('.', '.'),
#  ('Присутствовавший', 'VB'),
#  ('при', 'JJ'),
#  ('разговоре', 'NNP'),
#  ('политрук', 'NNP'),
#  (',', ','),
#  ('отвечая', 'NNP'),
#  ('на', 'NNP'),
#  ('мой', 'NNP'),
#  ('удивленный', 'NNP'),
#  ('взгляд', 'NNP'),
#  (',', ','),
#  ('вполголоса', 'NNP'),
#  ('сказал', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('Ничего', 'NNP'),
#  ('не', 'NNP'),
#  ('поделаешь', 'NNP'),
#  ('—', 'NNP'),
#  ('нервы', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('в', 'JJ'),
#  ('плену', 'NNP'),
#  ('у', 'NNP'),
#  ('немцев', 'NNP'),
#  ('был', 'NNP'),
#  (',', ','),
#  ('разве', 'NNP'),
#  ('вы', 'NNP'),
#  ('не', 'NNP'),
#  ('знаете', 'NNP'),
#  ('?', '.'),
#  ('Вы', 'NNP'),
#  ('поговорите', 'NNP'),
#  ('с', 'NNP'),
#  ('ним', 'NNP'),
#  ('как-нибудь', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('очень', 'JJ'),
#  ('много', 'NNP'),
#  ('пережил', 'NNP'),
#  ('там', 'NNP'),
#  ('и', 'NNP'),
#  ('после', 'NNP'),
#  ('этого', 'NNP'),
#  ('живых', 'NNP'),
#  ('гитлеровцев', 'NNP'),
#  ('не', 'NNP'),
#  ('может', 'NNP'),
#  ('видеть', 'NNP'),
#  (',', ','),
#  ('именно', 'NNP'),
#  ('живых', 'NN'),
#  ('!', '.'),
#  ('На', 'JJ'),
#  ('мертвых', 'JJ'),
#  ('смотрит', 'NN'),
#  ('ничего', 'NN'),
#  (',', ','),
#  ('я', 'NNP'),
#  ('бы', 'NNP'),
#  ('сказал', 'NNP'),
#  ('—', 'NNP'),
#  ('даже', 'NNP'),
#  ('с', 'NNP'),
#  ('удовольствием', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('вот', 'NNP'),
#  ('пленных', 'NNP'),
#  ('увидит', 'NNP'),
#  ('и', 'NNP'),
#  ('либо', 'NNP'),
#  ('закроет', 'NNP'),
#  ('глаза', 'NNP'),
#  ('и', 'NNP'),
#  ('сидит', 'NNP'),
#  ('бледный', 'NNP'),
#  ('и', 'NNP'),
#  ('потный', 'NNP'),
#  (',', ','),
#  ('либо', 'NNP'),
#  ('повернется', 'NNP'),
#  ('и', 'NNP'),
#  ('уйдет', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('Политрук', 'JJ'),
#  ('придвинулся', 'NNP'),
#  ('ко', 'NNP'),
#  ('мне', 'NNP'),
#  (',', ','),
#  ('перешел', 'NNP'),
#  ('на', 'NNP'),
#  ('шепот', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('Мне', 'NNP'),
#  ('с', 'NNP'),
#  ('ним', 'NNP'),
#  ('пришлось', 'NNP'),
#  ('два', 'NNP'),
#  ('раза', 'NNP'),
#  ('ходить', 'NNP'),
#  ('в', 'NNP'),
#  ('атаку', 'NN'),
#  (':', ':'),
#  ('силища', 'JJ'),
#  ('у', 'NNP'),
#  ('него', 'NNP'),
#  ('лошадиная', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('вы', 'NNP'),
#  ('бы', 'NNP'),
#  ('посмотрели', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('он', 'NNP'),
#  ('делает…', 'NNP'),
#  ('Всякие', 'NNP'),
#  ('виды', 'NNP'),
#  ('мне', 'NNP'),
#  ('приходилось', 'NNP'),
#  ('видывать', 'NNP'),
#  (',', ','),
#  ('но', 'NNP'),
#  ('как', 'NNP'),
#  ('он', 'NNP'),
#  ('орудует', 'NNP'),
#  ('штыком', 'NNP'),
#  ('и', 'NNP'),
#  ('прикладом', 'NNP'),
#  (',', ','),
#  ('знаете', 'NNP'),
#  ('ли', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('это', 'NNP'),
#  ('страшно', 'NN'),
#  ('!', '.'),
#  ('*', 'JJ'),
#  ('*', 'JJ'),
#  ('*', 'NN'),
#  ('Ночью', 'NNP'),
#  ('немецкая', 'NNP'),
#  ('тяжелая', 'NNP'),
#  ('артиллерия', 'NNP'),
#  ('вела', 'NNP'),
#  ('тревожащий', 'NNP'),
#  ('огонь', 'NNP'),
#  ('.', '.'),
#  ('Методически', 'NN'),
#  (',', ','),
#  ('через', 'NNP'),
#  ('ровные', 'NNP'),
#  ('промежутки', 'NNP'),
#  ('времени', 'NNP'),
#  (',', ','),
#  ('издалека', 'NNP'),
#  ('доносился', 'NNP'),
#  ('орудийный', 'NNP'),
#  ('выстрел', 'NNP'),
#  (',', ','),
#  ('спустя', 'NNP'),
#  ('несколько', 'NNP'),
#  ('секунд', 'NNP'),
#  ('над', 'NNP'),
#  ('нашими', 'NNP'),
#  ('головами', 'NNP'),
#  (',', ','),
#  ('высоко', 'NNP'),
#  ('в', 'NNP'),
#  ('звездном', 'NNP'),
#  ('небе', 'NNP'),
#  (',', ','),
#  ('слышался', 'NNP'),
#  ('железный', 'NNP'),
#  ('клекот', 'NNP'),
#  ('снаряда', 'NNP'),
#  (',', ','),
#  ('воющий', 'NNP'),
#  ('звук', 'NNP'),
#  ('нарастал', 'NNP'),
#  ('и', 'NNP'),
#  ('удалялся', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('затем', 'NNP'),
#  ('где-то', 'JJ'),
#  ('позади', 'NNP'),
#  ('нас', 'NNP'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('направлении', 'NNP'),
#  ('дороги', 'NNP'),
#  (',', ','),
#  ('по', 'NNP'),
#  ('которой', 'NNP'),
#  ('днем', 'NNP'),
#  ('густо', 'NNP'),
#  ('шли', 'NNP'),
#  ('машины', 'NNP'),
#  (',', ','),
#  ('подвозившие', 'NNP'),
#  ('к', 'NNP'),
#  ('линии', 'NNP'),
#  ('фронта', 'NNP'),
#  ('боеприпасы', 'NNP'),
#  (',', ','),
#  ('желтой', 'NNP'),
#  ('зарницей', 'NNP'),
#  ('вспыхивало', 'NNP'),
#  ('пламя', 'NNP'),
#  ('и', 'NNP'),
#  ('громово', 'NNP'),
#  ('звучал', 'NNP'),
#  ('разрыв', 'NNP'),
#  ('.', '.'),
#  ('В', 'VB'),
#  ('промежутках', 'JJ'),
#  ('между', 'NNP'),
#  ('выстрелами', 'NNP'),
#  (',', ','),
#  ('когда', 'NNP'),
#  ('в', 'NNP'),
#  ('лесу', 'NNP'),
#  ('устанавливалась', 'NNP'),
#  ('тишина', 'NNP'),
#  (',', ','),
#  ('слышно', 'NNP'),
#  ('было', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('тонко', 'NNP'),
#  ('пели', 'NNP'),
#  ('комары', 'NNP'),
#  ('и', 'NNP'),
#  ('несмело', 'NNP'),
#  ('перекликались', 'NNP'),
#  ('в', 'NNP'),
#  ('соседнем', 'NNP'),
#  ('болотце', 'NNP'),
#  ('потревоженные', 'NNP'),
#  ('стрельбой', 'NNP'),
#  ('лягушки', 'NNP'),
#  ('.', '.'),
#  ('Мы', 'VB'),
#  ('лежали', 'JJ'),
#  ('под', 'NNP'),
#  ('кустом', 'NNP'),
#  ('орешника', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('лейтенант', 'NNP'),
#  ('Герасимов', 'NNP'),
#  (',', ','),
#  ('отмахиваясь', 'NNP'),
#  ('от', 'NNP'),
#  ('комаров', 'NNP'),
#  ('сломленной', 'NNP'),
#  ('веткой', 'NNP'),
#  (',', ','),
#  ('неторопливо', 'NNP'),
#  ('рассказывал', 'NNP'),
#  ('о', 'NNP'),
#  ('себе', 'NNP'),
#  ('.', '.'),
#  ('Я', 'VB'),
#  ('передаю', 'JJ'),
#  ('этот', 'NNP'),
#  ('рассказ', 'NNP'),
#  ('так', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('мне', 'NNP'),
#  ('удалось', 'NNP'),
#  ('его', 'NNP'),
#  ('запомнить', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('До', 'JJ'),
#  ('войны', 'NNP'),
#  ('работал', 'NNP'),
#  ('я', 'NNP'),
#  ('механиком', 'NNP'),
#  ('на', 'NNP'),
#  ('одном', 'NNP'),
#  ('из', 'NNP'),
#  ('заводов', 'NNP'),
#  ('Западной', 'NNP'),
#  ('Сибири', 'NNP'),
#  ('.', '.'),
#  ('В', 'VB'),
#  ('армию', 'JJ'),
#  ('призван', 'NNP'),
#  ('девятого', 'NNP'),
#  ('июля', 'NNP'),
#  ('прошлого', 'NNP'),
#  ('года', 'NNP'),
#  ('.', '.'),
#  ('Семья', 'VB'),
#  ('у', 'JJ'),
#  ('меня', 'NNP'),
#  ('—', 'NNP'),
#  ('жена', 'NNP'),
#  (',', ','),
#  ('двое', 'NNP'),
#  ('ребят', 'NNP'),
#  (',', ','),
#  ('отец-инвалид', 'NNP'),
#  ('.', '.'),
#  ('Ну', 'NN'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('проводах', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('полагается', 'NNP'),
#  (',', ','),
#  ('жена', 'NNP'),
#  ('и', 'NNP'),
#  ('поплакала', 'NNP'),
#  ('и', 'NNP'),
#  ('напутствие', 'NNP'),
#  ('сказала', 'NN'),
#  (':', ':'),
#  ('«', 'JJ'),
#  ('Защищай', 'NNP'),
#  ('родину', 'NNP'),
#  ('и', 'NNP'),
#  ('нас', 'NNP'),
#  ('крепко', 'NNP'),
#  ('.', '.'),
#  ('Если', 'VB'),
#  ('понадобится', 'JJ'),
#  ('—', 'NNP'),
#  ('жизнь', 'NNP'),
#  ('отдай', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('чтобы', 'NNP'),
#  ('победа', 'NNP'),
#  ('была', 'NNP'),
#  ('нашей', 'NNP'),
#  ('»', 'NNP'),
#  ('.', '.'),
#  ('Помню', 'NN'),
#  (',', ','),
#  ('засмеялся', 'NNP'),
#  ('я', 'NNP'),
#  ('тогда', 'NNP'),
#  ('и', 'NNP'),
#  ('говорю', 'NNP'),
#  ('ей', 'NN'),
#  (':', ':'),
#  ('«', 'JJ'),
#  ('Кто', 'NNP'),
#  ('ты', 'NNP'),
#  ('мне', 'NNP'),
#  ('есть', 'NNP'),
#  (',', ','),
#  ('жена', 'NNP'),
#  ('или', 'NNP'),
#  ('семейный', 'NNP'),
#  ('агитатор', 'NNP'),
#  ('?', '.'),
#  ('Я', 'NNP'),
#  ('сам', 'NNP'),
#  ('большой', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('что', 'NNP'),
#  ('касается', 'NNP'),
#  ('победы', 'NNP'),
#  (',', ','),
#  ('так', 'NNP'),
#  ('мы', 'NNP'),
#  ('ее', 'NNP'),
#  ('у', 'NNP'),
#  ('фашистов', 'NNP'),
#  ('вместе', 'NNP'),
#  ('с', 'NNP'),
#  ('горлом', 'NNP'),
#  ('вынем', 'NNP'),
#  (',', ','),
#  ('не', 'NNP'),
#  ('беспокойся', 'NN'),
#  ('!', '.'),
#  ('»', 'NN'),
#  ('Отец', 'NN'),
#  (',', ','),
#  ('тот', 'NNP'),
#  (',', ','),
#  ('конечно', 'NNP'),
#  (',', ','),
#  ('покрепче', 'NNP'),
#  (',', ','),
#  ('но', 'NNP'),
#  ('без', 'NNP'),
#  ('наказа', 'NNP'),
#  ('и', 'NNP'),
#  ('тут', 'NNP'),
#  ('не', 'NNP'),
#  ('обошлось', 'NN'),
#  (':', ':'),
#  ('«', 'NN'),
#  ('Смотри', 'NN'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('говорит', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('Виктор', 'NNP'),
#  (',', ','),
#  ...]

# %%
from collections import Counter
lower_case = text4.lower()
tokens = nltk.word_tokenize(lower_case)
tags = nltk.pos_tag(tokens)
counts = Counter( tag for word,  tag in tags)
print(counts)
# Out:
# Counter({'NNP': 4475, ',': 677, 'JJ': 418, '.': 394, 'NN': 269, 'VB': 251, ':': 54, 'CC': 15, 'UH': 1, 'CD': 1})

# %%
from collections import Counter
lower_case = text4.lower()
tokens = nltk.word_tokenize(lower_case)
tags = nltk.pos_tag(tokens, lang='rus')
counts = Counter( tag for word,  tag in tags)
print(counts)

#  в тексте много эпитетов
# Out:
# Counter({'S': 1322, 'NONLEX': 1251, 'V': 1104, 'PR': 610, 'S-PRO': 516, 'CONJ': 475, 'ADV': 249, 'PART': 217, 'ADV-PRO': 126, 'A=pl': 107, 'A=f': 97, 'A=m': 92, 'A-PRO=pl': 70, 'A-PRO=m': 61, 'A-PRO=f': 59, 'PRAEDIC': 27, 'A=n': 24, 'NUM=acc': 16, 'A-PRO': 15, 'A-PRO=n': 12, 'PARENTH': 12, 'NUM=nom': 10, 'ANUM=m': 10, 'A-PRO=sg': 9, 'ANUM=f': 9, 'A=sg': 8, 'NUM=m': 6, 'NUM=gen': 4, 'S-PRO=acc': 4, 'ADV=comp': 4, 'S-PRO=gen': 3, 'A': 2, 'PRAEDIC=comp': 2, 'ANUM=n': 2, 'S-PRO=dat': 2, 'NUM=comp': 2, 'NUM=n': 2, 'NUM=dat': 2, 'S-PRO=pl': 2, 'S-PRO=loc': 1, 'A=comp2': 1, 'PRAEDIC-PRO': 1, 'INTJ': 1, 'NUM=loc': 1, 'ANUM=pl': 1, 'S-PRO=ins': 1, 'A=comp': 1, 'NUM=f': 1, 'NUM=ciph': 1})

# %%
tokenizer = nltk.tokenize.BlanklineTokenizer()
tokens = tokenizer.tokenize(text4)
print(len(tokenizer.tokenize(text4)))
# print(tokenizer.tokenize(text1))
print('Разделение текста по абзацам')

#  текст поделен на много абзацев
# Out:
# 97
# Разделение текста по абзацам

# %%
tokenizer = nltk.tokenize.WhitespaceTokenizer()
print(len(tokenizer.tokenize(text4)))
print(tokenizer.tokenize(text4))

#  произведение небольшое
# Out:
# 5367
# ['На', 'войне', 'деревья,', 'как', 'и', 'люди,', 'имеют', 'каждое', 'свою', 'судьбу.', 'Я', 'видел', 'огромный', 'участок', 'леса,', 'срезанного', 'огнем', 'нашей', 'артиллерии.', 'В', 'этом', 'лесу', 'недавно', 'укреплялись', 'немцы,', 'выбитые', 'из', 'села', 'С.,', 'здесь', 'они', 'думали', 'задержаться,', 'но', 'смерть', 'скосила', 'их', 'вместе', 'с', 'деревьями.', 'Под', 'поверженными', 'стволами', 'сосен', 'лежали', 'мертвые', 'немецкие', 'солдаты,', 'в', 'зеленом', 'папоротнике', 'гнили', 'их', 'изорванные', 'в', 'клочья', 'тела,', 'и', 'смолистый', 'аромат', 'расщепленных', 'снарядами', 'сосен', 'не', 'мог', 'заглушить', 'удушливо-приторной,', 'острой', 'вони', 'разлагающихся', 'трупов.', 'Казалось,', 'что', 'даже', 'земля', 'с', 'бурыми,', 'опаленными', 'и', 'жесткими', 'краями', 'воронок', 'источает', 'могильный', 'запах.', 'Смерть', 'величественно', 'и', 'безмолвно', 'властвовала', 'на', 'этой', 'поляне,', 'созданной', 'и', 'взрытой', 'нашими', 'снарядами,', 'и', 'только', 'в', 'самом', 'центре', 'поляны', 'стояла', 'одна', 'чудом', 'сохранившаяся', 'березка,', 'и', 'ветер', 'раскачивал', 'ее', 'израненные', 'осколками', 'ветви', 'и', 'шумел', 'в', 'молодых,', 'глянцевито-клейких', 'листках.', 'Мы', 'проходили', 'через', 'поляну.', 'Шедший', 'впереди', 'меня', 'связной', 'красноармеец', 'слегка', 'коснулся', 'рукой', 'ствола', 'березы,', 'спросил', 'с', 'искренним', 'и', 'ласковым', 'удивлением:', '—', 'Как', 'же', 'ты', 'тут', 'уцелела,', 'милая?..', 'Но', 'если', 'сосна', 'гибнет', 'от', 'снаряда,', 'падая,', 'как', 'скошенная,', 'и', 'на', 'месте', 'среза', 'остается', 'лишь', 'иглистая,', 'истекающая', 'смолой', 'макушка,', 'то', 'по-иному', 'встречается', 'со', 'смертью', 'дуб.', 'На', 'провесне', 'немецкий', 'снаряд', 'попал', 'в', 'ствол', 'старого', 'дуба,', 'росшего', 'на', 'берегу', 'безыменной', 'речушки.', 'Рваная,', 'зияющая', 'пробоина', 'иссушила', 'полдерева,', 'но', 'вторая', 'половина,', 'пригнутая', 'разрывом', 'к', 'воде,', 'весною', 'дивно', 'ожила', 'и', 'покрылась', 'свежей', 'листвой.', 'И', 'до', 'сегодняшнего', 'дня,', 'наверное,', 'нижние', 'ветви', 'искалеченного', 'дуба', 'купаются', 'в', 'текучей', 'воде,', 'а', 'верхние', 'все', 'еще', 'жадно', 'протягивают', 'к', 'солнцу', 'точеные,', 'тугие', 'листья…', '*', '*', '*', 'Высокий,', 'немного', 'сутулый,', 'с', 'приподнятыми,', 'как', 'у', 'коршуна,', 'широкими', 'плечами,', 'лейтенант', 'Герасимов', 'сидел', 'у', 'входа', 'в', 'блиндаж', 'и', 'обстоятельно', 'рассказывал', 'о', 'сегодняшнем', 'бое,', 'о', 'танковой', 'атаке', 'противника,', 'успешно', 'отбитой', 'батальоном.', 'Худое', 'лицо', 'лейтенанта', 'было', 'спокойно,', 'почти', 'бесстрастно,', 'воспаленные', 'глаза', 'устало', 'прищурены.', 'Он', 'говорил', 'надтреснутым', 'баском,', 'изредка', 'скрещивая', 'крупные', 'узловатые', 'пальцы', 'рук,', 'и', 'странно', 'не', 'вязался', 'с', 'его', 'сильной', 'фигурой,', 'с', 'энергическим,', 'мужественным', 'лицом', 'этот', 'жест,', 'так', 'красноречиво', 'передающий', 'безмолвное', 'горе', 'или', 'глубокое', 'и', 'тягостное', 'раздумье.', 'Но', 'вдруг', 'он', 'умолк,', 'и', 'лицо', 'его', 'мгновенно', 'преобразилось:', 'смуглые', 'щеки', 'побледнели,', 'под', 'скулами,', 'перекатываясь,', 'заходили', 'желваки,', 'а', 'пристально', 'устремленные', 'вперед', 'глаза', 'вспыхнули', 'такой', 'неугасимой,', 'лютой', 'ненавистью,', 'что', 'я', 'невольно', 'повернулся', 'в', 'сторону', 'его', 'взгляда', 'и', 'увидел', 'шедших', 'по', 'лесу', 'от', 'переднего', 'края', 'нашей', 'обороны', 'трех', 'пленных', 'немцев', 'и', 'сзади', '—', 'конвоировавшего', 'их', 'красноармейца', 'в', 'выгоревшей,', 'почти', 'белой', 'от', 'солнца,', 'летней', 'гимнастерке', 'и', 'сдвинутой', 'на', 'затылок', 'пилотке.', 'Красноармеец', 'шел', 'медленно.', 'Мерно', 'раскачивалась', 'в', 'его', 'руках', 'винтовка,', 'посверкивая', 'на', 'солнце', 'жалом', 'штыка.', 'И', 'так', 'же', 'медленно', 'брели', 'пленные', 'немцы,', 'нехотя', 'переставляя', 'ноги,', 'о ...
