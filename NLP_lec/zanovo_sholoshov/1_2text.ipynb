# %%
# %pip install -Uq spacy nltk numpy scikit-learn
import nltk
import spacy
import numpy as np
from nltk import word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk import SnowballStemmer




from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.metrics.pairwise import cosine_similarity 
import itertools
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Елизавета\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
with open("1_Nahalenok_1925.txt", "r", encoding="utf-8") as file:
    text1 = file.read()

# %%
words=word_tokenize(text1)
words
# Out:
# ['Снится',
#  'Мишке',
#  ',',
#  'будто',
#  'дед',
#  'срезал',
#  'в',
#  'саду',
#  'здоровенную',
#  'вишневую',
#  'хворостину',
#  ',',
#  'идет',
#  'к',
#  'нему',
#  ',',
#  'хворостиной',
#  'машет',
#  ',',
#  'а',
#  'сам',
#  'строго',
#  'так',
#  'говорит',
#  '.',
#  '—',
#  'А',
#  'ну',
#  ',',
#  'иди',
#  'сюда',
#  ',',
#  'Михайло',
#  'Фомич',
#  ',',
#  'я',
#  'те',
#  'полохану',
#  'по',
#  'тем',
#  'местам',
#  ',',
#  'откель',
#  'ноги',
#  'растут',
#  '!',
#  '..',
#  '—',
#  'За',
#  'что',
#  ',',
#  'дедуня',
#  '?',
#  '—',
#  'спрашивает',
#  'Мишка',
#  '.',
#  '—',
#  'А',
#  'за',
#  'то',
#  ',',
#  'что',
#  'ты',
#  'в',
#  'курятнике',
#  'из',
#  'гнезда',
#  'чубатой',
#  'курицы',
#  'все',
#  'яйца',
#  'покрал',
#  'и',
#  'на',
#  'каруселю',
#  'отнес',
#  ',',
#  'прокатал',
#  '!',
#  '..',
#  '—',
#  'Дедуня',
#  ',',
#  'я',
#  'нонешний',
#  'год',
#  'не',
#  'катался',
#  'на',
#  'каруселях',
#  '!',
#  '—',
#  'в',
# ...

# %%
len(words)
# Out:
# 9261

# %%
stop = stopwords.words('russian')
stop
# Out:
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
# ...

# %%
tokenized_filter = [token for token in words if token not in stop] 
tokenized_filter
# Out:
# ['Снится',
#  'Мишке',
#  ',',
#  'дед',
#  'срезал',
#  'саду',
#  'здоровенную',
#  'вишневую',
#  'хворостину',
#  ',',
#  'идет',
#  'нему',
#  ',',
#  'хворостиной',
#  'машет',
#  ',',
#  'строго',
#  'говорит',
#  '.',
#  '—',
#  'А',
#  ',',
#  'иди',
#  'сюда',
#  ',',
#  'Михайло',
#  'Фомич',
#  ',',
#  'те',
#  'полохану',
#  'местам',
#  ',',
#  'откель',
#  'ноги',
#  'растут',
#  '!',
#  '..',
#  '—',
#  'За',
#  ',',
#  'дедуня',
#  '?',
#  '—',
#  'спрашивает',
#  'Мишка',
#  '.',
#  '—',
#  'А',
#  ',',
#  'курятнике',
#  'гнезда',
#  'чубатой',
#  'курицы',
#  'яйца',
#  'покрал',
#  'каруселю',
#  'отнес',
#  ',',
#  'прокатал',
#  '!',
#  '..',
#  '—',
#  'Дедуня',
#  ',',
#  'нонешний',
#  'год',
#  'катался',
#  'каруселях',
#  '!',
#  '—',
#  'страхе',
#  'кричит',
#  'Мишка',
#  '.',
#  'Но',
#  'дед',
#  'степенно',
#  'разгладил',
#  'бороду',
#  'топнет',
#  'ногой',
#  ':',
#  '—',
#  'Ложись',
#  ',',
#  'постреленыш',
#  ',',
#  'спущай',
#  'портки',
# ...

# %%
len(tokenized_filter)
# Out:
# 7352

# %%
stemmer = SnowballStemmer(language='russian')
tokenized = nltk.word_tokenize(text1)
stemmed = [stemmer.stem(tokenized_filter) for tokenized_filter in tokenized]
stemmed
# Out:
# ['снит',
#  'мишк',
#  ',',
#  'будт',
#  'дед',
#  'среза',
#  'в',
#  'сад',
#  'здоровен',
#  'вишнев',
#  'хворостин',
#  ',',
#  'идет',
#  'к',
#  'нем',
#  ',',
#  'хворостин',
#  'машет',
#  ',',
#  'а',
#  'сам',
#  'строг',
#  'так',
#  'говор',
#  '.',
#  '—',
#  'а',
#  'ну',
#  ',',
#  'ид',
#  'сюд',
#  ',',
#  'михайл',
#  'фомич',
#  ',',
#  'я',
#  'те',
#  'полохан',
#  'по',
#  'тем',
#  'мест',
#  ',',
#  'откел',
#  'ног',
#  'растут',
#  '!',
#  '..',
#  '—',
#  'за',
#  'что',
#  ',',
#  'дедун',
#  '?',
#  '—',
#  'спрашива',
#  'мишк',
#  '.',
#  '—',
#  'а',
#  'за',
#  'то',
#  ',',
#  'что',
#  'ты',
#  'в',
#  'курятник',
#  'из',
#  'гнезд',
#  'чубат',
#  'куриц',
#  'все',
#  'яйц',
#  'покра',
#  'и',
#  'на',
#  'карусел',
#  'отнес',
#  ',',
#  'проката',
#  '!',
#  '..',
#  '—',
#  'дедун',
#  ',',
#  'я',
#  'нонешн',
#  'год',
#  'не',
#  'ката',
#  'на',
#  'карусел',
#  '!',
#  '—',
#  'в',
#  'страх',
#  'крич',
#  'мишк',
#  '.',
#  'но',
# ...

# %%
len(stemmed)
# Out:
# 9261

# %%
with open("2_Lazorevaya_step_1926.txt", "r", encoding="utf-8") as file:
    text2 = file.read()

# %%
words=word_tokenize(text2)
words
# Out:
# ['Над',
#  'Доном',
#  ',',
#  'на',
#  'облысевшем',
#  'от',
#  'солнечного',
#  'жара',
#  'бугре',
#  ',',
#  'под',
#  'кустом',
#  'дикого',
#  'терна',
#  'лежим',
#  'мы',
#  ':',
#  'дед',
#  'Захар',
#  'и',
#  'я.',
#  'Рядом',
#  'с',
#  'чешуйчатой',
#  'грядкой',
#  'туч',
#  'бродит',
#  'коричневый',
#  'коршун',
#  '.',
#  'Листья',
#  'терна',
#  ',',
#  'пестро',
#  'окрашенные',
#  'птичьим',
#  'пометом',
#  ',',
#  'не',
#  'дают',
#  'нам',
#  'прохлады',
#  '.',
#  'От',
#  'зноя',
#  'в',
#  'ушах',
#  'горячий',
#  'звон',
#  ';',
#  'когда',
#  'смотришь',
#  'вниз',
#  'на',
#  'курчавую',
#  'рябь',
#  'Дона',
#  'или',
#  'под',
#  'ноги',
#  'на',
#  'сморщенные',
#  'арбузные',
#  'корки',
#  '—',
#  'в',
#  'рот',
#  'набегает',
#  'тягучая',
#  'слюна',
#  ',',
#  'и',
#  'слюну',
#  'эту',
#  'лень',
#  'сплевывать',
#  '.',
#  'В',
#  'лощине',
#  ',',
#  'возле',
#  'высыхающей',
#  'музги',
#  ',',
#  'овцы',
#  'жмутся',
#  'в',
#  'тесные',
# ...

# %%
len(words)
# Out:
# 3156

# %%
tokenized_filter = [token for token in words if token not in stop] 
tokenized_filter
# Out:
# ['Над',
#  'Доном',
#  ',',
#  'облысевшем',
#  'солнечного',
#  'жара',
#  'бугре',
#  ',',
#  'кустом',
#  'дикого',
#  'терна',
#  'лежим',
#  ':',
#  'дед',
#  'Захар',
#  'я.',
#  'Рядом',
#  'чешуйчатой',
#  'грядкой',
#  'туч',
#  'бродит',
#  'коричневый',
#  'коршун',
#  '.',
#  'Листья',
#  'терна',
#  ',',
#  'пестро',
#  'окрашенные',
#  'птичьим',
#  'пометом',
#  ',',
#  'дают',
#  'нам',
#  'прохлады',
#  '.',
#  'От',
#  'зноя',
#  'ушах',
#  'горячий',
#  'звон',
#  ';',
#  'смотришь',
#  'вниз',
#  'курчавую',
#  'рябь',
#  'Дона',
#  'ноги',
#  'сморщенные',
#  'арбузные',
#  'корки',
#  '—',
#  'рот',
#  'набегает',
#  'тягучая',
#  'слюна',
#  ',',
#  'слюну',
#  'лень',
#  'сплевывать',
#  '.',
#  'В',
#  'лощине',
#  ',',
#  'возле',
#  'высыхающей',
#  'музги',
#  ',',
#  'овцы',
#  'жмутся',
#  'тесные',
#  'кучи',
#  '.',
#  'Устало',
#  'откинув',
#  'зады',
#  ',',
#  'виляют',
#  'захлюстанными',
#  'курдюками',
#  ',',
#  'надрывно',
#  'чихают',
# ...

# %%
stemmer = SnowballStemmer(language='russian')
tokenized = nltk.word_tokenize(text2)
stemmed = [stemmer.stem(tokenized_filter) for tokenized_filter in tokenized]
stemmed
# Out:
# ['над',
#  'дон',
#  ',',
#  'на',
#  'облысевш',
#  'от',
#  'солнечн',
#  'жар',
#  'бугр',
#  ',',
#  'под',
#  'куст',
#  'дик',
#  'терн',
#  'леж',
#  'мы',
#  ':',
#  'дед',
#  'захар',
#  'и',
#  'я.',
#  'ряд',
#  'с',
#  'чешуйчат',
#  'грядк',
#  'туч',
#  'брод',
#  'коричнев',
#  'коршун',
#  '.',
#  'лист',
#  'терн',
#  ',',
#  'пестр',
#  'окрашен',
#  'птич',
#  'помет',
#  ',',
#  'не',
#  'дают',
#  'нам',
#  'прохлад',
#  '.',
#  'от',
#  'зно',
#  'в',
#  'уш',
#  'горяч',
#  'звон',
#  ';',
#  'когд',
#  'смотр',
#  'вниз',
#  'на',
#  'курчав',
#  'ряб',
#  'дон',
#  'ил',
#  'под',
#  'ног',
#  'на',
#  'сморщен',
#  'арбузн',
#  'корк',
#  '—',
#  'в',
#  'рот',
#  'набега',
#  'тягуч',
#  'слюн',
#  ',',
#  'и',
#  'слюн',
#  'эт',
#  'лен',
#  'сплевыва',
#  '.',
#  'в',
#  'лощин',
#  ',',
#  'возл',
#  'высыха',
#  'музг',
#  ',',
#  'овц',
#  'жмут',
#  'в',
#  'тесн',
#  'куч',
#  '.',
#  'уста',
#  'откинув',
#  'зад',
#  ',',
#  'виля',
# ...

# %%
len(tokenized_filter)
# Out:
# 2482

# %%
stemmer = SnowballStemmer(language='russian')
tokenized = nltk.word_tokenize(text2)
stemmed = [stemmer.stem(tokenized_filter) for tokenized_filter in tokenized]
stemmed
# Out:
# ['над',
#  'дон',
#  ',',
#  'на',
#  'облысевш',
#  'от',
#  'солнечн',
#  'жар',
#  'бугр',
#  ',',
#  'под',
#  'куст',
#  'дик',
#  'терн',
#  'леж',
#  'мы',
#  ':',
#  'дед',
#  'захар',
#  'и',
#  'я.',
#  'ряд',
#  'с',
#  'чешуйчат',
#  'грядк',
#  'туч',
#  'брод',
#  'коричнев',
#  'коршун',
#  '.',
#  'лист',
#  'терн',
#  ',',
#  'пестр',
#  'окрашен',
#  'птич',
#  'помет',
#  ',',
#  'не',
#  'дают',
#  'нам',
#  'прохлад',
#  '.',
#  'от',
#  'зно',
#  'в',
#  'уш',
#  'горяч',
#  'звон',
#  ';',
#  'когд',
#  'смотр',
#  'вниз',
#  'на',
#  'курчав',
#  'ряб',
#  'дон',
#  'ил',
#  'под',
#  'ног',
#  'на',
#  'сморщен',
#  'арбузн',
#  'корк',
#  '—',
#  'в',
#  'рот',
#  'набега',
#  'тягуч',
#  'слюн',
#  ',',
#  'и',
#  'слюн',
#  'эт',
#  'лен',
#  'сплевыва',
#  '.',
#  'в',
#  'лощин',
#  ',',
#  'возл',
#  'высыха',
#  'музг',
#  ',',
#  'овц',
#  'жмут',
#  'в',
#  'тесн',
#  'куч',
#  '.',
#  'уста',
#  'откинув',
#  'зад',
#  ',',
#  'виля',
# ...

# %%
len(stemmed)
# Out:
# 3156

# %%
class TextPreprocessor: 
    def __init__(self): 
        self.nlp = spacy.load("ru_core_news_sm") 
 
    def preprocess_texts(self, text1): 
        doc = self.nlp(text1) 
        words_filter = [token.lemma_ for token in doc if not token.is_punct and not token.is_stop] 
        preprocessed_text = " ".join(words_filter) 
        return preprocessed_text

# %%
preprocessor_t = TextPreprocessor() 
preprocessed_text = preprocessor_t.preprocess_texts(text1) 
print(preprocessed_text)
# Out:
#   сниться мишке дед срезать сад здоровенный вишнёвый хворостина идти хворостиной махать строго говорить
#     идти сюда михайло фомич полохану место откель нога расти
#     дедуня   спрашивать мишка
#     курятник гнездо чубатый курица яйцо покрасть каруселю отнести прокатать
#     дедуня нонешний год кататься карусель   страх кричать мишка
#   дед степенно разгладил борода топнет нога
#     ложись постреленыш спущай портки
#   вскрикнуть мишка проснуться сердце биться словно дело хворостина отпробовал чуточку открыть левый глаз хате светло утренний зорька теплится окошком приподнять мишка голова слышать сенцах голос мамка визжит лопотать смех захлёбываться дед кашлять чужой голос бу бу бу
#   протер мишка глаз видеть дверь открыться хлопнула дед горница бежать подпрыгивать очки нос болтаются мишка подумать поп певчими прийти пасха приходить дед суетиться следом дед прет горница чужой большущий солдат чёрный шинель шапка лента козырёк мамка шея висеть воет
# ...

# %%
class TextSimilarityCalculator: 
    def __init__(self): 
        self.vectorizer = CountVectorizer() 
         
    def calculate_similarity(self, text2): 
        # Преобразование текстов в векторы с помощью CountVectorizer 
        vectors = self.vectorizer.fit_transform(text2) 
         
        # Cравнение сходства текстов 
        similarity_matrix = cosine_similarity(vectors, dense_output=False) 
         
        return similarity_matrix

# %%
similar_calculator = TextSimilarityCalculator() 
texts = [text1, text2]  # Список текстов
similar_matrix = similar_calculator.calculate_similarity(texts)

# %%
for i, j in itertools.combinations(range(len(texts)), 2): 
    similarity = similar_matrix[i, j] 
    print(f"Косинусное сходство между текстом {i+1} и текстом {j+1}: {similarity}")
# Out:
# Косинусное сходство между текстом 1 и текстом 2: 0.7102034009205253
