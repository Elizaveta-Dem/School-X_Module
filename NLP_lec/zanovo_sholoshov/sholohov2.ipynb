# %%
import nltk
from nltk.corpus import wordnet
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_ru')
nltk.download('wordnet')
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('universal_tagset')
from nltk.stem import SnowballStemmer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Елизавета\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]     C:\Users\Елизавета\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_ru is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Елизавета\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\Елизавета\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!

# %%
with open("2_Lazorevaya_step_1926.txt", "r", encoding="utf-8") as file:
    text2 = file.read()

# %%
sentences = sent_tokenize(text2, language='russian')

for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    tag_words = nltk.pos_tag(words, lang='rus') 
    
    print(tag_words)
# Out:
# [('Над', 'PR'), ('Доном', 'S'), (',', 'NONLEX'), ('на', 'PR'), ('облысевшем', 'V'), ('от', 'PR'), ('солнечного', 'A=m'), ('жара', 'S'), ('бугре', 'S'), (',', 'NONLEX'), ('под', 'PR'), ('кустом', 'S'), ('дикого', 'A=m'), ('терна', 'S'), ('лежим', 'S'), ('мы', 'S-PRO'), (':', 'NONLEX'), ('дед', 'S'), ('Захар', 'S'), ('и', 'CONJ'), ('я.', 'S'), ('Рядом', 'ADV'), ('с', 'PR'), ('чешуйчатой', 'S'), ('грядкой', 'A=f'), ('туч', 'S'), ('бродит', 'V'), ('коричневый', 'A=m'), ('коршун', 'S'), ('.', 'NONLEX')]
# [('Листья', 'S'), ('терна', 'S'), (',', 'NONLEX'), ('пестро', 'ADV'), ('окрашенные', 'V'), ('птичьим', 'V'), ('пометом', 'S'), (',', 'NONLEX'), ('не', 'PART'), ('дают', 'V'), ('нам', 'S-PRO'), ('прохлады', 'S'), ('.', 'NONLEX')]
# [('От', 'PR'), ('зноя', 'S'), ('в', 'PR'), ('ушах', 'S'), ('горячий', 'A=m'), ('звон', 'S'), (';', 'NONLEX'), ('когда', 'ADV-PRO'), ('смотришь', 'V'), ('вниз', 'ADV'), ('на', 'PR'), ('курчавую', 'A=f'), ('рябь', 'S'), ('Дона', 'S'), ('или', 'CONJ'), ('под', 'PR'), ('ноги', 'S'), ('на', 'PR'), ('сморщенные', 'A=pl'), ('арбузные', 'A=pl'), ('корки', 'S'), ('—', 'S'), ('в', 'PR'), ('рот', 'S'), ('набегает', 'V'), ('тягучая', 'A=sg'), ('слюна', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('слюну', 'S'), ('эту', 'A-PRO=f'), ('лень', 'S'), ('сплевывать', 'V'), ('.', 'NONLEX')]
# [('В', 'PR'), ('лощине', 'S'), (',', 'NONLEX'), ('возле', 'PR'), ('высыхающей', 'V'), ('музги', 'S'), (',', 'NONLEX'), ('овцы', 'S'), ('жмутся', 'V'), ('в', 'PR'), ('тесные', 'A=pl'), ('кучи', 'S'), ('.', 'NONLEX')]
# [('Устало', 'V'), ('откинув', 'V'), ('зады', 'S'), (',', 'NONLEX'), ('виляют', 'V'), ('захлюстанными', 'A=pl'), ('курдюками', 'S'), (',', 'NONLEX'), ('надрывно', 'ADV'), ('чихают', 'V'), ('от', 'PR'), ('пыли', 'S'), ('.', 'NONLEX')]
# [('У', 'PR'), ('плотины', 'S'), ('здоровенный', 'V'), ('ягночище', 'S'), (',', 'NONLEX'), ('упираясь', 'V'), ('задними', 'A=pl'), ('ногами', 'S'), (',', 'NONLEX'), ('сосет', 'S'), ('грязножелтую', 'A=f'), ('овцу', 'S'), ('.', 'NONLEX')]
# [('Изредка', 'ADV'), ('поддает', 'V'), ('головой', 'S'), ('в', 'PR'), ('материно', 'S'), ('вымя', 'S'), (';', 'NONLEX'), ('овца', 'S'), ('стонет', 'V'), (',', 'NONLEX'), ('горбится', 'V'), (',', 'NONLEX'), ('припуская', 'A=f'), ('молоко', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), (',', 'NONLEX'), ('мне', 'S-PRO'), ('кажется', 'V'), (',', 'NONLEX'), ('выражение', 'S'), ('глаз', 'S'), ('у', 'PR'), ('нее', 'A=n'), ('страдальческое', 'A=n'), ('.', 'NONLEX')]
# [('Дед', 'S'), ('Захар', 'S'), ('сидит', 'V'), ('ко', 'PR'), ('мне', 'S-PRO'), ('боком', 'S'), ('.', 'NONLEX')]
# [('Скинув', 'V'), ('вязаную', 'A=f'), ('шерстяную', 'A=f'), ('рубаху', 'S'), (',', 'NONLEX'), ('он', 'S-PRO'), ('подслеповато', 'ADV'), ('жмурится', 'V'), ('и', 'CONJ'), ('ощупью', 'V'), ('что-то', 'S-PRO'), ('ищет', 'V'), ('в', 'PR'), ('складках', 'S'), ('и', 'CONJ'), ('швах', 'S'), ('.', 'NONLEX')]
# [('Деду', 'S'), ('без', 'PR'), ('года', 'S'), ('семьдесят', 'NUM=nom'), ('.', 'NONLEX')]
# [('Голая', 'A=f'), ('спина', 'S'), ('замысловато', 'ADV'), ('опутана', 'V'), ('морщинами', 'S'), (',', 'NONLEX'), ('лопатки', 'S'), ('острыми', 'A=pl'), ('углами', 'S'), ('выпирают', 'V'), ('под', 'PR'), ('кожей', 'S'), (',', 'NONLEX'), ('но', 'CONJ'), ('глаза', 'S'), ('—', 'S'), ('голубые', 'A=pl'), ('и', 'CONJ'), ('юные', 'A=pl'), (',', 'NONLEX'), ('взгляд', 'S'), ('из-под', 'PR'), ('серых', 'A=pl'), ('бровей', 'S'), ('—', 'S'), ('проворен', 'S'), ('и', 'CONJ'), ('колюч', 'S'), ('.', 'NONLEX')]
# [('Пойманную', 'V'), ('вошь', 'ADV'), ('он', 'S-PRO'), ('с', 'PR'), ('трудом', 'S'), ('держит', 'V'), ('в', 'PR'), ('дрожащих', 'A=pl'), ('зачерствелых', 'A=pl'), ('пальцах', 'S'), (',', 'NONLEX'), ('держит', 'V'), ('ее', 'S'), ('бережно', 'ADV'), ('и', 'CONJ'), ('нежно', 'ADV'), (',', 'NONLEX'), ('потом', 'ADV-PRO'), ('кладет', 'V'), ('на', 'PR'), ('землю', 'S'), (',', 'NONLEX'), ('подальше', 'ADV=comp2'), ('от', 'PR'), ('себя', 'S-PRO=gen'), (',', 'NONLEX'), ('мелким', 'A=m'), ('крестиком', 'S'), ('чертит', 'V'), ('воздух', 'S'), ('и', 'CONJ'), ('глухо', 'ADV'), ('бурчит', 'V'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Уползай', 'S'), (',', 'NONLEX'), ('тварь', 'S'), ('!', 'NONLEX')]
# [('Жить', 'V'), (',', 'NONLEX'), ('небось', 'PARENTH'), (',', 'NONLEX'), ('хочешь', 'V'), ('?', 'NONLEX')]
# [('а', 'CONJ'), ('?', 'NONLEX')]
# [('То-то', 'A-PRO=pl'), ('оно…', 'S'), ('Ишь', 'S'), ('ты', 'S-PRO'), (',', 'NONLEX'), ('насосалась…', 'S'), ('помещица…', 'S'), ('Кряхтя', 'S'), (',', 'NONLEX'), ('напяливает', 'V'), ('дед', 'S'), ('рубаху', 'S'), ('и', 'CONJ'), (',', 'NONLEX'), ('запрокидывая', 'V'), ('голову', 'S'), (',', 'NONLEX'), ('тянет', 'V'), ('из', 'PR'), ('деревянной', 'A=f'), ('баклаги', 'S'), ('степлившуюся', 'V'), ('воду', 'S'), ('.', 'NONLEX')]
# [('Кадык', 'S'), ('при', 'PR'), ('каждом', 'A-PRO=m'), ('глотке', 'S'), ('ползет', 'V'), ('вверх', 'ADV'), (',', 'NONLEX'), ('от', 'PR'), ('подбородка', 'S'), ('к', 'PR'), ('горлу', 'S'), ('свисают', 'V'), ('две', 'NUM=f'), ('обмякших', 'A=pl'), ('складки', 'S'), (',', 'NONLEX'), ('по', 'PR'), ('бороде', 'S'), ('текут', 'V'), ('капельки', 'S'), (',', 'NONLEX'), ('сквозь', 'PR'), ('опущенные', 'A=pl'), ('шафранные', 'A=pl'), ('веки', 'S'), ('красновато', 'ADV'), ('просвечивает', 'V'), ('солнце', 'S'), ('.', 'NONLEX')]
# [('Затыкая', 'A=f'), ('баклагу', 'S'), (',', 'NONLEX'), ('он', 'S-PRO'), ('искоса', 'ADV'), ('глядит', 'V'), ('на', 'PR'), ('меня', 'S-PRO'), ('и', 'CONJ'), (',', 'NONLEX'), ('перехватив', 'V'), ('мой', 'A-PRO=m'), ('взгляд', 'S'), (',', 'NONLEX'), ('сухо', 'S'), ('жует', 'V'), ('губами', 'S'), (',', 'NONLEX'), ('смотрит', 'V'), ('в', 'PR'), ('степь', 'S'), ('.', 'NONLEX')]
# [('За', 'PR'), ('лощиной', 'A=f'), ('дымкой', 'S'), ('теплится', 'V'), ('марево', 'ADV'), (',', 'NONLEX'), ('ветер', 'S'), ('над', 'PR'), ('обугленной', 'A=f'), ('землей', 'S'), ('пряно', 'S'), ('пахнет', 'V'), ('чеборцовым', 'A=sg'), ('медом', 'S'), ('.', 'NONLEX')]
# [('Помолчав', 'V'), (',', 'NONLEX'), ('дед', 'S'), ('отодвигает', 'V'), ('от', 'PR'), ('себя', 'S-PRO=gen'), ('пастушечью', 'V'), ('чакушу', 'S'), ('[', 'NONLEX'), ('1', 'NUM=ciph'), (']', 'NONLEX'), (',', 'NONLEX'), ('обкуренным', 'A=m'), ('пальцем', 'S'), ('указывает', 'V'), ('мимо', 'PR'), ('меня', 'S-PRO'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Видишь', 'V'), (',', 'NONLEX'), ('за', 'PR'), ('энтим', 'A-PRO=m'), ('логом', 'S'), ('макушки', 'S'), ('тополев', 'S'), ('?', 'NONLEX')]
# [('Имение', 'S'), ('панов', 'S'), ('Томилиных', 'A=pl'), ('—', 'S'), ('Тополевка', 'S'), ('.', 'NONLEX')]
# [('Там', 'ADV-PRO'), ('же', 'PART'), ('около', 'PR'), ('и', 'CONJ'), ('мужичий', 'A=m'), ('поселок', 'S'), ('Тополевка', 'S'), (',', 'NONLEX'), ('раньше', 'ADV=comp'), ('крепостные', 'A=pl'), ('были', 'V'), ('.', 'NONLEX')]
# [('Отец', 'S'), ('мой', 'A-PRO=m'), ('кучеровал', 'S'), ('у', 'PR'), ('пана', 'V'), ('до', 'PR'), ('смерти', 'S'), ('.', 'NONLEX')]
# [('Мне-то', 'PARENTH'), (',', 'NONLEX'), ('огольцу', 'S'), (',', 'NONLEX'), ('он', 'S-PRO'), ('рассказывал', 'V'), (',', 'NONLEX'), ('как', 'CONJ'), ('пан', 'S'), ('Евграф', 'S'), ('Томилин', 'S'), ('выменял', 'V'), ('его', 'S-PRO'), ('за', 'PR'), ('ручного', 'A=m'), ('журавля', 'S'), ('у', 'PR'), ('соседа-помещика', 'S'), ('.', 'NONLEX')]
# [('Посля', 'S'), ('отцовой', 'A=f'), ('смерти', 'S'), ('я', 'S-PRO'), ('заступил', 'V'), ('на', 'PR'), ('его', 'A-PRO'), ('место', 'S'), ('кучером', 'S'), ('.', 'NONLEX')]
# [('Самому', 'A-PRO=m'), ('пану', 'S'), ('в', 'PR'), ('это', 'A-PRO=n'), ('время', 'S'), ('было', 'V'), ('под', 'PR'), ('шестьдесят', 'NUM=acc'), ('.', 'NONLEX')]
# [('Тýшистый', 'ANUM=m'), ('был', 'V'), ('мужчина', 'S'), (',', 'NONLEX'), ('многокровный', 'A=m'), ('.', 'NONLEX')]
# [('В', 'PR'), ('молодости', 'S'), ('при', 'PR'), ('царе', 'S'), ('в', 'PR'), ('гвардии', 'S'), ('служил', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('потом', 'ADV-PRO'), ('кончил', 'V'), ('службу', 'S'), ('и', 'CONJ'), ('уехал', 'V'), ('доживать', 'V'), ('на', 'PR'), ('Дон', 'S'), ('.', 'NONLEX')]
# [('Землю', 'V'), ('ихнюю', 'A=f'), ('на', 'PR'), ('Дону', 'S'), ('казаки', 'S'), ('отобрали', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('пану', 'S'), ('казна', 'S'), ('отрезала', 'V'), ('в', 'PR'), ('Саратовской', 'A=f'), ('губернии', 'S'), ('три', 'NUM=acc'), ('тыщи', 'S'), ('десятин', 'S'), ('.', 'NONLEX')]
# [('Сдавал', 'V'), ('он', 'S-PRO'), ('их', 'S-PRO'), ('в', 'PR'), ('аренду', 'S'), ('саратовским', 'A=pl'), ('мужикам', 'S'), (',', 'NONLEX'), ('сам', 'A-PRO=m'), ('проживал', 'V'), ('в', 'PR'), ('Тополевке', 'S'), ('.', 'NONLEX')]
# [('Диковинный', 'A=m'), ('был', 'V'), ('человек', 'S'), ('.', 'NONLEX')]
# [('Ходил', 'V'), ('завсегда', 'ADV-PRO'), ('в', 'PR'), ('бешмете', 'S'), ('тонкого', 'A=sg'), ('сукна', 'S'), (',', 'NONLEX'), ('при', 'PR'), ('кинжале', 'S'), ('.', 'NONLEX')]
# [('Поедет', 'V'), (',', 'NONLEX'), ('бывало', 'PARENTH'), (',', 'NONLEX'), ('в', 'PR'), ('гости', 'S'), (',', 'NONLEX'), ('выберемся', 'V'), ('из', 'PR'), ('Тополевки', 'S'), (',', 'NONLEX'), ('приказывает', 'V'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Гони', 'S'), (',', 'NONLEX'), ('хамлюга', 'S'), ('!', 'NONLEX')]
# [('Я', 'S-PRO'), ('лошадям', 'S'), ('кнута', 'S'), ('.', 'NONLEX')]
# [('Скачем', 'S'), ('—', 'NONLEX'), ('ветер', 'S'), ('не', 'PART'), ('поспевает', 'V'), ('слезы', 'S'), ('сушить', 'V'), ('.', 'NONLEX')]
# [('Попадется', 'V'), ('середь', 'S'), ('дороги', 'S'), ('ярок', 'S'), (',', 'NONLEX'), ('—', 'NONLEX'), ('водой', 'S'), ('вешней', 'A=comp'), ('их', 'S-PRO'), ('нарежет', 'V'), ('через', 'PR'), ('дорогу', 'S'), ('пропасть', 'S'), (',', 'NONLEX'), ('—', 'NONLEX'), ('передних', 'A=pl'), ('колес', 'S'), ('не', 'PART'), ('слышно', 'PRAEDIC'), (',', 'NONLEX'), ('а', 'CONJ'), ('задние', 'S'), ('только', 'PART'), ('—', 'NONLEX'), ('гах', 'S'), ('!', 'NONLEX'), ('..', 'NONLEX')]
# [('Скрадем', 'V'), ('полверсты', 'S'), (',', 'NONLEX'), ('пан', 'V'), ('ревет', 'S'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Поворачивай', 'V'), ('!', 'NONLEX'), ('»', 'NONLEX'), ('Оберну', 'S'), ('назад', 'ADV'), ('и', 'CONJ'), ('во', 'PR'), ('весь', 'A-PRO=m'), ('опор', 'S'), ('к', 'PR'), ('тому', 'S-PRO'), ('ярку…', 'S'), ('Раз', 'S'), ('до', 'PR'), ('трех', 'NUM=gen'), ('в', 'PR'), ('проклятущем', 'V'), ('побываем', 'V'), (',', 'NONLEX'), ('покель', 'S'), ('изломаем', 'V'), ('лесóрину', 'S'), (',', 'NONLEX'), ('либо', 'CONJ'), ('колеса', 'S'), ('с', 'PR'), ('коляски', 'S'), ('живьем', 'S'), ('сымем', 'S'), ('.', 'NONLEX')]
# [('Тогда', 'ADV-PRO'), ('крякнет', 'V'), ('мой', 'A-PRO=m'), ('пан', 'S'), (',', 'NONLEX'), ('встанет', 'V'), ('и', 'CONJ'), ('идет', 'V'), ('пéшки', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('я', 'S-PRO'), ('следом', 'ADV'), ('коней', 'A=comp'), ('в', 'PR'), ('поводу', 'S'), ('веду', 'S'), ('.', 'NONLEX')]
# [('Была', 'V'), ('у', 'PR'), ('него', 'S-PRO'), ('ишо', 'S'), ('такая', 'A-PRO=f'), ('забава', 'S'), (':', 'NONLEX'), ('выедем', 'V'), ('из', 'PR'), ('имения', 'S'), ('—', 'S'), ('он', 'S-PRO'), ('сядет', 'V'), ('со', 'PR'), ('мной', 'S-PRO'), ('на', 'PR'), ('козлы', 'S'), (',', 'NONLEX'), ('вырвет', 'S'), ('кнут', 'V'), ('из', 'PR'), ('рук', 'S'), ('.', 'NONLEX'), ('«', 'NONLEX'), ('Шевели', 'S'), ('коренного', 'A=m'), ('!', 'NONLEX'), ('..', 'NONLEX'), ('»', 'NONLEX'), ('Я', 'S-PRO'), ('коренника', 'S'), ('раскачиваю', 'V'), ('вовсю', 'ADV'), (',', 'NONLEX'), ('дуга', 'S'), ('не', 'PART'), ('шелохнется', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('он', 'S-PRO'), ('кнутом', 'S'), ('пристяжную', 'V'), ('режет', 'V'), ('.', 'NONLEX')]
# [('Выезд', 'S'), ('был', 'V'), ('тройкой', 'S'), (',', 'NONLEX'), ('в', 'PR'), ('пристяжных', 'A=pl'), ('ходили', 'V'), ('дончаки', 'S'), ('чистых', 'A=pl'), ('кровей', 'S'), (',', 'NONLEX'), ('как', 'CONJ'), ('змеи', 'S'), (',', 'NONLEX'), ('голову', 'S'), ('набок', 'S'), (',', 'NONLEX'), ('землю', 'S'), ('грызут', 'S'), ('.', 'NONLEX')]
# [('И', 'CONJ'), ('вот', 'PART'), ('он', 'S-PRO'), ('кнутом', 'S'), ('полосует', 'V'), ('какую-нибудь', 'A-PRO=f'), ('одну', 'A-PRO=f'), (',', 'NONLEX'), ('сердяга', 'S'), ('пеной', 'A=f'), ('обливается…', 'S'), ('Потом', 'ADV-PRO'), ('кинжал', 'V'), ('вынет', 'V'), (',', 'NONLEX'), ('нагнется', 'V'), ('и', 'CONJ'), ('постромки', 'S'), ('—', 'NONLEX'), ('жик', 'S'), (',', 'NONLEX'), ('как', 'CONJ'), ('волос', 'S'), ('бритвой', 'A=sg'), ('срежет', 'S'), ('.', 'NONLEX')]
# [('Лошадь-то', 'PART'), ('саженя', 'S'), ('два', 'NUM=m'), ('через', 'PR'), ('голову', 'S'), ('летит', 'V'), (',', 'NONLEX'), ('грохнется', 'V'), ('обземь', 'NUM=nom'), (',', 'NONLEX'), ('кровь', 'S'), ('из', 'PR'), ('ноздрей', 'S'), ('потоком', 'S'), ('—', 'S'), ('и', 'CONJ'), ('готова', 'A=f'), ('!', 'NONLEX'), ('..', 'NONLEX')]
# [('Таким', 'A-PRO=m'), ('способом', 'S'), ('и', 'CONJ'), ('другую…', 'S'), ('Коренник', 'S'), ('до', 'PR'), ('той', 'A-PRO=f'), ('поры', 'S'), ('прет', 'S'), (',', 'NONLEX'), ('покеда', 'S'), ('не', 'PART'), ('запалится', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('пану', 'S'), ('хотя', 'PART'), ('бы', 'PART'), ('что', 'S-PRO'), (',', 'NONLEX'), ('ажник', 'S'), ('повеселеет', 'V'), ('малость', 'S'), (',', 'NONLEX'), ('кровица', 'S'), ('так', 'ADV-PRO'), ('и', 'CONJ'), ('заиграет', 'V'), ('на', 'PR'), ('щеках', 'S'), ('.', 'NONLEX')]
# [('Сроду', 'ADV'), ('до', 'PR'), ('места', 'S'), ('прибытия', 'S'), ('не', 'PART'), ('доезжал', 'V'), (':', 'NONLEX'), ('либо', 'CONJ'), ('коляску', 'S'), ('обломает', 'V'), (',', 'NONLEX'), ('либо', 'CONJ'), ('лошадей', 'S'), ('погубит', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('посля', 'S'), ('пéшки', 'S'), ('прет…', 'S'), ('Веселый', 'A=m'), ('был', 'V'), ('пан…', 'V'), ('Дело', 'S'), ('прошлое', 'S'), (',', 'NONLEX'), ('пущай', 'V'), ('нас', 'S-PRO'), ('бог', 'S'), ('судит…', 'S'), ('Присватался', 'V'), ('он', 'S-PRO'), ('к', 'PR'), ('моей', 'A-PRO=sg'), ('бабе', 'S'), (',', 'NONLEX'), ('она', 'S-PRO'), ('в', 'PR'), ('горничных', 'A=pl'), ('состояла', 'V'), ('.', 'NONLEX')]
# [('Прибежит', 'V'), (',', 'NONLEX'), ('бывало', 'PARENTH'), (',', 'NONLEX'), ('в', 'PR'), ('людскую', 'A=f'), ('—', 'S'), ('рубаха', 'S'), ('в', 'PR'), ('шмотьях', 'S'), ('—', 'NONLEX'), ('ревет', 'S'), ('белугой', 'A=f'), ('.', 'NONLEX')]
# [('Гляну', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('у', 'PR'), ('ней', 'S-PRO'), ('все', 'A-PRO=pl'), ('груди', 'S'), ('искусаны', 'V'), (',', 'NONLEX'), ('кожа', 'S'), ('лентами', 'S'), ('висит…', 'V'), ('Раз', 'S'), ('как-то', 'ADV-PRO'), ('посылает', 'V'), ('меня', 'S-PRO'), ('пан', 'S'), ('в', 'PR'), ('ночь', 'S'), ('за', 'PR'), ('фершалом', 'S'), ('.', 'NONLEX')]
# [('Знаю', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('надобности', 'S'), ('нету', 'PRAEDIC'), (',', 'NONLEX'), ('смекнул', 'V'), (',', 'NONLEX'), ('в', 'PR'), ('чем', 'CONJ'), ('дело', 'S'), (',', 'NONLEX'), ('взял', 'V'), ('в', 'PR'), ('степи', 'S'), ('ночи', 'S'), ('дождался', 'V'), ('и', 'CONJ'), ('вернулся', 'V'), ('.', 'NONLEX')]
# [('В', 'PR'), ('имение', 'S'), ('через', 'PR'), ('гумно', 'S'), ('въехал', 'V'), (',', 'NONLEX'), ('бросил', 'V'), ('лошадей', 'S'), ('в', 'PR'), ('саду', 'S'), (',', 'NONLEX'), ('взял', 'V'), ('кнут', 'S'), ('и', 'CONJ'), ('иду', 'V'), ('в', 'PR'), ('людскую', 'A=f'), (',', 'NONLEX'), ('в', 'PR'), ('свою', 'A-PRO=f'), ('каморку', 'S'), ('.', 'NONLEX')]
# [('Дверью', 'S'), ('рыпнул', 'V'), (',', 'NONLEX'), ('серников', 'S'), ('нарочно', 'ADV'), ('не', 'PART'), ('зажигаю', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('слышу', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('на', 'PR'), ('кровати', 'S'), ('возня…', 'S'), ('Тольки', 'S'), ('это', 'S-PRO'), ('приподнялся', 'V'), ('мой', 'A-PRO=m'), ('пан', 'S'), (',', 'NONLEX'), ('я', 'S-PRO'), ('его', 'S-PRO'), ('кнутом', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('кнут', 'V'), ('у', 'PR'), ('меня', 'S-PRO'), ('был', 'V'), ('с', 'PR'), ('свинчаткой', 'S'), ('на', 'PR'), ('конце…', 'S'), ('Слышу', 'S'), ('гребется', 'V'), ('к', 'PR'), ('окну', 'S'), (',', 'NONLEX'), ('я', 'S-PRO'), ('в', 'PR'), ('потемках', 'S'), ('ишо', 'S'), ('раз', 'S'), ('его', 'S-PRO'), ('потянул', 'V'), ('через', 'PR'), ('лоб', 'S'), ('.', 'NONLEX')]
# [('Высигнул', 'V'), ('он', 'S-PRO'), ('в', 'PR'), ('окно', 'S'), (',', 'NONLEX'), ('я', 'S-PRO'), ('маленько', 'ADV'), ('похлестал', 'V'), ('бабу', 'S'), ('и', 'CONJ'), ('лег', 'S'), ('спать', 'V'), ('.', 'NONLEX')]
# [('Дён', 'S'), ('через', 'PR'), ('пять', 'NUM=acc'), ('поехали', 'V'), ('в', 'PR'), ('станицу', 'S'), (';', 'NONLEX'), ('стал', 'V'), ('я', 'S-PRO'), ('пристегивать', 'V'), ('полсть', 'S'), ('на', 'PR'), ('коляске', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('пан', 'S'), ('кнут', 'V'), ('взял', 'V'), ('и', 'CONJ'), ('разглядывает', 'V'), ('конец', 'S'), ('.', 'NONLEX')]
# [('Вертел', 'S'), (',', 'NONLEX'), ('вертел', 'V'), ('в', 'PR'), ('руках', 'S'), (',', 'NONLEX'), ('свинчатку', 'S'), ('нащупал', 'V'), ('и', 'CONJ'), ('спрашивает', 'V'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Ты', 'S-PRO'), (',', 'NONLEX'), ('собачья', 'V'), ('кровь', 'S'), (',', 'NONLEX'), ('на', 'PR'), ('что', 'S-PRO'), ('свинец', 'S'), ('зашил', 'V'), ('в', 'PR'), ('кнут', 'S'), ('?', 'NONLEX')]
# [('—', 'V'), ('Вы', 'S-PRO'), ('сами', 'A-PRO=pl'), ('изволили', 'V'), ('приказать', 'V'), (',', 'NONLEX'), ('—', 'S'), ('отвечаю', 'V'), ('ему', 'S-PRO'), ('.', 'NONLEX')]
# [('Промолчал', 'V'), ('и', 'CONJ'), ('всю', 'A-PRO=f'), ('дорогу', 'S'), ('до', 'PR'), ('первого', 'ANUM=m'), ('ярка', 'S'), ('сквозь', 'PR'), ('зубы', 'S'), ('посвистывает', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('я', 'S-PRO'), ('обернусь', 'V'), ('этак', 'ADV-PRO'), ('мельком', 'ADV'), ('—', 'NONLEX'), ('вижу', 'V'), (':', 'NONLEX'), ('волосы', 'S'), ('на', 'PR'), ('лоб', 'S'), ('спущенные', 'A=pl'), (',', 'NONLEX'), ('и', 'CONJ'), ('фуражка', 'S'), ('глубоко', 'ADV'), ('надвинута…', 'A=m'), ('Года', 'S'), ('через', 'PR'), ('два', 'NUM=m'), ('паралик', 'S'), ('его', 'S-PRO'), ('задушил', 'V'), ('.', 'NONLEX')]
# [('Привезли', 'V'), ('в', 'PR'), ('Усть-Медведицу', 'S'), (',', 'NONLEX'), ('докторов', 'S'), ('поназвали', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('он', 'S-PRO'), ('лежит', 'V'), ('на', 'PR'), ('полу', 'S'), (',', 'NONLEX'), ('почернел', 'V'), ('весь', 'A-PRO=m'), ('.', 'NONLEX')]
# [('Достает', 'V'), ('катериновки', 'S'), ('из', 'PR'), ('кармана', 'S'), ('пачками', 'S'), (',', 'NONLEX'), ('кидает', 'V'), ('на', 'PR'), ('пол', 'S'), (',', 'NONLEX'), ('хрипит', 'V'), ('в', 'PR'), ('одну', 'ANUM=f'), ('душу', 'S'), (':', 'NONLEX'), ('«', 'NONLEX'), ('Лечите', 'S'), (',', 'NONLEX'), ('гады', 'S'), ('!', 'NONLEX')]
# [('Всё', 'S-PRO'), ('отдам', 'V'), ('!', 'NONLEX'), ('..', 'NONLEX'), ('»', 'NONLEX'), ('Царство', 'S'), ('небесное', 'A=n'), (',', 'NONLEX'), ('помер', 'V'), ('с', 'PR'), ('деньгами', 'S'), ('.', 'NONLEX')]
# [('Наследником', 'S'), ('сын-офицер', 'S'), ('остался', 'V'), ('.', 'NONLEX')]
# [('Махоньким', 'A=m'), ('был', 'V'), (',', 'NONLEX'), ('так', 'ADV-PRO'), ('щенят', 'V'), (',', 'NONLEX'), ('бывалоча', 'S'), (',', 'NONLEX'), ('живьем', 'S'), ('свежует', 'V'), ('—', 'S'), ('обдерет', 'S'), ('и', 'CONJ'), ('пустит', 'V'), ('.', 'NONLEX')]
# [('В', 'PR'), ('папашу', 'S'), ('выродился', 'V'), ('.', 'NONLEX')]
# [('А', 'CONJ'), ('подрос', 'S'), ('—', 'NONLEX'), ('перестал', 'V'), ('дурить', 'V'), ('.', 'NONLEX')]
# [('Высокий', 'A=m'), ('был', 'V'), (',', 'NONLEX'), ('тонкий', 'A=m'), (',', 'NONLEX'), ('под', 'PR'), ('глазами', 'S'), ('сроду', 'ADV'), ('черные', 'A=pl'), ('круги', 'S'), (',', 'NONLEX'), ('как', 'CONJ'), ('у', 'PR'), ('бабы…', 'S'), ('Носил', 'V'), ('на', 'PR'), ('носу', 'S'), ('очки', 'S'), ('золотые', 'A=pl'), (',', 'NONLEX'), ('на', 'PR'), ('снурке', 'S'), ('очки-то', 'ADV-PRO'), ('.', 'NONLEX')]
# [('В', 'PR'), ('германскую', 'A=f'), ('войну', 'S'), ('был', 'V'), ('начальником', 'S'), ('над', 'PR'), ('пленными', 'S'), ('в', 'PR'), ('Сибири', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('посля', 'S'), ('переворота', 'S'), ('объявился', 'V'), ('в', 'PR'), ('наших', 'A-PRO=pl'), ('краях', 'S'), ('.', 'NONLEX')]
# [('К', 'PR'), ('тому', 'A-PRO=n'), ('времени', 'S'), ('у', 'PR'), ('меня', 'S-PRO'), ('от', 'PR'), ('покойного', 'A=m'), ('сына', 'S'), ('уж', 'PART'), ('внуки', 'S'), ('были', 'V'), ('в', 'PR'), ('годах', 'S'), (';', 'NONLEX'), ('старшего', 'A=m'), (',', 'NONLEX'), ('Семена', 'S'), (',', 'NONLEX'), ('женил', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('Аникушка', 'S'), ('ходил', 'V'), ('ишо', 'S'), ('в', 'PR'), ('парубках', 'S'), ('.', 'NONLEX')]
# [('При', 'PR'), ('них', 'S-PRO'), ('я', 'S-PRO'), ('проживал', 'V'), (',', 'NONLEX'), ('концы', 'S'), ('жизни', 'S'), ('в', 'PR'), ('узелочек', 'S'), ('завязывал…', 'S'), ('Весной', 'S'), ('обратно', 'ADV'), ('получился', 'V'), ('переворот', 'S'), ('.', 'NONLEX')]
# [('Выгнали', 'V'), ('наши', 'A-PRO=pl'), ('мужики', 'S'), ('молодого', 'A=m'), ('пана', 'S'), ('из', 'PR'), ('имения', 'S'), (',', 'NONLEX'), ('в', 'PR'), ('тот', 'A-PRO=m'), ('же', 'PART'), ('день', 'S'), ('на', 'PR'), ('обчестве', 'S'), ('Семка', 'S'), ('мужиков', 'S'), ('уговаривал', 'V'), ('панские', 'A=pl'), ('угодья', 'S'), ('разделить', 'V'), ('и', 'CONJ'), ('имущество', 'S'), ('забрать', 'V'), ('по', 'PR'), ('домам', 'S'), ('.', 'NONLEX')]
# [('Так', 'ADV-PRO'), ('и', 'CONJ'), ('сделали', 'V'), (':', 'NONLEX'), ('добро', 'S'), ('растянули', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('землю', 'S'), ('порезали', 'V'), ('на', 'PR'), ('делянки', 'S'), ('и', 'CONJ'), ('зачали', 'V'), ('пахать', 'V'), ('.', 'NONLEX')]
# [('Через', 'PR'), ('неделю', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('может', 'PARENTH'), (',', 'NONLEX'), ('и', 'CONJ'), ('меньше', 'NUM=comp'), (',', 'NONLEX'), ('дошел', 'V'), ('слух', 'S'), (',', 'NONLEX'), ('что', 'CONJ'), ('идет', 'V'), ('пан', 'S'), ('с', 'PR'), ('казаками', 'S'), ('наш', 'A-PRO=m'), ('поселок', 'S'), ('вырезать', 'V'), ('.', 'NONLEX')]
# [('Сходом', 'S'), ('послали', 'V'), ('мы', 'S-PRO'), ('две', 'NUM=f'), ('подводы', 'S'), ('на', 'PR'), ('станцию', 'S'), ('за', 'PR'), ('оружием', 'S'), ('.', 'NONLEX')]
# [('На', 'PR'), ('страстной', 'A=f'), ('неделе', 'S'), ('привезли', 'V'), ('от', 'PR'), ('Красной', 'A=f'), ('гвардии', 'S'), ('оружье', 'S'), (',', 'NONLEX'), ('порыли', 'V'), ('за', 'PR'), ('Тополевкой', 'S'), ('окопы', 'S'), ('.', 'NONLEX')]
# [('Протянули', 'V'), ('их', 'A-PRO'), ('ажник', 'S'), ('до', 'PR'), ('панского', 'A=m'), ('пруда', 'S'), ('.', 'NONLEX')]
# [('Видишь', 'V'), (',', 'NONLEX'), ('вон', 'ADV-PRO'), ('там', 'ADV-PRO'), (',', 'NONLEX'), ('где', 'ADV-PRO'), ('чеборец', 'S'), ('растет', 'V'), ('круговинами', 'S'), (',', 'NONLEX'), ('за', 'PR'), ('энтой', 'S'), ('балкой', 'S'), ('и', 'CONJ'), ('легли', 'V'), ('тополевцы', 'S'), ('в', 'PR'), ('окопы', 'S'), ('.', 'NONLEX')]
# [('Были', 'V'), ('там', 'ADV-PRO'), ('и', 'CONJ'), ('мои', 'A-PRO=pl'), ('—', 'S'), ('Семка', 'S'), ('с', 'PR'), ('Аникеем', 'S'), ('.', 'NONLEX')]
# [('Бабы', 'S'), ('с', 'PR'), ('утра', 'S'), ('харчи', 'S'), ('им', 'S-PRO'), ('отнесли', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('солнце', 'S'), ('в', 'PR'), ('дуб', 'S'), ('—', 'S'), ('на', 'PR'), ('бугре', 'S'), ('появилась', 'V'), ('конница', 'S'), ('.', 'NONLEX')]
# [('Рассыпались', 'V'), ('лавой', 'S'), (',', 'NONLEX'), ('засинели', 'V'), ('шашки', 'S'), ('.', 'NONLEX')]
# [('С', 'PR'), ('гумна', 'S'), ('видал', 'V'), ('я', 'S-PRO'), (',', 'NONLEX'), ('как', 'CONJ'), ('передний', 'S'), ('на', 'PR'), ('белом', 'A=m'), ('коне', 'S'), ('махнул', 'V'), ('палашом', 'S'), (',', 'NONLEX'), ('и', 'CONJ'), ('конные', 'A=pl'), ('горохом', 'S'), ('посыпались', 'V'), ('с', 'PR'), ('бугра', 'S'), ('.', 'NONLEX')]
# [('По', 'PR'), ('проходке', 'S'), ('угадал', 'V'), ('я', 'S-PRO'), ('белого', 'A=m'), ('панского', 'A=m'), ('рысака', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('по', 'PR'), ('коню', 'S'), ('узнал', 'V'), ('и', 'CONJ'), ('седока…', 'S'), ('Два', 'NUM=m'), ('раза', 'S'), ('наши', 'A-PRO=pl'), ('сбивали', 'V'), ('их', 'S-PRO'), (',', 'NONLEX'), ('а', 'CONJ'), ('на', 'PR'), ('третий', 'ANUM=m'), ('обошли', 'V'), ('казаки', 'S'), ('сзаду', 'S'), (',', 'NONLEX'), ('хитростью', 'S'), ('взяли', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('пошла', 'V'), ('тут', 'ADV-PRO'), ('сеча…', 'S'), ('Заря', 'S'), ('истухла', 'V'), (',', 'NONLEX'), ('кончился', 'V'), ('бой', 'S'), ('.', 'NONLEX')]
# [('Вышел', 'V'), ('я', 'S-PRO'), ('из', 'PR'), ('хаты', 'S'), ('на', 'PR'), ('улицу', 'S'), (',', 'NONLEX'), ('вижу', 'V'), (':', 'NONLEX'), ('гонят', 'V'), ('конные', 'A=pl'), ('к', 'PR'), ('имению', 'S'), ('кучу', 'S'), ('народу', 'S'), ('.', 'NONLEX')]
# [('Я', 'S-PRO'), ('—', 'NONLEX'), ('костыль', 'S'), ('в', 'PR'), ('руки', 'S'), ('и', 'CONJ'), ('туда', 'ADV-PRO'), ('.', 'NONLEX')]
# [('Во', 'PR'), ('дворе', 'S'), ('наши', 'A-PRO=pl'), ('тополевские', 'A=pl'), ('мужики', 'S'), ('сбились', 'V'), ('в', 'PR'), ('кучу', 'S'), (',', 'NONLEX'), ('не', 'PART'), ('хуже', 'A=comp'), ('как', 'CONJ'), ('вот', 'PART'), ('эти', 'A-PRO=pl'), ('овцы', 'S'), ('.', 'NONLEX')]
# [('Кругом', 'ADV'), ('казаки…', 'S'), ('Подошел', 'S'), (',', 'NONLEX'), ('спрашиваю', 'V'), (':', 'NONLEX'), ('—', 'NONLEX'), ('А', 'CONJ'), ('скажите', 'V'), (',', 'NONLEX'), ('братцы', 'S'), (',', 'NONLEX'), ('где', 'ADV-PRO'), ('мои', 'A-PRO=pl'), ('внуки', 'S'), ('?', 'NONLEX')]
# [('Слышу', 'S'), (',', 'NONLEX'), ('из', 'PR'), ('середки', 'S'), ('откликаются', 'V'), ('обое', 'S'), ('.', 'NONLEX')]
# [('Потолковали', 'V'), ('мы', 'S-PRO'), ('промеж', 'V'), ('себя', 'S-PRO=acc'), ('трошки', 'S'), (';', 'NONLEX'), ('вижу', 'V'), (',', 'NONLEX'), ('выходит', 'V'), ('на', 'PR'), ('крыльцо', 'S'), ('пан', 'S'), ('.', 'NONLEX')]
# [('Увидал', 'V'), ('меня', 'S-PRO'), ('и', 'CONJ'), ('шумит', 'V'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Это', 'S-PRO'), ('ты', 'S-PRO'), (',', 'NONLEX'), ('дед', 'S'), ('Захар', 'S'), ('?', 'NONLEX')]
# [('—', 'ADV'), ('Так', 'ADV-PRO'), ('точно', 'ADV'), (',', 'NONLEX'), ('ваше', 'A-PRO=n'), ('благуродие', 'S'), ('!', 'NONLEX')]
# [('—', 'NONLEX'), ('Зачем', 'ADV-PRO'), ('пришел', 'V'), ('?', 'NONLEX')]
# [('Подхожу', 'V'), ('к', 'PR'), ('крыльцу', 'S'), (',', 'NONLEX'), ('стал', 'V'), ('на', 'PR'), ('колени', 'S'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Внуков', 'S'), ('пришел', 'V'), ('из', 'PR'), ('беды', 'S'), ('выручать', 'V'), ('.', 'NONLEX')]
# [('Поимей', 'V'), ('милость', 'S'), (',', 'NONLEX'), ('пан', 'S'), ('!', 'NONLEX')]
# [('Папаше', 'S'), ('вашему', 'PARENTH'), (',', 'NONLEX'), ('дай', 'V'), ('бог', 'S'), ('царство', 'S'), ('небесное', 'A=n'), (',', 'NONLEX'), ('век', 'S'), ('служил', 'V'), (',', 'NONLEX'), ('вспомни', 'V'), (',', 'NONLEX'), ('пан', 'S'), (',', 'NONLEX'), ('мое', 'A-PRO=sg'), ('усердие', 'S'), (',', 'NONLEX'), ('пожалей', 'S'), ('старость', 'S'), ('!', 'NONLEX'), ('..', 'NONLEX')]
# [('Он', 'S-PRO'), ('и', 'CONJ'), ('говорит', 'V'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Вот', 'PART'), ('что', 'S-PRO'), (',', 'NONLEX'), ('дед', 'S'), ('Захар', 'S'), (',', 'NONLEX'), ('я', 'S-PRO'), ('оченно', 'ADV'), ('уважаю', 'V'), ('твои', 'A-PRO=pl'), ('заслуги', 'S'), ('перед', 'PR'), ('моим', 'A-PRO=sg'), ('папашей', 'S'), (',', 'NONLEX'), ('но', 'CONJ'), ('внуков', 'S'), ('твоих', 'A-PRO=pl'), ('вызволить', 'V'), ('не', 'PART'), ('могу', 'V'), ('.', 'NONLEX')]
# [('Они', 'S-PRO'), ('коренные', 'A=pl'), ('смутьяны', 'S'), ('.', 'NONLEX')]
# [('Смирись', 'V'), (',', 'NONLEX'), ('дед', 'S'), (',', 'NONLEX'), ('духом', 'S'), ('.', 'NONLEX')]
# [('Я', 'S-PRO'), ('ножки', 'S'), ('его', 'A-PRO'), ('обнял', 'V'), (',', 'NONLEX'), ('ползу', 'V'), ('по', 'PR'), ('крыльцу', 'S'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Смилуйся', 'V'), (',', 'NONLEX'), ('пан', 'V'), ('!', 'NONLEX')]
# [('Родимушка', 'S'), ('мой', 'A-PRO=m'), (',', 'NONLEX'), ('вспомни', 'V'), (',', 'NONLEX'), ('как', 'CONJ'), ('дед', 'S'), ('Захар', 'S'), ('тебе', 'S-PRO'), ('услужал', 'V'), (',', 'NONLEX'), ('не', 'PART'), ('губи', 'V'), (',', 'NONLEX'), ('у', 'PR'), ('Семки', 'S'), ('мово', 'ADV'), ('ить', 'V'), ('дите', 'S'), ('грудное', 'A=n'), ('!', 'NONLEX')]
# [('Закурил', 'V'), ('он', 'S-PRO'), ('пахучую', 'V'), ('папироску', 'S'), (',', 'NONLEX'), ('дым', 'S'), ('кверху', 'ADV'), ('пущает', 'V'), ('и', 'CONJ'), ('говорит', 'V'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Поди', 'NONLEX'), ('скажи', 'V'), ('им', 'S-PRO'), (',', 'NONLEX'), ('мерзавцам', 'S'), (',', 'NONLEX'), ('пущай', 'S'), ('придут', 'V'), ('ко', 'PR'), ('мне', 'S-PRO'), ('в', 'PR'), ('комнаты', 'S'), (';', 'NONLEX'), ('ежели', 'CONJ'), ('выпросят', 'V'), ('прощение', 'S'), ('—', 'S'), ('так', 'ADV-PRO'), ('и', 'CONJ'), ('быть', 'V'), (',', 'NONLEX'), ('ради', 'PR'), ('папашиной', 'A=f'), ('памяти', 'S'), (',', 'NONLEX'), ('вкачу', 'V'), ('им', 'S-PRO'), ('розог', 'S'), ('и', 'CONJ'), ('запишу', 'V'), ('в', 'PR'), ('свой', 'A-PRO=m'), ('отряд', 'S'), ('.', 'NONLEX')]
# [('Может', 'PARENTH'), (',', 'NONLEX'), ('они', 'S-PRO'), ('усердием', 'S'), ('и', 'CONJ'), ('покроют', 'V'), ('свою', 'A-PRO=f'), ('страмную', 'A=f'), ('вину', 'S'), ('.', 'NONLEX')]
# [('Я', 'S-PRO'), ('рысью', 'V'), ('во', 'PR'), ('двор', 'S'), (',', 'NONLEX'), ('рассказал', 'V'), ('внукам', 'S'), (',', 'NONLEX'), ('тяну', 'V'), ('их', 'S-PRO'), ('за', 'PR'), ('рукава', 'S'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Идите', 'V'), (',', 'NONLEX'), ('дурные', 'A=pl'), (',', 'NONLEX'), ('с', 'PR'), ('земли', 'S'), ('не', 'PART'), ('вставайте', 'V'), (',', 'NONLEX'), ('покеда', 'S'), ('не', 'PART'), ('простит', 'V'), ('!', 'NONLEX')]
# [('Семен', 'S'), ('хоть', 'PART'), ('бы', 'PART'), ('голову', 'S'), ('поднял', 'V'), ('.', 'NONLEX')]
# [('Сидит', 'V'), ('на', 'PR'), ('припечках', 'S'), ('и', 'CONJ'), ('былкой', 'A=f'), ('землю', 'S'), ('ковыряет', 'V'), ('.', 'NONLEX')]
# [('Аникушка', 'S'), ('глядел-глядел', 'S'), ('на', 'PR'), ('меня', 'S-PRO'), ('да', 'CONJ'), ('как', 'ADV-PRO'), ('брякнет', 'V'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Поди', 'PARENTH'), (',', 'NONLEX'), ('—', 'S'), ('говорит', 'V'), (',', 'NONLEX'), ('—', 'NONLEX'), ('к', 'PR'), ('своему', 'A-PRO=m'), ('пану', 'S'), ('и', 'CONJ'), ('скажи', 'V'), ('ему', 'S-PRO'), (':', 'NONLEX'), ('мол', 'PARENTH'), (',', 'NONLEX'), ('дед', 'S'), ('Захар', 'S'), ('на', 'PR'), ('коленях', 'S'), ('всю', 'A-PRO=f'), ('жисть', 'S'), ('полозил', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('сын', 'S'), ('его', 'A-PRO'), ('полозил', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('внуки', 'S'), ('уже', 'ADV'), ('не', 'PART'), ('хочут', 'V'), ('.', 'NONLEX')]
# [('Так', 'ADV-PRO'), ('и', 'CONJ'), ('передай', 'V'), ('!', 'NONLEX')]
# [('—', 'S'), ('Не', 'PART'), ('пойдешь', 'V'), (',', 'NONLEX'), ('сучий', 'A=sg'), ('сын', 'S'), ('?', 'NONLEX')]
# [('—', 'S'), ('Не', 'PART'), ('пойду', 'V'), ('!', 'NONLEX')]
# [('—', 'NONLEX'), ('Тебе', 'S-PRO'), (',', 'NONLEX'), ('поганцу', 'S'), (',', 'NONLEX'), ('жить-помирать', 'V'), ('—', 'S'), ('один', 'A-PRO=m'), ('алтын', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('Семку', 'S'), ('куда', 'ADV-PRO'), ('тянешь', 'V'), ('?', 'NONLEX')]
# [('На', 'PR'), ('кого', 'S-PRO'), ('бабу', 'S'), ('с', 'PR'), ('дитем', 'S'), ('кинет', 'V'), ('?', 'NONLEX')]
# [('Вижу', 'V'), (',', 'NONLEX'), ('у', 'PR'), ('Семена', 'S'), ('затряслись', 'V'), ('руки', 'S'), (',', 'NONLEX'), ('копает', 'V'), ('землю', 'S'), ('былкой', 'A=f'), (',', 'NONLEX'), ('ищет', 'V'), ('там', 'ADV-PRO'), ('неположенного', 'A=m'), (',', 'NONLEX'), ('сам', 'A-PRO=m'), ('молчит', 'V'), ('.', 'NONLEX')]
# [('Молчит', 'V'), (',', 'NONLEX'), ('как', 'CONJ'), ('бык', 'S'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Иди', 'V'), (',', 'NONLEX'), ('дедушка', 'S'), (',', 'NONLEX'), ('не', 'PART'), ('квели', 'V'), ('нас', 'S-PRO'), (',', 'NONLEX'), ('—', 'S'), ('просит', 'V'), ('Аникей', 'S'), ('.', 'NONLEX')]
# [('—', 'S'), ('Не', 'PART'), ('пойду', 'V'), (',', 'NONLEX'), ('гад', 'S'), ('твоей', 'A-PRO=sg'), ('морде', 'S'), ('!', 'NONLEX')]
# [('Анисья', 'S'), ('Семкина', 'S'), ('руки', 'S'), ('на', 'PR'), ('себя', 'S-PRO=acc'), ('наложит', 'V'), ('в', 'PR'), ('случае', 'S'), ('чего', 'S-PRO'), ('!', 'NONLEX'), ('..', 'NONLEX')]
# [('У', 'PR'), ('Семена', 'S'), ('былка-то', 'ADV'), ('в', 'PR'), ('руках', 'S'), ('хрусть', 'S'), ('—', 'S'), ('и', 'CONJ'), ('сломилась', 'V'), ('.', 'NONLEX')]
# [('Жду', 'V'), ('.', 'NONLEX')]
# [('Обратно', 'ADV'), ('молчат', 'V'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Семушка', 'S'), (',', 'NONLEX'), ('опомнись', 'V'), (',', 'NONLEX'), ('кормилец', 'S'), ('мой', 'A-PRO=m'), ('!', 'NONLEX')]
# [('Иди', 'V'), ('к', 'PR'), ('пану', 'S'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Опомнились', 'V'), ('!', 'NONLEX')]
# [('Не', 'PART'), ('пойдем', 'V'), ('!', 'NONLEX')]
# [('Иди', 'V'), ('полозь', 'ADV'), ('ты', 'S-PRO'), ('!', 'NONLEX')]
# [('—', 'NONLEX'), ('лютует', 'V'), ('Аникушка', 'S'), ('.', 'NONLEX')]
# [('Я', 'S-PRO'), ('и', 'CONJ'), ('говорю', 'V'), (':', 'NONLEX'), ('—', 'S'), ('Попрекаешь', 'V'), ('тем', 'S-PRO'), (',', 'NONLEX'), ('что', 'CONJ'), ('перед', 'PR'), ('паном', 'S'), ('на', 'PR'), ('коленках', 'S'), ('стоял', 'V'), ('?', 'NONLEX')]
# [('Что', 'S-PRO'), ('ж', 'PART'), (',', 'NONLEX'), ('я', 'S-PRO'), ('человек', 'S'), ('старый', 'A=m'), (',', 'NONLEX'), ('вместо', 'PR'), ('материной', 'A=f'), ('титьки', 'S'), ('панский', 'A=m'), ('кнут', 'S'), ('сосал…', 'S'), ('Не', 'PART'), ('погребую', 'V'), ('и', 'CONJ'), ('перед', 'PR'), ('родными', 'A=pl'), ('внуками', 'S'), ('на', 'PR'), ('колени', 'S'), ('стать', 'V'), ('.', 'NONLEX')]
# [('Стал', 'V'), ('на', 'PR'), ('колени', 'S'), (',', 'NONLEX'), ('земно', 'ADV'), ('кланяюсь', 'V'), (',', 'NONLEX'), ('прошу', 'V'), ('.', 'NONLEX')]
# [('Мужики', 'S'), ('отвернулись', 'V'), (',', 'NONLEX'), ('быдто', 'CONJ'), ('и', 'CONJ'), ('не', 'PART'), ('видят', 'V'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Уйди', 'V'), (',', 'NONLEX'), ('дед…', 'S'), ('Уйди', 'V'), (',', 'NONLEX'), ('убью', 'V'), ('!', 'NONLEX')]
# [('—', 'NONLEX'), ('орет', 'V'), ('Аникушка', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('у', 'PR'), ('самого', 'A-PRO=m'), ('пена', 'S'), ('на', 'PR'), ('губах', 'S'), ('и', 'CONJ'), ('глаза', 'S'), ('дикие', 'A=pl'), (',', 'NONLEX'), ('как', 'CONJ'), ('у', 'PR'), ('заарканенного', 'A=m'), ('волка', 'S'), ('.', 'NONLEX')]
# [('Повернулся', 'V'), ('я', 'S-PRO'), ('и', 'CONJ'), ('опять', 'ADV'), ('к', 'PR'), ('пану', 'S'), ('.', 'NONLEX')]
# [('Ножки', 'S'), ('его', 'A-PRO'), ('прижал', 'V'), ('к', 'PR'), ('грудям', 'S'), ('—', 'S'), ('не', 'PART'), ('отпихнет', 'V'), (',', 'NONLEX'), ('руки', 'S'), ('закаменели', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('уж', 'PART'), ('слова', 'S'), ('не', 'PART'), ('выговорю', 'V'), ('.', 'NONLEX')]
# [('Спрашивает', 'V'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Где', 'ADV-PRO'), ('же', 'PART'), ('внуки', 'S'), ('?', 'NONLEX')]
# [('—', 'NONLEX'), ('Боятся', 'V'), (',', 'NONLEX'), ('пан…', 'V'), ('—', 'S'), ('А', 'INIT=abbr'), (',', 'NONLEX'), ('боятся…', 'S'), ('—', 'S'), ('и', 'CONJ'), ('больше', 'ADV'), ('ничего', 'S-PRO'), ('не', 'PART'), ('сказал', 'V'), ('.', 'NONLEX')]
# [('Сапожком', 'S'), ('своим', 'A-PRO=m'), ('ударил', 'V'), ('меня', 'S-PRO'), ('прямо', 'ADV'), ('в', 'PR'), ('рот', 'S'), ('и', 'CONJ'), ('пошел', 'V'), ('на', 'PR'), ('крыльцо', 'S'), ('.', 'NONLEX')]
# [('Дед', 'S'), ('Захар', 'S'), ('задышал', 'V'), ('порывисто', 'ADV'), ('и', 'CONJ'), ('часто', 'ADV'), (';', 'NONLEX'), ('на', 'PR'), ('минутку', 'S'), ('лицо', 'S'), ('его', 'A-PRO'), ('сморщилось', 'V'), ('и', 'CONJ'), ('побелело', 'V'), (';', 'NONLEX'), ('страшным', 'A=n'), ('усилием', 'S'), ('задушив', 'V'), ('короткое', 'A=n'), (',', 'NONLEX'), ('старческое', 'A=sg'), ('рыданье', 'S'), (',', 'NONLEX'), ('он', 'S-PRO'), ('вытер', 'V'), ('ладонью', 'S'), ('сухие', 'A=pl'), ('губы', 'S'), (',', 'NONLEX'), ('отвернулся', 'V'), ('.', 'NONLEX')]
# [('В', 'PR'), ('стороне', 'S'), ('за', 'PR'), ('музгой', 'S'), ('коршун', 'S'), (',', 'NONLEX'), ('косо', 'ADV'), ('распластав', 'V'), ('крылья', 'S'), (',', 'NONLEX'), ('ударился', 'V'), ('в', 'PR'), ('траву', 'S'), ('и', 'CONJ'), ('приподнял', 'V'), ('над', 'PR'), ('землей', 'S'), ('белогрудого', 'A=m'), ('стрепета', 'S'), ('.', 'NONLEX')]
# [('Перья', 'S'), ('упали', 'V'), ('снежными', 'A=pl'), ('лохмотьями', 'S'), (',', 'NONLEX'), ('блеск', 'S'), ('их', 'S-PRO'), ('на', 'PR'), ('траве', 'S'), ('был', 'V'), ('нестерпимо', 'ADV'), ('резок', 'S'), ('и', 'CONJ'), ('колюч', 'S'), ('.', 'NONLEX')]
# [('Дед', 'S'), ('Захар', 'S'), ('высморкался', 'V'), ('и', 'CONJ'), (',', 'NONLEX'), ('вытерев', 'V'), ('пальцы', 'S'), ('о', 'PR'), ('подол', 'S'), ('вязаной', 'A=f'), ('рубахи', 'S'), (',', 'NONLEX'), ('снова', 'ADV'), ('заговорил', 'V'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Вышел', 'V'), ('я', 'S-PRO'), ('следом', 'ADV'), ('на', 'PR'), ('крыльцо', 'S'), (',', 'NONLEX'), ('глядь', 'S'), ('—', 'NONLEX'), ('Аниська', 'S'), ('Семенова', 'S'), ('с', 'PR'), ('дитем', 'S'), ('бежит', 'V'), ('.', 'NONLEX')]
# [('Не', 'PART'), ('хуже', 'A=comp'), (',', 'NONLEX'), ('как', 'CONJ'), ('этот', 'A-PRO=m'), ('коршун', 'S'), (',', 'NONLEX'), ('вдарилась', 'V'), ('она', 'S-PRO'), ('об', 'PR'), ('мужа', 'S'), ('и', 'CONJ'), ('пристыла', 'V'), ('у', 'PR'), ('него', 'S-PRO'), ('на', 'PR'), ('руках…', 'S'), ('Подозвал', 'V'), ('пан', 'S'), ('вахмистра', 'S'), (',', 'NONLEX'), ('указывает', 'V'), ('на', 'PR'), ('Семена', 'S'), ('с', 'PR'), ('Аникушкой', 'S'), ('.', 'NONLEX')]
# [('Вахмистр', 'S'), (',', 'NONLEX'), ('с', 'PR'), ('ним', 'S-PRO'), ('шесть', 'NUM=acc'), ('казаков', 'S'), (',', 'NONLEX'), ('взяли', 'V'), ('их', 'S-PRO'), ('и', 'CONJ'), ('повели', 'V'), ('в', 'PR'), ('панскую', 'A=f'), ('леваду', 'S'), ('.', 'NONLEX')]
# [('Я', 'S-PRO'), ('следом', 'ADV'), ('иду', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('Аниська', 'S'), ('дитя', 'S'), ('кинула', 'V'), ('посередь', 'S'), ('двора', 'S'), ('и', 'CONJ'), ('за', 'PR'), ('паном', 'S'), ('волокется', 'V'), ('.', 'NONLEX')]
# [('Семен', 'S'), ('попереди', 'V'), ('всех', 'S-PRO'), ('шибко-шибко', 'ADV'), ('идет', 'V'), (',', 'NONLEX'), ('дошел', 'V'), ('до', 'PR'), ('конюшни', 'S'), ('и', 'CONJ'), ('сел', 'V'), ('.', 'NONLEX'), ('—', 'S'), ('Ты', 'S-PRO'), ('чего', 'ADV-PRO'), ('это', 'S-PRO'), ('?', 'NONLEX')]
# [('—', 'NONLEX'), ('спрашивает', 'V'), ('пан', 'S'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Сапог', 'S'), ('ногу', 'S'), ('жмет', 'V'), (',', 'NONLEX'), ('мóчи', 'S'), ('нет', 'PRAEDIC'), (',', 'NONLEX'), ('—', 'S'), ('и', 'CONJ'), ('улыбается', 'V'), ('.', 'NONLEX')]
# [('Снял', 'V'), ('сапоги', 'S'), (',', 'NONLEX'), ('подает', 'V'), ('мне', 'S-PRO'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Носи', 'V'), (',', 'NONLEX'), ('дедушка', 'S'), (',', 'NONLEX'), ('на', 'PR'), ('доброе', 'A=n'), ('здоровье', 'S'), ('.', 'NONLEX')]
# [('На', 'PR'), ('них', 'S-PRO'), ('подошвы', 'V'), ('двойные', 'A=pl'), (',', 'NONLEX'), ('добрые', 'A=pl'), ('.', 'NONLEX')]
# [('Забрал', 'V'), ('я', 'S-PRO'), ('эти', 'A-PRO=pl'), ('сапоги', 'S'), (',', 'NONLEX'), ('опять', 'ADV'), ('идем', 'V'), ('.', 'NONLEX')]
# [('Поравнялись', 'V'), ('с', 'PR'), ('огорожей', 'S'), (',', 'NONLEX'), ('поставили', 'V'), ('их', 'S-PRO'), ('к', 'PR'), ('плетню', 'S'), (',', 'NONLEX'), ('казаки', 'S'), ('ружья', 'S'), ('заряжают', 'V'), (',', 'NONLEX'), ('пан', 'S'), ('стоит', 'V'), ('около', 'PR'), (',', 'NONLEX'), ('ноготки', 'S'), ('на', 'PR'), ('пальцах', 'S'), ('махонькими', 'A=pl'), ('ножничками', 'S'), ('обрезает', 'V'), (',', 'NONLEX'), ('и', 'CONJ'), ('ручка', 'S'), ('ихняя', 'A=f'), ('очень', 'ADV'), ('белая', 'A=f'), ('.', 'NONLEX')]
# [('Говорю', 'V'), ('я', 'S-PRO'), ('ему', 'S-PRO'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Дозвольте', 'V'), (',', 'NONLEX'), ('пан', 'S'), (',', 'NONLEX'), ('посымать', 'V'), ('им', 'S-PRO'), ('одежу', 'S'), ('.', 'NONLEX')]
# [('Одежа', 'V'), ('на', 'PR'), ('них', 'S-PRO'), ('добрая', 'A=f'), (',', 'NONLEX'), ('нам', 'S-PRO'), ('по', 'PR'), ('бедности', 'S'), ('сгодится', 'V'), (',', 'NONLEX'), ('сносим', 'V'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Пущай', 'S'), ('сымают', 'V'), ('.', 'NONLEX')]
# [('Снял', 'V'), ('Аникушка', 'S'), ('шаровары', 'S'), (',', 'NONLEX'), ('вывернул', 'V'), ('наизнанку', 'S'), ('и', 'CONJ'), ('повесил', 'V'), ('на', 'PR'), ('колышек', 'S'), ('плетня', 'S'), ('.', 'NONLEX')]
# [('Из', 'PR'), ('кармана', 'S'), ('вынул', 'V'), ('кисет', 'S'), (',', 'NONLEX'), ('закурил', 'V'), (',', 'NONLEX'), ('стоит', 'V'), (',', 'NONLEX'), ('ногу', 'S'), ('отставил', 'V'), ('и', 'CONJ'), ('дым', 'S'), ('колечками', 'S'), ('пущает', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('плюет', 'V'), ('через', 'PR'), ('плетень…', 'S'), ('Семен', 'S'), ('растелешился', 'V'), ('догола', 'S'), (',', 'NONLEX'), ('исподники', 'S'), ('холщовые', 'A=pl'), ('—', 'S'), ('и', 'CONJ'), ('то', 'S-PRO'), ('снял', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('шапку-то', 'ADV-PRO'), ('позабыл', 'V'), ('снять', 'V'), (',', 'NONLEX'), ('знать', 'V'), ('замстило…', 'S'), ('Меня', 'S-PRO'), ('то', 'CONJ'), ('морозом', 'S'), ('дерет', 'S'), (',', 'NONLEX'), ('то', 'CONJ'), ('в', 'PR'), ('жар', 'S'), ('кинет', 'V'), ('.', 'NONLEX')]
# [('Лапну', 'V'), ('себя', 'S-PRO=acc'), ('за', 'PR'), ('голову', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('пот', 'S'), ('зачем-то', 'ADV-PRO'), ('холодный', 'A=m'), (',', 'NONLEX'), ('как', 'CONJ'), ('родниковая', 'A=f'), ('вода…', 'S'), ('Гляну', 'S'), ('—', 'S'), ('стоят', 'V'), ('рядушком…', 'S'), ('У', 'PR'), ('Семена', 'S'), ('грудь', 'S'), ('вся', 'A-PRO=f'), ('дремучим', 'A=m'), ('волосом', 'S'), ('поросла', 'V'), (',', 'NONLEX'), ('голый', 'A=m'), (',', 'NONLEX'), ('а', 'CONJ'), ('на', 'PR'), ('голове', 'S'), ('шапка…', 'S'), ('Анисья', 'S'), (',', 'NONLEX'), ('по', 'PR'), ('бабьему', 'A=n'), ('положению', 'S'), (',', 'NONLEX'), ('глянула', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('стоит', 'V'), ('муж', 'S'), ('такой', 'A-PRO=m'), ('нáгий', 'A=m'), ('и', 'CONJ'), ('в', 'PR'), ('шапке', 'S'), (',', 'NONLEX'), ('как', 'ADV-PRO'), ('кинется', 'V'), ('к', 'PR'), ('нему', 'S-PRO'), (',', 'NONLEX'), ('обвилась', 'V'), (',', 'NONLEX'), ('ровно', 'ADV'), ('хмель', 'S'), ('вокруг', 'PR'), ('дуба', 'S'), ('.', 'NONLEX')]
# [('Семен', 'S'), ('от', 'PR'), ('себя', 'S-PRO=gen'), ('ее', 'ADV'), ('отпихивает', 'V'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Уйди', 'V'), (',', 'NONLEX'), ('шалава', 'S'), ('!', 'NONLEX'), ('..', 'NONLEX')]
# [('Опомнись', 'V'), (',', 'NONLEX'), ('на', 'PR'), ('людях-то', 'A-PRO=f'), ('!', 'NONLEX'), ('..', 'NONLEX')]
# [('Повылазило', 'V'), ('тебе', 'S-PRO'), (',', 'NONLEX'), ('не', 'PART'), ('видишь', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('я', 'S-PRO'), ('очень', 'ADV'), ('голый…', 'A=m'), ('совестно…', 'S'), ('Она', 'S-PRO'), ('же', 'PART'), ('раскосматилась', 'V'), (',', 'NONLEX'), ('ревет', 'V'), ('в', 'PR'), ('одну', 'ANUM=f'), ('душу', 'S'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Стреляйте', 'V'), ('обех', 'V'), ('нас', 'S-PRO'), ('!', 'NONLEX'), ('..', 'NONLEX')]
# [('Пан', 'S'), ('ножнички', 'S'), ('свои', 'A-PRO=pl'), ('положил', 'V'), ('в', 'PR'), ('кармашек', 'S'), (',', 'NONLEX'), ('спрашивает', 'V'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Стрелять', 'V'), ('?', 'NONLEX')]
# [('—', 'NONLEX'), ('Стреляй', 'V'), (',', 'NONLEX'), ('проклятый', 'A=m'), ('!', 'NONLEX'), ('..', 'NONLEX')]
# [('Это', 'S-PRO'), ('на', 'PR'), ('пана-то', 'S-PRO'), ('!', 'NONLEX')]
# [('—', 'NONLEX'), ('Привяжите', 'V'), ('ее', 'S'), ('к', 'PR'), ('мужу', 'S'), ('!', 'NONLEX')]
# [('—', 'NONLEX'), ('приказывает', 'V'), ('.', 'NONLEX')]
# [('Анисья', 'S'), ('опамятовалась', 'V'), ('да', 'CONJ'), ('назад', 'ADV'), (',', 'NONLEX'), ('ан', 'CONJ'), ('не', 'PART'), ('тут-то', 'S-PRO'), ('было', 'V'), ('.', 'NONLEX')]
# [('Казаки', 'S'), ('смеются', 'V'), (',', 'NONLEX'), ('вяжут', 'V'), ('ее', 'S'), ('к', 'PR'), ('Семену', 'S'), ('недоуздком…', 'S'), ('Упала', 'V'), (',', 'NONLEX'), ('глупая', 'A=sg'), (',', 'NONLEX'), ('наземь', 'ADV'), ('и', 'CONJ'), ('мужа', 'S'), ('свалила…', 'S'), ('Пан', 'S'), ('подошел', 'S'), (',', 'NONLEX'), ('скрозь', 'ADV'), ('зубы', 'S'), ('спрашивает', 'V'), (':', 'NONLEX'), ('—', 'S'), ('Может', 'V'), (',', 'NONLEX'), ('ради', 'PR'), ('дитя', 'S'), (',', 'NONLEX'), ('какое', 'A-PRO=sg'), ('осталось', 'V'), (',', 'NONLEX'), ('попросишь', 'V'), ('прощенья', 'S'), ('?', 'NONLEX')]
# [('—', 'NONLEX'), ('Попрошу', 'V'), (',', 'NONLEX'), ('—', 'S'), ('стонает', 'V'), ('Семен', 'S'), ('.', 'NONLEX')]
# [('—', 'NONLEX'), ('Ну', 'PART'), (',', 'NONLEX'), ('попроси', 'V'), (',', 'NONLEX'), ('только', 'PART'), ('у', 'PR'), ('бога…', 'S'), ('опоздал', 'V'), ('у', 'PR'), ('меня', 'S-PRO'), ('просить', 'V'), ('!', 'NONLEX'), ('..', 'NONLEX')]
# [('На', 'PR'), ('земле', 'S'), ('лежачих', 'A=pl'), ('их', 'S-PRO'), ('и', 'CONJ'), ('побили…', 'V'), ('Аникушка', 'S'), ('после', 'PR'), ('выстрелов', 'S'), ('закачался', 'V'), ('на', 'PR'), ('ногах', 'S'), (',', 'NONLEX'), ('но', 'CONJ'), ('упал', 'V'), ('не', 'PART'), ('сразу', 'ADV'), ('.', 'NONLEX')]
# [('Спервоначалу', 'S'), ('на', 'PR'), ('колени', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('потом', 'ADV-PRO'), ('резко', 'ADV'), ('обернулся', 'V'), ('и', 'CONJ'), ('лег', 'V'), ('вверх', 'ADV'), ('лицом', 'S'), ('.', 'NONLEX')]
# [('Пан', 'S'), ('подошел', 'S'), (',', 'NONLEX'), ('спрашивает', 'V'), ('очень', 'ADV'), ('ласково', 'ADV'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Хочешь', 'V'), ('жить', 'V'), ('?', 'NONLEX')]
# [('Коли', 'S'), ('хочешь', 'V'), ('—', 'S'), ('проси', 'V'), ('прощенья', 'S'), ('.', 'NONLEX')]
# [('Так', 'ADV-PRO'), ('и', 'CONJ'), ('быть', 'V'), (',', 'NONLEX'), ('полсотни', 'V'), ('розог', 'S'), ('—', 'S'), ('и', 'CONJ'), ('на', 'PR'), ('фронт', 'S'), ('.', 'NONLEX')]
# [('Набрал', 'V'), ('Аникушка', 'S'), ('слюней', 'A=f'), ('полон', 'S'), ('рот', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('доплюнуть', 'V'), ('силов', 'S'), ('не', 'PART'), ('хватило', 'V'), (',', 'NONLEX'), ('по', 'PR'), ('бороде', 'S'), ('потекли…', 'S'), ('Побелел', 'V'), ('весь', 'A-PRO=m'), ('от', 'PR'), ('злости', 'S'), (',', 'NONLEX'), ('только', 'CONJ'), ('куда', 'ADV-PRO'), ('уж…', 'V'), ('три', 'NUM=acc'), ('пули', 'S'), ('его', 'A-PRO'), ('продырявили…', 'S'), ('—', 'NONLEX'), ('Перетяните', 'V'), ('его', 'S-PRO'), ('на', 'PR'), ('дорогу', 'S'), ('!', 'NONLEX')]
# [('—', 'NONLEX'), ('приказывает', 'V'), ('пан', 'S'), ('.', 'NONLEX')]
# [('Поволокли', 'V'), ('его', 'S-PRO'), ('казаки', 'S'), ('и', 'CONJ'), ('кинули', 'V'), ('через', 'PR'), ('плетень', 'S'), (',', 'NONLEX'), ('поперек', 'S'), ('дороги', 'S'), ('.', 'NONLEX')]
# [('Тем', 'A-PRO=pl'), ('часом', 'S'), ('в', 'PR'), ('станицу', 'S'), ('из', 'PR'), ('Тополевки', 'S'), ('ехала', 'V'), ('сотня', 'S'), ('казаков', 'S'), (',', 'NONLEX'), ('при', 'PR'), ('них', 'S-PRO'), ('две', 'NUM=f'), ('пушки', 'S'), ('.', 'NONLEX')]
# [('Пан', 'S'), ('на', 'PR'), ('плетень', 'S'), (',', 'NONLEX'), ('как', 'CONJ'), ('кочет', 'S'), (',', 'NONLEX'), ('вскочил', 'V'), (',', 'NONLEX'), ('звонко', 'S'), ('кричит', 'V'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Ездовый', 'A=m'), (',', 'NONLEX'), ('ры-сью', 'S'), (',', 'NONLEX'), ('не', 'PART'), ('объезжать', 'V'), ('!', 'NONLEX'), ('..', 'NONLEX')]
# [('На', 'PR'), ('мне', 'S-PRO'), ('волосы', 'S'), ('встали', 'V'), ('дыбом', 'S'), ('.', 'NONLEX')]
# [('Держу', 'S'), ('в', 'PR'), ('руках', 'S'), ('Семенову', 'S'), ('одежу', 'V'), ('и', 'CONJ'), ('сапоги', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('ноги', 'S'), ('не', 'PART'), ('держат', 'V'), (',', 'NONLEX'), ('гнутся…', 'S'), ('Лошади', 'S'), (',', 'NONLEX'), ('они', 'S-PRO'), ('имеют', 'V'), ('божью', 'S'), ('искру', 'S'), (',', 'NONLEX'), ('ни', 'PART'), ('одна', 'A-PRO=f'), ('на', 'PR'), ('Аникушку', 'S'), ('не', 'PART'), ('ступнула', 'V'), (',', 'NONLEX'), ('сигают', 'V'), ('через…', 'S'), ('Припал', 'V'), ('я', 'S-PRO'), ('к', 'PR'), ('плетню', 'S'), (',', 'NONLEX'), ('глаза', 'S'), ('не', 'PART'), ('могу', 'V'), ('закрыть', 'V'), (',', 'NONLEX'), ('во', 'PR'), ('рту', 'S'), ('спеклось…', 'S'), ('Колеса', 'S'), ('пушки', 'S'), ('попали', 'V'), ('на', 'PR'), ('ноги', 'S'), ('Аникею…', 'S'), ('Захрустели', 'S'), ('они', 'S-PRO'), (',', 'NONLEX'), ('как', 'CONJ'), ('ржаной', 'A=f'), ('сухарь', 'S'), ('на', 'PR'), ('зубах', 'S'), (',', 'NONLEX'), ('измялись', 'V'), ('в', 'PR'), ('тоненькие', 'A=pl'), ('трощинки…', 'S'), ('Думал', 'S'), (',', 'NONLEX'), ('помрет', 'S'), ('Аникей', 'S'), ('от', 'PR'), ('смертной', 'A=f'), ('боли', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('он', 'S-PRO'), ('хоть', 'PART'), ('бы', 'PART'), ('крикнул', 'V'), (',', 'NONLEX'), ('хоть', 'PART'), ('бы', 'PART'), ('стон', 'S'), ('уронил…', 'S'), ('Лежит', 'S'), (',', 'NONLEX'), ('голову', 'S'), ('плотно', 'ADV'), ('прижал', 'V'), (',', 'NONLEX'), ('землю', 'S'), ('с', 'PR'), ('дороги', 'S'), ('пригоршнями', 'S'), ('в', 'PR'), ('рот', 'S'), ('пихает…', 'S'), ('Землю', 'S'), ('жует', 'V'), ('и', 'CONJ'), ('смотрит', 'V'), ('на', 'PR'), ('пана', 'S'), (',', 'NONLEX'), ('глазом', 'S'), ('не', 'PART'), ('сморгнет', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('глаза', 'S'), ('ясные', 'A=pl'), (',', 'NONLEX'), ('светлые', 'A=pl'), (',', 'NONLEX'), ('как', 'CONJ'), ('небушко…', 'S'), ('Тридцать', 'NUM=acc'), ('два', 'NUM=m'), ('человека', 'S'), ('в', 'PR'), ('тот', 'A-PRO=m'), ('день', 'S'), ('расстрелял', 'V'), ('пан', 'S'), ('Томилин', 'S'), ('.', 'NONLEX')]
# [('Один', 'A-PRO=m'), ('Аникей', 'S'), ('живой', 'A=m'), ('остался', 'V'), ('через', 'PR'), ('гордость', 'S'), ('свою…', 'A=m'), ('Дед', 'S'), ('Захар', 'S'), ('пил', 'V'), ('из', 'PR'), ('баклаги', 'S'), ('долго', 'ADV'), ('и', 'CONJ'), ('жадно', 'ADV'), ('.', 'NONLEX')]
# [('Утирая', 'V'), ('выцветшие', 'V'), ('губы', 'S'), (',', 'NONLEX'), ('нехотя', 'ADV'), ('докончил', 'V'), (':', 'NONLEX'), ('—', 'NONLEX'), ('Быльем', 'S'), ('поросло', 'V'), ('это', 'S-PRO'), ('.', 'NONLEX')]
# [('Остались', 'V'), ('одни', 'A-PRO=pl'), ('окопы', 'S'), (',', 'NONLEX'), ('в', 'PR'), ('каких', 'A-PRO=pl'), ('наши', 'A-PRO=pl'), ('мужики', 'S'), ('землю', 'S'), ('себе', 'S-PRO=dat'), ('завоевывали', 'V'), ('.', 'NONLEX')]
# [('Растет', 'S'), ('в', 'PR'), ('них', 'S-PRO'), ('мурава', 'S'), ('да', 'CONJ'), ('краснобыл', 'S'), ('степной…', 'V'), ('Аникею', 'S'), ('ноги', 'S'), ('отняли', 'V'), (',', 'NONLEX'), ('ходит', 'V'), ('он', 'S-PRO'), ('теперя', 'S'), ('на', 'PR'), ('руках', 'S'), (',', 'NONLEX'), ('туловищу', 'S'), ('по', 'PR'), ('земле', 'S'), ('тягает', 'V'), ('.', 'NONLEX')]
# [('С', 'PR'), ('виду', 'S'), ('—', 'S'), ('веселый', 'A=m'), (',', 'NONLEX'), ('с', 'PR'), ('Семеновым', 'S'), ('парнишкой', 'S'), ('кажин', 'NONLEX'), ('день', 'S'), ('возле', 'PR'), ('притолоки', 'S'), ('меряются', 'V'), ('.', 'NONLEX')]
# [('Парнишка-то', 'ADV-PRO'), ('перерастает', 'V'), ('его…', 'S'), ('Зимой', 'S'), (',', 'NONLEX'), ('бывало', 'PARENTH'), (',', 'NONLEX'), ('вылезет', 'V'), ('на', 'PR'), ('проулок', 'S'), (',', 'NONLEX'), ('люди', 'S'), ('скотину', 'ADV'), ('к', 'PR'), ('речке', 'S'), ('гонят', 'V'), ('поить', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('он', 'S-PRO'), ('подымет', 'V'), ('руки', 'S'), ('и', 'CONJ'), ('сидит', 'V'), ('на', 'PR'), ('дороге…', 'S'), ('Быки', 'S'), ('со', 'PR'), ('страху', 'S'), ('на', 'PR'), ('лед', 'S'), ('побегут', 'V'), (',', 'NONLEX'), ('на', 'PR'), ('сколизи', 'S'), ('чуть', 'ADV'), ('не', 'PART'), ('раздираются', 'V'), (',', 'NONLEX'), ('а', 'CONJ'), ('он', 'S-PRO'), ('смеется…', 'V'), ('Один', 'ANUM=m'), ('раз', 'S'), ('лишь', 'PART'), ('заприметил', 'V'), ('я…', 'S'), ('Весной', 'S'), ('трактор', 'S'), ('нашей', 'A-PRO=f'), ('коммуны', 'S'), ('землю', 'S'), ('пахал', 'V'), ('за', 'PR'), ('казачьей', 'S'), ('гранью', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('он', 'S-PRO'), ('увязался', 'V'), (',', 'NONLEX'), ('поехал', 'V'), ('туда', 'ADV-PRO'), ('.', 'NONLEX')]
# [('Я', 'S-PRO'), ('овец', 'S'), ('пас', 'V'), ('неподалеку', 'S'), ('.', 'NONLEX')]
# [('Гляжу', 'V'), (',', 'NONLEX'), ('полозит', 'V'), ('мой', 'A-PRO=m'), ('Аникей', 'S'), ('по', 'PR'), ('пахоте', 'S'), ('.', 'NONLEX')]
# [('Думаю', 'V'), (',', 'NONLEX'), ('что', 'CONJ'), ('он', 'S-PRO'), ('будет', 'V'), ('делать', 'V'), ('?', 'NONLEX')]
# [('И', 'CONJ'), ('вижу', 'V'), (':', 'NONLEX'), ('оглянулся', 'V'), ('Аникей', 'S'), ('кругом', 'ADV'), (',', 'NONLEX'), ('видит', 'V'), (',', 'NONLEX'), ('людей', 'S'), ('вблизи', 'PR'), ('нету', 'PRAEDIC'), (',', 'NONLEX'), ('так', 'ADV-PRO'), ('он', 'S-PRO'), ('припал', 'V'), ('к', 'PR'), ('земле', 'S'), ('лицом', 'S'), (',', 'NONLEX'), ('глыбу', 'S'), (',', 'NONLEX'), ('лемешами', 'S'), ('отвернутую', 'V'), (',', 'NONLEX'), ('обнял', 'V'), (',', 'NONLEX'), ('к', 'PR'), ('себе', 'S-PRO=dat'), ('жмет', 'S'), (',', 'NONLEX'), ('руками', 'S'), ('гладит', 'V'), (',', 'NONLEX'), ('целует…', 'S'), ('Двадцать', 'NUM=nom'), ('пятый', 'ANUM=m'), ('год', 'S'), ('ему', 'S-PRO'), (',', 'NONLEX'), ('а', 'CONJ'), ('землю', 'S'), ('сроду', 'ADV'), ('не', 'PART'), ('придется', 'V'), ('пахать…', 'S'), ('Вот', 'PART'), ('он', 'S-PRO'), ('и', 'CONJ'), ('тоскует…', 'S'), ('В', 'INIT=abbr'), ('дымчато-синих', 'A=pl'), ('сумерках', 'S'), ('дремала', 'V'), ('лазоревая', 'A=f'), ('степь', 'S'), (',', 'NONLEX'), ('на', 'PR'), ('круговинах', 'S'), ('отцветающего', 'V'), ('чеборца', 'S'), ('последнюю', 'A=f'), ('за', 'PR'), ('день', 'S'), ('взятку', 'S'), ('брали', 'V'), ('пчелы', 'S'), ('.', 'NONLEX')]
# [('Ковыль', 'S'), (',', 'NONLEX'), ('белобрысый', 'A=m'), ('и', 'CONJ'), ('напыщенный', 'A=m'), (',', 'NONLEX'), ('надменно', 'ADV'), ('качал', 'V'), ('султанистыми', 'A=pl'), ('метелками', 'S'), ('.', 'NONLEX')]
# [('Овечья', 'S'), ('отара', 'S'), ('двигалась', 'V'), ('под', 'PR'), ('гору', 'S'), ('к', 'PR'), ('Тополевке', 'S'), ('.', 'NONLEX')]
# [('Дед', 'S'), ('Захар', 'S'), (',', 'NONLEX'), ('опираясь', 'V'), ('на', 'PR'), ('чакушу', 'S'), (',', 'NONLEX'), ('шел', 'S'), ('молча', 'ADV'), ('.', 'NONLEX')]
# [('По', 'PR'), ('дороге', 'S'), (',', 'NONLEX'), ('на', 'PR'), ('заботливо', 'ADV'), ('расшитом', 'V'), ('полотнище', 'S'), ('пыли', 'S'), (',', 'NONLEX'), ('виднелись', 'V'), ('следы', 'S'), (':', 'NONLEX'), ('один', 'A-PRO=sg'), ('волчий', 'S'), (',', 'NONLEX'), ('шаг', 'S'), ('в', 'PR'), ('шаг', 'S'), (',', 'NONLEX'), ('редкий', 'A=m'), ('и', 'CONJ'), ('разлапистый', 'A=m'), (',', 'NONLEX'), ('другой', 'A-PRO=m'), ('—', 'S'), ('косыми', 'A=pl'), ('полосами', 'S'), ('кромсавший', 'A=m'), ('дорогу', 'S'), ('—', 'NONLEX'), ('след', 'S'), ('тополевского', 'A=m'), ('трактора', 'S'), ('.', 'NONLEX')]
# [('Там', 'ADV-PRO'), (',', 'NONLEX'), ('где', 'ADV-PRO'), ('летник', 'S'), ('вливается', 'V'), ('в', 'PR'), ('заросший', 'A=m'), ('подорожником', 'S'), ('позабытый', 'A=m'), ('Гетманский', 'S'), ('шлях', 'S'), (',', 'NONLEX'), ('следы', 'S'), ('расстались', 'V'), ('.', 'NONLEX')]
# [('Волчий', 'S'), ('свернул', 'V'), ('в', 'PR'), ('сторону', 'S'), (',', 'NONLEX'), ('в', 'PR'), ('яры', 'S'), (',', 'NONLEX'), ('залохматевшие', 'V'), ('зеленой', 'A=f'), ('непролазью', 'S'), ('бурьяна', 'S'), ('и', 'CONJ'), ('терновника', 'S'), (',', 'NONLEX'), ('а', 'CONJ'), ('на', 'PR'), ('дороге', 'S'), ('остался', 'V'), ('один', 'A-PRO=m'), ('след', 'S'), (',', 'NONLEX'), ('пахнувший', 'V'), ('керосиновой', 'A=sg'), ('гарью', 'S'), (',', 'NONLEX'), ('размеренный', 'A=m'), ('и', 'CONJ'), ('грузный', 'A=m'), ('.', 'NONLEX')]
# [('1926', 'NUM=ciph')]

# %%
# лемматизация с учетом части речи
# меняем теги
tokenized = nltk.word_tokenize(text2)
tagged = nltk.pos_tag(tokenized)

def pos_tagger(nltk_tag):
    if nltk_tag.startswith('J'):
        return nltk.corpus.wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return nltk.corpus.wordnet.VERB
    elif nltk_tag.startswith('N'):
        return nltk.corpus.wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return nltk.corpus.wordnet.ADV
    else:          
        return None

tagged
# Out:
# [('Над', 'NN'),
#  ('Доном', 'NN'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('облысевшем', 'NNP'),
#  ('от', 'NNP'),
#  ('солнечного', 'NNP'),
#  ('жара', 'NNP'),
#  ('бугре', 'NNP'),
#  (',', ','),
#  ('под', 'NNP'),
#  ('кустом', 'NNP'),
#  ('дикого', 'NNP'),
#  ('терна', 'NNP'),
#  ('лежим', 'NNP'),
#  ('мы', 'NN'),
#  (':', ':'),
#  ('дед', 'JJ'),
#  ('Захар', 'NNP'),
#  ('и', 'NNP'),
#  ('я.', 'NNP'),
#  ('Рядом', 'NNP'),
#  ('с', 'NNP'),
#  ('чешуйчатой', 'NNP'),
#  ('грядкой', 'NNP'),
#  ('туч', 'NNP'),
#  ('бродит', 'NNP'),
#  ('коричневый', 'NNP'),
#  ('коршун', 'NNP'),
#  ('.', '.'),
#  ('Листья', 'NN'),
#  ('терна', 'NN'),
#  (',', ','),
#  ('пестро', 'NNP'),
#  ('окрашенные', 'NNP'),
#  ('птичьим', 'NNP'),
#  ('пометом', 'NNP'),
#  (',', ','),
#  ('не', 'NNP'),
#  ('дают', 'NNP'),
#  ('нам', 'NNP'),
#  ('прохлады', 'NNP'),
#  ('.', '.'),
#  ('От', 'VB'),
#  ('зноя', 'JJ'),
#  ('в', 'NNP'),
#  ('ушах', 'NNP'),
#  ('горячий', 'NNP'),
#  ('звон', 'NNP'),
#  (';', ':'),
#  ('когда', 'NNP'),
#  ('смотришь', 'NNP'),
#  ('вниз', 'NNP'),
#  ('на', 'NNP'),
#  ('курчавую', 'NNP'),
#  ('рябь', 'NNP'),
#  ('Дона', 'NNP'),
#  ('или', 'NNP'),
#  ('под', 'NNP'),
#  ('ноги', 'NNP'),
#  ('на', 'NNP'),
#  ('сморщенные', 'NNP'),
#  ('арбузные', 'NNP'),
#  ('корки', 'NNP'),
#  ('—', 'NNP'),
#  ('в', 'NNP'),
#  ('рот', 'NNP'),
#  ('набегает', 'NNP'),
#  ('тягучая', 'NNP'),
#  ('слюна', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('слюну', 'NNP'),
#  ('эту', 'NNP'),
#  ('лень', 'NNP'),
#  ('сплевывать', 'NNP'),
#  ('.', '.'),
#  ('В', 'NN'),
#  ('лощине', 'NN'),
#  (',', ','),
#  ('возле', 'NNP'),
#  ('высыхающей', 'NNP'),
#  ('музги', 'NNP'),
#  (',', ','),
#  ('овцы', 'NNP'),
#  ('жмутся', 'NNP'),
#  ('в', 'NNP'),
#  ('тесные', 'NNP'),
#  ('кучи', 'NNP'),
#  ('.', '.'),
#  ('Устало', 'VB'),
#  ('откинув', 'JJ'),
#  ('зады', 'NNP'),
#  (',', ','),
#  ('виляют', 'NNP'),
#  ('захлюстанными', 'NNP'),
#  ('курдюками', 'NNP'),
#  (',', ','),
#  ('надрывно', 'NNP'),
#  ('чихают', 'NNP'),
#  ('от', 'NNP'),
#  ('пыли', 'NNP'),
#  ('.', '.'),
#  ('У', 'VB'),
#  ('плотины', 'JJ'),
#  ('здоровенный', 'NNP'),
#  ('ягночище', 'NNP'),
#  (',', ','),
#  ('упираясь', 'NNP'),
#  ('задними', 'NNP'),
#  ('ногами', 'NNP'),
#  (',', ','),
#  ('сосет', 'NNP'),
#  ('грязножелтую', 'NNP'),
#  ('овцу', 'NNP'),
#  ('.', '.'),
#  ('Изредка', 'VB'),
#  ('поддает', 'JJ'),
#  ('головой', 'NNP'),
#  ('в', 'NNP'),
#  ('материно', 'NNP'),
#  ('вымя', 'NNP'),
#  (';', ':'),
#  ('овца', 'NNP'),
#  ('стонет', 'NNP'),
#  (',', ','),
#  ('горбится', 'NNP'),
#  (',', ','),
#  ('припуская', 'NNP'),
#  ('молоко', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  (',', ','),
#  ('мне', 'NNP'),
#  ('кажется', 'NNP'),
#  (',', ','),
#  ('выражение', 'NNP'),
#  ('глаз', 'NNP'),
#  ('у', 'NNP'),
#  ('нее', 'NNP'),
#  ('страдальческое', 'NNP'),
#  ('.', '.'),
#  ('Дед', 'VB'),
#  ('Захар', 'JJ'),
#  ('сидит', 'NNP'),
#  ('ко', 'NNP'),
#  ('мне', 'NNP'),
#  ('боком', 'NNP'),
#  ('.', '.'),
#  ('Скинув', 'VB'),
#  ('вязаную', 'JJ'),
#  ('шерстяную', 'NNP'),
#  ('рубаху', 'NNP'),
#  (',', ','),
#  ('он', 'NNP'),
#  ('подслеповато', 'NNP'),
#  ('жмурится', 'NNP'),
#  ('и', 'NNP'),
#  ('ощупью', 'NNP'),
#  ('что-то', 'JJ'),
#  ('ищет', 'NNP'),
#  ('в', 'NNP'),
#  ('складках', 'NNP'),
#  ('и', 'NNP'),
#  ('швах', 'NNP'),
#  ('.', '.'),
#  ('Деду', 'VB'),
#  ('без', 'JJ'),
#  ('года', 'NNP'),
#  ('семьдесят', 'NNP'),
#  ('.', '.'),
#  ('Голая', 'VB'),
#  ('спина', 'JJ'),
#  ('замысловато', 'NNP'),
#  ('опутана', 'NNP'),
#  ('морщинами', 'NNP'),
#  (',', ','),
#  ('лопатки', 'NNP'),
#  ('острыми', 'NNP'),
#  ('углами', 'NNP'),
#  ('выпирают', 'NNP'),
#  ('под', 'NNP'),
#  ('кожей', 'NNP'),
#  (',', ','),
#  ('но', 'NNP'),
#  ('глаза', 'NNP'),
#  ('—', 'NNP'),
#  ('голубые', 'NNP'),
#  ('и', 'NNP'),
#  ('юные', 'NNP'),
#  (',', ','),
#  ('взгляд', 'NNP'),
#  ('из-под', 'NNP'),
#  ('серых', 'NNP'),
#  ('бровей', 'NNP'),
#  ('—', 'NNP'),
#  ('проворен', 'NNP'),
#  ('и', 'NNP'),
#  ('колюч', 'NNP'),
#  ('.', '.'),
#  ('Пойманную', 'VB'),
#  ('вошь', 'JJ'),
#  ('он', 'NNP'),
#  ('с', 'NNP'),
#  ('трудом', 'NNP'),
#  ('держит', 'NNP'),
#  ('в', 'NNP'),
#  ('дрожащих', 'NNP'),
#  ('зачерствелых', 'NNP'),
#  ('пальцах', 'NNP'),
#  (',', ','),
#  ('держит', 'NNP'),
#  ('ее', 'NNP'),
#  ('бережно', 'NNP'),
#  ('и', 'NNP'),
#  ('нежно', 'NNP'),
#  (',', ','),
#  ('потом', 'NNP'),
#  ('кладет', 'NNP'),
#  ('на', 'NNP'),
#  ('землю', 'NNP'),
#  (',', ','),
#  ('подальше', 'NNP'),
#  ('от', 'NNP'),
#  ('себя', 'NNP'),
#  (',', ','),
#  ('мелким', 'NNP'),
#  ('крестиком', 'NNP'),
#  ('чертит', 'NNP'),
#  ('воздух', 'NNP'),
#  ('и', 'NNP'),
#  ('глухо', 'NNP'),
#  ('бурчит', 'NN'),
#  (':', ':'),
#  ('—', 'NN'),
#  ('Уползай', 'NN'),
#  (',', ','),
#  ('тварь', 'NN'),
#  ('!', '.'),
#  ('Жить', 'NN'),
#  (',', ','),
#  ('небось', 'NNP'),
#  (',', ','),
#  ('хочешь', 'NNP'),
#  ('?', '.'),
#  ('а', 'VB'),
#  ('?', '.'),
#  ('То-то', 'JJ'),
#  ('оно…', 'NN'),
#  ('Ишь', 'NNP'),
#  ('ты', 'NNP'),
#  (',', ','),
#  ('насосалась…', 'NNP'),
#  ('помещица…', 'NNP'),
#  ('Кряхтя', 'NNP'),
#  (',', ','),
#  ('напяливает', 'NNP'),
#  ('дед', 'NNP'),
#  ('рубаху', 'NNP'),
#  ('и', 'NNP'),
#  (',', ','),
#  ('запрокидывая', 'NNP'),
#  ('голову', 'NNP'),
#  (',', ','),
#  ('тянет', 'NNP'),
#  ('из', 'NNP'),
#  ('деревянной', 'NNP'),
#  ('баклаги', 'NNP'),
#  ('степлившуюся', 'NNP'),
#  ('воду', 'NNP'),
#  ('.', '.'),
#  ('Кадык', 'VB'),
#  ('при', 'JJ'),
#  ('каждом', 'NNP'),
#  ('глотке', 'NNP'),
#  ('ползет', 'NNP'),
#  ('вверх', 'NNP'),
#  (',', ','),
#  ('от', 'NNP'),
#  ('подбородка', 'NNP'),
#  ('к', 'NNP'),
#  ('горлу', 'NNP'),
#  ('свисают', 'NNP'),
#  ('две', 'NNP'),
#  ('обмякших', 'NNP'),
#  ('складки', 'NNP'),
#  (',', ','),
#  ('по', 'NNP'),
#  ('бороде', 'NNP'),
#  ('текут', 'NNP'),
#  ('капельки', 'NNP'),
#  (',', ','),
#  ('сквозь', 'NNP'),
#  ('опущенные', 'NNP'),
#  ('шафранные', 'NNP'),
#  ('веки', 'NNP'),
#  ('красновато', 'NNP'),
#  ('просвечивает', 'NNP'),
#  ('солнце', 'NNP'),
#  ('.', '.'),
#  ('Затыкая', 'NN'),
#  ('баклагу', 'NN'),
#  (',', ','),
#  ('он', 'NNP'),
#  ('искоса', 'NNP'),
#  ('глядит', 'NNP'),
#  ('на', 'NNP'),
#  ('меня', 'NNP'),
#  ('и', 'NNP'),
#  (',', ','),
#  ('перехватив', 'NNP'),
#  ('мой', 'NNP'),
#  ('взгляд', 'NNP'),
#  (',', ','),
#  ('сухо', 'NNP'),
#  ('жует', 'NNP'),
#  ('губами', 'NNP'),
#  (',', ','),
#  ('смотрит', 'NNP'),
#  ('в', 'NNP'),
#  ('степь', 'NNP'),
#  ('.', '.'),
#  ('За', 'VB'),
#  ('лощиной', 'JJ'),
#  ('дымкой', 'NNP'),
#  ('теплится', 'NNP'),
#  ('марево', 'NNP'),
#  (',', ','),
#  ('ветер', 'NNP'),
#  ('над', 'NNP'),
#  ('обугленной', 'NNP'),
#  ('землей', 'NNP'),
#  ('пряно', 'NNP'),
#  ('пахнет', 'NNP'),
#  ('чеборцовым', 'NNP'),
#  ('медом', 'NNP'),
#  ('.', '.'),
#  ('Помолчав', 'NN'),
#  (',', ','),
#  ('дед', 'NNP'),
#  ('отодвигает', 'NNP'),
#  ('от', 'NNP'),
#  ('себя', 'NNP'),
#  ('пастушечью', 'NNP'),
#  ('чакушу', 'NNP'),
#  ('[', 'VBD'),
#  ('1', 'CD'),
#  (']', 'NN'),
#  (',', ','),
#  ('обкуренным', 'NNP'),
#  ('пальцем', 'NNP'),
#  ('указывает', 'NNP'),
#  ('мимо', 'NNP'),
#  ('меня', 'NNP'),
#  ('.', '.'),
#  ('—', 'NN'),
#  ('Видишь', 'NN'),
#  (',', ','),
#  ('за', 'NNP'),
#  ('энтим', 'NNP'),
#  ('логом', 'NNP'),
#  ('макушки', 'NNP'),
#  ('тополев', 'NNP'),
#  ('?', '.'),
#  ('Имение', 'NNP'),
#  ('панов', 'NNP'),
#  ('Томилиных', 'NNP'),
#  ('—', 'NNP'),
#  ('Тополевка', 'NNP'),
#  ('.', '.'),
#  ('Там', 'VB'),
#  ('же', 'JJ'),
#  ('около', 'NNP'),
#  ('и', 'NNP'),
#  ('мужичий', 'NNP'),
#  ('поселок', 'NNP'),
#  ('Тополевка', 'NNP'),
#  (',', ','),
#  ('раньше', 'NNP'),
#  ('крепостные', 'NNP'),
#  ('были', 'NNP'),
#  ('.', '.'),
#  ('Отец', 'VB'),
#  ('мой', 'JJ'),
#  ('кучеровал', 'NNP'),
#  ('у', 'NNP'),
#  ('пана', 'NNP'),
#  ('до', 'NNP'),
#  ('смерти', 'NNP'),
#  ('.', '.'),
#  ('Мне-то', 'NN'),
#  (',', ','),
#  ('огольцу', 'NNP'),
#  (',', ','),
#  ('он', 'NNP'),
#  ('рассказывал', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('пан', 'NNP'),
#  ('Евграф', 'NNP'),
#  ('Томилин', 'NNP'),
#  ('выменял', 'NNP'),
#  ('его', 'NNP'),
#  ('за', 'NNP'),
#  ('ручного', 'NNP'),
#  ('журавля', 'NNP'),
#  ('у', 'NNP'),
#  ('соседа-помещика', 'NNP'),
#  ('.', '.'),
#  ('Посля', 'VB'),
#  ('отцовой', 'JJ'),
#  ('смерти', 'NNP'),
#  ('я', 'NNP'),
#  ('заступил', 'NNP'),
#  ('на', 'NNP'),
#  ('его', 'NNP'),
#  ('место', 'NNP'),
#  ('кучером', 'NNP'),
#  ('.', '.'),
#  ('Самому', 'VB'),
#  ('пану', 'JJ'),
#  ('в', 'NNP'),
#  ('это', 'NNP'),
#  ('время', 'NNP'),
#  ('было', 'NNP'),
#  ('под', 'NNP'),
#  ('шестьдесят', 'NNP'),
#  ('.', '.'),
#  ('Тýшистый', 'VB'),
#  ('был', 'JJ'),
#  ('мужчина', 'NNP'),
#  (',', ','),
#  ('многокровный', 'NNP'),
#  ('.', '.'),
#  ('В', 'VB'),
#  ('молодости', 'JJ'),
#  ('при', 'NNP'),
#  ('царе', 'NNP'),
#  ('в', 'NNP'),
#  ('гвардии', 'NNP'),
#  ('служил', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('потом', 'NNP'),
#  ('кончил', 'NNP'),
#  ('службу', 'NNP'),
#  ('и', 'NNP'),
#  ('уехал', 'NNP'),
#  ('доживать', 'NNP'),
#  ('на', 'NNP'),
#  ('Дон', 'NNP'),
#  ('.', '.'),
#  ('Землю', 'VB'),
#  ('ихнюю', 'JJ'),
#  ('на', 'NNP'),
#  ('Дону', 'NNP'),
#  ('казаки', 'NNP'),
#  ('отобрали', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('пану', 'NNP'),
#  ('казна', 'NNP'),
#  ('отрезала', 'NNP'),
#  ('в', 'NNP'),
#  ('Саратовской', 'NNP'),
#  ('губернии', 'NNP'),
#  ('три', 'NNP'),
#  ('тыщи', 'NNP'),
#  ('десятин', 'NNP'),
#  ('.', '.'),
#  ('Сдавал', 'VB'),
#  ('он', 'JJ'),
#  ('их', 'NNP'),
#  ('в', 'NNP'),
#  ('аренду', 'NNP'),
#  ('саратовским', 'NNP'),
#  ('мужикам', 'NNP'),
#  (',', ','),
#  ('сам', 'NNP'),
#  ('проживал', 'NNP'),
#  ('в', 'NNP'),
#  ('Тополевке', 'NNP'),
#  ('.', '.'),
#  ('Диковинный', 'VB'),
#  ('был', 'JJ'),
#  ('человек', 'NNP'),
#  ('.', '.'),
#  ('Ходил', 'VB'),
#  ('завсегда', 'JJ'),
#  ('в', 'NNP'),
#  ('бешмете', 'NNP'),
#  ('тонкого', 'NNP'),
#  ('сукна', 'NNP'),
#  (',', ','),
#  ('при', 'NNP'),
#  ('кинжале', 'NNP'),
#  ('.', '.'),
#  ('Поедет', 'NN'),
#  (',', ','),
#  ('бывало', 'NNP'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('гости', 'NNP'),
#  (',', ','),
#  ('выберемся', 'NNP'),
#  ('из', 'NNP'),
#  ('Тополевки', 'NNP'),
#  (',', ','),
#  ('приказывает', 'NN'),
#  (':', ':'),
#  ('—', 'NN'),
#  ('Гони', 'NN'),
#  (',', ','),
#  ('хамлюга', 'NN'),
#  ('!', '.'),
#  ('Я', 'JJ'),
#  ('лошадям', 'JJ'),
#  ('кнута', 'NN'),
#  ('.', '.'),
#  ('Скачем', 'CC'),
#  ('—', 'JJ'),
#  ('ветер', 'NNP'),
#  ('не', 'NNP'),
#  ('поспевает', 'NNP'),
#  ('слезы', 'NNP'),
#  ('сушить', 'NNP'),
#  ('.', '.'),
#  ('Попадется', 'VB'),
#  ('середь', 'JJ'),
#  ('дороги', 'NNP'),
#  ('ярок', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('водой', 'NNP'),
#  ('вешней', 'NNP'),
#  ('их', 'NNP'),
#  ('нарежет', 'NNP'),
#  ('через', 'NNP'),
#  ('дорогу', 'NNP'),
#  ('пропасть', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('передних', 'NNP'),
#  ('колес', 'NNP'),
#  ('не', 'NNP'),
#  ('слышно', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('задние', 'NNP'),
#  ('только', 'NNP'),
#  ('—', 'NNP'),
#  ('гах', 'NN'),
#  ('!', '.'),
#  ('..', 'JJ'),
#  ('Скрадем', 'NNP'),
#  ('полверсты', 'NNP'),
#  (',', ','),
#  ('пан', 'NNP'),
#  ('ревет', 'NN'),
#  (':', ':'),
#  ('«', 'JJ'),
#  ('Поворачивай', 'NN'),
#  ('!', '.'),
#  ('»', 'JJ'),
#  ('Оберну', 'JJ'),
#  ('назад', 'NN'),
#  ('и', 'NNP'),
#  ('во', 'NNP'),
#  ('весь', 'NNP'),
#  ('опор', 'NNP'),
#  ('к', 'NNP'),
#  ('тому', 'NNP'),
#  ('ярку…', 'NNP'),
#  ('Раз', 'NNP'),
#  ('до', 'NNP'),
#  ('трех', 'NNP'),
#  ('в', 'NNP'),
#  ('проклятущем', 'NNP'),
#  ('побываем', 'NNP'),
#  (',', ','),
#  ('покель', 'NNP'),
#  ('изломаем', 'NNP'),
#  ('лесóрину', 'NNP'),
#  (',', ','),
#  ('либо', 'NNP'),
#  ('колеса', 'NNP'),
#  ('с', 'NNP'),
#  ('коляски', 'NNP'),
#  ('живьем', 'NNP'),
#  ('сымем', 'NNP'),
#  ('.', '.'),
#  ('Тогда', 'VB'),
#  ('крякнет', 'JJ'),
#  ('мой', 'NNP'),
#  ('пан', 'NNP'),
#  (',', ','),
#  ('встанет', 'NNP'),
#  ('и', 'NNP'),
#  ('идет', 'NNP'),
#  ('пéшки', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('я', 'NNP'),
#  ('следом', 'NNP'),
#  ('коней', 'NNP'),
#  ('в', 'NNP'),
#  ('поводу', 'NNP'),
#  ('веду', 'NNP'),
#  ('.', '.'),
#  ('Была', 'VB'),
#  ('у', 'JJ'),
#  ('него', 'NNP'),
#  ('ишо', 'NNP'),
#  ('такая', 'NNP'),
#  ('забава', 'NN'),
#  (':', ':'),
#  ('выедем', 'JJ'),
#  ('из', 'NNP'),
#  ('имения', 'NNP'),
#  ('—', 'NNP'),
#  ('он', 'NNP'),
#  ('сядет', 'NNP'),
#  ('со', 'NNP'),
#  ('мной', 'NNP'),
#  ('на', 'NNP'),
#  ('козлы', 'NNP'),
#  (',', ','),
#  ('вырвет', 'NNP'),
#  ('кнут', 'NNP'),
#  ('из', 'NNP'),
#  ('рук', 'NNP'),
#  ('.', '.'),
#  ('«', 'VB'),
#  ('Шевели', 'JJ'),
#  ('коренного', 'NN'),
#  ('!', '.'),
#  ('..', 'JJ'),
#  ('»', 'JJ'),
#  ('Я', 'NN'),
#  ('коренника', 'NNP'),
#  ('раскачиваю', 'NNP'),
#  ('вовсю', 'NNP'),
#  (',', ','),
#  ('дуга', 'NNP'),
#  ('не', 'NNP'),
#  ('шелохнется', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('он', 'NNP'),
#  ('кнутом', 'NNP'),
#  ('пристяжную', 'NNP'),
#  ('режет', 'NNP'),
#  ('.', '.'),
#  ('Выезд', 'VB'),
#  ('был', 'JJ'),
#  ('тройкой', 'NNP'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('пристяжных', 'NNP'),
#  ('ходили', 'NNP'),
#  ('дончаки', 'NNP'),
#  ('чистых', 'NNP'),
#  ('кровей', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('змеи', 'NNP'),
#  (',', ','),
#  ('голову', 'NNP'),
#  ('набок', 'NNP'),
#  (',', ','),
#  ('землю', 'NNP'),
#  ('грызут', 'NNP'),
#  ('.', '.'),
#  ('И', 'VB'),
#  ('вот', 'JJ'),
#  ('он', 'NNP'),
#  ('кнутом', 'NNP'),
#  ('полосует', 'NNP'),
#  ('какую-нибудь', 'JJ'),
#  ('одну', 'NNP'),
#  (',', ','),
#  ('сердяга', 'NNP'),
#  ('пеной', 'NNP'),
#  ('обливается…', 'NNP'),
#  ('Потом', 'NNP'),
#  ('кинжал', 'NNP'),
#  ('вынет', 'NNP'),
#  (',', ','),
#  ('нагнется', 'NNP'),
#  ('и', 'NNP'),
#  ('постромки', 'NNP'),
#  ('—', 'NNP'),
#  ('жик', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('волос', 'NNP'),
#  ('бритвой', 'NNP'),
#  ('срежет', 'NNP'),
#  ('.', '.'),
#  ('Лошадь-то', 'JJ'),
#  ('саженя', 'JJ'),
#  ('два', 'NN'),
#  ('через', 'NNP'),
#  ('голову', 'NNP'),
#  ('летит', 'NNP'),
#  (',', ','),
#  ('грохнется', 'NNP'),
#  ('обземь', 'NNP'),
#  (',', ','),
#  ('кровь', 'NNP'),
#  ('из', 'NNP'),
#  ('ноздрей', 'NNP'),
#  ('потоком', 'NNP'),
#  ('—', 'NNP'),
#  ('и', 'NNP'),
#  ('готова', 'NN'),
#  ('!', '.'),
#  ('..', 'JJ'),
#  ('Таким', 'JJ'),
#  ('способом', 'NN'),
#  ('и', 'NNP'),
#  ('другую…', 'NNP'),
#  ('Коренник', 'NNP'),
#  ('до', 'NNP'),
#  ('той', 'NNP'),
#  ('поры', 'NNP'),
#  ('прет', 'NNP'),
#  (',', ','),
#  ('покеда', 'NNP'),
#  ('не', 'NNP'),
#  ('запалится', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('пану', 'NNP'),
#  ('хотя', 'NNP'),
#  ('бы', 'NNP'),
#  ('что', 'NNP'),
#  (',', ','),
#  ('ажник', 'NNP'),
#  ('повеселеет', 'NNP'),
#  ('малость', 'NNP'),
#  (',', ','),
#  ('кровица', 'NNP'),
#  ('так', 'NNP'),
#  ('и', 'NNP'),
#  ('заиграет', 'NNP'),
#  ('на', 'NNP'),
#  ('щеках', 'NNP'),
#  ('.', '.'),
#  ('Сроду', 'VB'),
#  ('до', 'JJ'),
#  ('места', 'NNP'),
#  ('прибытия', 'NNP'),
#  ('не', 'NNP'),
#  ('доезжал', 'NN'),
#  (':', ':'),
#  ('либо', 'JJ'),
#  ('коляску', 'NNP'),
#  ('обломает', 'NNP'),
#  (',', ','),
#  ('либо', 'NNP'),
#  ('лошадей', 'NNP'),
#  ('погубит', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('посля', 'NNP'),
#  ('пéшки', 'NNP'),
#  ('прет…', 'NNP'),
#  ('Веселый', 'NNP'),
#  ('был', 'NNP'),
#  ('пан…', 'NNP'),
#  ('Дело', 'NNP'),
#  ('прошлое', 'NNP'),
#  (',', ','),
#  ('пущай', 'NNP'),
#  ('нас', 'NNP'),
#  ('бог', 'NNP'),
#  ('судит…', 'NNP'),
#  ('Присватался', 'NNP'),
#  ('он', 'NNP'),
#  ('к', 'NNP'),
#  ('моей', 'NNP'),
#  ('бабе', 'NNP'),
#  (',', ','),
#  ('она', 'NNP'),
#  ('в', 'NNP'),
#  ('горничных', 'NNP'),
#  ('состояла', 'NNP'),
#  ('.', '.'),
#  ('Прибежит', 'NN'),
#  (',', ','),
#  ('бывало', 'NNP'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('людскую', 'NNP'),
#  ('—', 'NNP'),
#  ('рубаха', 'NNP'),
#  ('в', 'NNP'),
#  ('шмотьях', 'NNP'),
#  ('—', 'NNP'),
#  ('ревет', 'NNP'),
#  ('белугой', 'NNP'),
#  ('.', '.'),
#  ('Гляну', 'NN'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('у', 'NNP'),
#  ('ней', 'NNP'),
#  ('все', 'NNP'),
#  ('груди', 'NNP'),
#  ('искусаны', 'NNP'),
#  (',', ','),
#  ('кожа', 'NNP'),
#  ('лентами', 'NNP'),
#  ('висит…', 'NNP'),
#  ('Раз', 'NNP'),
#  ('как-то', 'JJ'),
#  ('посылает', 'NNP'),
#  ('меня', 'NNP'),
#  ('пан', 'NNP'),
#  ('в', 'NNP'),
#  ('ночь', 'NNP'),
#  ('за', 'NNP'),
#  ('фершалом', 'NNP'),
#  ('.', '.'),
#  ('Знаю', 'NN'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('надобности', 'NNP'),
#  ('нету', 'NNP'),
#  (',', ','),
#  ('смекнул', 'NNP'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('чем', 'NNP'),
#  ('дело', 'NNP'),
#  (',', ','),
#  ('взял', 'NNP'),
#  ('в', 'NNP'),
#  ('степи', 'NNP'),
#  ('ночи', 'NNP'),
#  ('дождался', 'NNP'),
#  ('и', 'NNP'),
#  ('вернулся', 'NNP'),
#  ('.', '.'),
#  ('В', 'VB'),
#  ('имение', 'JJ'),
#  ('через', 'NNP'),
#  ('гумно', 'NNP'),
#  ('въехал', 'NNP'),
#  (',', ','),
#  ('бросил', 'NNP'),
#  ('лошадей', 'NNP'),
#  ('в', 'NNP'),
#  ('саду', 'NNP'),
#  (',', ','),
#  ('взял', 'NNP'),
#  ('кнут', 'NNP'),
#  ('и', 'NNP'),
#  ('иду', 'NNP'),
#  ('в', 'NNP'),
#  ('людскую', 'NNP'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('свою', 'NNP'),
#  ('каморку', 'NNP'),
#  ('.', '.'),
#  ('Дверью', 'NN'),
#  ('рыпнул', 'NN'),
#  (',', ','),
#  ('серников', 'NNP'),
#  ('нарочно', 'NNP'),
#  ('не', 'NNP'),
#  ('зажигаю', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('слышу', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('на', 'NNP'),
#  ('кровати', 'NNP'),
#  ('возня…', 'NNP'),
#  ('Тольки', 'NNP'),
#  ('это', 'NNP'),
#  ('приподнялся', 'NNP'),
#  ('мой', 'NNP'),
#  ('пан', 'NNP'),
#  (',', ','),
#  ('я', 'NNP'),
#  ('его', 'NNP'),
#  ('кнутом', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('кнут', 'NNP'),
#  ('у', 'NNP'),
#  ('меня', 'NNP'),
#  ('был', 'NNP'),
#  ('с', 'NNP'),
#  ('свинчаткой', 'NNP'),
#  ('на', 'NNP'),
#  ('конце…', 'NNP'),
#  ('Слышу', 'NNP'),
#  ('гребется', 'NNP'),
#  ('к', 'NNP'),
#  ('окну', 'NNP'),
#  (',', ','),
#  ('я', 'NNP'),
#  ('в', 'NNP'),
#  ('потемках', 'NNP'),
#  ('ишо', 'NNP'),
#  ('раз', 'NNP'),
#  ('его', 'NNP'),
#  ('потянул', 'NNP'),
#  ('через', 'NNP'),
#  ('лоб', 'NNP'),
#  ('.', '.'),
#  ('Высигнул', 'VB'),
#  ('он', 'JJ'),
#  ('в', 'NNP'),
#  ('окно', 'NNP'),
#  (',', ','),
#  ('я', 'NNP'),
#  ('маленько', 'NNP'),
#  ('похлестал', 'NNP'),
#  ('бабу', 'NNP'),
#  ('и', 'NNP'),
#  ('лег', 'NNP'),
#  ('спать', 'NNP'),
#  ('.', '.'),
#  ('Дён', 'VB'),
#  ('через', 'JJ'),
#  ('пять', 'NNP'),
#  ('поехали', 'NNP'),
#  ('в', 'NNP'),
#  ('станицу', 'NNP'),
#  (';', ':'),
#  ('стал', 'NNP'),
#  ('я', 'NNP'),
#  ('пристегивать', 'NNP'),
#  ('полсть', 'NNP'),
#  ('на', 'NNP'),
#  ('коляске', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('пан', 'NNP'),
#  ('кнут', 'NNP'),
#  ('взял', 'NNP'),
#  ('и', 'NNP'),
#  ('разглядывает', 'NNP'),
#  ('конец', 'NNP'),
#  ('.', '.'),
#  ('Вертел', 'NN'),
#  (',', ','),
#  ('вертел', 'NNP'),
#  ('в', 'NNP'),
#  ('руках', 'NNP'),
#  (',', ','),
#  ('свинчатку', 'NNP'),
#  ('нащупал', 'NNP'),
#  ('и', 'NNP'),
#  ('спрашивает', 'NN'),
#  (':', ':'),
#  ('—', 'NN'),
#  ('Ты', 'NN'),
#  (',', ','),
#  ('собачья', 'NNP'),
#  ('кровь', 'NNP'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('что', 'NNP'),
#  ('свинец', 'NNP'),
#  ('зашил', 'NNP'),
#  ('в', 'NNP'),
#  ('кнут', 'NNP'),
#  ('?', '.'),
#  ('—', 'NNP'),
#  ('Вы', 'NNP'),
#  ('сами', 'NNP'),
#  ('изволили', 'NNP'),
#  ('приказать', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('отвечаю', 'NNP'),
#  ('ему', 'NNP'),
#  ('.', '.'),
#  ('Промолчал', 'VB'),
#  ('и', 'JJ'),
#  ('всю', 'NNP'),
#  ('дорогу', 'NNP'),
#  ('до', 'NNP'),
#  ('первого', 'NNP'),
#  ('ярка', 'NNP'),
#  ('сквозь', 'NNP'),
#  ('зубы', 'NNP'),
#  ('посвистывает', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('я', 'NNP'),
#  ('обернусь', 'NNP'),
#  ('этак', 'NNP'),
#  ...]

# %%
from collections import Counter
lower_case = text2.lower()
tokens = nltk.word_tokenize(lower_case)
tags = nltk.pos_tag(tokens)
counts = Counter( tag for word,  tag in tags)
print(counts)

# Предполагаю, что диалогов меньше, так как имен собственных в 2,5 раза меньше, чем в 1 тексте.
# Возможно потому что текст меньше по объему, буду проверять дальше
# Out:
# Counter({'NNP': 2055, ',': 364, '.': 200, 'NN': 198, 'JJ': 196, 'VB': 100, ':': 37, 'CC': 4, 'CD': 2, 'VBD': 1})

# %%
from collections import Counter
lower_case = text2.lower()
tokens = nltk.word_tokenize(lower_case)
tags = nltk.pos_tag(tokens, lang='rus')
counts = Counter( tag for word,  tag in tags)
print(counts)
# Out:
# Counter({'S': 868, 'NONLEX': 675, 'V': 538, 'PR': 310, 'CONJ': 171, 'S-PRO': 136, 'ADV': 72, 'PART': 62, 'A=m': 50, 'A=pl': 45, 'A=f': 42, 'ADV-PRO': 39, 'A-PRO=m': 30, 'A-PRO=pl': 18, 'A-PRO=f': 16, 'A=n': 9, 'A=sg': 8, 'PARENTH': 7, 'A-PRO': 7, 'NUM=acc': 6, 'A-PRO=sg': 6, 'A=comp': 4, 'PRAEDIC': 4, 'NUM=m': 4, 'ANUM=m': 4, 'S-PRO=gen': 3, 'NUM=f': 3, 'A-PRO=n': 3, 'S-PRO=acc': 3, 'NUM=ciph': 2, 'NUM=nom': 2, 'ANUM=f': 2, 'INTJ': 2, 'S-PRO=dat': 2, 'ADV=comp2': 1, 'ADV=comp': 1, 'NUM=gen': 1, 'NUM=comp': 1})

# %%
tokenizer = nltk.tokenize.BlanklineTokenizer()
tokens = tokenizer.tokenize(text2)
print(len(tokenizer.tokenize(text2)))
# print(tokenizer.tokenize(text1))
print('Разделение текста по абзацам')

# Один абзац, думаю, поэтому и диалогов меньше в 2,5 раза. Нужно посмотреть объем токенов
# Но это наталкивает на мысль, что тексты в основном состоят из диалогов
# Out:
# 1
# Разделение текста по абзацам

# %%
tokenizer = nltk.tokenize.WhitespaceTokenizer()
print(len(tokenizer.tokenize(text2)))
print(tokenizer.tokenize(text2))
# текст действительно маленький. Стал ли Шолохов писать только маленькие произведения, пока писал Тихий Дон?
# Out:
# 2537
# ['Над', 'Доном,', 'на', 'облысевшем', 'от', 'солнечного', 'жара', 'бугре,', 'под', 'кустом', 'дикого', 'терна', 'лежим', 'мы:', 'дед', 'Захар', 'и', 'я.', 'Рядом', 'с', 'чешуйчатой', 'грядкой', 'туч', 'бродит', 'коричневый', 'коршун.', 'Листья', 'терна,', 'пестро', 'окрашенные', 'птичьим', 'пометом,', 'не', 'дают', 'нам', 'прохлады.', 'От', 'зноя', 'в', 'ушах', 'горячий', 'звон;', 'когда', 'смотришь', 'вниз', 'на', 'курчавую', 'рябь', 'Дона', 'или', 'под', 'ноги', 'на', 'сморщенные', 'арбузные', 'корки', '—', 'в', 'рот', 'набегает', 'тягучая', 'слюна,', 'и', 'слюну', 'эту', 'лень', 'сплевывать.', 'В', 'лощине,', 'возле', 'высыхающей', 'музги,', 'овцы', 'жмутся', 'в', 'тесные', 'кучи.', 'Устало', 'откинув', 'зады,', 'виляют', 'захлюстанными', 'курдюками,', 'надрывно', 'чихают', 'от', 'пыли.', 'У', 'плотины', 'здоровенный', 'ягночище,', 'упираясь', 'задними', 'ногами,', 'сосет', 'грязножелтую', 'овцу.', 'Изредка', 'поддает', 'головой', 'в', 'материно', 'вымя;', 'овца', 'стонет,', 'горбится,', 'припуская', 'молоко,', 'и,', 'мне', 'кажется,', 'выражение', 'глаз', 'у', 'нее', 'страдальческое.', 'Дед', 'Захар', 'сидит', 'ко', 'мне', 'боком.', 'Скинув', 'вязаную', 'шерстяную', 'рубаху,', 'он', 'подслеповато', 'жмурится', 'и', 'ощупью', 'что-то', 'ищет', 'в', 'складках', 'и', 'швах.', 'Деду', 'без', 'года', 'семьдесят.', 'Голая', 'спина', 'замысловато', 'опутана', 'морщинами,', 'лопатки', 'острыми', 'углами', 'выпирают', 'под', 'кожей,', 'но', 'глаза', '—', 'голубые', 'и', 'юные,', 'взгляд', 'из-под', 'серых', 'бровей', '—', 'проворен', 'и', 'колюч.', 'Пойманную', 'вошь', 'он', 'с', 'трудом', 'держит', 'в', 'дрожащих', 'зачерствелых', 'пальцах,', 'держит', 'ее', 'бережно', 'и', 'нежно,', 'потом', 'кладет', 'на', 'землю,', 'подальше', 'от', 'себя,', 'мелким', 'крестиком', 'чертит', 'воздух', 'и', 'глухо', 'бурчит:', '—', 'Уползай,', 'тварь!', 'Жить,', 'небось,', 'хочешь?', 'а?', 'То-то', 'оно…', 'Ишь', 'ты,', 'насосалась…', 'помещица…', 'Кряхтя,', 'напяливает', 'дед', 'рубаху', 'и,', 'запрокидывая', 'голову,', 'тянет', 'из', 'деревянной', 'баклаги', 'степлившуюся', 'воду.', 'Кадык', 'при', 'каждом', 'глотке', 'ползет', 'вверх,', 'от', 'подбородка', 'к', 'горлу', 'свисают', 'две', 'обмякших', 'складки,', 'по', 'бороде', 'текут', 'капельки,', 'сквозь', 'опущенные', 'шафранные', 'веки', 'красновато', 'просвечивает', 'солнце.', 'Затыкая', 'баклагу,', 'он', 'искоса', 'глядит', 'на', 'меня', 'и,', 'перехватив', 'мой', 'взгляд,', 'сухо', 'жует', 'губами,', 'смотрит', 'в', 'степь.', 'За', 'лощиной', 'дымкой', 'теплится', 'марево,', 'ветер', 'над', 'обугленной', 'землей', 'пряно', 'пахнет', 'чеборцовым', 'медом.', 'Помолчав,', 'дед', 'отодвигает', 'от', 'себя', 'пастушечью', 'чакушу', '[1]', ',', 'обкуренным', 'пальцем', 'указывает', 'мимо', 'меня.', '—', 'Видишь,', 'за', 'энтим', 'логом', 'макушки', 'тополев?', 'Имение', 'панов', 'Томилиных', '—', 'Тополевка.', 'Там', 'же', 'около', 'и', 'мужичий', 'поселок', 'Тополевка,', 'раньше', 'крепостные', 'были.', 'Отец', 'мой', 'кучеровал', 'у', 'пана', 'до', 'смерти.', 'Мне-то,', 'огольцу,', 'он', 'рассказывал,', 'как', 'пан', 'Евграф', 'Томилин', 'выменял', 'его', 'за', 'ручного', 'журавля', 'у', 'соседа-помещика.', 'Посля', 'отцовой', 'смерти', 'я', 'заступил', 'на', 'его', 'место', 'кучером.', 'Самому', 'пану', 'в', 'это', 'время', 'было', 'под', 'шестьдесят.', 'Тýшистый', 'был', 'мужчина,', 'многокровный.', 'В', 'молодости', 'при', 'царе', 'в', 'гвардии', 'служил,', 'а', 'потом', 'кончил', 'службу', 'и', 'уехал', 'доживать', 'на', 'Дон.', 'Землю', 'ихнюю', 'на', 'Дону', 'казаки', 'отобрали,', 'а', 'пану', 'казна', 'отрезала', 'в', 'Саратовской', 'губернии', 'три', 'тыщи', 'десятин.', 'Сдавал', 'он', 'их', 'в', 'аренду', 'саратовским', 'мужикам,', 'сам', 'проживал', 'в', 'Тополевке.', 'Диковинный', 'был', 'человек.', 'Ходил', 'завсегда', 'в', 'бешмете', 'тонкого', 'сукна,', 'при', 'кинжале.', 'Поедет,', 'бывало,', 'в', 'гости,', 'выберемся', 'из', 'Тополевки,', 'приказывает:', '—', 'Гони,', 'хамлю ...
