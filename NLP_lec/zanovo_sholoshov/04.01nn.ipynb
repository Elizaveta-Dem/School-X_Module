# %%
# %pip install -Uq gensim

import gensim.downloader
from gensim.models import KeyedVectors
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
import spacy
nlp = spacy.load('ru_core_news_sm')
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
class PreprocessorText:
    def __init__(self):
        self.nlp = spacy.load("ru_core_news_sm")
        self.word2vec_rus = gensim.downloader.load('word2vec-ruscorpora-300')
        
    def load_file(self):
        with open("1_Nahalenok_1925.txt", "r", encoding="utf-8") as file:
            self.text1 = file.read()
            
    def tokenized_words(self):
        self.tokenized = nltk.word_tokenize(self.text1)
        
    def filter_words(self):
        words = self.nlp(self.text1)
        self.word_filt = [token.text for token in words if not token.is_punct and not token.is_stop]
        
    def lemmatized_words(self):
        words = self.nlp(self.text1)
        self.word_learn = [token.lemma_ for token in words if not token.is_punct and not token.is_stop]
        
    def word2vec_text(self, num_word):
        for index, word in enumerate(self.word2vec_rus.index_to_key):
            if index == num_word:
                break
            print(f"word#{index}/{len(self.word2vec_rus.index_to_key)} is {word}")


processor_text1 = PreprocessorText()
processor_text1.load_file()
processor_text1.tokenized_words()
processor_text1.filter_words()
processor_text1.lemmatized_words()
processor_text1.word2vec_text(100)
# Out:
# word#0/184973 is весь_DET
# word#1/184973 is человек_NOUN
# word#2/184973 is мочь_VERB
# word#3/184973 is год_NOUN
# word#4/184973 is сказать_VERB
# word#5/184973 is время_NOUN
# word#6/184973 is говорить_VERB
# word#7/184973 is становиться_VERB
# word#8/184973 is знать_VERB
# word#9/184973 is самый_DET
# word#10/184973 is дело_NOUN
# word#11/184973 is день_NOUN
# word#12/184973 is жизнь_NOUN
# word#13/184973 is рука_NOUN
# word#14/184973 is очень_ADV
# word#15/184973 is первый_ADJ
# word#16/184973 is давать_VERB
# word#17/184973 is новый_ADJ
# word#18/184973 is слово_NOUN
# word#19/184973 is иметь_VERB
# word#20/184973 is большой_ADJ
# word#21/184973 is идти_VERB
# word#22/184973 is глаз_NOUN
# word#23/184973 is место_NOUN
# word#24/184973 is лицо_NOUN
# word#25/184973 is видеть_VERB
# word#26/184973 is хотеть_VERB
# word#27/184973 is понимать_VERB
# word#28/184973 is должный_ADJ
# word#29/184973 is работа_NOUN
# word#30/184973 is каждый_DET
# word#31/184973 is друг_NOUN
# word#32/184973 is голова_NOUN
# word#33/184973 is дом_NOUN
# word#34/184973 is оставаться_VERB
# word#35/184973 is сторона_NOUN
# word#36/184973 is начинать_VERB
# word#37/184973 is думать_VERB
# word#38/184973 is хорошо_ADV
# word#39/184973 is жить_VERB
# word#40/184973 is стоять_VERB
# word#41/184973 is спрашивать_VERB
# word#42/184973 is сделать_VERB
# word#43/184973 is выходить_VERB
# word#44/184973 is последний_ADJ
# word#45/184973 is русский_ADJ
# word#46/184973 is сила_NOUN
# word#47/184973 is получать_VERB
# word#48/184973 is какой-то_DET
# word#49/184973 is хороший_ADJ
# word#50/184973 is случай_NOUN
# word#51/184973 is вопрос_NOUN
# word#52/184973 is отвечать_VERB
# word#53/184973 is россия_NOUN
# word#54/184973 is несколько_NUM
# word#55/184973 is мир_NOUN
# word#56/184973 is город_NOUN
# word#57/184973 is делать_VERB
# word#58/184973 is пойти_VERB
# word#59/184973 is приходить_VERB
# word#60/184973 is земля_NOUN
# word#61/184973 is принимать_VERB
# word#62/184973 is часть_NOUN
# word#63/184973 is вид_NOUN
# word#64/184973 is ребенок_NOUN
# word#65/184973 is конец_NOUN
# word#66/184973 is взять_VERB
# word#67/184973 is всякий_DET
# word#68/184973 is находить_VERB
# word#69/184973 is высокий_ADJ
# word#70/184973 is сидеть_VERB
# word#71/184973 is что-то_PRON
# word#72/184973 is отец_NOUN
# word#73/184973 is оказываться_VERB
# word#74/184973 is вода_NOUN
# word#75/184973 is смотреть_VERB
# word#76/184973 is москва_NOUN
# word#77/184973 is час_NOUN
# word#78/184973 is являться_VERB
# word#79/184973 is народ_NOUN
# word#80/184973 is любить_VERB
# word#81/184973 is проходить_VERB
# word#82/184973 is никто_PRON
# word#83/184973 is образ_NOUN
# word#84/184973 is казаться_VERB
# word#85/184973 is женщина_NOUN
# word#86/184973 is бог_NOUN
# word#87/184973 is нога_NOUN
# word#88/184973 is страна_NOUN
# word#89/184973 is голос_NOUN
# word#90/184973 is писать_VERB
# word#91/184973 is ночь_NOUN
# word#92/184973 is душа_NOUN
# word#93/184973 is старый_ADJ
# word#94/184973 is лишь_PART
# word#95/184973 is также_ADV
# word#96/184973 is общий_ADJ
# word#97/184973 is называть_VERB
# word#98/184973 is молодой_ADJ
# word#99/184973 is отношение_NOUN

# %%
slova = ['весь_DET',
'человек_NOUN',
'мочь_VERB',
'год_NOUN',
'сказать_VERB',
'время_NOUN',
'говорить_VERB',
'становиться_VERB',
'знать_VERB',
'самый_DET',
'дело_NOUN',
'день_NOUN',
'жизнь_NOUN',
'очень_ADV',
'первый_ADJ',
'давать_VERB',
'новый_ADJ',
'слово_NOUN',
'иметь_VERB',
'большой_ADJ',
'идти_VERB',
'глаз_NOUN',
'место_NOUN',
'лицо_NOUN',
'видеть_VERB',
'хотеть_VERB',
'понимать_VERB',
'должный_ADJ',
'работа_NOUN',
'каждый_DET',
'друг_NOUN',
'голова_NOUN',
'дом_NOUN',
'оставаться_VERB',
'сторона_NOUN',
'начинать_VERB',
'думать_VERB',
'хорошо_ADV',
'жить_VERB',
'стоять_VERB',
'спрашивать_VERB',
'сделать_VERB',
'выходить_VERB',
'последний_ADJ',
'русский_ADJ',
'сила_NOUN',
'получать_VERB',
'какой-то_DET',
'хороший_ADJ',
'случай_NOUN',
'вопрос_NOUN',
'отвечать_VERB',
'россия_NOUN',
'несколько_NUM',
'мир_NOUN',
'город_NOUN',
'делать_VERB',
'пойти_VERB',
'приходить_VERB',
'земля_NOUN',
'принимать_VERB',
'часть_NOUN',
'вид_NOUN',
'ребенок_NOUN',
'конец_NOUN',
'взять_VERB',
'всякий_DET',
'находить_VERB',
'высокий_ADJ',
'сидеть_VERB',
'что-то_PRON',
'отец_NOUN',
'оказываться_VERB',
'вода_NOUN',
'смотреть_VERB',
'москва_NOUN',
'час_NOUN',
'являться_VERB',
'народ_NOUN',
'любить_VERB',
'проходить_VERB',
'никто_PRON',
'образ_NOUN',
'казаться_VERB',
'женщина_NOUN',
'бог_NOUN',
'нога_NOUN',
'страна_NOUN',
'голос_NOUN',
'писать_VERB',
'ночь_NOUN',
'душа_NOUN',
'старый_ADJ',
'лишь_PART',
'также_ADV',
'общий_ADJ',
'называть_VERB',
'молодой_ADJ',
'отношение_NOUN']

# %%
def final_sinonims(slova):
    for i in slova:
        w = word2vec_rus.most_similar([i],topn=3)
        print (w)
    return final_sinonims
# Out:
# [('замечивать_VERB', 0.47553887963294983), ('totem::тотем_NOUN', 0.4747896194458008), ('остальной_DET', 0.4544719159603119)]
# [('женщина_NOUN', 0.5500056743621826), ('мужчина_NOUN', 0.5161216855049133), ('человеческий_ADJ', 0.5005477666854858)]
# [('смочь_VERB', 0.6919744610786438), ('невозможно_ADV', 0.6359431743621826), ('возможно_ADV', 0.62834233045578)]
# [('полгода_NOUN', 0.6607913970947266), ('месяц_NOUN', 0.6588570475578308), ('десятилетие_NOUN', 0.6157364845275879)]
# [('говорить_VERB', 0.7460559606552124), ('проговаривать_VERB', 0.7006840705871582), ('спрашивать_VERB', 0.6981898546218872)]
# [('пора_NOUN', 0.5308493375778198), ('ситлуэт_NOUN', 0.5053750276565552), ('период_NOUN', 0.4943215847015381)]
# [('сказать_VERB', 0.7460559606552124), ('заговаривать_VERB', 0.6289093494415283), ('разговаривать_VERB', 0.6109618544578552)]
# [('сделаться_VERB', 0.651938796043396), ('начинать_VERB', 0.5939475893974304), ('делаться_VERB', 0.4943119287490845)]
# [('понимать_VERB', 0.6547385454177856), ('помнить_VERB', 0.6451283097267151), ('узнавать_VERB', 0.6163167953491211)]
# [('наиболее_ADV', 0.5390406847000122), ('столь_ADV', 0.511998176574707), ('действительно_ADV', 0.4688490629196167)]
# [('делишки_NOUN', 0.49108782410621643), ('дельце_NOUN', 0.47739964723587036), ('горрайорган_NOUN', 0.47554856538772583)]
# [('неделя_NOUN', 0.7186020016670227), ('утро_NOUN', 0.6839577555656433), ('месяц_NOUN', 0.6676345467567444)]
# [('жизненный_ADJ', 0.6052187085151672), ('бытие_NOUN', 0.5376636385917664), ('быт_NOUN', 0.5341748595237732)]
# [('чрезвычайно_ADV', 0.8314101099967957), ('весьма_ADV', 0.728129506111145), ('довольно_ADV', 0.6873273253440857)]
# [('второй_ADJ', 0.7737860083580017), ('третий_ADJ', 0.6765356659889221), ('четвертый_ADJ', 0.6184691786766052)]
# [('получать_VERB', 0.5360719561576843), ('даваться_VERB', 0.5141987800598145), ('заходь_NOUN', 0.45001956820487976)]
# [('новое_NOUN', 0.7109202742576599), ('обновлять_VERB', 0.5369077920913696), ('заново_ADV', 0.5145987272262573)]
# [('фраза_NOUN', 0.7368753552436829), ('словечко_NOUN', 0.615956723690033), ('тетраграмматон_NOUN', 0.5587656497955322)]
# [('иметься_VERB', 0.5741803646087646), ('приобретать_VERB', 0.5152267217636108), ('обладать_VERB', 0.5086100101470947)]
# [('огромный_ADJ', 0.7633992433547974), ('громадный_ADJ', 0.6909629106521606), ('небольшой_ADJ', 0.6376962661743164)]
# [('пойти_VERB', 0.7285876274108887), ('брести_VERB', 0.5698232650756836), ('плестись_VERB', 0.5263213515281677)]
# [('глазок_NOUN', 0.7104843258857727), ('зрачок_NOUN', 0.6920626163482666), ('глазенки_NOUN', 0.6611951589584351)]
# [('местечко_NOUN', 0.4386518895626068), ('злачня_NOUN', 0.4249691367149353), ('ненаселенный_ADJ', 0.42234665155410767)]
# [('физиономия_NOUN', 0.6133463978767395), ('личико_NOUN', 0.607413649559021), ('щека_NOUN', 0.5391091704368591)]
# [('увидеть_VERB', 0.71371990442276), ('видать_VERB', 0.6739031672477722), ('увидать_VERB', 0.617680549621582)]
# [('захотеть_VERB', 0.7732996940612793), ('желать_VERB', 0.7239466905593872), ('хотеться_VERB', 0.7220498323440552)]
# [('догадываться_VERB', 0.7077844738960266), ('осознавать_VERB', 0.6749676465988159), ('знать_VERB', 0.6547384858131409)]
# [('необходимо_ADV', 0.6891896724700928), ('должно_ADV', 0.6659892797470093), ('нужно_ADV', 0.6524524092674255)]
# [('работать_VERB', 0.6488216519355774), ('пуско::наладочный_ADJ', 0.5520831942558289), ('наладочный_ADJ', 0.5179657936096191)]
# [('отдельность_NOUN', 0.514959990978241), ('ежедневно_ADV', 0.4717578887939453), ('притания_NOUN', 0.4618729054927826)]
# [('дружка_NOUN', 0.7470189332962036), ('взаимно_ADV', 0.643467903137207), ('единомыслие::исповем_NOUN', 0.5991154313087463)]
# [('башка_NOUN', 0.6777328848838806), ('затылок_NOUN', 0.589667558670044), ('лейтенант::галишников_NOUN', 0.5619000196456909)]
# [('дома_ADV', 0.6836265921592712), ('домик_NOUN', 0.6716411709785461), ('особняк_NOUN', 0.6681575775146484)]
# [('оставлять_VERB', 0.7345039248466492), ('сохраняться_VERB', 0.5115207433700562), ('оказываться_VERB', 0.47731027007102966)]
# [('вправо_ADV', 0.5002204775810242), ('противоположный_ADJ', 0.49604088068008423), ('направление_NOUN', 0.4924043118953705)]
# [('продолжать_VERB', 0.6201584935188293), ('приниматься_VERB', 0.6122379899024963), ('становиться_VERB', 0.5939475893974304)]
# [('подумать_VERB', 0.7572886347770691), ('размышлять_VERB', 0.6760968565940857), ('неужели_PART', 0.6635090708732605)]
# [('плохо_ADV', 0.7656179070472717), ('отлично_ADV', 0.7570395469665527), ('прекрасно_ADV', 0.7528685927391052)]
# [('проживать_VERB', 0.7359465956687927), ('поселяться_VERB', 0.7100815176963806), ('житься_VERB', 0.6164941191673279)]
# [('стоящий_ADJ', 0.663714587688446), ('сидеть_VERB', 0.6171644926071167), ('простаивать_VERB', 0.5575822591781616)]
# [('поинтересоваться_VERB', 0.7266015410423279), ('осведомляться_VERB', 0.7241883277893066), ('переспрашивать_VERB', 0.7106470465660095)]
# [('делать_VERB', 0.779567539691925), ('делаться_VERB', 0.5033201575279236), ('предпринимать_VERB', 0.47929245233535767)]
# [('выбегать_VERB', 0.6281648278236389), ('выскочить_VERB', 0.6230625510215759), ('выход_NOUN', 0.5998391509056091)]
# [('предпоследний_ADJ', 0.5668560266494751), ('первый_ADJ', 0.5443336367607117), ('предыдущий_ADJ', 0.49922212958335876)]
# [('русский_NOUN', 0.7669479846954346), ('французский_ADJ', 0.5663967728614807), ('славянский_ADJ', 0.5490821599960327)]
# [('мощь_NOUN', 0.5128763318061829), ('усилие_NOUN', 0.48556727170944214), ('энергия_NOUN', 0.4798487722873688)]
# [('получение_NOUN', 0.7299525141716003), ('давать_VERB', 0.5360719561576843), ('доставлять_VERB', 0.4798072576522827)]
# [('что-то_PRON', 0.6120334267616272), ('какой-нибудь_DET', 0.6052801012992859), ('некий_DET', 0.5918564200401306)]
# [('плохой_ADJ', 0.7462217807769775), ('неплохой_ADJ', 0.6795689463615417), ('отличный_ADJ', 0.6773216128349304)]
# [('обстоятельство_NOUN', 0.5025612115859985), ('причем_CCONJ', 0.4892035722732544), ('момент_NOUN', 0.4651680588722229)]
# [('проблема_NOUN', 0.6677187085151672), ('задавать_VERB', 0.5654783248901367), ('задача_NOUN', 0.545269787311554)]
# [('сказать_VERB', 0.6946645379066467), ('возражать_VERB', 0.639751136302948), ('ответ_NOUN', 0.6271829009056091)]
# [('страна_NOUN', 0.7258070111274719), ('европа_NOUN', 0.6865813732147217), ('издание::нти_NOUN', 0.677743136882782)]
# [('полтора_NUM', 0.6617396473884583), ('десять_NUM', 0.6465097069740295), ('десяток_NOUN', 0.6312237977981567)]
# [('европа_NOUN', 0.5369696617126465), ('космичный_ADJ', 0.5308237671852112), ('плерома_NOUN', 0.5197948217391968)]
# [('столица_NOUN', 0.7531285285949707), ('городок_NOUN', 0.6759740710258484), ('пригород_NOUN', 0.665625810623169)]
# [('сделать_VERB', 0.779567539691925), ('делаться_VERB', 0.5862048864364624), ('нисколечко_NUM', 0.4822719693183899)]
# [('идти_VERB', 0.7285876274108887), ('побежать_VERB', 0.6871424913406372), ('поехать_VERB', 0.61635422706604)]
# [('прийти_VERB', 0.8142374753952026), ('приезжать_VERB', 0.5669416189193726), ('притти_NOUN', 0.501556932926178)]
# [('землица_NOUN', 0.5413888692855835), ('пашня_NOUN', 0.5407807230949402), ('чернозем_NOUN', 0.5061137080192566)]
# [('принятый_ADJ', 0.6671159863471985), ('принятие_NOUN', 0.6324176788330078), ('участие_NOUN', 0.5316895246505737)]
# [('половина_NOUN', 0.532850980758667), ('частично_ADV', 0.52619868516922), ('ст::знобь_NOUN', 0.5179859399795532)]
# [('форма_NOUN', 0.4616510272026062), ('голарктический_ADJ', 0.4590036869049072), ('bifrons_NOUN', 0.4411481022834778)]
# [('детишки_NOUN', 0.7447909116744995), ('ребеночек_NOUN', 0.7192486524581909), ('малыш_NOUN', 0.6763865947723389)]
# [('середина_NOUN', 0.6817758083343506), ('начало_NOUN', 0.6584972143173218), ('сябринец_NOUN', 0.5129650235176086)]
# [('брать_VERB', 0.778863787651062), ('забирать_VERB', 0.57106614112854), ('захватить_VERB', 0.537092387676239)]
# [('всяческий_ADJ', 0.6247314214706421), ('безо_ADP', 0.5990079045295715), ('всякий_PRON', 0.5854036211967468)]
# [('отыскивать_VERB', 0.7492324113845825), ('искать_VERB', 0.6931495666503906), ('отыскиваться_VERB', 0.5822502970695496)]
# [('низкий_ADJ', 0.7322282195091248), ('невысокий_ADJ', 0.6598683595657349), ('высоко_ADV', 0.5965583920478821)]
# [('усаживаться_VERB', 0.6882057189941406), ('просиживать_VERB', 0.6762977838516235), ('садиться_VERB', 0.6457331776618958)]
# [('нечто_PRON', 0.7017675638198853), ('что-нибудь_PRON', 0.6758808493614197), ('какой-то_DET', 0.6120334267616272)]
# [('мать_NOUN', 0.7377551198005676), ('сын_NOUN', 0.7254576683044434), ('дед_NOUN', 0.6675097346305847)]
# [('выясняться_VERB', 0.6385815143585205), ('обнаруживаться_VERB', 0.5342985391616821), ('обнаруживать_VERB', 0.5094483494758606)]
# [('вод_NOUN', 0.5985299944877625), ('влага_NOUN', 0.5929107069969177), ('отчерпывать_VERB', 0.5788257718086243)]
# [('глядеть_VERB', 0.8638976812362671), ('посмотреть_VERB', 0.7330541610717773), ('поглядывать_VERB', 0.7063522338867188)]
# [('петербург_NOUN', 0.68415367603302), ('столица_NOUN', 0.6805936694145203), ('московский_ADJ', 0.674876868724823)]
# [('полчаса_NOUN', 0.763296365737915), ('утро_NOUN', 0.7124212384223938), ('пополудни_ADV', 0.6792699098587036)]
# [('представляться_VERB', 0.5358110070228577), ('рассматриваться_VERB', 0.5351598262786865), ('заключаться_VERB', 0.49735158681869507)]
# [('нация_NOUN', 0.6279987096786499), ('народность_NOUN', 0.5569697618484497), ('племя_NOUN', 0.545339047908783)]
# [('обожать_VERB', 0.7660109996795654), ('полюбить_VERB', 0.7165552377700806), ('уважать_VERB', 0.6788132786750793)]
# [('пройти_VERB', 0.7930945754051208), ('миновать_VERB', 0.5778095126152039), ('пролететь_VERB', 0.5507276654243469)]
# [('кто-нибудь_PRON', 0.6033811569213867), ('посметь_VERB', 0.6022767424583435), ('сметь_VERB', 0.5687472820281982)]
# [('никой_DET', 0.48090997338294983), ('vita::moysis_NOUN', 0.4670141041278839), ('заключаться_VERB', 0.457538902759552)]
# [('кажется_ADV', 0.7150599360466003), ('показываться_VERB', 0.7094494700431824), ('представляться_VERB', 0.6168165802955627)]
# [('мужчина_NOUN', 0.8522827625274658), ('девушка_NOUN', 0.7294459939002991), ('дама_NOUN', 0.620084285736084)]
# [('господь_NOUN', 0.8023736476898193), ('христос_NOUN', 0.6623279452323914), ('всевышний_NOUN', 0.6598852872848511)]
# [('ступня_NOUN', 0.7718374729156494), ('колено_NOUN', 0.6962578296661377), ('пятка_NOUN', 0.683724582195282)]
# [('россия_NOUN', 0.7258069515228271), ('европа_NOUN', 0.6566071510314941), ('государство_NOUN', 0.6314784288406372)]
# [('голосок_NOUN', 0.7061754465103149), ('хриплый_ADJ', 0.6803653836250305), ('бас_NOUN', 0.6463322639465332)]
# [('написать_VERB', 0.8070606589317322), ('писаться_VERB', 0.6612510681152344), ('читать_VERB', 0.6283602714538574)]
# [('вечер_NOUN', 0.7375167608261108), ('рассвет_NOUN', 0.736522376537323), ('утро_NOUN', 0.6998549103736877)]
# [('сердце_NOUN', 0.6362314820289612), ('душевный_ADJ', 0.5907288789749146), ('самопрезрение_NOUN', 0.5200070738792419)]
# [('престарый_ADJ', 0.6504433155059814), ('старинный_ADJ', 0.5639446973800659), ('старое_NOUN', 0.5409898161888123)]
# [('лишь_CCONJ', 0.7382734417915344), ('немногий_DET', 0.5358874797821045), ('постольку_CCONJ', 0.530755341053009)]
# [('частность_NOUN', 0.6917258501052856), ('др_NOUN', 0.6807992458343506), ('наряду_ADV', 0.6703363656997681)]
# [('целое_NOUN', 0.5317344665527344), ('всеобщий_ADJ', 0.48045405745506287), ('совокупность_NOUN', 0.4751807749271393)]
# [('называться_VERB', 0.7143133878707886), ('именовать_VERB', 0.7110559344291687), ('именоваться_VERB', 0.6206808686256409)]
# [('молоденький_ADJ', 0.6732797026634216), ('пожилой_ADJ', 0.6139197945594788), ('юный_ADJ', 0.6137704253196716)]
# [('взаимоотношение_NOUN', 0.7007677555084229), ('взаимоотношения_NOUN', 0.6307134628295898), ('связь_NOUN', 0.5395280718803406)]
# <function __main__.final_sinonims(slova)>
